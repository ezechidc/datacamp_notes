# %%
# %load_ext sql

# %%
import psycopg2

# %%
#engine = psycopg2.create_engine(" postgresql://dennis@localhost/dennis")
# %sql postgresql://dennis:dennis@localhost/dennis
# Out:
# 'Connected: dennis@dennis'

# %%
# %%sql CREATE TABLE presidents (
#   country                 VARCHAR   PRIMARY KEY,
#   continent               VARCHAR,
#   president               VARCHAR
# );
#
# CREATE TABLE prime_ministers (
#   country                 VARCHAR   PRIMARY KEY,
#   continent               VARCHAR,
#   prime_minister          VARCHAR
# );
#
# CREATE TABLE states (
#   name                    VARCHAR   PRIMARY KEY,
#   continent               VARCHAR,
#   indep_year              INTEGER,
#   fert_rate               REAL,
#   women_parli_perc        REAL
#
# );
#
# CREATE TABLE monarchs (
#   country                 VARCHAR   PRIMARY KEY,
#   continent               VARCHAR,
#   monarch                 VARCHAR
# );
# Out:
#  * postgresql://dennis:***@localhost/dennis
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# %sql \copy presidents FROM 'data/leaders/presidents.csv' DELIMITER ',' CSV HEADER;
# \copy prime_ministers FROM 'data/leaders/prime_ministers.csv' DELIMITER ',' CSV HEADER;
# \copy states FROM 'data/leaders/states.csv' DELIMITER ',' CSV HEADER;
# \copy monarchs FROM 'data/leaders/monarchs.csv' DELIMITER ',' CSV HEADER;

# %%
# %%sql \copy prime_ministers FROM 'data/leaders/prime_ministers.csv' DELIMITER ',' CSV HEADER;
# Out:
# UsageError: %%sql is a cell magic, but the cell body is empty. Did you mean the line magic %sql (single %)?

# %%
# %ls data/leaders/
# Out:
# monarchs.csv  presidents.csv  prime_ministers.csv  states.csv

# %%
# %sql \d
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 16 rows affected.
# [('public', 'cities', 'table', 'dennis'),
#  ('public', 'company_divisions', 'table', 'postgres'),
#  ('public', 'company_regions', 'table', 'postgres'),
#  ('public', 'countries', 'table', 'dennis'),
#  ('public', 'countries_plus', 'table', 'dennis'),
#  ('public', 'currencies', 'table', 'dennis'),
#  ('public', 'economies', 'table', 'dennis'),
#  ('public', 'economies2010', 'table', 'dennis'),
#  ('public', 'economies2015', 'table', 'dennis'),
#  ('public', 'languages', 'table', 'dennis'),
#  ('public', 'monarchs', 'table', 'dennis'),
#  ('public', 'populations', 'table', 'dennis'),
#  ('public', 'presidents', 'table', 'dennis'),
#  ('public', 'prime_ministers', 'table', 'dennis'),
#  ('public', 'staff', 'table', 'postgres'),
#  ('public', 'states', 'table', 'dennis')]

# %%
# %sql select * from prime_ministers
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 10 rows affected.
# [('Egypt', 'Africa', 'Sherif Ismail'),
#  ('Portugal', 'Europe', 'Antonio Costa'),
#  ('Vietnam', 'Asia', 'Nguyen Xuan Phuc'),
#  ('Haiti', 'North America', 'Jack Guy Lafontant'),
#  ('India', 'Asia', 'Narendra Modi'),
#  ('Australia', 'Oceania', 'Malcolm Turnbull'),
#  ('Norway', 'Europe', 'Erna Solberg'),
#  ('Brunei', 'Asia', 'Hassanal Bolkiah'),
#  ('Oman', 'Asia', 'Qaboos bin Said al Said'),
#  ('Spain', 'Europe', 'Mariano Rajoy')]

# %%
# %%sql
# CREATE TABLE cities (
#   name                    VARCHAR   PRIMARY KEY,
#   country_code            VARCHAR,
#   city_proper_pop         REAL,
#   metroarea_pop           REAL,
#   urbanarea_pop           REAL
# );
#
# CREATE TABLE countries (
#   code                  VARCHAR     PRIMARY KEY,
#   name                  VARCHAR,
#   continent             VARCHAR,
#   region                VARCHAR,
#   surface_area          REAL,
#   indep_year            INTEGER,
#   local_name            VARCHAR,
#   gov_form              VARCHAR,
#   capital               VARCHAR,
#   cap_long              REAL,
#   cap_lat               REAL
# );
#
# CREATE TABLE languages (
#   lang_id               INTEGER     PRIMARY KEY,
#   code                  VARCHAR,
#   name                  VARCHAR,
#   percent               REAL,
#   official              BOOLEAN
# );
#
# CREATE TABLE economies (
#   econ_id               INTEGER     PRIMARY KEY,
#   code                  VARCHAR,
#   year                  INTEGER,
#   income_group          VARCHAR,
#   gdp_percapita         REAL,
#   gross_savings         REAL,
#   inflation_rate        REAL,
#   total_investment      REAL,
#   unemployment_rate     REAL,
#   exports               REAL,
#   imports               REAL
# );
#
# CREATE TABLE currencies (
#   curr_id               INTEGER     PRIMARY KEY,
#   code                  VARCHAR,
#   basic_unit            VARCHAR,
#   curr_code             VARCHAR,
#   frac_unit             VARCHAR,
#   frac_perbasic         REAL
# );
#
# CREATE TABLE populations (
#   pop_id                INTEGER     PRIMARY KEY,
#   country_code          VARCHAR,
#   year                  INTEGER,
#   fertility_rate        REAL,
#   life_expectancy       REAL,
#   size                  REAL
# );
#
#
# CREATE TABLE countries_plus (
#   name                  VARCHAR,
#   continent             VARCHAR,
#   code                  VARCHAR     PRIMARY KEY,
#   surface_area          REAL,
#   geosize_group         VARCHAR
# );
#
# CREATE TABLE economies2010 (
#   code                  VARCHAR     PRIMARY KEY,
#   year                  INTEGER,
#   income_group          VARCHAR,
#   gross_savings         REAL
# );
#
# CREATE TABLE economies2015 (
#   code                  VARCHAR     PRIMARY KEY,
#   year                  INTEGER,
#   income_group          VARCHAR,
#   gross_savings         REAL
# );
# Out:
#  * postgresql://dennis:***@localhost/dennis
# Done.
# Done.
# Done.
# Done.
# Done.
# (psycopg2.ProgrammingError) relation "populations" already exists
#  [SQL: 'CREATE TABLE populations (\n  pop_id                INTEGER     PRIMARY KEY,\n  country_code          VARCHAR,\n  year                  INTEGER,\n  fertility_rate        REAL,\n  life_expectancy       REAL,\n  size                  REAL\n);'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql SELECT count(*) FROM cities;
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %ls data/countries/
# Out:
# cities.csv          countries.sql      economies2015.csv  __MACOSX/
# countries.csv       currencies.csv     economies.csv      populations.csv
# countries_plus.csv  economies2010.csv  languages.csv

# %%
# %sql SELECT id, last_name, email, gender, department, start_date, salary, job_title, region_id FROM public.staff limit 10;
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %sql select * from cities;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 236 rows affected.
# [('Abidjan', 'CIV', 4765000.0, None, 4765000.0),
#  ('Abu Dhabi', 'ARE', 1145000.0, None, 1145000.0),
#  ('Abuja', 'NGA', 1235880.0, 6000000.0, 1235880.0),
#  ('Accra', 'GHA', 2070460.0, 4010050.0, 2070460.0),
#  ('Addis Ababa', 'ETH', 3103670.0, 4567860.0, 3103670.0),
#  ('Ahmedabad', 'IND', 5570580.0, None, 5570580.0),
#  ('Alexandria', 'EGY', 4616620.0, None, 4616620.0),
#  ('Algiers', 'DZA', 3415810.0, 5000000.0, 3415810.0),
#  ('Almaty', 'KAZ', 1703480.0, None, 1703480.0),
#  ('Ankara', 'TUR', 5271000.0, 4585000.0, 5271000.0),
#  ('Auckland', 'NZL', 1495000.0, 1614300.0, 1495000.0),
#  ('Baghdad', 'IRQ', 7180890.0, None, 7180890.0),
#  ('Baku', 'AZE', 3202300.0, 4308740.0, 3202300.0),
#  ('Bandung', 'IDN', 2575480.0, 6965660.0, 2575480.0),
#  ('Bangkok', 'THA', 8280920.0, 14998000.0, 8280920.0),
#  ('Barcelona', 'ESP', 1604560.0, 5375770.0, 1604560.0),
#  ('Barranquilla', 'COL', 1386860.0, 2370750.0, 1386860.0),
#  ('Basra', 'IRQ', 2750000.0, None, 2750000.0),
#  ('Beijing', 'CHN', 21516000.0, 24900000.0, 21516000.0),
#  ('Belo Horizonte', 'BRA', 2502560.0, 5156220.0, 2502560.0),
#  ('Bengaluru', 'IND', 8425970.0, 9807000.0, 8425970.0),
#  ('Berlin', 'DEU', 3517420.0, 5871020.0, 3517420.0),
#  ('Bhopal', 'IND', 1798220.0, 1864390.0, 1798220.0),
#  ('Birmingham', 'GBR', 1111300.0, 3683000.0, 1111300.0),
#  ('Bogota', 'COL', 7878780.0, 9800000.0, 7878780.0),
#  ('Brasilia', 'BRA', 2556150.0, 3919860.0, 2556150.0),
#  ('Brazzaville', 'COG', 1827000.0, None, 1827000.0),
#  ('Brisbane', 'AUS', 1180280.0, 2349700.0, 1180280.0),
#  ('Bucharest', 'ROM', 1883420.0, 2272160.0, 1883420.0),
#  ('Budapest', 'HUN', 1759410.0, 2927940.0, 1759410.0),
#  ('Buenos Aires', 'ARG', 3054300.0, 14122000.0, 3054300.0),
#  ('Busan', 'KOR', 3510830.0, 8202240.0, 3510830.0),
#  ('Cairo', 'EGY', 10230400.0, 18290000.0, 10230400.0),
#  ('Calgary', 'CAN', 1235170.0, 1214840.0, 1235170.0),
#  ('Cali', 'COL', 2400650.0, 3400000.0, 2400650.0),
#  ('Caloocan', 'PHL', 1583980.0, None, 1583980.0),
#  ('Campinas', 'BRA', 1164100.0, 3094180.0, 1164100.0),
#  ('Cape Town', 'ZAF', 3740030.0, None, 3740030.0),
#  ('Caracas', 'VEN', 1943900.0, 2923960.0, 1943900.0),
#  ('Casablanca', 'MAR', 5117830.0, 6861740.0, 5117830.0),
#  ('Changchun', 'CHN', 3815270.0, 7674440.0, 3815270.0),
#  ('Changsha', 'CHN', 7044120.0, None, 7044120.0),
#  ('Chaozhou', 'CHN', 2669840.0, None, 2669840.0),
#  ('Chengdu', 'CHN', 4741930.0, 10376000.0, 4741930.0),
#  ('Chennai', 'IND', 7088000.0, None, 7088000.0),
#  ('Chicago', 'USA', 2695600.0, 9156000.0, 2695600.0),
#  ('Chittagong', 'BGD', 2581640.0, 4009420.0, 2581640.0),
#  ('Chongqing', 'CHN', 8189800.0, 52100100.0, 8189800.0),
#  ('Cologne', 'DEU', 1057330.0, 3573500.0, 1057330.0),
#  ('Cordoba', 'ARG', 1330020.0, 1528000.0, 1330020.0),
#  ('Curitiba', 'BRA', 1879360.0, 3400000.0, 1879360.0),
#  ('Daegu', 'KOR', 2492990.0, None, 2492990.0),
#  ('Daejeon', 'KOR', 1535030.0, None, 1535030.0),
#  ('Dakar', 'SEN', 1146050.0, 2452660.0, 1146050.0),
#  ('Dalian', 'CHN', 2146100.0, 5935640.0, 2146100.0),
#  ('Dallas', 'USA', 1317930.0, 7233320.0, 1317930.0),
#  ('Dar es Salaam', 'TZA', 4364540.0, None, 4364540.0),
#  ('Davao City', 'PHL', 1632990.0, 2516220.0, 1632990.0),
#  ('Delhi', 'IND', 16787900.0, 24998000.0, 16787900.0),
#  ('Dhaka', 'BGD', 14543100.0, None, 14543100.0),
#  ('Dongguan', 'CHN', 8220210.0, None, 8220210.0),
#  ('Douala', 'CMR', 2446940.0, None, 2446940.0),
#  ('Dubai', 'ARE', 2643410.0, None, 2643410.0),
#  ('Durban', 'ZAF', 3442360.0, None, 3442360.0),
#  ('Ekurhuleni', 'ZAF', 3178470.0, None, 3178470.0),
#  ('Faisalabad', 'PAK', 6480760.0, 3675000.0, 6480760.0),
#  ('Fez', 'MAR', 1112070.0, None, 1112070.0),
#  ('Fortaleza', 'BRA', 2609720.0, 4019210.0, 2609720.0),
#  ('Foshan', 'CHN', 6151620.0, None, 6151620.0),
#  ('Fukuoka', 'JPN', 1483050.0, 5590380.0, 1483050.0),
#  ('Fuzhou', 'CHN', 7115370.0, None, 7115370.0),
#  ('Giza', 'EGY', 4239990.0, None, 4239990.0),
#  ('Guadalajara', 'MEX', 1495190.0, 4424250.0, 1495190.0),
#  ('Guangzhou', 'CHN', 14043500.0, 44259000.0, 14043500.0),
#  ('Guatemala City', 'GTM', 2110100.0, 4500000.0, 2110100.0),
#  ('Guayaquil', 'ECU', 3600000.0, 5000000.0, 3600000.0),
#  ('Gujranwala', 'PAK', 2700000.0, None, 2700000.0),
#  ('Hamburg', 'DEU', 1787410.0, None, 1787410.0),
#  ('Hangzhou', 'CHN', 3560390.0, None, 3560390.0),
#  ('Hanoi', 'VNM', 6844100.0, None, 6844100.0),
#  ('Harare', 'ZWE', 1606000.0, None, 1606000.0),
#  ('Harbin', 'CHN', 4280700.0, 10636000.0, 4280700.0),
#  ('Havana', 'CUB', 2106150.0, None, 2106150.0),
#  ('Hefei', 'CHN', 3352080.0, None, 3352080.0),
#  ('Hiroshima', 'JPN', 1196270.0, None, 1196270.0),
#  ('Ho Chi Minh City', 'VNM', 7681700.0, None, 7681700.0),
#  ('Hong Kong', 'CHN', 7374900.0, None, 7374900.0),
#  ('Houston', 'USA', 2489560.0, 6490180.0, 2489560.0),
#  ('Hyderabad (India)', 'IND', 7859250.0, None, 7859250.0),
#  ('Hyderabad', 'PAK', 3429470.0, None, 3429470.0),
#  ('Ibadan', 'NGA', 1338660.0, 2837000.0, 1338660.0),
#  ('Incheon', 'KOR', 2978370.0, None, 2978370.0),
#  ('Isfahan', 'IRN', 2243250.0, None, 2243250.0),
#  ('Islamabad', 'PAK', 1900000.0, 2200000.0, 1900000.0),
#  ('Istanbul', 'TUR', 14025000.0, 13520000.0, 14025000.0),
#  ('Izmir', 'TUR', 4168000.0, 3019000.0, 4168000.0),
#  ('Jaipur', 'IND', 3073350.0, None, 3073350.0),
#  ('Jakarta', 'IDN', 10075300.0, 30539000.0, 10075300.0),
#  ('Jeddah', 'SAU', 3456260.0, None, 3456260.0),
#  ('Jinan', 'CHN', 2009270.0, 5853200.0, 2009270.0),
#  ('Johannesburg', 'ZAF', 4434830.0, None, 4434830.0),
#  ('Kabul', 'AFG', 3414100.0, None, 3414100.0),
#  ('Kampala', 'UGA', 1507080.0, None, 1507080.0),
#  ('Kano', 'NGA', 2153220.0, 3395000.0, 2153220.0),
#  ('Kanpur', 'IND', 2768060.0, 3152320.0, 2768060.0),
#  ('Kaohsiung', 'TWN', 2778920.0, None, 2778920.0),
#  ('Karachi', 'PAK', 27506000.0, 25400000.0, 27506000.0),
#  ('Karaj', 'IRN', 1973470.0, None, 1973470.0),
#  ('Kawasaki', 'JPN', 1496040.0, None, 1496040.0),
#  ('Kharkov', 'UKR', 1439570.0, 1650000.0, 1439570.0),
#  ('Khartoum', 'SDN', 3639600.0, 5274320.0, 3639600.0),
#  ('Kiev', 'UKR', 2908700.0, None, 2908700.0),
#  ('Kinshasa', 'COD', 10130000.0, 13265000.0, 10130000.0),
#  ('Kobe', 'JPN', 1536500.0, None, 1536500.0),
#  ('Kochi', 'IND', 2232460.0, 4221140.0, 2232460.0),
#  ('Kolkata', 'IND', 4486680.0, 14667000.0, 4486680.0),
#  ('Kuala Lumpur', 'MYS', 1768000.0, 7200000.0, 1768000.0),
#  ('Kwangju', 'KOR', 1477780.0, None, 1477780.0),
#  ('Kyoto', 'JPN', 1474570.0, None, 1474570.0),
#  ('Lagos', 'NGA', 16060300.0, 21000000.0, 16060300.0),
#  ('Lahore', 'PAK', 10355000.0, 13569000.0, 10355000.0),
#  ('Lanzhou', 'CHN', 2177130.0, 3616160.0, 2177130.0),
#  ('Lima', 'PER', 8852000.0, 10750000.0, 8852000.0),
#  ('London', 'GBR', 8673710.0, 13879800.0, 8673710.0),
#  ('Los Angeles', 'USA', 3884310.0, 15058000.0, 3884310.0),
#  ('Luanda', 'AGO', 2825310.0, None, 2825310.0),
#  ('Lucknow', 'IND', 2815600.0, None, 2815600.0),
#  ('Lusaka', 'ZMB', 1742980.0, 2467470.0, 1742980.0),
#  ('Madrid', 'ESP', 3207250.0, None, 3207250.0),
#  ('Makassar', 'IDN', 1338630.0, 1976170.0, 1338630.0),
#  ('Managua', 'NIC', 2560790.0, None, 2560790.0),
#  ('Mandalay', 'MMR', 1319450.0, 1726890.0, 1319450.0),
#  ('Manila', 'PHL', 1780150.0, 12877300.0, 1780150.0),
#  ('Maputo', 'MOZ', 1766180.0, 1766820.0, 1766180.0),
#  ('Maracaibo', 'VEN', 1599940.0, 3897660.0, 1599940.0),
#  ('Mashhad', 'IRN', 3312090.0, 3372660.0, 3312090.0),
#  ('Medan', 'IDN', 2097610.0, 4103700.0, 2097610.0),
#  ('Medellin', 'COL', 2441120.0, 3731450.0, 2441120.0),
#  ('Mexico City', 'MEX', 8974720.0, 20063000.0, 8974720.0),
#  ('Milan', 'ITA', 1359900.0, 3206460.0, 1359900.0),
#  ('Minsk', 'BLR', 1959780.0, None, 1959780.0),
#  ('Monterrey', 'MEX', 1130960.0, 4520330.0, 1130960.0),
#  ('Montevideo', 'URY', 1305080.0, 1947600.0, 1305080.0),
#  ('Montreal', 'CAN', 1649520.0, 4127100.0, 1649520.0),
#  ('Moscow', 'RUS', 12197600.0, 16170000.0, 12197600.0),
#  ('Multan', 'PAK', 3117000.0, None, 3117000.0),
#  ('Mumbai', 'IND', 12478400.0, 17712000.0, 12478400.0),
#  ('Munich', 'DEU', 1450380.0, 2606020.0, 1450380.0),
#  ('Nagoya', 'JPN', 2296010.0, 9107410.0, 2296010.0),
#  ('Nagpur', 'IND', 2405660.0, 2497870.0, 2405660.0),
#  ('Nairobi', 'KEN', 3138370.0, None, 3138370.0),
#  ('Nanjing', 'CHN', 8230000.0, 34360000.0, 8230000.0),
#  ('New Taipei City', 'TWN', 3954930.0, None, 3954930.0),
#  ('New York City', 'USA', 8550400.0, 20182300.0, 8550400.0),
#  ('Ningbo', 'CHN', 3491600.0, 7639000.0, 3491600.0),
#  ('Nizhny Novgorod', 'RUS', 1250620.0, None, 1250620.0),
#  ('Novosibirsk', 'RUS', 1567090.0, None, 1567090.0),
#  ('Omsk', 'RUS', 1154120.0, None, 1154120.0),
#  ('Oran', 'DZA', 1560330.0, 3454080.0, 1560330.0),
#  ('Osaka', 'JPN', 2691740.0, 19342000.0, 2691740.0),
#  ('Ouagadougou', 'BFA', 2200000.0, 2500000.0, 2200000.0),
#  ('Palembang', 'IDN', 1708410.0, None, 1708410.0),
#  ('Paris', 'FRA', 2229620.0, 10601100.0, 2229620.0),
#  ('Patna', 'IND', 1683200.0, 2231550.0, 1683200.0),
#  ('Peshawar', 'PAK', 3201000.0, None, 3201000.0),
#  ('Philadelphia', 'USA', 1567870.0, 6069880.0, 1567870.0),
#  ('Phnom Penh', 'KHM', 2234570.0, None, 2234570.0),
#  ('Phoenix', 'USA', 1563020.0, 4574530.0, 1563020.0),
#  ('Porto Alegre', 'BRA', 1476870.0, None, 1476870.0),
#  ('Prague', 'CZE', 1324000.0, None, 1324000.0),
#  ('Pune', 'IND', 3115430.0, None, 3115430.0),
#  ('Pyongyang', 'PRK', 3255390.0, None, 3255390.0),
#  ('Qingdao', 'CHN', 6188100.0, 9046200.0, 6188100.0),
#  ('Quanzhou', 'CHN', 8128530.0, 6107480.0, 8128530.0),
#  ('Quezon City', 'PHL', 2936120.0, None, 2936120.0),
#  ('Quito', 'ECU', 2671190.0, 4700000.0, 2671190.0),
#  ('Rawalpindi', 'PAK', 3198910.0, None, 3198910.0),
#  ('Recife', 'BRA', 1555040.0, 3743850.0, 1555040.0),
#  ('Rio de Janeiro', 'BRA', 6429920.0, 12727000.0, 6429920.0),
#  ('Riyadh', 'SAU', 5676620.0, None, 5676620.0),
#  ('Rome', 'ITA', 2877220.0, 4353780.0, 2877220.0),
#  ('Rosario', 'ARG', 1193600.0, 1276000.0, 1193600.0),
#  ('Rostov-on-Don', 'RUS', 1119900.0, None, 1119900.0),
#  ('Saint Petersburg', 'RUS', 5191690.0, 5900000.0, 5191690.0),
#  ('Saitama', 'JPN', 1226660.0, None, 1226660.0),
#  ('Salvador', 'BRA', 2902930.0, 3919860.0, 2902930.0),
#  ('San Antonio', 'USA', 1469840.0, 2454060.0, 1469840.0),
#  ('San Diego', 'USA', 1394930.0, 3095310.0, 1394930.0),
#  ("Sana'a", 'YEM', 1937450.0, 2167960.0, 1937450.0),
#  ('Santa Cruz de la Sierra', 'BOL', 1453550.0, 1749000.0, 1453550.0),
#  ('Santiago', 'CHL', 5743720.0, None, 5743720.0),
#  ('Sao Paulo', 'BRA', 12038200.0, 21090800.0, 12038200.0),
#  ('Sapporo', 'JPN', 1918100.0, 2584880.0, 1918100.0),
#  ('Semarang', 'IDN', 1555980.0, 3183520.0, 1555980.0),
#  ('Seoul', 'KOR', 9995780.0, 12700000.0, 9995780.0),
#  ('Shanghai', 'CHN', 24256800.0, 34750000.0, 24256800.0),
#  ('Shantou', 'CHN', 5391030.0, 11535700.0, 5391030.0),
#  ('Shenyang', 'CHN', 8106170.0, None, 8106170.0),
#  ('Shenzhen', 'CHN', 10778900.0, None, 10778900.0),
#  ('Shijiazhuang', 'CHN', 4303700.0, 10701600.0, 4303700.0),
#  ('Shiraz', 'IRN', 1869000.0, None, 1869000.0),
#  ('Singapore', 'SGP', 5535000.0, None, 5535000.0),
#  ('Surabaya', 'IDN', 2765490.0, 7302280.0, 2765490.0),
#  ('Surat', 'IND', 4462000.0, None, 4462000.0),
#  ('Suzhou', 'CHN', 10650500.0, None, 10650500.0),
#  ("T'bilisi", 'GEO', 1118040.0, 1485290.0, 1118040.0),
#  ('Tabriz', 'IRN', 1733030.0, None, 1733030.0),
#  ('Taichung', 'TWN', 2752410.0, None, 2752410.0),
#  ('Tainan', 'TWN', 1885250.0, None, 1885250.0),
#  ('Taipei', 'TWN', 2704970.0, None, 2704970.0),
#  ('Tangshan', 'CHN', 3187170.0, 7536520.0, 3187170.0),
#  ('Tashkent', 'UZB', 2309600.0, None, 2309600.0),
#  ('Tehran', 'IRN', 8154050.0, 13532000.0, 8154050.0),
#  ('Tianjin', 'CHN', 6859780.0, 15469500.0, 6859780.0),
#  ('Tijuana', 'MEX', 1696920.0, 1895800.0, 1696920.0),
#  ('Tokyo', 'JPN', 13513700.0, 37843000.0, 13513700.0),
#  ('Toronto', 'CAN', 2731570.0, 6417520.0, 2731570.0),
#  ('Tripoli', 'LBY', 1126000.0, 2267000.0, 1126000.0),
#  ('Tunis', 'TUN', 1056250.0, 2643700.0, 1056250.0),
#  ('Ulsan', 'KOR', 1163690.0, None, 1163690.0),
#  ('Vienna', 'AUT', 1863880.0, 2600000.0, 1863880.0),
#  ('Vijayawada', 'IND', 1491200.0, None, 1491200.0),
#  ('Visakhapatnam', 'IND', 2035920.0, 5340000.0, 2035920.0),
#  ('Warsaw', 'POL', 1753980.0, 3100840.0, 1753980.0),
#  ('Wenzhou', 'CHN', 3039440.0, None, 3039440.0),
#  ('Wuhan', 'CHN', 6886250.0, None, 6886250.0),
#  ("Xi'an", 'CHN', 8705600.0, 13569700.0, 8705600.0),
#  ('Xiamen', 'CHN', 3531350.0, 5114760.0, 3531350.0),
#  ('Yangon', 'MMR', 5214000.0, None, 5214000.0),
#  ('Yaounde', 'CMR', 2440460.0, None, 2440460.0),
#  ('Yekaterinburg', 'RUS', 1428040.0, None, 1428040.0),
#  ('Yerevan', 'ARM', 1060140.0, None, 1060140.0),
#  ('Yokohama', 'JPN', 3726170.0, None, 3726170.0),
#  ('Zhengzhou', 'CHN', 4122090.0, None, 4122090.0),
#  ('Zhongshan', 'CHN', 3121280.0, None, 3121280.0),
#  ('Zunyi', 'CHN', 6127010.0, None, 6127010.0)]

# %%
# %%sql
#
# SELECT name, continent, indep_year,
#      CASE WHEN indep_year < 1900 THEN 'before 1900'
#      WHEN indep_year <= 1930 THEN 'between 1900 and 1930'
#      ELSE 'after 1930' END AS indep_year_group
# FROM states
# ORDER BY indep_year_group;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 13 rows affected.
# [('Brunei', 'Asia', 1984, 'after 1930'),
#  ('India', 'Asia', 1947, 'after 1930'),
#  ('Oman', 'Asia', 1951, 'after 1930'),
#  ('Vietnam', 'Asia', 1945, 'after 1930'),
#  ('Liberia', 'Africa', 1847, 'before 1900'),
#  ('Chile', 'South America', 1810, 'before 1900'),
#  ('Haiti', 'North America', 1804, 'before 1900'),
#  ('Portugal', 'Europe', 1143, 'before 1900'),
#  ('Spain', 'Europe', 1492, 'before 1900'),
#  ('Uruguay', 'South America', 1828, 'before 1900'),
#  ('Norway', 'Europe', 1905, 'between 1900 and 1930'),
#  ('Australia', 'Oceania', 1901, 'between 1900 and 1930'),
#  ('Egypt', 'Africa', 1922, 'between 1900 and 1930')]

# %%
# %%sql
# SELECT p1.country_code,
#        p1.size AS size2010,
#        p2.size AS size2015,
#        ((p2.size - p1.size)/p1.size * 100.0) AS growth_perc
# FROM populations AS p1
# INNER JOIN populations AS p2
# ON p1.country_code = p2.country_code
#     AND p1.year = p2.year - 5;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 217 rows affected.
# [('ABW', 101597.0, 103889.0, 2.25597210228443),
#  ('AFG', 27962200.0, 32526600.0, 16.32329672575),
#  ('AGO', 21220000.0, 25022000.0, 17.9171919822693),
#  ('ALB', 2913020.0, 2889170.0, -0.818874966353178),
#  ('AND', 84419.0, 70473.0, -16.5199771523476),
#  ('ARE', 8329450.0, 9156960.0, 9.93474572896957),
#  ('ARG', 41222900.0, 43416800.0, 5.32199628651142),
#  ('ARM', 2963500.0, 3017710.0, 1.8294608220458),
#  ('ASM', 55636.0, 55538.0, -0.176144938450307),
#  ('ATG', 87233.0, 91818.0, 5.25603853166103),
#  ('AUS', 22031800.0, 23789800.0, 7.97940269112587),
#  ('AUT', 8363400.0, 8638370.0, 3.28768044710159),
#  ('AZE', 9054330.0, 9649340.0, 6.57153949141502),
#  ('BDI', 9461120.0, 11178900.0, 18.156461417675),
#  ('BEL', 10895600.0, 11249400.0, 3.24749872088432),
#  ('BEN', 9509800.0, 10879800.0, 14.4065201282501),
#  ('BFA', 15632100.0, 18105600.0, 15.823270380497),
#  ('BGD', 151617000.0, 160996000.0, 6.18590079247952),
#  ('BGR', 7395600.0, 7177990.0, -2.94239856302738),
#  ('BHR', 1261320.0, 1377240.0, 9.19022038578987),
#  ('BHS', 360830.0, 388019.0, 7.53512755036354),
#  ('BIH', 3835260.0, 3810420.0, -0.64772698096931),
#  ('BLR', 9490580.0, 9489620.0, -0.0101890473160893),
#  ('BLZ', 321609.0, 359287.0, 11.7154680192471),
#  ('BMU', 65124.0, 65235.0, 0.170444080140442),
#  ('BOL', 9918240.0, 10724700.0, 8.13107565045357),
#  ('BRA', 198614000.0, 207848000.0, 4.64886799454689),
#  ('BRB', 279566.0, 284215.0, 1.66293475776911),
#  ('BRN', 393302.0, 423188.0, 7.59874060750008),
#  ('BTN', 720246.0, 774830.0, 7.5785219669342),
#  ('BWA', 2047830.0, 2262480.0, 10.4820169508457),
#  ('CAF', 4444970.0, 4900270.0, 10.2430544793606),
#  ('CAN', 34005300.0, 35848600.0, 5.42073585093021),
#  ('CHE', 7824910.0, 8281430.0, 5.8342020958662),
#  ('CHI', 159583.0, 163692.0, 2.57483571767807),
#  ('CHL', 17015000.0, 17948100.0, 5.48392236232758),
#  ('CHN', 1337700000.0, 1371220000.0, 2.50541102141142),
#  ('CIV', 20131700.0, 22701600.0, 12.7651765942574),
#  ('CMR', 20590700.0, 23344200.0, 13.3726313710213),
#  ('COD', 65938700.0, 77266800.0, 17.1797469258308),
#  ('COG', 4066080.0, 4620330.0, 13.6311203241348),
#  ('COL', 45918100.0, 48228700.0, 5.03201149404049),
#  ('COM', 698695.0, 788474.0, 12.8495261073112),
#  ('CPV', 490379.0, 520502.0, 6.14279992878437),
#  ('CRI', 4545270.0, 4807850.0, 5.77692463994026),
#  ('CUB', 11308100.0, 11389600.0, 0.720092328265309),
#  ('CUW', 148703.0, 157979.0, 6.23793751001358),
#  ('CYM', 55509.0, 59967.0, 8.03112983703613),
#  ('CYP', 1103680.0, 1165300.0, 5.58266155421734),
#  ('CZE', 10474400.0, 10546100.0, 0.684038549661636),
#  ('DEU', 81776900.0, 81679800.0, -0.118811021093279),
#  ('DJI', 830802.0, 887861.0, 6.86794221401215),
#  ('DMA', 71167.0, 72680.0, 2.12598536163568),
#  ('DNK', 5547680.0, 5683480.0, 2.44786869734526),
#  ('DOM', 9897980.0, 10528400.0, 6.36905506253242),
#  ('DZA', 36036200.0, 39666500.0, 10.0742146372795),
#  ('ECU', 14934700.0, 16144400.0, 8.09973850846291),
#  ('EGY', 82041000.0, 91508100.0, 11.5394607186317),
#  ('ERI', 4689660.0, None, None),
#  ('ESP', 46576900.0, 46444000.0, -0.28534319717437),
#  ('EST', 1331480.0, 1314610.0, -1.26679055392742),
#  ('ETH', 87561800.0, 99390800.0, 13.5092407464981),
#  ('FIN', 5363350.0, 5479530.0, 2.1661639213562),
#  ('FJI', 859952.0, 892145.0, 3.74358110129833),
#  ('FRA', 65027500.0, 66538400.0, 2.3234473541379),
#  ('FRO', 48567.0, 48199.0, -0.757716130465269),
#  ('FSM', 103619.0, 104460.0, 0.811627227813005),
#  ('GAB', 1541940.0, 1725290.0, 11.8912845849991),
#  ('GBR', 62766400.0, 65128900.0, 3.76395247876644),
#  ('GEO', 3926000.0, 3717100.0, -5.32093718647957),
#  ('GHA', 24317700.0, 27409900.0, 12.7156496047974),
#  ('GIB', 30732.0, 32217.0, 4.83209677040577),
#  ('GIN', 11012400.0, 12608600.0, 14.4944161176682),
#  ('GMB', 1693000.0, 1990920.0, 17.5972625613213),
#  ('GNB', 1634200.0, 1844320.0, 12.8582492470741),
#  ('GNQ', 728710.0, 845060.0, 15.9665703773499),
#  ('GRC', 11121300.0, 10820900.0, -2.70163454115391),
#  ('GRD', 104677.0, 106825.0, 2.05202680081129),
#  ('GRL', 56905.0, 56114.0, -1.39003600925207),
#  ('GTM', 14732300.0, 16342900.0, 10.9327144920826),
#  ('GUM', 159440.0, 169885.0, 6.55105337500572),
#  ('GUY', 753362.0, 767085.0, 1.82156786322594),
#  ('HKG', 7024200.0, 7305700.0, 4.00757379829884),
#  ('HND', 7503880.0, 8075060.0, 7.61186704039574),
#  ('HRV', 4417780.0, 4203600.0, -4.84806746244431),
#  ('HTI', 9999620.0, 10711100.0, 7.11477249860764),
#  ('HUN', 10000000.0, 9843030.0, -1.56994629651308),
#  ('IDN', 241613000.0, 257564000.0, 6.60174712538719),
#  ('IMN', 84327.0, 87780.0, 4.09477390348911),
#  ('IND', 1230980000.0, 1311050000.0, 6.50422871112823),
#  ('IRL', 4560160.0, 4643740.0, 1.83294210582972),
#  ('IRN', 74253400.0, 79109300.0, 6.53963014483452),
#  ('IRQ', 30868200.0, 36423400.0, 17.9966688156128),
#  ('ISL', 318041.0, 330815.0, 4.01646345853806),
#  ('ISR', 7623600.0, 8380100.0, 9.92313325405121),
#  ('ITA', 59277400.0, 60730600.0, 2.45146993547678),
#  ('JAM', 2741250.0, 2793340.0, 1.89993400126696),
#  ('JOR', 6517910.0, 7594550.0, 16.5180966258049),
#  ('JPN', 128070000.0, 126958000.0, -0.867906585335732),
#  ('KAZ', 16321600.0, 17544100.0, 7.4903592467308),
#  ('KEN', 40328300.0, 46050300.0, 14.1885235905647),
#  ('KGZ', 5447900.0, 5956900.0, 9.34304967522621),
#  ('KHM', 14363600.0, 15577900.0, 8.45410749316216),
#  ('KIR', 102648.0, 112423.0, 9.52283516526222),
#  ('KNA', 52352.0, 55572.0, 6.15067221224308),
#  ('KOR', 49410400.0, 50617000.0, 2.44215149432421),
#  ('KWT', 3059470.0, 3892120.0, 27.2152096033096),
#  ('LAO', 6260540.0, 6802020.0, 8.64907279610634),
#  ('LBN', 4337160.0, 5850740.0, 34.8981440067291),
#  ('LBR', 3957990.0, 4503440.0, 13.7809336185455),
#  ('LBY', 6265700.0, 6278440.0, 0.203345296904445),
#  ('LCA', 177397.0, 184999.0, 4.28530350327492),
#  ('LIE', 36276.0, 37531.0, 3.45958769321442),
#  ('LKA', 20119000.0, 20966000.0, 4.20995093882084),
#  ('LSO', 2010590.0, 2135020.0, 6.18904158473015),
#  ('LTU', 3097280.0, 2904910.0, -6.21099397540092),
#  ('LUX', 506953.0, 569604.0, 12.3583450913429),
#  ('LVA', 2097560.0, 1977530.0, -5.72228133678436),
#  ('MAC', 534626.0, 587606.0, 9.90973114967346),
#  ('MAF', 30235.0, 31754.0, 5.02397865056992),
#  ('MAR', 32107700.0, 34377500.0, 7.06923604011536),
#  ('MCO', 36845.0, 37731.0, 2.40466818213463),
#  ('MDA', 3562040.0, 3554110.0, -0.222821440547705),
#  ('MDG', 21079500.0, 24235400.0, 14.9711951613426),
#  ('MDV', 367000.0, 409163.0, 11.4885561168194),
#  ('MEX', 118618000.0, 127017000.0, 7.08131343126297),
#  ('MHL', 52428.0, 52993.0, 1.07766846194863),
#  ('MKD', 2062440.0, 2078450.0, 0.776263885200024),
#  ('MLI', 15167300.0, 17599700.0, 16.0372003912926),
#  ('MLT', 414508.0, 431874.0, 4.18954528868198),
#  ('MMR', 51733000.0, 53897200.0, 4.18328642845154),
#  ('MNE', 619428.0, 622159.0, 0.440890621393919),
#  ('MNG', 2712660.0, 2959130.0, 9.08618345856667),
#  ('MNP', 53860.0, 55070.0, 2.24656518548727),
#  ('MOZ', 24321500.0, 27977900.0, 15.0336727499962),
#  ('MRT', 3591400.0, 4067560.0, 13.2584512233734),
#  ('MUS', 1250400.0, 1262600.0, 0.976087618619204),
#  ('MWI', 14769800.0, 17215200.0, 16.5567845106125),
#  ('MYS', 28119500.0, 30331000.0, 7.86467790603638),
#  ('NAM', 2193640.0, 2458830.0, 12.0888859033585),
#  ('NCL', 250000.0, 273000.0, 9.20000001788139),
#  ('NER', 16292000.0, 19899100.0, 22.1405118703842),
#  ('NGA', 159425000.0, 182202000.0, 14.2871379852295),
#  ('NIC', 5737720.0, 6082030.0, 6.00081346929073),
#  ('NLD', 16615400.0, 16939900.0, 1.9531887024641),
#  ('NOR', 4889250.0, 5190240.0, 6.15609511733055),
#  ('NPL', 26875900.0, 28513700.0, 6.09389580786228),
#  ('NRU', 10025.0, 12475.0, 24.4389027357101),
#  ('NZL', 4350700.0, 4595700.0, 5.63127771019936),
#  ('OMN', 2943750.0, 4490540.0, 52.5450706481934),
#  ('PAK', 170044000.0, 188925000.0, 11.1035786569118),
#  ('PAN', 3620510.0, 3929140.0, 8.52463692426682),
#  ('PER', 29373600.0, 31376700.0, 6.81912675499916),
#  ('PHL', 93038900.0, 100699000.0, 8.23363959789276),
#  ('PLW', 20470.0, 21291.0, 4.0107473731041),
#  ('PNG', 6847520.0, 7619320.0, 11.2712971866131),
#  ('POL', 38042800.0, 37986400.0, -0.148201535921544),
#  ('PRI', 3721530.0, 3474180.0, -6.64630606770515),
#  ('PRK', 24500500.0, 25155300.0, 2.67263874411583),
#  ('PRT', 10573100.0, 10358100.0, -2.03368924558163),
#  ('PRY', 6209880.0, 6639120.0, 6.91231116652489),
#  ('PSE', 3811100.0, 4422140.0, 16.0331845283508),
#  ('PYF', 268065.0, 282764.0, 5.48337139189243),
#  ('QAT', 1765510.0, 2235360.0, 26.6122072935104),
#  ('ROU', 20246900.0, 19815300.0, -2.13150940835476),
#  ('RUS', 142849000.0, 144097000.0, 0.873232632875443),
#  ('RWA', 10293700.0, 11609700.0, 12.7845287322998),
#  ('SAU', 28090600.0, 31540400.0, 12.280684709549),
#  ('SDN', 36114900.0, 40234900.0, 11.4080280065536),
#  ('SEN', 12956800.0, 15129300.0, 16.767130792141),
#  ('SGP', 5076730.0, 5535000.0, 9.02687013149261),
#  ('SLB', 526177.0, 583591.0, 10.911537706852),
#  ('SLE', 5775900.0, 6453180.0, 11.7259956896305),
#  ('SLV', 6038310.0, 6126580.0, 1.46194975823164),
#  ('SMR', 30690.0, 31781.0, 3.55490371584892),
#  ('SOM', 9581710.0, 10787100.0, 12.5801086425781),
#  ('SRB', 7291440.0, 7095380.0, -2.68881190568209),
#  ('SSD', 10056500.0, 12339800.0, 22.7051421999931),
#  ('STP', 170880.0, 190344.0, 11.3904491066933),
#  ('SUR', 518141.0, 542975.0, 4.79290373623371),
#  ('SVK', 5391430.0, 5423800.0, 0.600453186780214),
#  ('SVN', 2048580.0, 2063530.0, 0.729675078764558),
#  ('SWE', 9378130.0, 9799190.0, 4.48980964720249),
#  ('SWZ', 1193150.0, 1286970.0, 7.863400131464),
#  ('SXM', 35474.0, 38824.0, 9.44353640079498),
#  ('SYC', 89770.0, 93419.0, 4.06483225524426),
#  ('SYR', 20720600.0, 18502400.0, -10.7052393257618),
#  ('TCA', 30993.0, 34339.0, 10.7959859073162),
#  ('TCD', 11896400.0, 14037500.0, 17.997844517231),
#  ('TGO', 6390850.0, 7304580.0, 14.2974227666855),
#  ('THA', 66692000.0, 67959400.0, 1.90028119832277),
#  ('TJK', 7581700.0, 8481860.0, 11.8727922439575),
#  ('TKM', 5042000.0, 5373500.0, 6.57491758465767),
#  ('TLS', 1057120.0, 1184760.0, 12.074576318264),
#  ('TON', 103947.0, 106170.0, 2.13858988136053),
#  ('TTO', 1328100.0, 1360090.0, 2.4089390411973),
#  ('TUN', 10639200.0, 11253600.0, 5.77449761331081),
#  ('TUR', 72310400.0, 78665800.0, 8.7890736758709),
#  ('TUV', 9827.0, 9916.0, 0.905668083578348),
#  ('TZA', 45648500.0, 53470400.0, 17.1350464224815),
#  ('UGA', 33149400.0, 39032400.0, 17.7468225359917),
#  ('UKR', 45870700.0, 45154000.0, -1.56237427145243),
#  ('URY', 3374410.0, 3431560.0, 1.69336069375277),
#  ('USA', 309347000.0, 321419000.0, 3.90240550041199),
#  ('UZB', 28562400.0, 31298900.0, 9.58077758550644),
#  ('VCT', 109316.0, 109462.0, 0.133557757362723),
#  ('VEN', 28995700.0, 31108100.0, 7.28500038385391),
#  ('VGB', 27223.0, 30117.0, 10.6307163834572),
#  ('VIR', 106267.0, 103574.0, -2.53418274223804),
#  ('VNM', 86932500.0, 91713300.0, 5.49943931400776),
#  ('VUT', 236299.0, 264652.0, 11.9987815618515),
#  ('WSM', 186029.0, 193228.0, 3.86982671916485),
#  ('XKX', 1775680.0, 1801800.0, 1.47098572924733),
#  ('YEM', 23592000.0, 26832200.0, 13.7345194816589),
#  ('ZAF', 50979400.0, 55012000.0, 7.91013911366463),
#  ('ZMB', 13917400.0, 16211800.0, 16.4852738380432),
#  ('ZWE', 13973900.0, 15602800.0, 11.6564050316811)]

# %% [markdown]
# Using the `countries` table, create a new field AS geosize_group that groups the countries into three groups:
#
# - If `surface_area` is greater than 2 million, `geosize_group` is 'large'.
# - If `surface_area` is greater than 350 thousand but not larger than 2 million, `geosize_group` is 'medium'.
# - Otherwise, `geosize_group` is 'small'.

# %%
# %%sql
# SELECT name, continent, code, surface_area,
#     CASE WHEN surface_area > 2000000
#             THEN 'large'
#        WHEN surface_area > 350000 AND surface_area < 2000000
#             THEN 'medium'
#        ELSE 'small'
#        END AS geosize_group
# FROM countries;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 206 rows affected.
# [('Afghanistan', 'Asia', 'AFG', 652090.0, 'medium'),
#  ('Netherlands', 'Europe', 'NLD', 41526.0, 'small'),
#  ('Albania', 'Europe', 'ALB', 28748.0, 'small'),
#  ('Algeria', 'Africa', 'DZA', 2381740.0, 'large'),
#  ('American Samoa', 'Oceania', 'ASM', 199.0, 'small'),
#  ('Andorra', 'Europe', 'AND', 468.0, 'small'),
#  ('Angola', 'Africa', 'AGO', 1246700.0, 'medium'),
#  ('Antigua and Barbuda', 'North America', 'ATG', 442.0, 'small'),
#  ('United Arab Emirates', 'Asia', 'ARE', 83600.0, 'small'),
#  ('Argentina', 'South America', 'ARG', 2780400.0, 'large'),
#  ('Armenia', 'Asia', 'ARM', 29800.0, 'small'),
#  ('Aruba', 'North America', 'ABW', 193.0, 'small'),
#  ('Australia', 'Oceania', 'AUS', 7741220.0, 'large'),
#  ('Azerbaijan', 'Asia', 'AZE', 86600.0, 'small'),
#  ('Bahamas', 'North America', 'BHS', 13878.0, 'small'),
#  ('Bahrain', 'Asia', 'BHR', 694.0, 'small'),
#  ('Bangladesh', 'Asia', 'BGD', 143998.0, 'small'),
#  ('Barbados', 'North America', 'BRB', 430.0, 'small'),
#  ('Belgium', 'Europe', 'BEL', 30518.0, 'small'),
#  ('Belize', 'North America', 'BLZ', 22696.0, 'small'),
#  ('Benin', 'Africa', 'BEN', 112622.0, 'small'),
#  ('Bermuda', 'North America', 'BMU', 53.0, 'small'),
#  ('Bhutan', 'Asia', 'BTN', 47000.0, 'small'),
#  ('Bolivia', 'South America', 'BOL', 1098580.0, 'medium'),
#  ('Bosnia and Herzegovina', 'Europe', 'BIH', 51197.0, 'small'),
#  ('Botswana', 'Africa', 'BWA', 581730.0, 'medium'),
#  ('Brazil', 'South America', 'BRA', 8547400.0, 'large'),
#  ('United Kingdom', 'Europe', 'GBR', 242900.0, 'small'),
#  ('Virgin Islands, British', 'North America', 'VGB', 151.0, 'small'),
#  ('Brunei', 'Asia', 'BRN', 5765.0, 'small'),
#  ('Bulgaria', 'Europe', 'BGR', 110994.0, 'small'),
#  ('Burkina Faso', 'Africa', 'BFA', 274000.0, 'small'),
#  ('Burundi', 'Africa', 'BDI', 27834.0, 'small'),
#  ('Cayman Islands', 'North America', 'CYM', 264.0, 'small'),
#  ('Chile', 'South America', 'CHL', 756626.0, 'medium'),
#  ('Costa Rica', 'North America', 'CRI', 51100.0, 'small'),
#  ('Djibouti', 'Africa', 'DJI', 23200.0, 'small'),
#  ('Dominica', 'North America', 'DMA', 751.0, 'small'),
#  ('Dominican Republic', 'North America', 'DOM', 48511.0, 'small'),
#  ('Ecuador', 'South America', 'ECU', 283561.0, 'small'),
#  ('Egypt', 'Africa', 'EGY', 1001450.0, 'medium'),
#  ('El Salvador', 'North America', 'SLV', 21041.0, 'small'),
#  ('Eritrea', 'Africa', 'ERI', 117600.0, 'small'),
#  ('Spain', 'Europe', 'ESP', 505992.0, 'medium'),
#  ('South Africa', 'Africa', 'ZAF', 1221040.0, 'medium'),
#  ('Ethiopia', 'Africa', 'ETH', 1104300.0, 'medium'),
#  ('Fiji Islands', 'Oceania', 'FJI', 18274.0, 'small'),
#  ('Philippines', 'Asia', 'PHL', 300000.0, 'small'),
#  ('Faroe Islands', 'Europe', 'FRO', 1399.0, 'small'),
#  ('Gabon', 'Africa', 'GAB', 267668.0, 'small'),
#  ('Gambia', 'Africa', 'GMB', 11295.0, 'small'),
#  ('Georgia', 'Asia', 'GEO', 69700.0, 'small'),
#  ('Ghana', 'Africa', 'GHA', 238533.0, 'small'),
#  ('Gibraltar', 'Europe', 'GIB', 6.0, 'small'),
#  ('Grenada', 'North America', 'GRD', 344.0, 'small'),
#  ('Greenland', 'North America', 'GRL', 2166090.0, 'large'),
#  ('Guam', 'Oceania', 'GUM', 549.0, 'small'),
#  ('Guatemala', 'North America', 'GTM', 108889.0, 'small'),
#  ('Guinea', 'Africa', 'GIN', 245857.0, 'small'),
#  ('Guinea-Bissau', 'Africa', 'GNB', 36125.0, 'small'),
#  ('Guyana', 'South America', 'GUY', 214969.0, 'small'),
#  ('Haiti', 'North America', 'HTI', 27750.0, 'small'),
#  ('Honduras', 'North America', 'HND', 112088.0, 'small'),
#  ('Hong Kong', 'Asia', 'HKG', 1075.0, 'small'),
#  ('Indonesia', 'Asia', 'IDN', 1904570.0, 'medium'),
#  ('India', 'Asia', 'IND', 3287260.0, 'large'),
#  ('Iraq', 'Asia', 'IRQ', 438317.0, 'medium'),
#  ('Iran', 'Asia', 'IRN', 1648200.0, 'medium'),
#  ('Ireland', 'Europe', 'IRL', 70273.0, 'small'),
#  ('Iceland', 'Europe', 'ISL', 103000.0, 'small'),
#  ('Israel', 'Asia', 'ISR', 21056.0, 'small'),
#  ('Italy', 'Europe', 'ITA', 301316.0, 'small'),
#  ('Austria', 'Europe', 'AUT', 83859.0, 'small'),
#  ('Jamaica', 'North America', 'JAM', 10990.0, 'small'),
#  ('Japan', 'Asia', 'JPN', 377829.0, 'medium'),
#  ('Yemen', 'Asia', 'YEM', 527968.0, 'medium'),
#  ('Jordan', 'Asia', 'JOR', 88946.0, 'small'),
#  ('Cambodia', 'Asia', 'KHM', 181035.0, 'small'),
#  ('Cameroon', 'Africa', 'CMR', 475442.0, 'medium'),
#  ('Canada', 'North America', 'CAN', 9970610.0, 'large'),
#  ('Cape Verde', 'Africa', 'CPV', 4033.0, 'small'),
#  ('Kazakhstan', 'Asia', 'KAZ', 2724900.0, 'large'),
#  ('Kenya', 'Africa', 'KEN', 580367.0, 'medium'),
#  ('Central African Republic', 'Africa', 'CAF', 622984.0, 'medium'),
#  ('China', 'Asia', 'CHN', 9572900.0, 'large'),
#  ('Kyrgyzstan', 'Asia', 'KGZ', 199900.0, 'small'),
#  ('Kiribati', 'Oceania', 'KIR', 726.0, 'small'),
#  ('Colombia', 'South America', 'COL', 1138910.0, 'medium'),
#  ('Comoros', 'Africa', 'COM', 1862.0, 'small'),
#  ('Congo', 'Africa', 'COG', 342000.0, 'small'),
#  ('Congo, The Democratic Republic of the', 'Africa', 'COD', 2344860.0, 'large'),
#  ('North Korea', 'Asia', 'PRK', 120538.0, 'small'),
#  ('South Korea', 'Asia', 'KOR', 99434.0, 'small'),
#  ('Greece', 'Europe', 'GRC', 131626.0, 'small'),
#  ('Croatia', 'Europe', 'HRV', 56538.0, 'small'),
#  ('Cuba', 'North America', 'CUB', 110861.0, 'small'),
#  ('Kuwait', 'Asia', 'KWT', 17818.0, 'small'),
#  ('Cyprus', 'Asia', 'CYP', 9251.0, 'small'),
#  ('Laos', 'Asia', 'LAO', 236800.0, 'small'),
#  ('Latvia', 'Europe', 'LVA', 64589.0, 'small'),
#  ('Lesotho', 'Africa', 'LSO', 30355.0, 'small'),
#  ('Lebanon', 'Asia', 'LBN', 10400.0, 'small'),
#  ('Liberia', 'Africa', 'LBR', 111369.0, 'small'),
#  ('Libya', 'Africa', 'LBY', 1759540.0, 'medium'),
#  ('Liechtenstein', 'Europe', 'LIE', 160.0, 'small'),
#  ('Lithuania', 'Europe', 'LTU', 65301.0, 'small'),
#  ('Luxembourg', 'Europe', 'LUX', 2586.0, 'small'),
#  ('Macao', 'Asia', 'MAC', 18.0, 'small'),
#  ('Madagascar', 'Africa', 'MDG', 587041.0, 'medium'),
#  ('Macedonia', 'Europe', 'MKD', 25713.0, 'small'),
#  ('Malawi', 'Africa', 'MWI', 118484.0, 'small'),
#  ('Maldives', 'Asia', 'MDV', 298.0, 'small'),
#  ('Malaysia', 'Asia', 'MYS', 329758.0, 'small'),
#  ('Mali', 'Africa', 'MLI', 1240190.0, 'medium'),
#  ('Malta', 'Europe', 'MLT', 316.0, 'small'),
#  ('Morocco', 'Africa', 'MAR', 446550.0, 'medium'),
#  ('Marshall Islands', 'Oceania', 'MHL', 181.0, 'small'),
#  ('Mauritania', 'Africa', 'MRT', 1025520.0, 'medium'),
#  ('Mauritius', 'Africa', 'MUS', 2040.0, 'small'),
#  ('Mexico', 'North America', 'MEX', 1958200.0, 'medium'),
#  ('Micronesia, Federated States of', 'Oceania', 'FSM', 702.0, 'small'),
#  ('Moldova', 'Europe', 'MDA', 33851.0, 'small'),
#  ('Monaco', 'Europe', 'MCO', 1.5, 'small'),
#  ('Mongolia', 'Asia', 'MNG', 1566500.0, 'medium'),
#  ('Mozambique', 'Africa', 'MOZ', 801590.0, 'medium'),
#  ('Myanmar', 'Asia', 'MMR', 676578.0, 'medium'),
#  ('Namibia', 'Africa', 'NAM', 824292.0, 'medium'),
#  ('Nauru', 'Oceania', 'NRU', 21.0, 'small'),
#  ('Nepal', 'Asia', 'NPL', 147181.0, 'small'),
#  ('Nicaragua', 'North America', 'NIC', 130000.0, 'small'),
#  ('Niger', 'Africa', 'NER', 1267000.0, 'medium'),
#  ('Nigeria', 'Africa', 'NGA', 923768.0, 'medium'),
#  ('Norway', 'Europe', 'NOR', 323877.0, 'small'),
#  ("Cote d'Ivoire", 'Africa', 'CIV', 322463.0, 'small'),
#  ('Oman', 'Asia', 'OMN', 309500.0, 'small'),
#  ('Pakistan', 'Asia', 'PAK', 796095.0, 'medium'),
#  ('Palau', 'Oceania', 'PLW', 459.0, 'small'),
#  ('Panama', 'North America', 'PAN', 75517.0, 'small'),
#  ('Papua New Guinea', 'Oceania', 'PNG', 462840.0, 'medium'),
#  ('Paraguay', 'South America', 'PRY', 406752.0, 'medium'),
#  ('Peru', 'South America', 'PER', 1285220.0, 'medium'),
#  ('Northern Mariana Islands', 'Oceania', 'MNP', 464.0, 'small'),
#  ('Portugal', 'Europe', 'PRT', 91982.0, 'small'),
#  ('Puerto Rico', 'North America', 'PRI', 8875.0, 'small'),
#  ('Poland', 'Europe', 'POL', 323250.0, 'small'),
#  ('Equatorial Guinea', 'Africa', 'GNQ', 28051.0, 'small'),
#  ('Qatar', 'Asia', 'QAT', 11000.0, 'small'),
#  ('France', 'Europe', 'FRA', 551500.0, 'medium'),
#  ('French Polynesia', 'Oceania', 'PYF', 4000.0, 'small'),
#  ('Rwanda', 'Africa', 'RWA', 26338.0, 'small'),
#  ('Sweden', 'Europe', 'SWE', 449964.0, 'medium'),
#  ('Saint Kitts and Nevis', 'North America', 'KNA', 261.0, 'small'),
#  ('Saint Lucia', 'North America', 'LCA', 622.0, 'small'),
#  ('Saint Vincent and the Grenadines', 'North America', 'VCT', 388.0, 'small'),
#  ('Germany', 'Europe', 'DEU', 357022.0, 'medium'),
#  ('Solomon Islands', 'Oceania', 'SLB', 28896.0, 'small'),
#  ('Zambia', 'Africa', 'ZMB', 752618.0, 'medium'),
#  ('Samoa', 'Oceania', 'WSM', 2831.0, 'small'),
#  ('San Marino', 'Europe', 'SMR', 61.0, 'small'),
#  ('Sao Tome and Principe', 'Africa', 'STP', 964.0, 'small'),
#  ('Saudi Arabia', 'Asia', 'SAU', 2149690.0, 'large'),
#  ('Senegal', 'Africa', 'SEN', 196722.0, 'small'),
#  ('Seychelles', 'Africa', 'SYC', 455.0, 'small'),
#  ('Sierra Leone', 'Africa', 'SLE', 71740.0, 'small'),
#  ('Singapore', 'Asia', 'SGP', 618.0, 'small'),
#  ('Slovakia', 'Europe', 'SVK', 49012.0, 'small'),
#  ('Slovenia', 'Europe', 'SVN', 20256.0, 'small'),
#  ('Somalia', 'Africa', 'SOM', 637657.0, 'medium'),
#  ('Sri Lanka', 'Asia', 'LKA', 65610.0, 'small'),
#  ('Sudan', 'Africa', 'SDN', 2505810.0, 'large'),
#  ('Finland', 'Europe', 'FIN', 338145.0, 'small'),
#  ('Suriname', 'South America', 'SUR', 163265.0, 'small'),
#  ('Swaziland', 'Africa', 'SWZ', 17364.0, 'small'),
#  ('Switzerland', 'Europe', 'CHE', 41284.0, 'small'),
#  ('Syria', 'Asia', 'SYR', 185180.0, 'small'),
#  ('Tajikistan', 'Asia', 'TJK', 143100.0, 'small'),
#  ('Tanzania', 'Africa', 'TZA', 883749.0, 'medium'),
#  ('Denmark', 'Europe', 'DNK', 43094.0, 'small'),
#  ('Thailand', 'Asia', 'THA', 513115.0, 'medium'),
#  ('Togo', 'Africa', 'TGO', 56785.0, 'small'),
#  ('Tonga', 'Oceania', 'TON', 650.0, 'small'),
#  ('Trinidad and Tobago', 'North America', 'TTO', 5130.0, 'small'),
#  ('Chad', 'Africa', 'TCD', 1284000.0, 'medium'),
#  ('Czech Republic', 'Europe', 'CZE', 78866.0, 'small'),
#  ('Tunisia', 'Africa', 'TUN', 163610.0, 'small'),
#  ('Turkey', 'Asia', 'TUR', 774815.0, 'medium'),
#  ('Turkmenistan', 'Asia', 'TKM', 488100.0, 'medium'),
#  ('Turks and Caicos Islands', 'North America', 'TCA', 430.0, 'small'),
#  ('Tuvalu', 'Oceania', 'TUV', 26.0, 'small'),
#  ('Uganda', 'Africa', 'UGA', 241038.0, 'small'),
#  ('Ukraine', 'Europe', 'UKR', 603700.0, 'medium'),
#  ('Hungary', 'Europe', 'HUN', 93030.0, 'small'),
#  ('Uruguay', 'South America', 'URY', 175016.0, 'small'),
#  ('New Caledonia', 'Oceania', 'NCL', 18575.0, 'small'),
#  ('New Zealand', 'Oceania', 'NZL', 270534.0, 'small'),
#  ('Uzbekistan', 'Asia', 'UZB', 447400.0, 'medium'),
#  ('Belarus', 'Europe', 'BLR', 207600.0, 'small'),
#  ('Vanuatu', 'Oceania', 'VUT', 12189.0, 'small'),
#  ('Venezuela', 'South America', 'VEN', 912050.0, 'medium'),
#  ('Russian Federation', 'Europe', 'RUS', 17075400.0, 'large'),
#  ('Vietnam', 'Asia', 'VNM', 331689.0, 'small'),
#  ('Estonia', 'Europe', 'EST', 45227.0, 'small'),
#  ('United States', 'North America', 'USA', 9363520.0, 'large'),
#  ('Virgin Islands, U.S.', 'North America', 'VIR', 347.0, 'small'),
#  ('Zimbabwe', 'Africa', 'ZWE', 390757.0, 'medium'),
#  ('Palestine', 'Asia', 'PSE', 6257.0, 'small')]

# %% [markdown]
# Qestion:
# Using the populations table focused only on 2015, create a new field AS `popsize_group` to organize population size into
#
# - 'large' (> 50 million),
# - 'medium' (> 1 million), and
# - 'small' groups.
#
# Select only the country code, population size, and this new `popsize_group` as fields.

# %%
# %%sql
# SELECT country_code, size,
#     CASE WHEN size > 50000000
#         THEN 'large'
#     WHEN size > 1000000 AND size < 50000000
#       THEN 'medium'
#     ELSE 'small'
#     END AS popsize_group
# FROM populations
# WHERE year = 2015;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 217 rows affected.
# [('ABW', 103889.0, 'small'),
#  ('AFG', 32526600.0, 'medium'),
#  ('AGO', 25022000.0, 'medium'),
#  ('ALB', 2889170.0, 'medium'),
#  ('AND', 70473.0, 'small'),
#  ('ARE', 9156960.0, 'medium'),
#  ('ARG', 43416800.0, 'medium'),
#  ('ARM', 3017710.0, 'medium'),
#  ('ASM', 55538.0, 'small'),
#  ('ATG', 91818.0, 'small'),
#  ('AUS', 23789800.0, 'medium'),
#  ('AUT', 8638370.0, 'medium'),
#  ('AZE', 9649340.0, 'medium'),
#  ('BDI', 11178900.0, 'medium'),
#  ('BEL', 11249400.0, 'medium'),
#  ('BEN', 10879800.0, 'medium'),
#  ('BFA', 18105600.0, 'medium'),
#  ('BGD', 160996000.0, 'large'),
#  ('BGR', 7177990.0, 'medium'),
#  ('BHR', 1377240.0, 'medium'),
#  ('BHS', 388019.0, 'small'),
#  ('BIH', 3810420.0, 'medium'),
#  ('BLR', 9489620.0, 'medium'),
#  ('BLZ', 359287.0, 'small'),
#  ('BMU', 65235.0, 'small'),
#  ('BOL', 10724700.0, 'medium'),
#  ('BRA', 207848000.0, 'large'),
#  ('BRB', 284215.0, 'small'),
#  ('BRN', 423188.0, 'small'),
#  ('BTN', 774830.0, 'small'),
#  ('BWA', 2262480.0, 'medium'),
#  ('CAF', 4900270.0, 'medium'),
#  ('CAN', 35848600.0, 'medium'),
#  ('CHE', 8281430.0, 'medium'),
#  ('CHI', 163692.0, 'small'),
#  ('CHL', 17948100.0, 'medium'),
#  ('CHN', 1371220000.0, 'large'),
#  ('CIV', 22701600.0, 'medium'),
#  ('CMR', 23344200.0, 'medium'),
#  ('COD', 77266800.0, 'large'),
#  ('COG', 4620330.0, 'medium'),
#  ('COL', 48228700.0, 'medium'),
#  ('COM', 788474.0, 'small'),
#  ('CPV', 520502.0, 'small'),
#  ('CRI', 4807850.0, 'medium'),
#  ('CUB', 11389600.0, 'medium'),
#  ('CUW', 157979.0, 'small'),
#  ('CYM', 59967.0, 'small'),
#  ('CYP', 1165300.0, 'medium'),
#  ('CZE', 10546100.0, 'medium'),
#  ('DEU', 81679800.0, 'large'),
#  ('DJI', 887861.0, 'small'),
#  ('DMA', 72680.0, 'small'),
#  ('DNK', 5683480.0, 'medium'),
#  ('DOM', 10528400.0, 'medium'),
#  ('DZA', 39666500.0, 'medium'),
#  ('ECU', 16144400.0, 'medium'),
#  ('EGY', 91508100.0, 'large'),
#  ('ERI', None, 'small'),
#  ('ESP', 46444000.0, 'medium'),
#  ('EST', 1314610.0, 'medium'),
#  ('ETH', 99390800.0, 'large'),
#  ('FIN', 5479530.0, 'medium'),
#  ('FJI', 892145.0, 'small'),
#  ('FRA', 66538400.0, 'large'),
#  ('FRO', 48199.0, 'small'),
#  ('FSM', 104460.0, 'small'),
#  ('GAB', 1725290.0, 'medium'),
#  ('GBR', 65128900.0, 'large'),
#  ('GEO', 3717100.0, 'medium'),
#  ('GHA', 27409900.0, 'medium'),
#  ('GIB', 32217.0, 'small'),
#  ('GIN', 12608600.0, 'medium'),
#  ('GMB', 1990920.0, 'medium'),
#  ('GNB', 1844320.0, 'medium'),
#  ('GNQ', 845060.0, 'small'),
#  ('GRC', 10820900.0, 'medium'),
#  ('GRD', 106825.0, 'small'),
#  ('GRL', 56114.0, 'small'),
#  ('GTM', 16342900.0, 'medium'),
#  ('GUM', 169885.0, 'small'),
#  ('GUY', 767085.0, 'small'),
#  ('HKG', 7305700.0, 'medium'),
#  ('HND', 8075060.0, 'medium'),
#  ('HRV', 4203600.0, 'medium'),
#  ('HTI', 10711100.0, 'medium'),
#  ('HUN', 9843030.0, 'medium'),
#  ('IDN', 257564000.0, 'large'),
#  ('IMN', 87780.0, 'small'),
#  ('IND', 1311050000.0, 'large'),
#  ('IRL', 4643740.0, 'medium'),
#  ('IRN', 79109300.0, 'large'),
#  ('IRQ', 36423400.0, 'medium'),
#  ('ISL', 330815.0, 'small'),
#  ('ISR', 8380100.0, 'medium'),
#  ('ITA', 60730600.0, 'large'),
#  ('JAM', 2793340.0, 'medium'),
#  ('JOR', 7594550.0, 'medium'),
#  ('JPN', 126958000.0, 'large'),
#  ('KAZ', 17544100.0, 'medium'),
#  ('KEN', 46050300.0, 'medium'),
#  ('KGZ', 5956900.0, 'medium'),
#  ('KHM', 15577900.0, 'medium'),
#  ('KIR', 112423.0, 'small'),
#  ('KNA', 55572.0, 'small'),
#  ('KOR', 50617000.0, 'large'),
#  ('KWT', 3892120.0, 'medium'),
#  ('LAO', 6802020.0, 'medium'),
#  ('LBN', 5850740.0, 'medium'),
#  ('LBR', 4503440.0, 'medium'),
#  ('LBY', 6278440.0, 'medium'),
#  ('LCA', 184999.0, 'small'),
#  ('LIE', 37531.0, 'small'),
#  ('LKA', 20966000.0, 'medium'),
#  ('LSO', 2135020.0, 'medium'),
#  ('LTU', 2904910.0, 'medium'),
#  ('LUX', 569604.0, 'small'),
#  ('LVA', 1977530.0, 'medium'),
#  ('MAC', 587606.0, 'small'),
#  ('MAF', 31754.0, 'small'),
#  ('MAR', 34377500.0, 'medium'),
#  ('MCO', 37731.0, 'small'),
#  ('MDA', 3554110.0, 'medium'),
#  ('MDG', 24235400.0, 'medium'),
#  ('MDV', 409163.0, 'small'),
#  ('MEX', 127017000.0, 'large'),
#  ('MHL', 52993.0, 'small'),
#  ('MKD', 2078450.0, 'medium'),
#  ('MLI', 17599700.0, 'medium'),
#  ('MLT', 431874.0, 'small'),
#  ('MMR', 53897200.0, 'large'),
#  ('MNE', 622159.0, 'small'),
#  ('MNG', 2959130.0, 'medium'),
#  ('MNP', 55070.0, 'small'),
#  ('MOZ', 27977900.0, 'medium'),
#  ('MRT', 4067560.0, 'medium'),
#  ('MUS', 1262600.0, 'medium'),
#  ('MWI', 17215200.0, 'medium'),
#  ('MYS', 30331000.0, 'medium'),
#  ('NAM', 2458830.0, 'medium'),
#  ('NCL', 273000.0, 'small'),
#  ('NER', 19899100.0, 'medium'),
#  ('NGA', 182202000.0, 'large'),
#  ('NIC', 6082030.0, 'medium'),
#  ('NLD', 16939900.0, 'medium'),
#  ('NOR', 5190240.0, 'medium'),
#  ('NPL', 28513700.0, 'medium'),
#  ('NRU', 12475.0, 'small'),
#  ('NZL', 4595700.0, 'medium'),
#  ('OMN', 4490540.0, 'medium'),
#  ('PAK', 188925000.0, 'large'),
#  ('PAN', 3929140.0, 'medium'),
#  ('PER', 31376700.0, 'medium'),
#  ('PHL', 100699000.0, 'large'),
#  ('PLW', 21291.0, 'small'),
#  ('PNG', 7619320.0, 'medium'),
#  ('POL', 37986400.0, 'medium'),
#  ('PRI', 3474180.0, 'medium'),
#  ('PRK', 25155300.0, 'medium'),
#  ('PRT', 10358100.0, 'medium'),
#  ('PRY', 6639120.0, 'medium'),
#  ('PSE', 4422140.0, 'medium'),
#  ('PYF', 282764.0, 'small'),
#  ('QAT', 2235360.0, 'medium'),
#  ('ROU', 19815300.0, 'medium'),
#  ('RUS', 144097000.0, 'large'),
#  ('RWA', 11609700.0, 'medium'),
#  ('SAU', 31540400.0, 'medium'),
#  ('SDN', 40234900.0, 'medium'),
#  ('SEN', 15129300.0, 'medium'),
#  ('SGP', 5535000.0, 'medium'),
#  ('SLB', 583591.0, 'small'),
#  ('SLE', 6453180.0, 'medium'),
#  ('SLV', 6126580.0, 'medium'),
#  ('SMR', 31781.0, 'small'),
#  ('SOM', 10787100.0, 'medium'),
#  ('SRB', 7095380.0, 'medium'),
#  ('SSD', 12339800.0, 'medium'),
#  ('STP', 190344.0, 'small'),
#  ('SUR', 542975.0, 'small'),
#  ('SVK', 5423800.0, 'medium'),
#  ('SVN', 2063530.0, 'medium'),
#  ('SWE', 9799190.0, 'medium'),
#  ('SWZ', 1286970.0, 'medium'),
#  ('SXM', 38824.0, 'small'),
#  ('SYC', 93419.0, 'small'),
#  ('SYR', 18502400.0, 'medium'),
#  ('TCA', 34339.0, 'small'),
#  ('TCD', 14037500.0, 'medium'),
#  ('TGO', 7304580.0, 'medium'),
#  ('THA', 67959400.0, 'large'),
#  ('TJK', 8481860.0, 'medium'),
#  ('TKM', 5373500.0, 'medium'),
#  ('TLS', 1184760.0, 'medium'),
#  ('TON', 106170.0, 'small'),
#  ('TTO', 1360090.0, 'medium'),
#  ('TUN', 11253600.0, 'medium'),
#  ('TUR', 78665800.0, 'large'),
#  ('TUV', 9916.0, 'small'),
#  ('TZA', 53470400.0, 'large'),
#  ('UGA', 39032400.0, 'medium'),
#  ('UKR', 45154000.0, 'medium'),
#  ('URY', 3431560.0, 'medium'),
#  ('USA', 321419000.0, 'large'),
#  ('UZB', 31298900.0, 'medium'),
#  ('VCT', 109462.0, 'small'),
#  ('VEN', 31108100.0, 'medium'),
#  ('VGB', 30117.0, 'small'),
#  ('VIR', 103574.0, 'small'),
#  ('VNM', 91713300.0, 'large'),
#  ('VUT', 264652.0, 'small'),
#  ('WSM', 193228.0, 'small'),
#  ('XKX', 1801800.0, 'medium'),
#  ('YEM', 26832200.0, 'medium'),
#  ('ZAF', 55012000.0, 'large'),
#  ('ZMB', 16211800.0, 'medium'),
#  ('ZWE', 15602800.0, 'medium')]

# %% [markdown]
# Use INTO to save the result of the previous query as `pop_plus`. You
#
# Then, display `pop_plus` in query result.

# %%
# %%sql
# SELECT country_code, size,
#     CASE WHEN size > 50000000
#         THEN 'large'
#     WHEN size > 1000000 AND size < 50000000
#       THEN 'medium'
#     ELSE 'small'
#     END AS popsize_group
# INTO pop_plus
# FROM populations
# WHERE year = 2015;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 217 rows affected.
# []

# %%
# %sql SELECT * FROM pop_plus;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 217 rows affected.
# [('ABW', 103889.0, 'small'),
#  ('AFG', 32526600.0, 'medium'),
#  ('AGO', 25022000.0, 'medium'),
#  ('ALB', 2889170.0, 'medium'),
#  ('AND', 70473.0, 'small'),
#  ('ARE', 9156960.0, 'medium'),
#  ('ARG', 43416800.0, 'medium'),
#  ('ARM', 3017710.0, 'medium'),
#  ('ASM', 55538.0, 'small'),
#  ('ATG', 91818.0, 'small'),
#  ('AUS', 23789800.0, 'medium'),
#  ('AUT', 8638370.0, 'medium'),
#  ('AZE', 9649340.0, 'medium'),
#  ('BDI', 11178900.0, 'medium'),
#  ('BEL', 11249400.0, 'medium'),
#  ('BEN', 10879800.0, 'medium'),
#  ('BFA', 18105600.0, 'medium'),
#  ('BGD', 160996000.0, 'large'),
#  ('BGR', 7177990.0, 'medium'),
#  ('BHR', 1377240.0, 'medium'),
#  ('BHS', 388019.0, 'small'),
#  ('BIH', 3810420.0, 'medium'),
#  ('BLR', 9489620.0, 'medium'),
#  ('BLZ', 359287.0, 'small'),
#  ('BMU', 65235.0, 'small'),
#  ('BOL', 10724700.0, 'medium'),
#  ('BRA', 207848000.0, 'large'),
#  ('BRB', 284215.0, 'small'),
#  ('BRN', 423188.0, 'small'),
#  ('BTN', 774830.0, 'small'),
#  ('BWA', 2262480.0, 'medium'),
#  ('CAF', 4900270.0, 'medium'),
#  ('CAN', 35848600.0, 'medium'),
#  ('CHE', 8281430.0, 'medium'),
#  ('CHI', 163692.0, 'small'),
#  ('CHL', 17948100.0, 'medium'),
#  ('CHN', 1371220000.0, 'large'),
#  ('CIV', 22701600.0, 'medium'),
#  ('CMR', 23344200.0, 'medium'),
#  ('COD', 77266800.0, 'large'),
#  ('COG', 4620330.0, 'medium'),
#  ('COL', 48228700.0, 'medium'),
#  ('COM', 788474.0, 'small'),
#  ('CPV', 520502.0, 'small'),
#  ('CRI', 4807850.0, 'medium'),
#  ('CUB', 11389600.0, 'medium'),
#  ('CUW', 157979.0, 'small'),
#  ('CYM', 59967.0, 'small'),
#  ('CYP', 1165300.0, 'medium'),
#  ('CZE', 10546100.0, 'medium'),
#  ('DEU', 81679800.0, 'large'),
#  ('DJI', 887861.0, 'small'),
#  ('DMA', 72680.0, 'small'),
#  ('DNK', 5683480.0, 'medium'),
#  ('DOM', 10528400.0, 'medium'),
#  ('DZA', 39666500.0, 'medium'),
#  ('ECU', 16144400.0, 'medium'),
#  ('EGY', 91508100.0, 'large'),
#  ('ERI', None, 'small'),
#  ('ESP', 46444000.0, 'medium'),
#  ('EST', 1314610.0, 'medium'),
#  ('ETH', 99390800.0, 'large'),
#  ('FIN', 5479530.0, 'medium'),
#  ('FJI', 892145.0, 'small'),
#  ('FRA', 66538400.0, 'large'),
#  ('FRO', 48199.0, 'small'),
#  ('FSM', 104460.0, 'small'),
#  ('GAB', 1725290.0, 'medium'),
#  ('GBR', 65128900.0, 'large'),
#  ('GEO', 3717100.0, 'medium'),
#  ('GHA', 27409900.0, 'medium'),
#  ('GIB', 32217.0, 'small'),
#  ('GIN', 12608600.0, 'medium'),
#  ('GMB', 1990920.0, 'medium'),
#  ('GNB', 1844320.0, 'medium'),
#  ('GNQ', 845060.0, 'small'),
#  ('GRC', 10820900.0, 'medium'),
#  ('GRD', 106825.0, 'small'),
#  ('GRL', 56114.0, 'small'),
#  ('GTM', 16342900.0, 'medium'),
#  ('GUM', 169885.0, 'small'),
#  ('GUY', 767085.0, 'small'),
#  ('HKG', 7305700.0, 'medium'),
#  ('HND', 8075060.0, 'medium'),
#  ('HRV', 4203600.0, 'medium'),
#  ('HTI', 10711100.0, 'medium'),
#  ('HUN', 9843030.0, 'medium'),
#  ('IDN', 257564000.0, 'large'),
#  ('IMN', 87780.0, 'small'),
#  ('IND', 1311050000.0, 'large'),
#  ('IRL', 4643740.0, 'medium'),
#  ('IRN', 79109300.0, 'large'),
#  ('IRQ', 36423400.0, 'medium'),
#  ('ISL', 330815.0, 'small'),
#  ('ISR', 8380100.0, 'medium'),
#  ('ITA', 60730600.0, 'large'),
#  ('JAM', 2793340.0, 'medium'),
#  ('JOR', 7594550.0, 'medium'),
#  ('JPN', 126958000.0, 'large'),
#  ('KAZ', 17544100.0, 'medium'),
#  ('KEN', 46050300.0, 'medium'),
#  ('KGZ', 5956900.0, 'medium'),
#  ('KHM', 15577900.0, 'medium'),
#  ('KIR', 112423.0, 'small'),
#  ('KNA', 55572.0, 'small'),
#  ('KOR', 50617000.0, 'large'),
#  ('KWT', 3892120.0, 'medium'),
#  ('LAO', 6802020.0, 'medium'),
#  ('LBN', 5850740.0, 'medium'),
#  ('LBR', 4503440.0, 'medium'),
#  ('LBY', 6278440.0, 'medium'),
#  ('LCA', 184999.0, 'small'),
#  ('LIE', 37531.0, 'small'),
#  ('LKA', 20966000.0, 'medium'),
#  ('LSO', 2135020.0, 'medium'),
#  ('LTU', 2904910.0, 'medium'),
#  ('LUX', 569604.0, 'small'),
#  ('LVA', 1977530.0, 'medium'),
#  ('MAC', 587606.0, 'small'),
#  ('MAF', 31754.0, 'small'),
#  ('MAR', 34377500.0, 'medium'),
#  ('MCO', 37731.0, 'small'),
#  ('MDA', 3554110.0, 'medium'),
#  ('MDG', 24235400.0, 'medium'),
#  ('MDV', 409163.0, 'small'),
#  ('MEX', 127017000.0, 'large'),
#  ('MHL', 52993.0, 'small'),
#  ('MKD', 2078450.0, 'medium'),
#  ('MLI', 17599700.0, 'medium'),
#  ('MLT', 431874.0, 'small'),
#  ('MMR', 53897200.0, 'large'),
#  ('MNE', 622159.0, 'small'),
#  ('MNG', 2959130.0, 'medium'),
#  ('MNP', 55070.0, 'small'),
#  ('MOZ', 27977900.0, 'medium'),
#  ('MRT', 4067560.0, 'medium'),
#  ('MUS', 1262600.0, 'medium'),
#  ('MWI', 17215200.0, 'medium'),
#  ('MYS', 30331000.0, 'medium'),
#  ('NAM', 2458830.0, 'medium'),
#  ('NCL', 273000.0, 'small'),
#  ('NER', 19899100.0, 'medium'),
#  ('NGA', 182202000.0, 'large'),
#  ('NIC', 6082030.0, 'medium'),
#  ('NLD', 16939900.0, 'medium'),
#  ('NOR', 5190240.0, 'medium'),
#  ('NPL', 28513700.0, 'medium'),
#  ('NRU', 12475.0, 'small'),
#  ('NZL', 4595700.0, 'medium'),
#  ('OMN', 4490540.0, 'medium'),
#  ('PAK', 188925000.0, 'large'),
#  ('PAN', 3929140.0, 'medium'),
#  ('PER', 31376700.0, 'medium'),
#  ('PHL', 100699000.0, 'large'),
#  ('PLW', 21291.0, 'small'),
#  ('PNG', 7619320.0, 'medium'),
#  ('POL', 37986400.0, 'medium'),
#  ('PRI', 3474180.0, 'medium'),
#  ('PRK', 25155300.0, 'medium'),
#  ('PRT', 10358100.0, 'medium'),
#  ('PRY', 6639120.0, 'medium'),
#  ('PSE', 4422140.0, 'medium'),
#  ('PYF', 282764.0, 'small'),
#  ('QAT', 2235360.0, 'medium'),
#  ('ROU', 19815300.0, 'medium'),
#  ('RUS', 144097000.0, 'large'),
#  ('RWA', 11609700.0, 'medium'),
#  ('SAU', 31540400.0, 'medium'),
#  ('SDN', 40234900.0, 'medium'),
#  ('SEN', 15129300.0, 'medium'),
#  ('SGP', 5535000.0, 'medium'),
#  ('SLB', 583591.0, 'small'),
#  ('SLE', 6453180.0, 'medium'),
#  ('SLV', 6126580.0, 'medium'),
#  ('SMR', 31781.0, 'small'),
#  ('SOM', 10787100.0, 'medium'),
#  ('SRB', 7095380.0, 'medium'),
#  ('SSD', 12339800.0, 'medium'),
#  ('STP', 190344.0, 'small'),
#  ('SUR', 542975.0, 'small'),
#  ('SVK', 5423800.0, 'medium'),
#  ('SVN', 2063530.0, 'medium'),
#  ('SWE', 9799190.0, 'medium'),
#  ('SWZ', 1286970.0, 'medium'),
#  ('SXM', 38824.0, 'small'),
#  ('SYC', 93419.0, 'small'),
#  ('SYR', 18502400.0, 'medium'),
#  ('TCA', 34339.0, 'small'),
#  ('TCD', 14037500.0, 'medium'),
#  ('TGO', 7304580.0, 'medium'),
#  ('THA', 67959400.0, 'large'),
#  ('TJK', 8481860.0, 'medium'),
#  ('TKM', 5373500.0, 'medium'),
#  ('TLS', 1184760.0, 'medium'),
#  ('TON', 106170.0, 'small'),
#  ('TTO', 1360090.0, 'medium'),
#  ('TUN', 11253600.0, 'medium'),
#  ('TUR', 78665800.0, 'large'),
#  ('TUV', 9916.0, 'small'),
#  ('TZA', 53470400.0, 'large'),
#  ('UGA', 39032400.0, 'medium'),
#  ('UKR', 45154000.0, 'medium'),
#  ('URY', 3431560.0, 'medium'),
#  ('USA', 321419000.0, 'large'),
#  ('UZB', 31298900.0, 'medium'),
#  ('VCT', 109462.0, 'small'),
#  ('VEN', 31108100.0, 'medium'),
#  ('VGB', 30117.0, 'small'),
#  ('VIR', 103574.0, 'small'),
#  ('VNM', 91713300.0, 'large'),
#  ('VUT', 264652.0, 'small'),
#  ('WSM', 193228.0, 'small'),
#  ('XKX', 1801800.0, 'medium'),
#  ('YEM', 26832200.0, 'medium'),
#  ('ZAF', 55012000.0, 'large'),
#  ('ZMB', 16211800.0, 'medium'),
#  ('ZWE', 15602800.0, 'medium')]

# %% [markdown]
#
# - Select country name, continent, the surface area grouping (NOT `surface_area`), and the population grouping fields. (Four fields total.)
# - Sort the data based on `geosize_group`, in ascending order so that large appears on top.

# %%
# %%sql
# SELECT c.name , c.continent , c.geosize_group , p.popsize_group
# FROM countries_plus  AS c
# INNER JOIN pop_plus AS p
# ON c.code= p.country_code
# ORDER BY c.geosize_group;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 206 rows affected.
# [('India', 'Asia', 'large', 'large'),
#  ('United States', 'North America', 'large', 'large'),
#  ('Saudi Arabia', 'Asia', 'large', 'medium'),
#  ('China', 'Asia', 'large', 'large'),
#  ('Kazakhstan', 'Asia', 'large', 'medium'),
#  ('Sudan', 'Africa', 'large', 'medium'),
#  ('Argentina', 'South America', 'large', 'medium'),
#  ('Algeria', 'Africa', 'large', 'medium'),
#  ('Congo, The Democratic Republic of the', 'Africa', 'large', 'large'),
#  ('Canada', 'North America', 'large', 'medium'),
#  ('Australia', 'Oceania', 'large', 'medium'),
#  ('Brazil', 'South America', 'large', 'large'),
#  ('Russian Federation', 'Europe', 'large', 'large'),
#  ('Greenland', 'North America', 'large', 'small'),
#  ('Iran', 'Asia', 'medium', 'large'),
#  ('Madagascar', 'Africa', 'medium', 'medium'),
#  ('Iraq', 'Asia', 'medium', 'medium'),
#  ('Mexico', 'North America', 'medium', 'large'),
#  ('Somalia', 'Africa', 'medium', 'medium'),
#  ('Central African Republic', 'Africa', 'medium', 'medium'),
#  ('Mali', 'Africa', 'medium', 'medium'),
#  ('Afghanistan', 'Asia', 'medium', 'medium'),
#  ('Sweden', 'Europe', 'medium', 'medium'),
#  ('Myanmar', 'Asia', 'medium', 'large'),
#  ('Mongolia', 'Asia', 'medium', 'medium'),
#  ('Germany', 'Europe', 'medium', 'large'),
#  ('Mozambique', 'Africa', 'medium', 'medium'),
#  ('Chad', 'Africa', 'medium', 'medium'),
#  ('Mauritania', 'Africa', 'medium', 'medium'),
#  ('Thailand', 'Asia', 'medium', 'large'),
#  ('Chile', 'South America', 'medium', 'medium'),
#  ('Turkmenistan', 'Asia', 'medium', 'medium'),
#  ('Japan', 'Asia', 'medium', 'large'),
#  ('Namibia', 'Africa', 'medium', 'medium'),
#  ('Turkey', 'Asia', 'medium', 'large'),
#  ('Kenya', 'Africa', 'medium', 'medium'),
#  ('Tanzania', 'Africa', 'medium', 'large'),
#  ('Niger', 'Africa', 'medium', 'medium'),
#  ('Ukraine', 'Europe', 'medium', 'medium'),
#  ('Nigeria', 'Africa', 'medium', 'large'),
#  ('Uzbekistan', 'Asia', 'medium', 'medium'),
#  ('Venezuela', 'South America', 'medium', 'medium'),
#  ('Bolivia', 'South America', 'medium', 'medium'),
#  ('Cameroon', 'Africa', 'medium', 'medium'),
#  ('Egypt', 'Africa', 'medium', 'large'),
#  ('Yemen', 'Asia', 'medium', 'medium'),
#  ('South Africa', 'Africa', 'medium', 'large'),
#  ('Zambia', 'Africa', 'medium', 'medium'),
#  ('Zimbabwe', 'Africa', 'medium', 'medium'),
#  ('Pakistan', 'Asia', 'medium', 'large'),
#  ('Peru', 'South America', 'medium', 'medium'),
#  ('Spain', 'Europe', 'medium', 'medium'),
#  ('Libya', 'Africa', 'medium', 'medium'),
#  ('Papua New Guinea', 'Oceania', 'medium', 'medium'),
#  ('Colombia', 'South America', 'medium', 'medium'),
#  ('Ethiopia', 'Africa', 'medium', 'large'),
#  ('Paraguay', 'South America', 'medium', 'medium'),
#  ('France', 'Europe', 'medium', 'large'),
#  ('Angola', 'Africa', 'medium', 'medium'),
#  ('Indonesia', 'Asia', 'medium', 'large'),
#  ('Morocco', 'Africa', 'medium', 'medium'),
#  ('Botswana', 'Africa', 'medium', 'medium'),
#  ('Haiti', 'North America', 'small', 'medium'),
#  ('Hungary', 'Europe', 'small', 'medium'),
#  ('Ireland', 'Europe', 'small', 'medium'),
#  ('Iceland', 'Europe', 'small', 'small'),
#  ('Israel', 'Asia', 'small', 'medium'),
#  ('Italy', 'Europe', 'small', 'large'),
#  ('Jamaica', 'North America', 'small', 'medium'),
#  ('Jordan', 'Asia', 'small', 'medium'),
#  ('Kyrgyzstan', 'Asia', 'small', 'medium'),
#  ('Cambodia', 'Asia', 'small', 'medium'),
#  ('Kiribati', 'Oceania', 'small', 'small'),
#  ('Saint Kitts and Nevis', 'North America', 'small', 'small'),
#  ('South Korea', 'Asia', 'small', 'large'),
#  ('Kuwait', 'Asia', 'small', 'medium'),
#  ('Laos', 'Asia', 'small', 'medium'),
#  ('Lebanon', 'Asia', 'small', 'medium'),
#  ('Liberia', 'Africa', 'small', 'medium'),
#  ('Saint Lucia', 'North America', 'small', 'small'),
#  ('Liechtenstein', 'Europe', 'small', 'small'),
#  ('Sri Lanka', 'Asia', 'small', 'medium'),
#  ('Lesotho', 'Africa', 'small', 'medium'),
#  ('Lithuania', 'Europe', 'small', 'medium'),
#  ('Luxembourg', 'Europe', 'small', 'small'),
#  ('Latvia', 'Europe', 'small', 'medium'),
#  ('Macao', 'Asia', 'small', 'small'),
#  ('Monaco', 'Europe', 'small', 'small'),
#  ('Moldova', 'Europe', 'small', 'medium'),
#  ('Maldives', 'Asia', 'small', 'small'),
#  ('Marshall Islands', 'Oceania', 'small', 'small'),
#  ('Macedonia', 'Europe', 'small', 'medium'),
#  ('Malta', 'Europe', 'small', 'small'),
#  ('Aruba', 'North America', 'small', 'small'),
#  ('Mauritius', 'Africa', 'small', 'medium'),
#  ('Malawi', 'Africa', 'small', 'medium'),
#  ('Malaysia', 'Asia', 'small', 'medium'),
#  ('New Caledonia', 'Oceania', 'small', 'small'),
#  ('Nicaragua', 'North America', 'small', 'medium'),
#  ('Netherlands', 'Europe', 'small', 'medium'),
#  ('Norway', 'Europe', 'small', 'medium'),
#  ('Nepal', 'Asia', 'small', 'medium'),
#  ('Nauru', 'Oceania', 'small', 'small'),
#  ('New Zealand', 'Oceania', 'small', 'medium'),
#  ('Oman', 'Asia', 'small', 'medium'),
#  ('Panama', 'North America', 'small', 'medium'),
#  ('Philippines', 'Asia', 'small', 'large'),
#  ('Palau', 'Oceania', 'small', 'small'),
#  ('Poland', 'Europe', 'small', 'medium'),
#  ('Puerto Rico', 'North America', 'small', 'medium'),
#  ('North Korea', 'Asia', 'small', 'medium'),
#  ('Portugal', 'Europe', 'small', 'medium'),
#  ('Palestine', 'Asia', 'small', 'medium'),
#  ('French Polynesia', 'Oceania', 'small', 'small'),
#  ('Qatar', 'Asia', 'small', 'medium'),
#  ('Rwanda', 'Africa', 'small', 'medium'),
#  ('Senegal', 'Africa', 'small', 'medium'),
#  ('Singapore', 'Asia', 'small', 'medium'),
#  ('Solomon Islands', 'Oceania', 'small', 'small'),
#  ('Sierra Leone', 'Africa', 'small', 'medium'),
#  ('El Salvador', 'North America', 'small', 'medium'),
#  ('San Marino', 'Europe', 'small', 'small'),
#  ('Sao Tome and Principe', 'Africa', 'small', 'small'),
#  ('Suriname', 'South America', 'small', 'small'),
#  ('Slovakia', 'Europe', 'small', 'medium'),
#  ('Slovenia', 'Europe', 'small', 'medium'),
#  ('Swaziland', 'Africa', 'small', 'medium'),
#  ('Seychelles', 'Africa', 'small', 'small'),
#  ('Syria', 'Asia', 'small', 'medium'),
#  ('Turks and Caicos Islands', 'North America', 'small', 'small'),
#  ('Togo', 'Africa', 'small', 'medium'),
#  ('Tajikistan', 'Asia', 'small', 'medium'),
#  ('Tonga', 'Oceania', 'small', 'small'),
#  ('Trinidad and Tobago', 'North America', 'small', 'medium'),
#  ('Tunisia', 'Africa', 'small', 'medium'),
#  ('Tuvalu', 'Oceania', 'small', 'small'),
#  ('Uganda', 'Africa', 'small', 'medium'),
#  ('Uruguay', 'South America', 'small', 'medium'),
#  ('Saint Vincent and the Grenadines', 'North America', 'small', 'small'),
#  ('Virgin Islands, British', 'North America', 'small', 'small'),
#  ('Virgin Islands, U.S.', 'North America', 'small', 'small'),
#  ('Vietnam', 'Asia', 'small', 'large'),
#  ('Vanuatu', 'Oceania', 'small', 'small'),
#  ('Samoa', 'Oceania', 'small', 'small'),
#  ('Northern Mariana Islands', 'Oceania', 'small', 'small'),
#  ('Albania', 'Europe', 'small', 'medium'),
#  ('Andorra', 'Europe', 'small', 'small'),
#  ('United Arab Emirates', 'Asia', 'small', 'medium'),
#  ('Armenia', 'Asia', 'small', 'medium'),
#  ('American Samoa', 'Oceania', 'small', 'small'),
#  ('Antigua and Barbuda', 'North America', 'small', 'small'),
#  ('Austria', 'Europe', 'small', 'medium'),
#  ('Azerbaijan', 'Asia', 'small', 'medium'),
#  ('Burundi', 'Africa', 'small', 'medium'),
#  ('Belgium', 'Europe', 'small', 'medium'),
#  ('Benin', 'Africa', 'small', 'medium'),
#  ('Burkina Faso', 'Africa', 'small', 'medium'),
#  ('Bangladesh', 'Asia', 'small', 'large'),
#  ('Bulgaria', 'Europe', 'small', 'medium'),
#  ('Bahrain', 'Asia', 'small', 'medium'),
#  ('Bahamas', 'North America', 'small', 'small'),
#  ('Bosnia and Herzegovina', 'Europe', 'small', 'medium'),
#  ('Belarus', 'Europe', 'small', 'medium'),
#  ('Belize', 'North America', 'small', 'small'),
#  ('Bermuda', 'North America', 'small', 'small'),
#  ('Barbados', 'North America', 'small', 'small'),
#  ('Brunei', 'Asia', 'small', 'small'),
#  ('Bhutan', 'Asia', 'small', 'small'),
#  ('Switzerland', 'Europe', 'small', 'medium'),
#  ("Cote d'Ivoire", 'Africa', 'small', 'medium'),
#  ('Congo', 'Africa', 'small', 'medium'),
#  ('Comoros', 'Africa', 'small', 'small'),
#  ('Cape Verde', 'Africa', 'small', 'small'),
#  ('Costa Rica', 'North America', 'small', 'medium'),
#  ('Cuba', 'North America', 'small', 'medium'),
#  ('Cayman Islands', 'North America', 'small', 'small'),
#  ('Cyprus', 'Asia', 'small', 'medium'),
#  ('Czech Republic', 'Europe', 'small', 'medium'),
#  ('Djibouti', 'Africa', 'small', 'small'),
#  ('Dominica', 'North America', 'small', 'small'),
#  ('Denmark', 'Europe', 'small', 'medium'),
#  ('Dominican Republic', 'North America', 'small', 'medium'),
#  ('Ecuador', 'South America', 'small', 'medium'),
#  ('Eritrea', 'Africa', 'small', 'small'),
#  ('Estonia', 'Europe', 'small', 'medium'),
#  ('Finland', 'Europe', 'small', 'medium'),
#  ('Fiji Islands', 'Oceania', 'small', 'small'),
#  ('Faroe Islands', 'Europe', 'small', 'small'),
#  ('Micronesia, Federated States of', 'Oceania', 'small', 'small'),
#  ('Gabon', 'Africa', 'small', 'medium'),
#  ('United Kingdom', 'Europe', 'small', 'large'),
#  ('Georgia', 'Asia', 'small', 'medium'),
#  ('Ghana', 'Africa', 'small', 'medium'),
#  ('Gibraltar', 'Europe', 'small', 'small'),
#  ('Guinea', 'Africa', 'small', 'medium'),
#  ('Gambia', 'Africa', 'small', 'medium'),
#  ('Guinea-Bissau', 'Africa', 'small', 'medium'),
#  ('Equatorial Guinea', 'Africa', 'small', 'small'),
#  ('Greece', 'Europe', 'small', 'medium'),
#  ('Grenada', 'North America', 'small', 'small'),
#  ('Guatemala', 'North America', 'small', 'medium'),
#  ('Guam', 'Oceania', 'small', 'small'),
#  ('Guyana', 'South America', 'small', 'small'),
#  ('Hong Kong', 'Asia', 'small', 'medium'),
#  ('Honduras', 'North America', 'small', 'medium'),
#  ('Croatia', 'Europe', 'small', 'medium')]

# %%
# %%sql
# SELECT p1.country, prime_minister,president
# FROM prime_ministers AS p1
# LEFT JOIN presidents AS p2
# ON p1.country = p2.country;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 10 rows affected.
# [('Egypt', 'Sherif Ismail', 'Abdel Fattah el-Sisi'),
#  ('Portugal', 'Antonio Costa', 'Marcelo Rebelo de Sousa'),
#  ('Vietnam', 'Nguyen Xuan Phuc', 'Tran Dai Quang'),
#  ('Haiti', 'Jack Guy Lafontant', 'Jovenel Moise'),
#  ('India', 'Narendra Modi', None),
#  ('Australia', 'Malcolm Turnbull', None),
#  ('Norway', 'Erna Solberg', None),
#  ('Brunei', 'Hassanal Bolkiah', None),
#  ('Oman', 'Qaboos bin Said al Said', None),
#  ('Spain', 'Mariano Rajoy', None)]

# %%
# Inner join
# %%sql
SELECT c1.name AS city, code, c2.name AS country,
       region, city_proper_pop
-- specify left table
FROM cities AS c1
-- specify right table and type of join
INNER JOIN countries AS c2
-- how should the tables be matched?
ON c1.country_code = c2.code
-- sort based on descending country code
ORDER BY code DESC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 230 rows affected.
# [('Harare', 'ZWE', 'Zimbabwe', 'Eastern Africa', 1606000.0),
#  ('Lusaka', 'ZMB', 'Zambia', 'Eastern Africa', 1742980.0),
#  ('Cape Town', 'ZAF', 'South Africa', 'Southern Africa', 3740030.0),
#  ('Johannesburg', 'ZAF', 'South Africa', 'Southern Africa', 4434830.0),
#  ('Durban', 'ZAF', 'South Africa', 'Southern Africa', 3442360.0),
#  ('Ekurhuleni', 'ZAF', 'South Africa', 'Southern Africa', 3178470.0),
#  ("Sana'a", 'YEM', 'Yemen', 'Middle East', 1937450.0),
#  ('Ho Chi Minh City', 'VNM', 'Vietnam', 'Southeast Asia', 7681700.0),
#  ('Hanoi', 'VNM', 'Vietnam', 'Southeast Asia', 6844100.0),
#  ('Caracas', 'VEN', 'Venezuela', 'South America', 1943900.0),
#  ('Maracaibo', 'VEN', 'Venezuela', 'South America', 1599940.0),
#  ('Tashkent', 'UZB', 'Uzbekistan', 'Southern and Central Asia', 2309600.0),
#  ('Chicago', 'USA', 'United States', 'North America', 2695600.0),
#  ('Los Angeles', 'USA', 'United States', 'North America', 3884310.0),
#  ('Philadelphia', 'USA', 'United States', 'North America', 1567870.0),
#  ('Phoenix', 'USA', 'United States', 'North America', 1563020.0),
#  ('Dallas', 'USA', 'United States', 'North America', 1317930.0),
#  ('New York City', 'USA', 'United States', 'North America', 8550400.0),
#  ('Houston', 'USA', 'United States', 'North America', 2489560.0),
#  ('San Diego', 'USA', 'United States', 'North America', 1394930.0),
#  ('San Antonio', 'USA', 'United States', 'North America', 1469840.0),
#  ('Montevideo', 'URY', 'Uruguay', 'South America', 1305080.0),
#  ('Kiev', 'UKR', 'Ukraine', 'Eastern Europe', 2908700.0),
#  ('Kharkov', 'UKR', 'Ukraine', 'Eastern Europe', 1439570.0),
#  ('Kampala', 'UGA', 'Uganda', 'Eastern Africa', 1507080.0),
#  ('Dar es Salaam', 'TZA', 'Tanzania', 'Eastern Africa', 4364540.0),
#  ('Ankara', 'TUR', 'Turkey', 'Middle East', 5271000.0),
#  ('Izmir', 'TUR', 'Turkey', 'Middle East', 4168000.0),
#  ('Istanbul', 'TUR', 'Turkey', 'Middle East', 14025000.0),
#  ('Tunis', 'TUN', 'Tunisia', 'Northern Africa', 1056250.0),
#  ('Bangkok', 'THA', 'Thailand', 'Southeast Asia', 8280920.0),
#  ('Singapore', 'SGP', 'Singapore', 'Southeast Asia', 5535000.0),
#  ('Dakar', 'SEN', 'Senegal', 'Western Africa', 1146050.0),
#  ('Khartoum', 'SDN', 'Sudan', 'Northern Africa', 3639600.0),
#  ('Riyadh', 'SAU', 'Saudi Arabia', 'Middle East', 5676620.0),
#  ('Jeddah', 'SAU', 'Saudi Arabia', 'Middle East', 3456260.0),
#  ('Yekaterinburg', 'RUS', 'Russian Federation', 'Eastern Europe', 1428040.0),
#  ('Nizhny Novgorod', 'RUS', 'Russian Federation', 'Eastern Europe', 1250620.0),
#  ('Moscow', 'RUS', 'Russian Federation', 'Eastern Europe', 12197600.0),
#  ('Rostov-on-Don', 'RUS', 'Russian Federation', 'Eastern Europe', 1119900.0),
#  ('Omsk', 'RUS', 'Russian Federation', 'Eastern Europe', 1154120.0),
#  ('Novosibirsk', 'RUS', 'Russian Federation', 'Eastern Europe', 1567090.0),
#  ('Saint Petersburg', 'RUS', 'Russian Federation', 'Eastern Europe', 5191690.0),
#  ('Pyongyang', 'PRK', 'North Korea', 'Eastern Asia', 3255390.0),
#  ('Warsaw', 'POL', 'Poland', 'Eastern Europe', 1753980.0),
#  ('Quezon City', 'PHL', 'Philippines', 'Southeast Asia', 2936120.0),
#  ('Manila', 'PHL', 'Philippines', 'Southeast Asia', 1780150.0),
#  ('Caloocan', 'PHL', 'Philippines', 'Southeast Asia', 1583980.0),
#  ('Davao City', 'PHL', 'Philippines', 'Southeast Asia', 1632990.0),
#  ('Lima', 'PER', 'Peru', 'South America', 8852000.0),
#  ('Multan', 'PAK', 'Pakistan', 'Southern and Central Asia', 3117000.0),
#  ('Hyderabad', 'PAK', 'Pakistan', 'Southern and Central Asia', 3429470.0),
#  ('Islamabad', 'PAK', 'Pakistan', 'Southern and Central Asia', 1900000.0),
#  ('Rawalpindi', 'PAK', 'Pakistan', 'Southern and Central Asia', 3198910.0),
#  ('Karachi', 'PAK', 'Pakistan', 'Southern and Central Asia', 27506000.0),
#  ('Gujranwala', 'PAK', 'Pakistan', 'Southern and Central Asia', 2700000.0),
#  ('Lahore', 'PAK', 'Pakistan', 'Southern and Central Asia', 10355000.0),
#  ('Faisalabad', 'PAK', 'Pakistan', 'Southern and Central Asia', 6480760.0),
#  ('Peshawar', 'PAK', 'Pakistan', 'Southern and Central Asia', 3201000.0),
#  ('Auckland', 'NZL', 'New Zealand', 'Australia and New Zealand', 1495000.0),
#  ('Managua', 'NIC', 'Nicaragua', 'Central America', 2560790.0),
#  ('Lagos', 'NGA', 'Nigeria', 'Western Africa', 16060300.0),
#  ('Abuja', 'NGA', 'Nigeria', 'Western Africa', 1235880.0),
#  ('Ibadan', 'NGA', 'Nigeria', 'Western Africa', 1338660.0),
#  ('Kano', 'NGA', 'Nigeria', 'Western Africa', 2153220.0),
#  ('Kuala Lumpur', 'MYS', 'Malaysia', 'Southeast Asia', 1768000.0),
#  ('Maputo', 'MOZ', 'Mozambique', 'Eastern Africa', 1766180.0),
#  ('Yangon', 'MMR', 'Myanmar', 'Southeast Asia', 5214000.0),
#  ('Mandalay', 'MMR', 'Myanmar', 'Southeast Asia', 1319450.0),
#  ('Tijuana', 'MEX', 'Mexico', 'Central America', 1696920.0),
#  ('Monterrey', 'MEX', 'Mexico', 'Central America', 1130960.0),
#  ('Guadalajara', 'MEX', 'Mexico', 'Central America', 1495190.0),
#  ('Mexico City', 'MEX', 'Mexico', 'Central America', 8974720.0),
#  ('Casablanca', 'MAR', 'Morocco', 'Northern Africa', 5117830.0),
#  ('Fez', 'MAR', 'Morocco', 'Northern Africa', 1112070.0),
#  ('Tripoli', 'LBY', 'Libya', 'Northern Africa', 1126000.0),
#  ('Kwangju', 'KOR', 'South Korea', 'Eastern Asia', 1477780.0),
#  ('Daegu', 'KOR', 'South Korea', 'Eastern Asia', 2492990.0),
#  ('Daejeon', 'KOR', 'South Korea', 'Eastern Asia', 1535030.0),
#  ('Incheon', 'KOR', 'South Korea', 'Eastern Asia', 2978370.0),
#  ('Ulsan', 'KOR', 'South Korea', 'Eastern Asia', 1163690.0),
#  ('Busan', 'KOR', 'South Korea', 'Eastern Asia', 3510830.0),
#  ('Seoul', 'KOR', 'South Korea', 'Eastern Asia', 9995780.0),
#  ('Phnom Penh', 'KHM', 'Cambodia', 'Southeast Asia', 2234570.0),
#  ('Nairobi', 'KEN', 'Kenya', 'Eastern Africa', 3138370.0),
#  ('Almaty', 'KAZ', 'Kazakhstan', 'Southern and Central Asia', 1703480.0),
#  ('Osaka', 'JPN', 'Japan', 'Eastern Asia', 2691740.0),
#  ('Tokyo', 'JPN', 'Japan', 'Eastern Asia', 13513700.0),
#  ('Kawasaki', 'JPN', 'Japan', 'Eastern Asia', 1496040.0),
#  ('Nagoya', 'JPN', 'Japan', 'Eastern Asia', 2296010.0),
#  ('Hiroshima', 'JPN', 'Japan', 'Eastern Asia', 1196270.0),
#  ('Saitama', 'JPN', 'Japan', 'Eastern Asia', 1226660.0),
#  ('Sapporo', 'JPN', 'Japan', 'Eastern Asia', 1918100.0),
#  ('Kyoto', 'JPN', 'Japan', 'Eastern Asia', 1474570.0),
#  ('Fukuoka', 'JPN', 'Japan', 'Eastern Asia', 1483050.0),
#  ('Yokohama', 'JPN', 'Japan', 'Eastern Asia', 3726170.0),
#  ('Kobe', 'JPN', 'Japan', 'Eastern Asia', 1536500.0),
#  ('Rome', 'ITA', 'Italy', 'Southern Europe', 2877220.0),
#  ('Milan', 'ITA', 'Italy', 'Southern Europe', 1359900.0),
#  ('Baghdad', 'IRQ', 'Iraq', 'Middle East', 7180890.0),
#  ('Basra', 'IRQ', 'Iraq', 'Middle East', 2750000.0),
#  ('Tabriz', 'IRN', 'Iran', 'Southern and Central Asia', 1733030.0),
#  ('Isfahan', 'IRN', 'Iran', 'Southern and Central Asia', 2243250.0),
#  ('Shiraz', 'IRN', 'Iran', 'Southern and Central Asia', 1869000.0),
#  ('Tehran', 'IRN', 'Iran', 'Southern and Central Asia', 8154050.0),
#  ('Karaj', 'IRN', 'Iran', 'Southern and Central Asia', 1973470.0),
#  ('Mashhad', 'IRN', 'Iran', 'Southern and Central Asia', 3312090.0),
#  ('Bengaluru', 'IND', 'India', 'Southern and Central Asia', 8425970.0),
#  ('Bhopal', 'IND', 'India', 'Southern and Central Asia', 1798220.0),
#  ('Patna', 'IND', 'India', 'Southern and Central Asia', 1683200.0),
#  ('Surat', 'IND', 'India', 'Southern and Central Asia', 4462000.0),
#  ('Nagpur', 'IND', 'India', 'Southern and Central Asia', 2405660.0),
#  ('Lucknow', 'IND', 'India', 'Southern and Central Asia', 2815600.0),
#  ('Visakhapatnam', 'IND', 'India', 'Southern and Central Asia', 2035920.0),
#  ('Ahmedabad', 'IND', 'India', 'Southern and Central Asia', 5570580.0),
#  ('Delhi', 'IND', 'India', 'Southern and Central Asia', 16787900.0),
#  ('Pune', 'IND', 'India', 'Southern and Central Asia', 3115430.0),
#  ('Kanpur', 'IND', 'India', 'Southern and Central Asia', 2768060.0),
#  ('Kochi', 'IND', 'India', 'Southern and Central Asia', 2232460.0),
#  ('Kolkata', 'IND', 'India', 'Southern and Central Asia', 4486680.0),
#  ('Jaipur', 'IND', 'India', 'Southern and Central Asia', 3073350.0),
#  ('Vijayawada', 'IND', 'India', 'Southern and Central Asia', 1491200.0),
#  ('Hyderabad (India)', 'IND', 'India', 'Southern and Central Asia', 7859250.0),
#  ('Chennai', 'IND', 'India', 'Southern and Central Asia', 7088000.0),
#  ('Mumbai', 'IND', 'India', 'Southern and Central Asia', 12478400.0),
#  ('Surabaya', 'IDN', 'Indonesia', 'Southeast Asia', 2765490.0),
#  ('Palembang', 'IDN', 'Indonesia', 'Southeast Asia', 1708410.0),
#  ('Makassar', 'IDN', 'Indonesia', 'Southeast Asia', 1338630.0),
#  ('Jakarta', 'IDN', 'Indonesia', 'Southeast Asia', 10075300.0),
#  ('Medan', 'IDN', 'Indonesia', 'Southeast Asia', 2097610.0),
#  ('Semarang', 'IDN', 'Indonesia', 'Southeast Asia', 1555980.0),
#  ('Bandung', 'IDN', 'Indonesia', 'Southeast Asia', 2575480.0),
#  ('Budapest', 'HUN', 'Hungary', 'Eastern Europe', 1759410.0),
#  ('Guatemala City', 'GTM', 'Guatemala', 'Central America', 2110100.0),
#  ('Accra', 'GHA', 'Ghana', 'Western Africa', 2070460.0),
#  ("T'bilisi", 'GEO', 'Georgia', 'Middle East', 1118040.0),
#  ('Birmingham', 'GBR', 'United Kingdom', 'British Islands', 1111300.0),
#  ('London', 'GBR', 'United Kingdom', 'British Islands', 8673710.0),
#  ('Paris', 'FRA', 'France', 'Western Europe', 2229620.0),
#  ('Addis Ababa', 'ETH', 'Ethiopia', 'Eastern Africa', 3103670.0),
#  ('Barcelona', 'ESP', 'Spain', 'Southern Europe', 1604560.0),
#  ('Madrid', 'ESP', 'Spain', 'Southern Europe', 3207250.0),
#  ('Cairo', 'EGY', 'Egypt', 'Northern Africa', 10230400.0),
#  ('Giza', 'EGY', 'Egypt', 'Northern Africa', 4239990.0),
#  ('Alexandria', 'EGY', 'Egypt', 'Northern Africa', 4616620.0),
#  ('Guayaquil', 'ECU', 'Ecuador', 'South America', 3600000.0),
#  ('Quito', 'ECU', 'Ecuador', 'South America', 2671190.0),
#  ('Oran', 'DZA', 'Algeria', 'Northern Africa', 1560330.0),
#  ('Algiers', 'DZA', 'Algeria', 'Northern Africa', 3415810.0),
#  ('Hamburg', 'DEU', 'Germany', 'Western Europe', 1787410.0),
#  ('Munich', 'DEU', 'Germany', 'Western Europe', 1450380.0),
#  ('Berlin', 'DEU', 'Germany', 'Western Europe', 3517420.0),
#  ('Cologne', 'DEU', 'Germany', 'Western Europe', 1057330.0),
#  ('Prague', 'CZE', 'Czech Republic', 'Eastern Europe', 1324000.0),
#  ('Havana', 'CUB', 'Cuba', 'Caribbean', 2106150.0),
#  ('Bogota', 'COL', 'Colombia', 'South America', 7878780.0),
#  ('Medellin', 'COL', 'Colombia', 'South America', 2441120.0),
#  ('Cali', 'COL', 'Colombia', 'South America', 2400650.0),
#  ('Barranquilla', 'COL', 'Colombia', 'South America', 1386860.0),
#  ('Brazzaville', 'COG', 'Congo', 'Central Africa', 1827000.0),
#  ('Kinshasa', 'COD', 'Congo, The Democratic Republic of the', 'Central Africa', 10130000.0),
#  ('Douala', 'CMR', 'Cameroon', 'Central Africa', 2446940.0),
#  ('Yaounde', 'CMR', 'Cameroon', 'Central Africa', 2440460.0),
#  ('Abidjan', 'CIV', "Cote d'Ivoire", 'Western Africa', 4765000.0),
#  ('Qingdao', 'CHN', 'China', 'Eastern Asia', 6188100.0),
#  ('Quanzhou', 'CHN', 'China', 'Eastern Asia', 8128530.0),
#  ('Fuzhou', 'CHN', 'China', 'Eastern Asia', 7115370.0),
#  ('Foshan', 'CHN', 'China', 'Eastern Asia', 6151620.0),
#  ('Dongguan', 'CHN', 'China', 'Eastern Asia', 8220210.0),
#  ('Ningbo', 'CHN', 'China', 'Eastern Asia', 3491600.0),
#  ('Dalian', 'CHN', 'China', 'Eastern Asia', 2146100.0),
#  ('Nanjing', 'CHN', 'China', 'Eastern Asia', 8230000.0),
#  ('Hangzhou', 'CHN', 'China', 'Eastern Asia', 3560390.0),
#  ('Chongqing', 'CHN', 'China', 'Eastern Asia', 8189800.0),
#  ('Chengdu', 'CHN', 'China', 'Eastern Asia', 4741930.0),
#  ('Chaozhou', 'CHN', 'China', 'Eastern Asia', 2669840.0),
#  ('Changsha', 'CHN', 'China', 'Eastern Asia', 7044120.0),
#  ('Changchun', 'CHN', 'China', 'Eastern Asia', 3815270.0),
#  ('Zhongshan', 'CHN', 'China', 'Eastern Asia', 3121280.0),
#  ('Harbin', 'CHN', 'China', 'Eastern Asia', 4280700.0),
#  ('Shanghai', 'CHN', 'China', 'Eastern Asia', 24256800.0),
#  ('Shantou', 'CHN', 'China', 'Eastern Asia', 5391030.0),
#  ('Shenyang', 'CHN', 'China', 'Eastern Asia', 8106170.0),
#  ('Shenzhen', 'CHN', 'China', 'Eastern Asia', 10778900.0),
#  ('Shijiazhuang', 'CHN', 'China', 'Eastern Asia', 4303700.0),
#  ('Suzhou', 'CHN', 'China', 'Eastern Asia', 10650500.0),
#  ('Hefei', 'CHN', 'China', 'Eastern Asia', 3352080.0),
#  ('Tangshan', 'CHN', 'China', 'Eastern Asia', 3187170.0),
#  ('Hong Kong', 'CHN', 'China', 'Eastern Asia', 7374900.0),
#  ('Jinan', 'CHN', 'China', 'Eastern Asia', 2009270.0),
#  ('Tianjin', 'CHN', 'China', 'Eastern Asia', 6859780.0),
#  ('Beijing', 'CHN', 'China', 'Eastern Asia', 21516000.0),
#  ('Zunyi', 'CHN', 'China', 'Eastern Asia', 6127010.0),
#  ('Wenzhou', 'CHN', 'China', 'Eastern Asia', 3039440.0),
#  ('Wuhan', 'CHN', 'China', 'Eastern Asia', 6886250.0),
#  ("Xi'an", 'CHN', 'China', 'Eastern Asia', 8705600.0),
#  ('Xiamen', 'CHN', 'China', 'Eastern Asia', 3531350.0),
#  ('Lanzhou', 'CHN', 'China', 'Eastern Asia', 2177130.0),
#  ('Zhengzhou', 'CHN', 'China', 'Eastern Asia', 4122090.0),
#  ('Guangzhou', 'CHN', 'China', 'Eastern Asia', 14043500.0),
#  ('Santiago', 'CHL', 'Chile', 'South America', 5743720.0),
#  ('Calgary', 'CAN', 'Canada', 'North America', 1235170.0),
#  ('Montreal', 'CAN', 'Canada', 'North America', 1649520.0),
#  ('Toronto', 'CAN', 'Canada', 'North America', 2731570.0),
#  ('Brasilia', 'BRA', 'Brazil', 'South America', 2556150.0),
#  ('Porto Alegre', 'BRA', 'Brazil', 'South America', 1476870.0),
#  ('Curitiba', 'BRA', 'Brazil', 'South America', 1879360.0),
#  ('Recife', 'BRA', 'Brazil', 'South America', 1555040.0),
#  ('Rio de Janeiro', 'BRA', 'Brazil', 'South America', 6429920.0),
#  ('Fortaleza', 'BRA', 'Brazil', 'South America', 2609720.0),
#  ('Salvador', 'BRA', 'Brazil', 'South America', 2902930.0),
#  ('Campinas', 'BRA', 'Brazil', 'South America', 1164100.0),
#  ('Sao Paulo', 'BRA', 'Brazil', 'South America', 12038200.0),
#  ('Belo Horizonte', 'BRA', 'Brazil', 'South America', 2502560.0),
#  ('Santa Cruz de la Sierra', 'BOL', 'Bolivia', 'South America', 1453550.0),
#  ('Minsk', 'BLR', 'Belarus', 'Eastern Europe', 1959780.0),
#  ('Chittagong', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2581640.0),
#  ('Dhaka', 'BGD', 'Bangladesh', 'Southern and Central Asia', 14543100.0),
#  ('Ouagadougou', 'BFA', 'Burkina Faso', 'Western Africa', 2200000.0),
#  ('Baku', 'AZE', 'Azerbaijan', 'Middle East', 3202300.0),
#  ('Vienna', 'AUT', 'Austria', 'Western Europe', 1863880.0),
#  ('Brisbane', 'AUS', 'Australia', 'Australia and New Zealand', 1180280.0),
#  ('Yerevan', 'ARM', 'Armenia', 'Middle East', 1060140.0),
#  ('Rosario', 'ARG', 'Argentina', 'South America', 1193600.0),
#  ('Cordoba', 'ARG', 'Argentina', 'South America', 1330020.0),
#  ('Buenos Aires', 'ARG', 'Argentina', 'South America', 3054300.0),
#  ('Abu Dhabi', 'ARE', 'United Arab Emirates', 'Middle East', 1145000.0),
#  ('Dubai', 'ARE', 'United Arab Emirates', 'Middle East', 2643410.0),
#  ('Luanda', 'AGO', 'Angola', 'Central Africa', 2825310.0),
#  ('Kabul', 'AFG', 'Afghanistan', 'Southern and Central Asia', 3414100.0)]

# %%
# %%sql
# SELECT c1.name AS city, code, c2.name AS country,
#        region, city_proper_pop
# -- specify left table
# FROM cities AS c1
# -- specify right table and type of join
# LEFT JOIN countries AS c2
# -- how should the tables be matched?
# ON c1.country_code = c2.code
# -- sort based on descending country code
# ORDER BY code DESC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 236 rows affected.
# [('Taichung', None, None, None, 2752410.0),
#  ('Tainan', None, None, None, 1885250.0),
#  ('Kaohsiung', None, None, None, 2778920.0),
#  ('Bucharest', None, None, None, 1883420.0),
#  ('Taipei', None, None, None, 2704970.0),
#  ('New Taipei City', None, None, None, 3954930.0),
#  ('Harare', 'ZWE', 'Zimbabwe', 'Eastern Africa', 1606000.0),
#  ('Lusaka', 'ZMB', 'Zambia', 'Eastern Africa', 1742980.0),
#  ('Cape Town', 'ZAF', 'South Africa', 'Southern Africa', 3740030.0),
#  ('Ekurhuleni', 'ZAF', 'South Africa', 'Southern Africa', 3178470.0),
#  ('Durban', 'ZAF', 'South Africa', 'Southern Africa', 3442360.0),
#  ('Johannesburg', 'ZAF', 'South Africa', 'Southern Africa', 4434830.0),
#  ("Sana'a", 'YEM', 'Yemen', 'Middle East', 1937450.0),
#  ('Hanoi', 'VNM', 'Vietnam', 'Southeast Asia', 6844100.0),
#  ('Ho Chi Minh City', 'VNM', 'Vietnam', 'Southeast Asia', 7681700.0),
#  ('Maracaibo', 'VEN', 'Venezuela', 'South America', 1599940.0),
#  ('Caracas', 'VEN', 'Venezuela', 'South America', 1943900.0),
#  ('Tashkent', 'UZB', 'Uzbekistan', 'Southern and Central Asia', 2309600.0),
#  ('Dallas', 'USA', 'United States', 'North America', 1317930.0),
#  ('San Diego', 'USA', 'United States', 'North America', 1394930.0),
#  ('New York City', 'USA', 'United States', 'North America', 8550400.0),
#  ('Philadelphia', 'USA', 'United States', 'North America', 1567870.0),
#  ('Los Angeles', 'USA', 'United States', 'North America', 3884310.0),
#  ('Houston', 'USA', 'United States', 'North America', 2489560.0),
#  ('Phoenix', 'USA', 'United States', 'North America', 1563020.0),
#  ('San Antonio', 'USA', 'United States', 'North America', 1469840.0),
#  ('Chicago', 'USA', 'United States', 'North America', 2695600.0),
#  ('Montevideo', 'URY', 'Uruguay', 'South America', 1305080.0),
#  ('Kharkov', 'UKR', 'Ukraine', 'Eastern Europe', 1439570.0),
#  ('Kiev', 'UKR', 'Ukraine', 'Eastern Europe', 2908700.0),
#  ('Kampala', 'UGA', 'Uganda', 'Eastern Africa', 1507080.0),
#  ('Dar es Salaam', 'TZA', 'Tanzania', 'Eastern Africa', 4364540.0),
#  ('Istanbul', 'TUR', 'Turkey', 'Middle East', 14025000.0),
#  ('Izmir', 'TUR', 'Turkey', 'Middle East', 4168000.0),
#  ('Ankara', 'TUR', 'Turkey', 'Middle East', 5271000.0),
#  ('Tunis', 'TUN', 'Tunisia', 'Northern Africa', 1056250.0),
#  ('Bangkok', 'THA', 'Thailand', 'Southeast Asia', 8280920.0),
#  ('Singapore', 'SGP', 'Singapore', 'Southeast Asia', 5535000.0),
#  ('Dakar', 'SEN', 'Senegal', 'Western Africa', 1146050.0),
#  ('Khartoum', 'SDN', 'Sudan', 'Northern Africa', 3639600.0),
#  ('Riyadh', 'SAU', 'Saudi Arabia', 'Middle East', 5676620.0),
#  ('Jeddah', 'SAU', 'Saudi Arabia', 'Middle East', 3456260.0),
#  ('Novosibirsk', 'RUS', 'Russian Federation', 'Eastern Europe', 1567090.0),
#  ('Yekaterinburg', 'RUS', 'Russian Federation', 'Eastern Europe', 1428040.0),
#  ('Moscow', 'RUS', 'Russian Federation', 'Eastern Europe', 12197600.0),
#  ('Saint Petersburg', 'RUS', 'Russian Federation', 'Eastern Europe', 5191690.0),
#  ('Rostov-on-Don', 'RUS', 'Russian Federation', 'Eastern Europe', 1119900.0),
#  ('Omsk', 'RUS', 'Russian Federation', 'Eastern Europe', 1154120.0),
#  ('Nizhny Novgorod', 'RUS', 'Russian Federation', 'Eastern Europe', 1250620.0),
#  ('Pyongyang', 'PRK', 'North Korea', 'Eastern Asia', 3255390.0),
#  ('Warsaw', 'POL', 'Poland', 'Eastern Europe', 1753980.0),
#  ('Quezon City', 'PHL', 'Philippines', 'Southeast Asia', 2936120.0),
#  ('Davao City', 'PHL', 'Philippines', 'Southeast Asia', 1632990.0),
#  ('Caloocan', 'PHL', 'Philippines', 'Southeast Asia', 1583980.0),
#  ('Manila', 'PHL', 'Philippines', 'Southeast Asia', 1780150.0),
#  ('Lima', 'PER', 'Peru', 'South America', 8852000.0),
#  ('Multan', 'PAK', 'Pakistan', 'Southern and Central Asia', 3117000.0),
#  ('Gujranwala', 'PAK', 'Pakistan', 'Southern and Central Asia', 2700000.0),
#  ('Peshawar', 'PAK', 'Pakistan', 'Southern and Central Asia', 3201000.0),
#  ('Islamabad', 'PAK', 'Pakistan', 'Southern and Central Asia', 1900000.0),
#  ('Hyderabad', 'PAK', 'Pakistan', 'Southern and Central Asia', 3429470.0),
#  ('Karachi', 'PAK', 'Pakistan', 'Southern and Central Asia', 27506000.0),
#  ('Rawalpindi', 'PAK', 'Pakistan', 'Southern and Central Asia', 3198910.0),
#  ('Lahore', 'PAK', 'Pakistan', 'Southern and Central Asia', 10355000.0),
#  ('Faisalabad', 'PAK', 'Pakistan', 'Southern and Central Asia', 6480760.0),
#  ('Auckland', 'NZL', 'New Zealand', 'Australia and New Zealand', 1495000.0),
#  ('Managua', 'NIC', 'Nicaragua', 'Central America', 2560790.0),
#  ('Abuja', 'NGA', 'Nigeria', 'Western Africa', 1235880.0),
#  ('Lagos', 'NGA', 'Nigeria', 'Western Africa', 16060300.0),
#  ('Kano', 'NGA', 'Nigeria', 'Western Africa', 2153220.0),
#  ('Ibadan', 'NGA', 'Nigeria', 'Western Africa', 1338660.0),
#  ('Kuala Lumpur', 'MYS', 'Malaysia', 'Southeast Asia', 1768000.0),
#  ('Maputo', 'MOZ', 'Mozambique', 'Eastern Africa', 1766180.0),
#  ('Mandalay', 'MMR', 'Myanmar', 'Southeast Asia', 1319450.0),
#  ('Yangon', 'MMR', 'Myanmar', 'Southeast Asia', 5214000.0),
#  ('Tijuana', 'MEX', 'Mexico', 'Central America', 1696920.0),
#  ('Monterrey', 'MEX', 'Mexico', 'Central America', 1130960.0),
#  ('Guadalajara', 'MEX', 'Mexico', 'Central America', 1495190.0),
#  ('Mexico City', 'MEX', 'Mexico', 'Central America', 8974720.0),
#  ('Fez', 'MAR', 'Morocco', 'Northern Africa', 1112070.0),
#  ('Casablanca', 'MAR', 'Morocco', 'Northern Africa', 5117830.0),
#  ('Tripoli', 'LBY', 'Libya', 'Northern Africa', 1126000.0),
#  ('Ulsan', 'KOR', 'South Korea', 'Eastern Asia', 1163690.0),
#  ('Incheon', 'KOR', 'South Korea', 'Eastern Asia', 2978370.0),
#  ('Busan', 'KOR', 'South Korea', 'Eastern Asia', 3510830.0),
#  ('Kwangju', 'KOR', 'South Korea', 'Eastern Asia', 1477780.0),
#  ('Daejeon', 'KOR', 'South Korea', 'Eastern Asia', 1535030.0),
#  ('Seoul', 'KOR', 'South Korea', 'Eastern Asia', 9995780.0),
#  ('Daegu', 'KOR', 'South Korea', 'Eastern Asia', 2492990.0),
#  ('Phnom Penh', 'KHM', 'Cambodia', 'Southeast Asia', 2234570.0),
#  ('Nairobi', 'KEN', 'Kenya', 'Eastern Africa', 3138370.0),
#  ('Almaty', 'KAZ', 'Kazakhstan', 'Southern and Central Asia', 1703480.0),
#  ('Fukuoka', 'JPN', 'Japan', 'Eastern Asia', 1483050.0),
#  ('Nagoya', 'JPN', 'Japan', 'Eastern Asia', 2296010.0),
#  ('Osaka', 'JPN', 'Japan', 'Eastern Asia', 2691740.0),
#  ('Kyoto', 'JPN', 'Japan', 'Eastern Asia', 1474570.0),
#  ('Tokyo', 'JPN', 'Japan', 'Eastern Asia', 13513700.0),
#  ('Saitama', 'JPN', 'Japan', 'Eastern Asia', 1226660.0),
#  ('Kawasaki', 'JPN', 'Japan', 'Eastern Asia', 1496040.0),
#  ('Hiroshima', 'JPN', 'Japan', 'Eastern Asia', 1196270.0),
#  ('Sapporo', 'JPN', 'Japan', 'Eastern Asia', 1918100.0),
#  ('Yokohama', 'JPN', 'Japan', 'Eastern Asia', 3726170.0),
#  ('Kobe', 'JPN', 'Japan', 'Eastern Asia', 1536500.0),
#  ('Milan', 'ITA', 'Italy', 'Southern Europe', 1359900.0),
#  ('Rome', 'ITA', 'Italy', 'Southern Europe', 2877220.0),
#  ('Baghdad', 'IRQ', 'Iraq', 'Middle East', 7180890.0),
#  ('Basra', 'IRQ', 'Iraq', 'Middle East', 2750000.0),
#  ('Isfahan', 'IRN', 'Iran', 'Southern and Central Asia', 2243250.0),
#  ('Mashhad', 'IRN', 'Iran', 'Southern and Central Asia', 3312090.0),
#  ('Karaj', 'IRN', 'Iran', 'Southern and Central Asia', 1973470.0),
#  ('Shiraz', 'IRN', 'Iran', 'Southern and Central Asia', 1869000.0),
#  ('Tabriz', 'IRN', 'Iran', 'Southern and Central Asia', 1733030.0),
#  ('Tehran', 'IRN', 'Iran', 'Southern and Central Asia', 8154050.0),
#  ('Visakhapatnam', 'IND', 'India', 'Southern and Central Asia', 2035920.0),
#  ('Jaipur', 'IND', 'India', 'Southern and Central Asia', 3073350.0),
#  ('Patna', 'IND', 'India', 'Southern and Central Asia', 1683200.0),
#  ('Nagpur', 'IND', 'India', 'Southern and Central Asia', 2405660.0),
#  ('Pune', 'IND', 'India', 'Southern and Central Asia', 3115430.0),
#  ('Delhi', 'IND', 'India', 'Southern and Central Asia', 16787900.0),
#  ('Kanpur', 'IND', 'India', 'Southern and Central Asia', 2768060.0),
#  ('Chennai', 'IND', 'India', 'Southern and Central Asia', 7088000.0),
#  ('Mumbai', 'IND', 'India', 'Southern and Central Asia', 12478400.0),
#  ('Kochi', 'IND', 'India', 'Southern and Central Asia', 2232460.0),
#  ('Kolkata', 'IND', 'India', 'Southern and Central Asia', 4486680.0),
#  ('Surat', 'IND', 'India', 'Southern and Central Asia', 4462000.0),
#  ('Bhopal', 'IND', 'India', 'Southern and Central Asia', 1798220.0),
#  ('Bengaluru', 'IND', 'India', 'Southern and Central Asia', 8425970.0),
#  ('Lucknow', 'IND', 'India', 'Southern and Central Asia', 2815600.0),
#  ('Vijayawada', 'IND', 'India', 'Southern and Central Asia', 1491200.0),
#  ('Hyderabad (India)', 'IND', 'India', 'Southern and Central Asia', 7859250.0),
#  ('Ahmedabad', 'IND', 'India', 'Southern and Central Asia', 5570580.0),
#  ('Surabaya', 'IDN', 'Indonesia', 'Southeast Asia', 2765490.0),
#  ('Medan', 'IDN', 'Indonesia', 'Southeast Asia', 2097610.0),
#  ('Palembang', 'IDN', 'Indonesia', 'Southeast Asia', 1708410.0),
#  ('Semarang', 'IDN', 'Indonesia', 'Southeast Asia', 1555980.0),
#  ('Jakarta', 'IDN', 'Indonesia', 'Southeast Asia', 10075300.0),
#  ('Makassar', 'IDN', 'Indonesia', 'Southeast Asia', 1338630.0),
#  ('Bandung', 'IDN', 'Indonesia', 'Southeast Asia', 2575480.0),
#  ('Budapest', 'HUN', 'Hungary', 'Eastern Europe', 1759410.0),
#  ('Guatemala City', 'GTM', 'Guatemala', 'Central America', 2110100.0),
#  ('Accra', 'GHA', 'Ghana', 'Western Africa', 2070460.0),
#  ("T'bilisi", 'GEO', 'Georgia', 'Middle East', 1118040.0),
#  ('Birmingham', 'GBR', 'United Kingdom', 'British Islands', 1111300.0),
#  ('London', 'GBR', 'United Kingdom', 'British Islands', 8673710.0),
#  ('Paris', 'FRA', 'France', 'Western Europe', 2229620.0),
#  ('Addis Ababa', 'ETH', 'Ethiopia', 'Eastern Africa', 3103670.0),
#  ('Madrid', 'ESP', 'Spain', 'Southern Europe', 3207250.0),
#  ('Barcelona', 'ESP', 'Spain', 'Southern Europe', 1604560.0),
#  ('Giza', 'EGY', 'Egypt', 'Northern Africa', 4239990.0),
#  ('Cairo', 'EGY', 'Egypt', 'Northern Africa', 10230400.0),
#  ('Alexandria', 'EGY', 'Egypt', 'Northern Africa', 4616620.0),
#  ('Guayaquil', 'ECU', 'Ecuador', 'South America', 3600000.0),
#  ('Quito', 'ECU', 'Ecuador', 'South America', 2671190.0),
#  ('Algiers', 'DZA', 'Algeria', 'Northern Africa', 3415810.0),
#  ('Oran', 'DZA', 'Algeria', 'Northern Africa', 1560330.0),
#  ('Cologne', 'DEU', 'Germany', 'Western Europe', 1057330.0),
#  ('Berlin', 'DEU', 'Germany', 'Western Europe', 3517420.0),
#  ('Munich', 'DEU', 'Germany', 'Western Europe', 1450380.0),
#  ('Hamburg', 'DEU', 'Germany', 'Western Europe', 1787410.0),
#  ('Prague', 'CZE', 'Czech Republic', 'Eastern Europe', 1324000.0),
#  ('Havana', 'CUB', 'Cuba', 'Caribbean', 2106150.0),
#  ('Cali', 'COL', 'Colombia', 'South America', 2400650.0),
#  ('Medellin', 'COL', 'Colombia', 'South America', 2441120.0),
#  ('Bogota', 'COL', 'Colombia', 'South America', 7878780.0),
#  ('Barranquilla', 'COL', 'Colombia', 'South America', 1386860.0),
#  ('Brazzaville', 'COG', 'Congo', 'Central Africa', 1827000.0),
#  ('Kinshasa', 'COD', 'Congo, The Democratic Republic of the', 'Central Africa', 10130000.0),
#  ('Douala', 'CMR', 'Cameroon', 'Central Africa', 2446940.0),
#  ('Yaounde', 'CMR', 'Cameroon', 'Central Africa', 2440460.0),
#  ('Abidjan', 'CIV', "Cote d'Ivoire", 'Western Africa', 4765000.0),
#  ('Shijiazhuang', 'CHN', 'China', 'Eastern Asia', 4303700.0),
#  ('Lanzhou', 'CHN', 'China', 'Eastern Asia', 2177130.0),
#  ('Jinan', 'CHN', 'China', 'Eastern Asia', 2009270.0),
#  ('Hong Kong', 'CHN', 'China', 'Eastern Asia', 7374900.0),
#  ('Nanjing', 'CHN', 'China', 'Eastern Asia', 8230000.0),
#  ('Hefei', 'CHN', 'China', 'Eastern Asia', 3352080.0),
#  ('Ningbo', 'CHN', 'China', 'Eastern Asia', 3491600.0),
#  ('Harbin', 'CHN', 'China', 'Eastern Asia', 4280700.0),
#  ('Hangzhou', 'CHN', 'China', 'Eastern Asia', 3560390.0),
#  ('Guangzhou', 'CHN', 'China', 'Eastern Asia', 14043500.0),
#  ('Fuzhou', 'CHN', 'China', 'Eastern Asia', 7115370.0),
#  ('Foshan', 'CHN', 'China', 'Eastern Asia', 6151620.0),
#  ('Qingdao', 'CHN', 'China', 'Eastern Asia', 6188100.0),
#  ('Quanzhou', 'CHN', 'China', 'Eastern Asia', 8128530.0),
#  ('Dongguan', 'CHN', 'China', 'Eastern Asia', 8220210.0),
#  ('Dalian', 'CHN', 'China', 'Eastern Asia', 2146100.0),
#  ('Chongqing', 'CHN', 'China', 'Eastern Asia', 8189800.0),
#  ('Chengdu', 'CHN', 'China', 'Eastern Asia', 4741930.0),
#  ('Chaozhou', 'CHN', 'China', 'Eastern Asia', 2669840.0),
#  ('Changsha', 'CHN', 'China', 'Eastern Asia', 7044120.0),
#  ('Changchun', 'CHN', 'China', 'Eastern Asia', 3815270.0),
#  ('Shanghai', 'CHN', 'China', 'Eastern Asia', 24256800.0),
#  ('Shantou', 'CHN', 'China', 'Eastern Asia', 5391030.0),
#  ('Shenyang', 'CHN', 'China', 'Eastern Asia', 8106170.0),
#  ('Shenzhen', 'CHN', 'China', 'Eastern Asia', 10778900.0),
#  ('Suzhou', 'CHN', 'China', 'Eastern Asia', 10650500.0),
#  ('Tangshan', 'CHN', 'China', 'Eastern Asia', 3187170.0),
#  ('Tianjin', 'CHN', 'China', 'Eastern Asia', 6859780.0),
#  ('Beijing', 'CHN', 'China', 'Eastern Asia', 21516000.0),
#  ('Wenzhou', 'CHN', 'China', 'Eastern Asia', 3039440.0),
#  ('Wuhan', 'CHN', 'China', 'Eastern Asia', 6886250.0),
#  ("Xi'an", 'CHN', 'China', 'Eastern Asia', 8705600.0),
#  ('Xiamen', 'CHN', 'China', 'Eastern Asia', 3531350.0),
#  ('Zhengzhou', 'CHN', 'China', 'Eastern Asia', 4122090.0),
#  ('Zhongshan', 'CHN', 'China', 'Eastern Asia', 3121280.0),
#  ('Zunyi', 'CHN', 'China', 'Eastern Asia', 6127010.0),
#  ('Santiago', 'CHL', 'Chile', 'South America', 5743720.0),
#  ('Calgary', 'CAN', 'Canada', 'North America', 1235170.0),
#  ('Montreal', 'CAN', 'Canada', 'North America', 1649520.0),
#  ('Toronto', 'CAN', 'Canada', 'North America', 2731570.0),
#  ('Curitiba', 'BRA', 'Brazil', 'South America', 1879360.0),
#  ('Rio de Janeiro', 'BRA', 'Brazil', 'South America', 6429920.0),
#  ('Brasilia', 'BRA', 'Brazil', 'South America', 2556150.0),
#  ('Recife', 'BRA', 'Brazil', 'South America', 1555040.0),
#  ('Belo Horizonte', 'BRA', 'Brazil', 'South America', 2502560.0),
#  ('Porto Alegre', 'BRA', 'Brazil', 'South America', 1476870.0),
#  ('Sao Paulo', 'BRA', 'Brazil', 'South America', 12038200.0),
#  ('Fortaleza', 'BRA', 'Brazil', 'South America', 2609720.0),
#  ('Campinas', 'BRA', 'Brazil', 'South America', 1164100.0),
#  ('Salvador', 'BRA', 'Brazil', 'South America', 2902930.0),
#  ('Santa Cruz de la Sierra', 'BOL', 'Bolivia', 'South America', 1453550.0),
#  ('Minsk', 'BLR', 'Belarus', 'Eastern Europe', 1959780.0),
#  ('Dhaka', 'BGD', 'Bangladesh', 'Southern and Central Asia', 14543100.0),
#  ('Chittagong', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2581640.0),
#  ('Ouagadougou', 'BFA', 'Burkina Faso', 'Western Africa', 2200000.0),
#  ('Baku', 'AZE', 'Azerbaijan', 'Middle East', 3202300.0),
#  ('Vienna', 'AUT', 'Austria', 'Western Europe', 1863880.0),
#  ('Brisbane', 'AUS', 'Australia', 'Australia and New Zealand', 1180280.0),
#  ('Yerevan', 'ARM', 'Armenia', 'Middle East', 1060140.0),
#  ('Cordoba', 'ARG', 'Argentina', 'South America', 1330020.0),
#  ('Buenos Aires', 'ARG', 'Argentina', 'South America', 3054300.0),
#  ('Rosario', 'ARG', 'Argentina', 'South America', 1193600.0),
#  ('Abu Dhabi', 'ARE', 'United Arab Emirates', 'Middle East', 1145000.0),
#  ('Dubai', 'ARE', 'United Arab Emirates', 'Middle East', 2643410.0),
#  ('Luanda', 'AGO', 'Angola', 'Central Africa', 2825310.0),
#  ('Kabul', 'AFG', 'Afghanistan', 'Southern and Central Asia', 3414100.0)]

# %%
# %%sql
# /*
# select country name AS country, the country's local name,
# the language name AS language, and
# the percent of the language spoken in the country
# */
# SELECT c.name AS country, local_name, l.name AS language, percent
# -- countries on the left (alias as c)
# FROM countries AS c
# -- inner join with languages (as l) on the right
# INNER JOIN languages AS l
# -- give fields to match on
# ON c.code = l.code
# -- sort by descending country name
# ORDER BY country DESC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 914 rows affected.
# [('Zimbabwe', 'Zimbabwe', 'Shona', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tonga', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tswana', None),
#  ('Zimbabwe', 'Zimbabwe', 'Venda', None),
#  ('Zimbabwe', 'Zimbabwe', 'Xhosa', None),
#  ('Zimbabwe', 'Zimbabwe', 'Sotho', None),
#  ('Zimbabwe', 'Zimbabwe', 'sign', None),
#  ('Zimbabwe', 'Zimbabwe', 'Shangani', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndau', None),
#  ('Zimbabwe', 'Zimbabwe', 'Nambya', None),
#  ('Zimbabwe', 'Zimbabwe', 'Koisan', None),
#  ('Zimbabwe', 'Zimbabwe', 'Kalanga', None),
#  ('Zimbabwe', 'Zimbabwe', 'Chibarwe', None),
#  ('Zimbabwe', 'Zimbabwe', 'Chewa', None),
#  ('Zimbabwe', 'Zimbabwe', 'English', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndebele', None),
#  ('Zambia', 'Zambia', 'Lozi', 5.5),
#  ('Zambia', 'Zambia', 'unspecified', 0.2),
#  ('Zambia', 'Zambia', 'Other', 9.7),
#  ('Zambia', 'Zambia', 'Bisa', 1.0),
#  ('Zambia', 'Zambia', 'Lenje', 1.1),
#  ('Zambia', 'Zambia', 'Namwanga', 1.2),
#  ('Zambia', 'Zambia', 'Mambwe', 1.3),
#  ('Zambia', 'Zambia', 'Luvale', 1.5),
#  ('Zambia', 'Zambia', 'English', 1.7),
#  ('Zambia', 'Zambia', 'Lamba', 1.8),
#  ('Zambia', 'Zambia', 'Lala', 1.8),
#  ('Zambia', 'Zambia', 'Kaonde', 1.8),
#  ('Zambia', 'Zambia', 'Lunda', 1.9),
#  ('Zambia', 'Zambia', 'Tumbuka', 2.5),
#  ('Zambia', 'Zambia', 'Nsenga', 2.9),
#  ('Zambia', 'Zambia', 'Chewa', 4.5),
#  ('Zambia', 'Zambia', 'Tonga', 11.4),
#  ('Zambia', 'Zambia', 'Nyanja', 14.7),
#  ('Zambia', 'Zambia', 'Bembe', 33.4),
#  ('Yemen', 'Al-Yaman', 'Arabic', None),
#  ('Vietnam', 'Viet Nam', 'Other', None),
#  ('Vietnam', 'Viet Nam', 'English', None),
#  ('Vietnam', 'Viet Nam', 'Vietnamese', None),
#  ('Venezuela', 'Venezuela', 'Spanish', None),
#  ('Venezuela', 'Venezuela', 'indigenous', None),
#  ('Vanuatu', 'Vanuatu', 'Other', 0.5),
#  ('Vanuatu', 'Vanuatu', 'French', 0.6),
#  ('Vanuatu', 'Vanuatu', 'English', 2.0),
#  ('Vanuatu', 'Vanuatu', 'Bislama', 33.7),
#  ('Vanuatu', 'Vanuatu', 'Tribal Languages', 63.2),
#  ('Uzbekistan', 'Uzbekiston', 'Uzbek', 74.3),
#  ('Uzbekistan', 'Uzbekiston', 'Russian', 14.2),
#  ('Uzbekistan', 'Uzbekiston', 'Other', 7.1),
#  ('Uzbekistan', 'Uzbekiston', 'Tajik', 4.4),
#  ('Uruguay', 'Uruguay', 'Brazilero', None),
#  ('Uruguay', 'Uruguay', 'Spanish', None),
#  ('Uruguay', 'Uruguay', 'Portunol', None),
#  ('United States', 'United States', 'Other', 8.0),
#  ('United States', 'United States', 'Spanish', 12.9),
#  ('United States', 'United States', 'English', 79.2),
#  ('United Kingdom', 'United Kingdom', 'English', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Arabic', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Urdu', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Hindi', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'English', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Persian', None),
#  ('Ukraine', 'Ukrajina', 'Russian', 29.6),
#  ('Ukraine', 'Ukrajina', 'Other', 2.9),
#  ('Ukraine', 'Ukrajina', 'Ukrainian', 67.5),
#  ('Uganda', 'Uganda', 'Ganda', None),
#  ('Uganda', 'Uganda', 'Arabic', None),
#  ('Uganda', 'Uganda', 'Swahili', None),
#  ('Uganda', 'Uganda', 'Nilo', None),
#  ('Uganda', 'Uganda', 'Other', None),
#  ('Uganda', 'Uganda', 'English', None),
#  ('Tuvalu', 'Tuvalu', 'Tuvaluan', None),
#  ('Tuvalu', 'Tuvalu', 'Kiribati', None),
#  ('Tuvalu', 'Tuvalu', 'Samoan', None),
#  ('Tuvalu', 'Tuvalu', 'English', None),
#  ('Turks and Caicos Islands', 'The Turks and Caicos Islands', 'English', None),
#  ('Turkmenistan', 'Turkmenostan', 'Russian', 12.0),
#  ('Turkmenistan', 'Turkmenostan', 'Other', 7.0),
#  ('Turkmenistan', 'Turkmenostan', 'Uzbek', 9.0),
#  ('Turkmenistan', 'Turkmenostan', 'Turkmen', 72.0),
#  ('Turkey', 'Turkiye', 'Kurdish', None),
#  ('Turkey', 'Turkiye', 'Other', None),
#  ('Turkey', 'Turkiye', 'Turkish', None),
#  ('Tunisia', 'Tunis/Tunisie', 'French', None),
#  ('Tunisia', 'Tunis/Tunisie', 'Arabic', None),
#  ('Tunisia', 'Tunis/Tunisie', 'Berber', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'French', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'English', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'Caribbean Hindustani', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'Chinese', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'Spanish', None),
#  ('Tonga', 'Tonga', 'English', None),
#  ('Tonga', 'Tonga', 'unspecified', 0.03),
#  ('Tonga', 'Tonga', 'Other', 1.1),
#  ('Tonga', 'Tonga', 'Tongan', None),
#  ('Togo', 'Togo', 'Ewe', None),
#  ('Togo', 'Togo', 'Dagomba', None),
#  ('Togo', 'Togo', 'Mina', None),
#  ('Togo', 'Togo', 'Kabye', None),
#  ('Togo', 'Togo', 'French', None),
#  ('Thailand', 'Prathet Thai', 'Burmese', 1.3),
#  ('Thailand', 'Prathet Thai', 'Other', 8.0),
#  ('Thailand', 'Prathet Thai', 'Thai', 90.7),
#  ('Tanzania', 'Tanzania', 'Kiswahili', None),
#  ('Tanzania', 'Tanzania', 'many', None),
#  ('Tanzania', 'Tanzania', 'Arabic', None),
#  ('Tanzania', 'Tanzania', 'English', None),
#  ('Tajikistan', 'Tocikiston', 'Tajik', None),
#  ('Tajikistan', 'Tocikiston', 'Russian', None),
#  ('Syria', 'Suriya', 'Armenian', None),
#  ('Syria', 'Suriya', 'English', None),
#  ('Syria', 'Suriya', 'French', None),
#  ('Syria', 'Suriya', 'Circassian', None),
#  ('Syria', 'Suriya', 'Aramaic', None),
#  ('Syria', 'Suriya', 'Kurdish', None),
#  ('Syria', 'Suriya', 'Arabic', None),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'German', 63.0),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Romansch', 0.5),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Spanish', 2.2),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Other', 7.1),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Serbo-Croatian', 2.4),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Albanian', 3.0),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Portuguese', 3.7),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'English', 4.9),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Italian', 8.1),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'French', 22.7),
#  ('Sweden', 'Sverige', 'Swedish', None),
#  ('Swaziland', 'kaNgwane', 'siSwati', None),
#  ('Swaziland', 'kaNgwane', 'English', None),
#  ('Suriname', 'Suriname', 'English', None),
#  ('Suriname', 'Suriname', 'Javanese', None),
#  ('Suriname', 'Suriname', 'Caribbean Hindustani', None),
#  ('Suriname', 'Suriname', 'Sranang Tongo', None),
#  ('Suriname', 'Suriname', 'Dutch', None),
#  ('Sudan', 'As-Sudan', 'Arabic', None),
#  ('Sudan', 'As-Sudan', 'Fur', None),
#  ('Sudan', 'As-Sudan', 'Ta Bedawie', None),
#  ('Sudan', 'As-Sudan', 'Nubian', None),
#  ('Sudan', 'As-Sudan', 'English', None),
#  ('Sri Lanka', 'Sri Lanka/Ilankai', 'Tamil', 18.0),
#  ('Sri Lanka', 'Sri Lanka/Ilankai', 'Other', 8.0),
#  ('Sri Lanka', 'Sri Lanka/Ilankai', 'Sinhala', 74.0),
#  ('Spain', 'Espana', 'Basque', 2.0),
#  ('Spain', 'Espana', 'Catalan', 17.0),
#  ('Spain', 'Espana', 'Castilian Spanish', 74.0),
#  ('Spain', 'Espana', 'Aranese', None),
#  ('Spain', 'Espana', 'Galician', 7.0),
#  ('South Korea', 'Taehan Min\x92guk (Namhan)', 'English', None),
#  ('South Korea', 'Taehan Min\x92guk (Namhan)', 'Korean', None),
#  ('South Africa', 'South Africa', 'Setswana', 8.0),
#  ('South Africa', 'South Africa', 'Sepedi', 9.1),
#  ('South Africa', 'South Africa', 'English', 9.6),
#  ('South Africa', 'South Africa', 'Afrikaans', 13.5),
#  ('South Africa', 'South Africa', 'IsiXhosa', 16.0),
#  ('South Africa', 'South Africa', 'IsiZulu', 22.7),
#  ('South Africa', 'South Africa', 'Sesotho', 7.6),
#  ('South Africa', 'South Africa', 'Other', 1.6),
#  ('South Africa', 'South Africa', 'sign', 0.5),
#  ('South Africa', 'South Africa', 'isiNdebele', 2.1),
#  ('South Africa', 'South Africa', 'Tshivenda', 2.4),
#  ('South Africa', 'South Africa', 'siSwati', 2.5),
#  ('South Africa', 'South Africa', 'Xitsonga', 4.5),
#  ('Somalia', 'Soomaaliya', 'English', None),
#  ('Somalia', 'Soomaaliya', 'Italian', None),
#  ('Somalia', 'Soomaaliya', 'Arabic', None),
#  ('Somalia', 'Soomaaliya', 'Somali', None),
#  ('Solomon Islands', 'Solomon Islands', 'indigenous', None),
#  ('Solomon Islands', 'Solomon Islands', 'Melanesian pidgin', None),
#  ('Solomon Islands', 'Solomon Islands', 'English', 1.0),
#  ('Slovenia', 'Slovenija', 'Serbo', 4.5),
#  ('Slovenia', 'Slovenija', 'Hungarian', None),
#  ('Slovenia', 'Slovenija', 'Italian', None),
#  ('Slovenia', 'Slovenija', 'Other', 4.4),
#  ('Slovenia', 'Slovenija', 'Slovenian', 91.1),
#  ('Slovakia', 'Slovensko', 'Other', 8.8),
#  ('Slovakia', 'Slovensko', 'Ruthenian', 1.0),
#  ('Slovakia', 'Slovensko', 'Roma', 2.3),
#  ('Slovakia', 'Slovensko', 'Hungarian', 9.4),
#  ('Slovakia', 'Slovensko', 'Slovak', 78.6),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Other', 1.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Other Chinese', 1.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Other Indian', 1.2),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Teochew', 3.2),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Tamil', 3.2),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Cantonese', 4.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Hokkien', 8.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Malay', 11.9),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'English', 29.8),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Mandarin', 36.3),
#  ('Sierra Leone', 'Sierra Leone', 'Krio', 10.0),
#  ('Sierra Leone', 'Sierra Leone', 'Temne', None),
#  ('Sierra Leone', 'Sierra Leone', 'Mende', None),
#  ('Sierra Leone', 'Sierra Leone', 'English', None),
#  ('Seychelles', 'Sesel/Seychelles', 'unspecified', 1.4),
#  ('Seychelles', 'Sesel/Seychelles', 'Other', 3.8),
#  ('Seychelles', 'Sesel/Seychelles', 'French', 0.7),
#  ('Seychelles', 'Sesel/Seychelles', 'English', 5.1),
#  ('Seychelles', 'Sesel/Seychelles', 'Seychellois', 89.1),
#  ('Senegal', 'Senegal/Sounougal', 'Soninke', None),
#  ('Senegal', 'Senegal/Sounougal', 'Serer', None),
#  ('Senegal', 'Senegal/Sounougal', 'Mandinka', None),
#  ('Senegal', 'Senegal/Sounougal', 'Jola', None),
#  ('Senegal', 'Senegal/Sounougal', 'Pular', None),
#  ('Senegal', 'Senegal/Sounougal', 'Wolof', None),
#  ('Senegal', 'Senegal/Sounougal', 'French', None),
#  ('Saudi Arabia', 'Al-´Arabiya as-Sa´udiya', 'Arabic', None),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Other', 2.4),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Lunguie', 1.0),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'English', 4.9),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Angolar', 6.6),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'French', 6.8),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Cabo', 8.5),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Forro', 36.2),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Portuguese', 98.4),
#  ('San Marino', 'San Marino', 'Italian', None),
#  ('Samoa', 'Samoa', 'English', None),
#  ('Samoa', 'Samoa', 'Samoan', None),
#  ('Saint Vincent and the Grenadines', 'Saint Vincent and the Grenadines', 'French patois', None),
#  ('Saint Vincent and the Grenadines', 'Saint Vincent and the Grenadines', 'English', None),
#  ('Saint Lucia', 'Saint Lucia', 'French patois', None),
#  ('Saint Lucia', 'Saint Lucia', 'English', None),
#  ('Saint Kitts and Nevis', 'Saint Kitts and Nevis', 'English', None),
#  ('Rwanda', 'Rwanda/Urwanda', 'unspecified', 0.3),
#  ('Rwanda', 'Rwanda/Urwanda', 'Other', 0.03),
#  ('Rwanda', 'Rwanda/Urwanda', 'Swahili', 0.02),
#  ('Rwanda', 'Rwanda/Urwanda', 'English', 0.1),
#  ('Rwanda', 'Rwanda/Urwanda', 'Kinyarwanda', 99.4),
#  ('Rwanda', 'Rwanda/Urwanda', 'French', 0.1),
#  ('Russian Federation', 'Rossija', 'Chechen', 1.0),
#  ('Russian Federation', 'Rossija', 'Other', 10.1),
#  ('Russian Federation', 'Rossija', 'Tatar', 3.2),
#  ('Russian Federation', 'Rossija', 'Russian', 85.7),
#  ('Qatar', 'Qatar', 'Arabic', None),
#  ('Qatar', 'Qatar', 'English', None),
#  ('Puerto Rico', 'Puerto Rico', 'Spanish', None),
#  ('Puerto Rico', 'Puerto Rico', 'English', None),
#  ('Portugal', 'Portugal', 'Portuguese', None),
#  ('Portugal', 'Portugal', 'Mirandese', None),
#  ('Poland', 'Polska', 'Polish', 98.2),
#  ('Poland', 'Polska', 'unspecified', 1.3),
#  ('Poland', 'Polska', 'Other', 1.1),
#  ('Poland', 'Polska', 'Silesian', 1.4),
#  ('Philippines', 'Pilipinas', 'Filipino', None),
#  ('Philippines', 'Pilipinas', 'Other', None),
#  ('Philippines', 'Pilipinas', 'English', None),
#  ('Peru', 'Peru/Piruw', 'Other', 0.2),
#  ('Peru', 'Peru/Piruw', 'Other Native', 0.7),
#  ('Peru', 'Peru/Piruw', 'Ashaninka', 0.3),
#  ('Peru', 'Peru/Piruw', 'Aymara', 1.7),
#  ('Peru', 'Peru/Piruw', 'Quechua', 13.0),
#  ('Peru', 'Peru/Piruw', 'Spanish', 84.1),
#  ('Paraguay', 'Paraguay', 'Guarani', None),
#  ('Paraguay', 'Paraguay', 'Spanish', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'Other', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'Hiri', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'English', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'Tok Pisin', None),
#  ('Panama', 'Panama', 'English', None),
#  ('Panama', 'Panama', 'Japanese', None),
#  ('Panama', 'Panama', 'Korean', None),
#  ('Panama', 'Panama', 'Hebrew', None),
#  ('Panama', 'Panama', 'Other', None),
#  ('Panama', 'Panama', 'French', None),
#  ('Panama', 'Panama', 'Arabic', None),
#  ('Panama', 'Panama', 'Chinese', None),
#  ('Panama', 'Panama', 'Panamanian English Creole', None),
#  ('Panama', 'Panama', 'indigenous', None),
#  ('Panama', 'Panama', 'Spanish', None),
#  ('Palau', 'Belau/Palau', 'Other', 2.8),
#  ('Palau', 'Belau/Palau', 'Chinese', 1.2),
#  ('Palau', 'Belau/Palau', 'Filipino', 9.9),
#  ('Palau', 'Belau/Palau', 'English', 19.1),
#  ('Palau', 'Belau/Palau', 'Other', 1.9),
#  ('Palau', 'Belau/Palau', 'Palauan', 65.2),
#  ('Pakistan', 'Pakistan', 'Other', None),
#  ('Pakistan', 'Pakistan', 'Burushaski', None),
#  ('Pakistan', 'Pakistan', 'English', None),
#  ('Pakistan', 'Pakistan', 'Brahui', 1.0),
#  ('Pakistan', 'Pakistan', 'Hindko', 2.0),
#  ('Pakistan', 'Pakistan', 'Balochi', 3.0),
#  ('Pakistan', 'Pakistan', 'Urdu', 8.0),
#  ('Pakistan', 'Pakistan', 'Pashto', 8.0),
#  ('Pakistan', 'Pakistan', 'Saraiki', 10.0),
#  ('Pakistan', 'Pakistan', 'Sindhi', 12.0),
#  ('Pakistan', 'Pakistan', 'Punjabi', 48.0),
#  ('Oman', '´Uman', 'Baluchi', None),
#  ('Oman', '´Uman', 'Indian', None),
#  ('Oman', '´Uman', 'Urdu', None),
#  ('Oman', '´Uman', 'English', None),
#  ('Oman', '´Uman', 'Arabic', None),
#  ('Norway', 'Norge', 'Bokmal', None),
#  ('Norway', 'Norge', 'Other', None),
#  ('Norway', 'Norge', 'Nynorsk', None),
#  ('North Korea', 'Choson Minjujuui In´min Konghwaguk (Bukhan)', 'Korean', None),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'English', 17.0),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Other Asian', 7.3),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Chamorro', 24.1),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Other', 1.9),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Philippine', 32.8),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Other Pacific Island', 10.1),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Chinese', 6.8),
#  ('Nigeria', 'Nigeria', 'Yoruba', None),
#  ('Nigeria', 'Nigeria', 'Other', None),
#  ('Nigeria', 'Nigeria', 'Fulani', None),
#  ('Nigeria', 'Nigeria', 'Igbo', None),
#  ('Nigeria', 'Nigeria', 'Hausa', None),
#  ('Nigeria', 'Nigeria', 'English', None),
#  ('Niger', 'Niger', 'French', None),
#  ('Niger', 'Niger', 'Djerma', None),
#  ('Niger', 'Niger', 'Hausa', None),
#  ('Nicaragua', 'Nicaragua', 'Spanish', 95.3),
#  ('Nicaragua', 'Nicaragua', 'Mestizo', 2.0),
#  ('Nicaragua', 'Nicaragua', 'Other', 0.5),
#  ('Nicaragua', 'Nicaragua', 'Miskito', 2.2),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Northern Chinese', 1.2),
#  ('New Zealand', 'New Zealand/Aotearoa', 'New Zealand Sign', None),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Other', 20.5),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Yue', 1.0),
#  ('New Zealand', 'New Zealand/Aotearoa', 'French', 1.2),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Hindi', 1.6),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Samoan', 2.0),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Maori', 3.5),
#  ('New Zealand', 'New Zealand/Aotearoa', 'English', 89.8),
#  ('New Caledonia', 'Nouvelle-Caledonie', 'French', None),
#  ('New Caledonia', 'Nouvelle-Caledonie', 'Other', None),
#  ('Netherlands', 'Nederland', 'Dutch', None),
#  ('Nepal', 'Nepal', 'Other', 10.4),
#  ('Nepal', 'Nepal', 'Gurung', 1.2),
#  ('Nepal', 'Nepal', 'Limbu', 1.3),
#  ('Nepal', 'Nepal', 'Avadhi', 1.9),
#  ('Nepal', 'Nepal', 'Urdu', 2.6),
#  ('Nepal', 'Nepal', 'Bajjika', 3.0),
#  ('Nepal', 'Nepal', 'Magar', 3.0),
#  ('Nepal', 'Nepal', 'Newar', 3.2),
#  ('Nepal', 'Nepal', 'unspecified', 0.2),
#  ('Nepal', 'Nepal', 'Tharu', 5.8),
#  ('Nepal', 'Nepal', 'Bhojpuri', 6.0),
#  ('Nepal', 'Nepal', 'Maithali', 11.7),
#  ('Nepal', 'Nepal', 'Nepali', 44.6),
#  ('Nepal', 'Nepal', 'Tamang', 5.1),
#  ('Nauru', 'Naoero/Nauru', 'English', 2.0),
#  ('Nauru', 'Naoero/Nauru', 'Nauruan', 93.0),
#  ('Nauru', 'Naoero/Nauru', 'Other', 5.0),
#  ('Namibia', 'Namibia', 'Caprivi', 4.8),
#  ('Namibia', 'Namibia', 'Other', 1.7),
#  ('Namibia', 'Namibia', 'Other', 2.3),
#  ('Namibia', 'Namibia', 'English', 3.4),
#  ('Namibia', 'Namibia', 'Kavango', 8.5),
#  ('Namibia', 'Namibia', 'Otjiherero', 8.6),
#  ('Namibia', 'Namibia', 'Afrikaans', 10.4),
#  ('Namibia', 'Namibia', 'Nama', 11.3),
#  ('Namibia', 'Namibia', 'Oshivambo', 48.9),
#  ('Myanmar', 'Myanma Pye', 'Burmese', None),
#  ('Mozambique', 'Mocambique', 'unspecified', 3.7),
#  ('Mozambique', 'Mocambique', 'Xichangana', 10.3),
#  ('Mozambique', 'Mocambique', 'Portuguese', 10.7),
#  ('Mozambique', 'Mocambique', 'Emakhuwa', 25.3),
#  ('Mozambique', 'Mocambique', 'Other', 30.4),
#  ('Mozambique', 'Mocambique', 'Echuwabo', 5.1),
#  ('Mozambique', 'Mocambique', 'Cisena', 7.5),
#  ('Mozambique', 'Mocambique', 'Elomwe', 7.0),
#  ('Morocco', 'Al-Maghrib', 'French', None),
#  ('Morocco', 'Al-Maghrib', 'Tarifit', None),
#  ('Morocco', 'Al-Maghrib', 'Tachelhit', None),
#  ('Morocco', 'Al-Maghrib', 'Berber', None),
#  ('Morocco', 'Al-Maghrib', 'Arabic', None),
#  ('Morocco', 'Al-Maghrib', 'and', None),
#  ('Morocco', 'Al-Maghrib', 'government', None),
#  ('Mongolia', 'Mongol Uls', 'Mongolian', 90.0),
#  ('Mongolia', 'Mongol Uls', 'Russian', None),
#  ('Mongolia', 'Mongol Uls', 'Turkic', None),
#  ('Monaco', 'Monaco', 'French', None),
#  ('Monaco', 'Monaco', 'English', None),
#  ('Monaco', 'Monaco', 'Monegasque', None),
#  ('Monaco', 'Monaco', 'Italian', None),
#  ('Moldova', 'Moldova', 'Other', 0.2),
#  ('Moldova', 'Moldova', 'Romani', 0.3),
#  ('Moldova', 'Moldova', 'Bulgarian', 1.5),
#  ('Moldova', 'Moldova', 'Ukrainian', 3.9),
#  ('Moldova', 'Moldova', 'Gagauz', 4.2),
#  ('Moldova', 'Moldova', 'Russian', 9.7),
#  ('Moldova', 'Moldova', 'Romanian', 80.2),
#  ('Micronesia, Federated States of', 'Micronesia', 'Woleaian', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Ulithian', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Yapese', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Pohnpeian', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Kosrean', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Chuukese', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'English', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Nukuoro', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Kapingamarangi', None),
#  ('Mexico', 'Mexico', 'Spanish', 92.7),
#  ('Mexico', 'Mexico', 'unspecified', 0.8),
#  ('Mexico', 'Mexico', 'indigenous', 0.8),
#  ('Mauritius', 'Mauritius', 'French', 4.1),
#  ('Mauritius', 'Mauritius', 'Bhojpuri', 5.3),
#  ('Mauritius', 'Mauritius', 'Creole', 86.5),
#  ('Mauritius', 'Mauritius', 'unspecified', 0.1),
#  ('Mauritius', 'Mauritius', 'Other', 2.6),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'French', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Wolof', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Arabic', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Soninke', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Pular', None),
#  ('Marshall Islands', 'Marshall Islands/Majol', 'Other', 1.8),
#  ('Marshall Islands', 'Marshall Islands/Majol', 'Marshallese', 98.2),
#  ('Malta', 'Malta', 'multilingual', 3.0),
#  ('Malta', 'Malta', 'Other', 0.9),
#  ('Malta', 'Malta', 'English', 6.0),
#  ('Malta', 'Malta', 'Maltese', 90.1),
#  ('Mali', 'Mali', 'French', None),
#  ('Mali', 'Mali', 'Senoufo', 2.6),
#  ('Mali', 'Mali', 'Tamacheq', 3.5),
#  ('Mali', 'Mali', 'Minianka', 4.3),
#  ('Mali', 'Mali', 'Sonrhai/Djerma', 5.6),
#  ('Mali', 'Mali', 'Malinke', 5.6),
#  ('Mali', 'Mali', 'Maraka/Soninke', 6.4),
#  ('Mali', 'Mali', 'Dogon', 7.2),
#  ('Mali', 'Mali', 'Peul/Foulfoulbe', 9.4),
#  ('Mali', 'Mali', 'Bambara', 46.3),
#  ('Mali', 'Mali', 'unspecified', 0.7),
#  ('Mali', 'Mali', 'Bobo', 2.1),
#  ('Mali', 'Mali', 'Other', 6.3),
#  ('Maldives', 'Dhivehi Raajje/Maldives', 'English', None),
#  ('Maldives', 'Dhivehi Raajje/Maldives', 'Dhivehi', None),
#  ('Malaysia', 'Malaysia', 'English', None),
#  ('Malaysia', 'Malaysia', 'Thai', None),
#  ('Malaysia', 'Malaysia', 'Panjabi', None),
#  ('Malaysia', 'Malaysia', 'Malayalam', None),
#  ('Malaysia', 'Malaysia', 'Telugu', None),
#  ('Malaysia', 'Malaysia', 'Tamil', None),
#  ('Malaysia', 'Malaysia', 'Chinese', None),
#  ('Malaysia', 'Malaysia', 'Bahasa Malaysia', None),
#  ('Malawi', 'Malawi', 'Chilomwe', None),
#  ('Malawi', 'Malawi', 'Chilambya', None),
#  ('Malawi', 'Malawi', 'Chinyakyusa', None),
#  ('Malawi', 'Malawi', 'Chitonga', None),
#  ('Malawi', 'Malawi', 'Chisena', None),
#  ('Malawi', 'Malawi', 'Chingoni', None),
#  ('Malawi', 'Malawi', 'Chinkhonde', None),
#  ('Malawi', 'Malawi', 'Chitumbuka', None),
#  ('Malawi', 'Malawi', 'Chiyao', None),
#  ('Malawi', 'Malawi', 'Chinyanja', None),
#  ('Malawi', 'Malawi', 'Chichewa', None),
#  ('Malawi', 'Malawi', 'English', None),
#  ('Madagascar', 'Madagasikara/Madagascar', 'French', None),
#  ('Madagascar', 'Madagasikara/Madagascar', 'English', None),
#  ('Madagascar', 'Madagasikara/Madagascar', 'Malagasy', None),
#  ('Macedonia', 'Makedonija', 'Romani', 1.9),
#  ('Macedonia', 'Makedonija', 'Turkish', 3.5),
#  ('Macedonia', 'Makedonija', 'Albanian', 25.1),
#  ('Macedonia', 'Makedonija', 'Macedonian', 66.5),
#  ('Macedonia', 'Makedonija', 'Other', 1.8),
#  ('Macedonia', 'Makedonija', 'Serbian', 1.2),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'Luxembourgish', 88.8),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'Other', 3.5),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'German', 1.1),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'Portuguese', 2.3),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'French', 4.2),
#  ('Lithuania', 'Lietuva', 'Other', 0.9),
#  ('Lithuania', 'Lietuva', 'Lithuanian', 82.0),
#  ('Lithuania', 'Lietuva', 'Russian', 8.0),
#  ('Lithuania', 'Lietuva', 'Polish', 5.6),
#  ('Lithuania', 'Lietuva', 'unspecified', 3.5),
#  ('Liechtenstein', 'Liechtenstein', 'German', 94.5),
#  ('Liechtenstein', 'Liechtenstein', 'Other', 4.3),
#  ('Liechtenstein', 'Liechtenstein', 'Italian', 1.1),
#  ('Libya', 'Libiya', 'Arabic', None),
#  ('Libya', 'Libiya', 'Berber', None),
#  ('Libya', 'Libiya', 'English', None),
#  ('Libya', 'Libiya', 'Italian', None),
#  ('Liberia', 'Liberia', 'Other', None),
#  ('Liberia', 'Liberia', 'English', 20.0),
#  ('Lesotho', 'Lesotho', 'English', None),
#  ('Lesotho', 'Lesotho', 'Xhosa', None),
#  ('Lesotho', 'Lesotho', 'Zulu', None),
#  ('Lesotho', 'Lesotho', 'Sesotho', None),
#  ('Lebanon', 'Lubnan', 'French', None),
#  ('Lebanon', 'Lubnan', 'Armenian', None),
#  ('Lebanon', 'Lubnan', 'English', None),
#  ('Lebanon', 'Lubnan', 'Arabic', None),
#  ('Latvia', 'Latvija', 'Russian', 33.8),
#  ('Latvia', 'Latvija', 'unspecified', 9.4),
#  ('Latvia', 'Latvija', 'Other', 0.6),
#  ('Latvia', 'Latvija', 'Latvian', 56.3),
#  ('Laos', 'Lao', 'French', None),
#  ('Laos', 'Lao', 'Other', None),
#  ('Laos', 'Lao', 'English', None),
#  ('Laos', 'Lao', 'Lao', None),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Other', 5.2),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Russian', 9.0),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Uzbek', 14.4),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Kyrgyz', 71.4),
#  ('Kuwait', 'Al-Kuwayt', 'Arabic', None),
#  ('Kuwait', 'Al-Kuwayt', 'English', None),
#  ('Kiribati', 'Kiribati', 'English', None),
#  ('Kiribati', 'Kiribati', 'Kiribati', None),
#  ('Kenya', 'Kenya', 'Kiswahili', None),
#  ('Kenya', 'Kenya', 'Other', None),
#  ('Kenya', 'Kenya', 'English', None),
#  ('Kazakhstan', 'Qazaqstan', 'Russian', 94.4),
#  ('Kazakhstan', 'Qazaqstan', 'Kazakh', 74.0),
#  ('Jordan', 'Al-Urdunn', 'Arabic', None),
#  ('Jordan', 'Al-Urdunn', 'English', None),
#  ('Japan', 'Nihon/Nippon', 'Japanese', None),
#  ('Jamaica', 'Jamaica', 'English patois', None),
#  ('Jamaica', 'Jamaica', 'English', None),
#  ('Italy', 'Italia', 'German', None),
#  ('Italy', 'Italia', 'Slovene', None),
#  ('Italy', 'Italia', 'French', None),
#  ('Italy', 'Italia', 'Italian', None),
#  ('Israel', 'Yisra\x92el/Isra\x92il', 'Hebrew', None),
#  ('Israel', 'Yisra\x92el/Isra\x92il', 'English', None),
#  ('Israel', 'Yisra\x92el/Isra\x92il', 'Arabic', None),
#  ('Ireland', 'Ireland/Eire', 'Irish', 38.7),
#  ('Ireland', 'Ireland/Eire', 'English', 61.3),
#  ('Iraq', 'Al-´Iraq', 'Syriac', None),
#  ('Iraq', 'Al-´Iraq', 'Armenian', None),
#  ('Iraq', 'Al-´Iraq', 'Turkmen', None),
#  ('Iraq', 'Al-´Iraq', 'Kurdish', None),
#  ('Iraq', 'Al-´Iraq', 'Arabic', None),
#  ('Iran', 'Iran', 'Persian', None),
#  ('Iran', 'Iran', 'Other', None),
#  ('Iran', 'Iran', 'Arabic', None),
#  ('Iran', 'Iran', 'Balochi', None),
#  ('Iran', 'Iran', 'Luri', None),
#  ('Iran', 'Iran', 'Gilaki and Mazandarani', None),
#  ('Iran', 'Iran', 'Kurdish', None),
#  ('Iran', 'Iran', 'Turkic', None),
#  ('Indonesia', 'Indonesia', 'English', None),
#  ('Indonesia', 'Indonesia', 'Other', None),
#  ('Indonesia', 'Indonesia', 'Dutch', None),
#  ('Indonesia', 'Indonesia', 'Bahasa', None),
#  ('India', 'Bharat/India', 'Kannada', 3.7),
#  ('India', 'Bharat/India', 'Other', 5.9),
#  ('India', 'Bharat/India', 'Maithili', 1.2),
#  ('India', 'Bharat/India', 'Assamese', 1.3),
#  ('India', 'Bharat/India', 'Punjabi', 2.8),
#  ('India', 'Bharat/India', 'Oriya', 3.2),
#  ('India', 'Bharat/India', 'Malayalam', 3.2),
#  ('India', 'Bharat/India', 'Gujarati', 4.5),
#  ('India', 'Bharat/India', 'Urdu', 5.0),
#  ('India', 'Bharat/India', 'Tamil', 5.9),
#  ('India', 'Bharat/India', 'Marathi', 7.0),
#  ('India', 'Bharat/India', 'Telugu', 7.2),
#  ('India', 'Bharat/India', 'Bengali', 8.1),
#  ('India', 'Bharat/India', 'Hindi', 41.0),
#  ('Iceland', 'Island', 'English', None),
#  ('Iceland', 'Island', 'Icelandic', None),
#  ('Iceland', 'Island', 'German', None),
#  ('Iceland', 'Island', 'Nordic', None),
#  ('Hungary', 'Magyarorszag', 'Russian', 1.6),
#  ('Hungary', 'Magyarorszag', 'German', 11.2),
#  ('Hungary', 'Magyarorszag', 'Hungarian', 99.6),
#  ('Hungary', 'Magyarorszag', 'English', 16.0),
#  ('Hungary', 'Magyarorszag', 'Other', 4.2),
#  ('Hungary', 'Magyarorszag', 'French', 1.2),
#  ('Hungary', 'Magyarorszag', 'Romanian', 1.3),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'English', 3.5),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Other', 1.6),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Other Chinese', 4.0),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Mandarin', 1.4),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Cantonese', 89.5),
#  ('Honduras', 'Honduras', 'Spanish', None),
#  ('Honduras', 'Honduras', 'Amerindian', None),
#  ('Haiti', 'Haiti/Dayti', 'French', None),
#  ('Haiti', 'Haiti/Dayti', 'Creole', None),
#  ('Guyana', 'Guyana', 'Indian', None),
#  ('Guyana', 'Guyana', 'Guyanese Creole', None),
#  ('Guyana', 'Guyana', 'Chinese', None),
#  ('Guyana', 'Guyana', 'English', None),
#  ('Guyana', 'Guyana', 'Amerindian', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Crioulo', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Mandingo', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Pular', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Portuguese', None),
#  ('Guinea', 'Guinee', 'French', None),
#  ('Guatemala', 'Guatemala', 'Spanish', 60.0),
#  ('Guatemala', 'Guatemala', 'Amerindian', 40.0),
#  ('Guam', 'Guam', 'Other Pacific Islander', 10.0),
#  ('Guam', 'Guam', 'Chamorro', 17.8),
#  ('Guam', 'Guam', 'English', 43.6),
#  ('Guam', 'Guam', 'Filipino', 21.2),
#  ('Guam', 'Guam', 'Other', 1.1),
#  ('Guam', 'Guam', 'Asian', 6.3),
#  ('Grenada', 'Grenada', 'French patois', None),
#  ('Grenada', 'Grenada', 'English', None),
#  ('Greenland', 'Kalaallit Nunaat/Gronland', 'Danish', None),
#  ('Greenland', 'Kalaallit Nunaat/Gronland', 'English', None),
#  ('Greenland', 'Kalaallit Nunaat/Gronland', 'Greenlandic', None),
#  ('Greece', 'Ellada', 'Other', 1.0),
#  ('Greece', 'Ellada', 'Greek', 99.0),
#  ('Gibraltar', 'Gibraltar', 'Spanish', None),
#  ('Gibraltar', 'Gibraltar', 'Portuguese', None),
#  ('Gibraltar', 'Gibraltar', 'Italian', None),
#  ('Gibraltar', 'Gibraltar', 'English', None),
#  ('Ghana', 'Ghana', 'Asante', 16.0),
#  ('Ghana', 'Ghana', 'Other', 31.2),
#  ('Ghana', 'Ghana', 'Ga', 3.1),
#  ('Ghana', 'Ghana', 'Akyem', 3.2),
#  ('Ghana', 'Ghana', 'Kokomba', 3.5),
#  ('Ghana', 'Ghana', 'Dagarte', 3.9),
#  ('Ghana', 'Ghana', 'Dangme', 4.2),
#  ('Ghana', 'Ghana', 'Dagomba', 4.4),
#  ('Ghana', 'Ghana', 'Boron', 4.9),
#  ('Ghana', 'Ghana', 'Fante', 11.6),
#  ('Ghana', 'Ghana', 'Ewe', 14.0),
#  ('Germany', 'Deutschland', 'German', None),
#  ('Georgia', 'Sakartvelo', 'Georgian', 87.6),
#  ('Georgia', 'Sakartvelo', 'Other', 1.0),
#  ('Georgia', 'Sakartvelo', 'Russian', 1.2),
#  ('Georgia', 'Sakartvelo', 'Armenian', 3.9),
#  ('Georgia', 'Sakartvelo', 'Azeri', 6.2),
#  ('Gambia', 'The Gambia', 'Mandinka', None),
#  ('Gambia', 'The Gambia', 'Other', None),
#  ('Gambia', 'The Gambia', 'Fula', None),
#  ('Gambia', 'The Gambia', 'Wolof', None),
#  ('Gambia', 'The Gambia', 'English', None),
#  ('Gabon', 'Le Gabon', 'Fang', None),
#  ('Gabon', 'Le Gabon', 'Bandjabi', None),
#  ('Gabon', 'Le Gabon', 'Bapounou/Eschira', None),
#  ('Gabon', 'Le Gabon', 'Nzebi', None),
#  ('Gabon', 'Le Gabon', 'Myene', None),
#  ('Gabon', 'Le Gabon', 'French', None),
#  ('French Polynesia', 'Polynesie francaise', 'Polynesian', 28.2),
#  ('French Polynesia', 'Polynesie francaise', 'Other', 1.8),
#  ('French Polynesia', 'Polynesie francaise', 'French', 70.0),
#  ('France', 'France', 'Occitan', None),
#  ('France', 'France', 'Mahorian', None),
#  ('France', 'France', 'Creole patois', None),
#  ('France', 'France', 'French', None),
#  ('France', 'France', 'Picard', None),
#  ('France', 'France', 'Flemish', None),
#  ('France', 'France', 'Basque', None),
#  ('France', 'France', 'Catalan', None),
#  ('France', 'France', 'Corsican', None),
#  ('France', 'France', 'Alsatian', None),
#  ('France', 'France', 'Breton', None),
#  ('France', 'France', 'Provencal', None),
#  ('France', 'France', 'French', 100.0),
#  ('Finland', 'Suomi', 'Swedish', 5.3),
#  ('Finland', 'Suomi', 'Finnish', 88.3),
#  ('Finland', 'Suomi', 'Other', 5.0),
#  ('Finland', 'Suomi', 'Russian', 1.4),
#  ('Faroe Islands', 'Foroyar', 'Other', 3.0),
#  ('Faroe Islands', 'Foroyar', 'Danish', 3.2),
#  ('Faroe Islands', 'Foroyar', 'Faroese', 93.8),
#  ('Ethiopia', 'YeItyop´iya', 'Gamo', 1.5),
#  ('Ethiopia', 'YeItyop´iya', 'Hadiyya', 1.7),
#  ('Ethiopia', 'YeItyop´iya', 'Afar', 1.7),
#  ('Ethiopia', 'YeItyop´iya', 'Gurage', 2.0),
#  ('Ethiopia', 'YeItyop´iya', 'Wolaytta', 2.2),
#  ('Ethiopia', 'YeItyop´iya', 'Sidamo', 4.0),
#  ('Ethiopia', 'YeItyop´iya', 'Tigrigna', 5.9),
#  ('Ethiopia', 'YeItyop´iya', 'Somali', 6.2),
#  ('Ethiopia', 'YeItyop´iya', 'Oromo', 33.8),
#  ('Ethiopia', 'YeItyop´iya', 'Amharic', 29.3),
#  ('Ethiopia', 'YeItyop´iya', 'Arabic', None),
#  ('Ethiopia', 'YeItyop´iya', 'English', None),
#  ('Ethiopia', 'YeItyop´iya', 'Other', 8.1),
#  ('Ethiopia', 'YeItyop´iya', 'Kafa', 1.1),
#  ('Ethiopia', 'YeItyop´iya', 'Opuuo', 1.2),
#  ('Ethiopia', 'YeItyop´iya', 'Gedeo', 1.3),
#  ('Estonia', 'Eesti', 'unspecified', 0.1),
#  ('Estonia', 'Eesti', 'Other', 1.2),
#  ('Estonia', 'Eesti', 'Ukrainian', 0.6),
#  ('Estonia', 'Eesti', 'Russian', 29.6),
#  ('Estonia', 'Eesti', 'Estonian', 68.5),
#  ('Eritrea', 'Ertra', 'Tigrinya', None),
#  ('Eritrea', 'Ertra', 'Other', None),
#  ('Eritrea', 'Ertra', 'Afar', None),
#  ('Eritrea', 'Ertra', 'Kunama', None),
#  ('Eritrea', 'Ertra', 'Tigre', None),
#  ('Eritrea', 'Ertra', 'English', None),
#  ('Eritrea', 'Ertra', 'Arabic', None),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Other', None),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Bubi', 32.4),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Fang', None),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Spanish', 67.6),
#  ('El Salvador', 'El Salvador', 'Spanish', None),
#  ('El Salvador', 'El Salvador', 'Nawat', None),
#  ('Egypt', 'Misr', 'English', None),
#  ('Egypt', 'Misr', 'Arabic', None),
#  ('Ecuador', 'Ecuador', 'Other', 0.7),
#  ('Ecuador', 'Ecuador', 'Spanish', 93.0),
#  ('Ecuador', 'Ecuador', 'Quechua', 4.1),
#  ('Ecuador', 'Ecuador', 'foreign', 2.2),
#  ('Dominican Republic', 'Republica Dominicana', 'Spanish', None),
#  ('Dominica', 'Dominica', 'French patois', None),
#  ('Dominica', 'Dominica', 'English', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'Somali', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'Arabic', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'French', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'Afar', None),
#  ('Denmark', 'Danmark', 'Greenlandic', None),
#  ('Denmark', 'Danmark', 'Faroese', None),
#  ('Denmark', 'Danmark', 'Danish', None),
#  ('Denmark', 'Danmark', 'German', None),
#  ('Cyprus', 'Kypros/Kibris', 'English', 4.1),
#  ('Cyprus', 'Kypros/Kibris', 'Turkish', 0.2),
#  ('Cyprus', 'Kypros/Kibris', 'Greek', 80.9),
#  ('Cyprus', 'Kypros/Kibris', 'unspecified', 0.6),
#  ('Cyprus', 'Kypros/Kibris', 'Other', 4.3),
#  ('Cyprus', 'Kypros/Kibris', 'Filipino', 1.1),
#  ('Cyprus', 'Kypros/Kibris', 'Arabic', 1.2),
#  ('Cyprus', 'Kypros/Kibris', 'Bulgarian', 2.2),
#  ('Cyprus', 'Kypros/Kibris', 'Russian', 2.5),
#  ('Cyprus', 'Kypros/Kibris', 'Romanian', 2.9),
#  ('Cuba', 'Cuba', 'Spanish', None),
#  ('Croatia', 'Hrvatska', 'Serbian', 1.2),
#  ('Croatia', 'Hrvatska', 'unspecified', 0.2),
#  ('Croatia', 'Hrvatska', 'Other', 3.0),
#  ('Croatia', 'Hrvatska', 'Croatian', 95.6),
#  ("Cote d'Ivoire", 'Cote d\x92Ivoire', 'Other', None),
#  ("Cote d'Ivoire", 'Cote d\x92Ivoire', 'French', None),
#  ('Costa Rica', 'Costa Rica', 'English', None),
#  ('Costa Rica', 'Costa Rica', 'Spanish', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Lingala', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Kikongo', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Kingwana', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'French', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Tshiluba', None),
#  ('Congo', 'Congo', 'Other', None),
#  ('Congo', 'Congo', 'Lingala', None),
#  ('Congo', 'Congo', 'French', None),
#  ('Comoros', 'Komori/Comores', 'Arabic', None),
#  ('Comoros', 'Komori/Comores', 'Shikomoro', None),
#  ('Comoros', 'Komori/Comores', 'French', None),
#  ('Colombia', 'Colombia', 'Spanish', None),
#  ('China', 'Zhongquo', 'Yue', None),
#  ('China', 'Zhongquo', 'Other', None),
#  ('China', 'Zhongquo', 'Hakka', None),
#  ('China', 'Zhongquo', 'Gan', None),
#  ('China', 'Zhongquo', 'Xiang', None),
#  ('China', 'Zhongquo', 'Minnan', None),
#  ('China', 'Zhongquo', 'Minbei', None),
#  ('China', 'Zhongquo', 'Wu', None),
#  ('China', 'Zhongquo', 'Mandarin', None),
#  ('Chile', 'Chile', 'Spanish', 99.5),
#  ('Chile', 'Chile', 'unspecified', 0.2),
#  ('Chile', 'Chile', 'Other', 2.3),
#  ('Chile', 'Chile', 'indigenous', 1.0),
#  ('Chile', 'Chile', 'English', 10.2),
#  ('Chad', 'Tchad/Tshad', 'Sara', None),
#  ('Chad', 'Tchad/Tshad', 'Other', None),
#  ('Chad', 'Tchad/Tshad', 'Arabic', None),
#  ('Chad', 'Tchad/Tshad', 'French', None),
#  ('Central African Republic', 'Centrafrique/Be-Afrika', 'Sangho', None),
#  ('Central African Republic', 'Centrafrique/Be-Afrika', 'French', None),
#  ('Central African Republic', 'Centrafrique/Be-Afrika', 'tribal', None),
#  ('Cayman Islands', 'Cayman Islands', 'Other', 1.7),
#  ('Cayman Islands', 'Cayman Islands', 'Filipino', 3.3),
#  ('Cayman Islands', 'Cayman Islands', 'Spanish', 4.0),
#  ('Cayman Islands', 'Cayman Islands', 'English', 90.9),
#  ('Cayman Islands', 'Cayman Islands', 'unspecified', 0.1),
#  ('Canada', 'Canada', 'Punjabi', 1.4),
#  ('Canada', 'Canada', 'English', 58.7),
#  ('Canada', 'Canada', 'French', 22.0),
#  ('Canada', 'Canada', 'Other', 10.5),
#  ('Canada', 'Canada', 'Arabic', 1.1),
#  ('Canada', 'Canada', 'Tagalog', 1.2),
#  ('Canada', 'Canada', 'Cantonese', 1.2),
#  ('Canada', 'Canada', 'German', 1.3),
#  ('Canada', 'Canada', 'Spanish', 1.3),
#  ('Canada', 'Canada', 'Italian', 1.3),
#  ('Cameroon', 'Cameroun/Cameroon', 'English', None),
#  ('Cameroon', 'Cameroun/Cameroon', 'French', None),
#  ('Cameroon', 'Cameroun/Cameroon', 'Other', None),
#  ('Cambodia', 'Kampuchea', 'Other', 3.7),
#  ('Cambodia', 'Kampuchea', 'Khmer', 96.3),
#  ('Burundi', 'Burundi/Uburundi', 'Swahili', 0.2),
#  ('Burundi', 'Burundi/Uburundi', 'unspecified', 56.9),
#  ('Burundi', 'Burundi/Uburundi', 'Other', 3.7),
#  ('Burundi', 'Burundi/Uburundi', 'English', 0.06),
#  ('Burundi', 'Burundi/Uburundi', 'French', 0.3),
#  ('Burundi', 'Burundi/Uburundi', 'Kirundi', 38.8),
#  ('Burkina Faso', 'Burkina Faso', 'Sudanic family', 90.0),
#  ('Burkina Faso', 'Burkina Faso', 'French', None),
#  ('Bulgaria', 'Balgarija', 'Other', 0.7),
#  ('Bulgaria', 'Balgarija', 'Romani', 3.8),
#  ('Bulgaria', 'Balgarija', 'Turkish', 8.2),
#  ('Bulgaria', 'Balgarija', 'unspecified', 10.5),
#  ('Bulgaria', 'Balgarija', 'Bulgarian', 76.8),
#  ('Brunei', 'Brunei Darussalam', 'Malay', None),
#  ('Brunei', 'Brunei Darussalam', 'Chinese', None),
#  ('Brunei', 'Brunei Darussalam', 'English', None),
#  ('Brazil', 'Brasil', 'Portuguese', None),
#  ('Botswana', 'Botswana', 'Sekalanga', 7.4),
#  ('Botswana', 'Botswana', 'Other', 2.8),
#  ('Botswana', 'Botswana', 'Ndebele', 1.0),
#  ('Botswana', 'Botswana', 'Sembukushu', 1.6),
#  ('Botswana', 'Botswana', 'Sesarwa', 1.7),
#  ('Botswana', 'Botswana', 'Zezuru', 2.0),
#  ('Botswana', 'Botswana', 'English', 2.8),
#  ('Botswana', 'Botswana', 'Shekgalagadi', 3.4),
#  ('Botswana', 'Botswana', 'Setswana', 77.3),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Bosnian', 52.9),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'No Answer', 0.2),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Other', 1.6),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Serbian', 30.8),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Croatian', 14.6),
#  ('Bolivia', 'Bolivia', 'none', 0.1),
#  ('Bolivia', 'Bolivia', 'Other', 0.4),
#  ('Bolivia', 'Bolivia', 'Guarani', 0.6),
#  ('Bolivia', 'Bolivia', 'Foreign Languages', 2.4),
#  ('Bolivia', 'Bolivia', 'Aymara', 14.6),
#  ('Bolivia', 'Bolivia', 'Quechua', 21.2),
#  ('Bolivia', 'Bolivia', 'Spanish', 60.7),
#  ('Bhutan', 'Druk-Yul', 'Other', 26.0),
#  ('Bhutan', 'Druk-Yul', 'Lhotshamkha', 22.0),
#  ('Bhutan', 'Druk-Yul', 'Dzongkha', 24.0),
#  ('Bhutan', 'Druk-Yul', 'Sharchhopka', 28.0),
#  ('Bermuda', 'Bermuda', 'English', None),
#  ('Bermuda', 'Bermuda', 'Portuguese', None),
#  ('Benin', 'Benin', 'Fon and Yoruba', None),
#  ('Benin', 'Benin', 'Tribal Languages', None),
#  ('Benin', 'Benin', 'French', None),
#  ('Belize', 'Belize', 'Spanish', 56.6),
#  ('Belize', 'Belize', 'none', 0.2),
#  ('Belize', 'Belize', 'unknown', 0.3),
#  ('Belize', 'Belize', 'Other', 1.8),
#  ('Belize', 'Belize', 'Garifuna', 2.9),
#  ('Belize', 'Belize', 'German', 3.2),
#  ('Belize', 'Belize', 'Maya', 10.5),
#  ('Belize', 'Belize', 'Creole', 44.6),
#  ('Belize', 'Belize', 'English', 62.9),
#  ('Belgium', 'Belgie/Belgique', 'French', 40.0),
#  ('Belgium', 'Belgie/Belgique', 'German', 1.0),
#  ('Belgium', 'Belgie/Belgique', 'Dutch', 60.0),
#  ('Belarus', 'Belarus', 'unspecified', 3.3),
#  ('Belarus', 'Belarus', 'Other', 3.1),
#  ('Belarus', 'Belarus', 'Belarusian', 23.4),
#  ('Belarus', 'Belarus', 'Russian', 70.2),
#  ('Barbados', 'Barbados', 'Bajan', None),
#  ('Barbados', 'Barbados', 'English', None),
#  ('Bangladesh', 'Bangladesh', 'Bangla', 98.8),
#  ('Bangladesh', 'Bangladesh', 'Other', 1.2),
#  ('Bahrain', 'Al-Bahrayn', 'English', None),
#  ('Bahrain', 'Al-Bahrayn', 'Urdu', None),
#  ('Bahrain', 'Al-Bahrayn', 'Farsi', None),
#  ('Bahrain', 'Al-Bahrayn', 'Arabic', None),
#  ('Bahamas', 'The Bahamas', 'Creole', None),
#  ('Bahamas', 'The Bahamas', 'English', None),
#  ('Azerbaijan', 'Azarbaycan', 'Russian', 1.4),
#  ('Azerbaijan', 'Azarbaycan', 'Other', 4.7),
#  ('Azerbaijan', 'Azarbaycan', 'Armenian', 1.4),
#  ('Azerbaijan', 'Azarbaycan', 'Azerbaijani', 92.5),
#  ('Austria', 'Osterreich', 'Serbian', 2.2),
#  ('Austria', 'Osterreich', 'Other', 5.3),
#  ('Austria', 'Osterreich', 'German', 88.6),
#  ('Austria', 'Osterreich', 'Croatian', 1.6),
#  ('Austria', 'Osterreich', 'Turkish', 2.3),
#  ('Australia', 'Australia', 'English', 76.8),
#  ('Australia', 'Australia', 'unspecified', 5.0),
#  ('Australia', 'Australia', 'Other', 10.4),
#  ('Australia', 'Australia', 'Vietnamese', 1.1),
#  ('Australia', 'Australia', 'Cantonese', 1.2),
#  ('Australia', 'Australia', 'Greek', 1.2),
#  ('Australia', 'Australia', 'Arabic', 1.3),
#  ('Australia', 'Australia', 'Italian', 1.4),
#  ('Australia', 'Australia', 'Mandarin', 1.6),
#  ('Aruba', 'Aruba', 'Papiamento', 69.4),
#  ('Aruba', 'Aruba', 'unspecified', 0.4),
#  ('Aruba', 'Aruba', 'Other', 1.7),
#  ('Aruba', 'Aruba', 'Chinese', 1.5),
#  ('Aruba', 'Aruba', 'Dutch', 6.1),
#  ('Aruba', 'Aruba', 'English', 7.1),
#  ('Aruba', 'Aruba', 'Spanish', 13.7),
#  ('Armenia', 'Hajastan', 'Kurdish', 1.0),
#  ('Armenia', 'Hajastan', 'Other', 1.0),
#  ('Armenia', 'Hajastan', 'Armenian', 97.9),
#  ('Argentina', 'Argentina', 'Italian', None),
#  ('Argentina', 'Argentina', 'indigenous', None),
#  ('Argentina', 'Argentina', 'French', None),
#  ('Argentina', 'Argentina', 'German', None),
#  ('Argentina', 'Argentina', 'English', None),
#  ('Argentina', 'Argentina', 'Spanish', None),
#  ('Antigua and Barbuda', 'Antigua and Barbuda', 'Antiguan creole', None),
#  ('Antigua and Barbuda', 'Antigua and Barbuda', 'English', None),
#  ('Angola', 'Angola', 'Luvale', 1.0),
#  ('Angola', 'Angola', 'Other', 3.6),
#  ('Angola', 'Angola', 'Muhumbi', 2.1),
#  ('Angola', 'Angola', 'Kwanhama', 2.3),
#  ('Angola', 'Angola', 'Fiote', 2.4),
#  ('Angola', 'Angola', 'Nganguela', 3.1),
#  ('Angola', 'Angola', 'Nhaneca', 3.4),
#  ('Angola', 'Angola', 'Chokwe', 6.5),
#  ('Angola', 'Angola', 'Kimbundu', 7.8),
#  ('Angola', 'Angola', 'Kikongo', 8.2),
#  ('Angola', 'Angola', 'Umbundu', 23.0),
#  ('Angola', 'Angola', 'Portuguese', 71.2),
#  ('Andorra', 'Andorra', 'Castilian', None),
#  ('Andorra', 'Andorra', 'Portuguese', None),
#  ('Andorra', 'Andorra', 'French', None),
#  ('Andorra', 'Andorra', 'Catalan', None),
#  ('American Samoa', 'Amerika Samoa', 'English', 3.9),
#  ('American Samoa', 'Amerika Samoa', 'Samoan', 88.6),
#  ('American Samoa', 'Amerika Samoa', 'Other', 1.8),
#  ('American Samoa', 'Amerika Samoa', 'Other', 3.0),
#  ('American Samoa', 'Amerika Samoa', 'Tongan', 2.7),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'French', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Arabic', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Mzab', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Shawiya', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Tuareg', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Berber or Tamazight', None),
#  ('Albania', 'Shqiperia', 'Greek', 0.5),
#  ('Albania', 'Shqiperia', 'Albanian', 98.8),
#  ('Albania', 'Shqiperia', 'unspecified', 0.1),
#  ('Albania', 'Shqiperia', 'Other', 0.6),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Other', 4.0),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Dari', 50.0),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Pashto', 35.0),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Turkic', 11.0)]

# %%
# %%sql
# /*
# select country name AS country, the country's local name,
# the language name AS language, and
# the percent of the language spoken in the country
# */
# SELECT c.name AS country, local_name, l.name AS language, percent
# -- countries on the left (alias as c)
# FROM countries AS c
# -- inner join with languages (as l) on the right
# LEFT JOIN languages AS l
# -- give fields to match on
# ON c.code = l.code
# -- sort by descending country name
# ORDER BY country DESC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 921 rows affected.
# [('Zimbabwe', 'Zimbabwe', 'Chibarwe', None),
#  ('Zimbabwe', 'Zimbabwe', 'Shona', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndebele', None),
#  ('Zimbabwe', 'Zimbabwe', 'English', None),
#  ('Zimbabwe', 'Zimbabwe', 'Chewa', None),
#  ('Zimbabwe', 'Zimbabwe', 'Xhosa', None),
#  ('Zimbabwe', 'Zimbabwe', 'Venda', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tswana', None),
#  ('Zimbabwe', 'Zimbabwe', 'Tonga', None),
#  ('Zimbabwe', 'Zimbabwe', 'Sotho', None),
#  ('Zimbabwe', 'Zimbabwe', 'sign', None),
#  ('Zimbabwe', 'Zimbabwe', 'Shangani', None),
#  ('Zimbabwe', 'Zimbabwe', 'Ndau', None),
#  ('Zimbabwe', 'Zimbabwe', 'Nambya', None),
#  ('Zimbabwe', 'Zimbabwe', 'Koisan', None),
#  ('Zimbabwe', 'Zimbabwe', 'Kalanga', None),
#  ('Zambia', 'Zambia', 'Lala', 1.8),
#  ('Zambia', 'Zambia', 'Mambwe', 1.3),
#  ('Zambia', 'Zambia', 'Luvale', 1.5),
#  ('Zambia', 'Zambia', 'English', 1.7),
#  ('Zambia', 'Zambia', 'Lamba', 1.8),
#  ('Zambia', 'Zambia', 'Kaonde', 1.8),
#  ('Zambia', 'Zambia', 'Lunda', 1.9),
#  ('Zambia', 'Zambia', 'Tumbuka', 2.5),
#  ('Zambia', 'Zambia', 'Nsenga', 2.9),
#  ('Zambia', 'Zambia', 'Chewa', 4.5),
#  ('Zambia', 'Zambia', 'Lozi', 5.5),
#  ('Zambia', 'Zambia', 'Tonga', 11.4),
#  ('Zambia', 'Zambia', 'Nyanja', 14.7),
#  ('Zambia', 'Zambia', 'Bembe', 33.4),
#  ('Zambia', 'Zambia', 'unspecified', 0.2),
#  ('Zambia', 'Zambia', 'Other', 9.7),
#  ('Zambia', 'Zambia', 'Bisa', 1.0),
#  ('Zambia', 'Zambia', 'Lenje', 1.1),
#  ('Zambia', 'Zambia', 'Namwanga', 1.2),
#  ('Yemen', 'Al-Yaman', 'Arabic', None),
#  ('Virgin Islands, U.S.', 'Virgin Islands of the United States', None, None),
#  ('Virgin Islands, British', 'British Virgin Islands', None, None),
#  ('Vietnam', 'Viet Nam', 'Other', None),
#  ('Vietnam', 'Viet Nam', 'Vietnamese', None),
#  ('Vietnam', 'Viet Nam', 'English', None),
#  ('Venezuela', 'Venezuela', 'indigenous', None),
#  ('Venezuela', 'Venezuela', 'Spanish', None),
#  ('Vanuatu', 'Vanuatu', 'Other', 0.5),
#  ('Vanuatu', 'Vanuatu', 'Tribal Languages', 63.2),
#  ('Vanuatu', 'Vanuatu', 'English', 2.0),
#  ('Vanuatu', 'Vanuatu', 'French', 0.6),
#  ('Vanuatu', 'Vanuatu', 'Bislama', 33.7),
#  ('Uzbekistan', 'Uzbekiston', 'Uzbek', 74.3),
#  ('Uzbekistan', 'Uzbekiston', 'Other', 7.1),
#  ('Uzbekistan', 'Uzbekiston', 'Tajik', 4.4),
#  ('Uzbekistan', 'Uzbekiston', 'Russian', 14.2),
#  ('Uruguay', 'Uruguay', 'Brazilero', None),
#  ('Uruguay', 'Uruguay', 'Portunol', None),
#  ('Uruguay', 'Uruguay', 'Spanish', None),
#  ('United States', 'United States', 'Spanish', 12.9),
#  ('United States', 'United States', 'Other', 8.0),
#  ('United States', 'United States', 'English', 79.2),
#  ('United Kingdom', 'United Kingdom', 'English', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Arabic', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Hindi', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'English', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Persian', None),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 'Urdu', None),
#  ('Ukraine', 'Ukrajina', 'Ukrainian', 67.5),
#  ('Ukraine', 'Ukrajina', 'Russian', 29.6),
#  ('Ukraine', 'Ukrajina', 'Other', 2.9),
#  ('Uganda', 'Uganda', 'Nilo', None),
#  ('Uganda', 'Uganda', 'Ganda', None),
#  ('Uganda', 'Uganda', 'English', None),
#  ('Uganda', 'Uganda', 'Arabic', None),
#  ('Uganda', 'Uganda', 'Swahili', None),
#  ('Uganda', 'Uganda', 'Other', None),
#  ('Tuvalu', 'Tuvalu', 'Kiribati', None),
#  ('Tuvalu', 'Tuvalu', 'Tuvaluan', None),
#  ('Tuvalu', 'Tuvalu', 'English', None),
#  ('Tuvalu', 'Tuvalu', 'Samoan', None),
#  ('Turks and Caicos Islands', 'The Turks and Caicos Islands', 'English', None),
#  ('Turkmenistan', 'Turkmenostan', 'Uzbek', 9.0),
#  ('Turkmenistan', 'Turkmenostan', 'Turkmen', 72.0),
#  ('Turkmenistan', 'Turkmenostan', 'Russian', 12.0),
#  ('Turkmenistan', 'Turkmenostan', 'Other', 7.0),
#  ('Turkey', 'Turkiye', 'Turkish', None),
#  ('Turkey', 'Turkiye', 'Other', None),
#  ('Turkey', 'Turkiye', 'Kurdish', None),
#  ('Tunisia', 'Tunis/Tunisie', 'Berber', None),
#  ('Tunisia', 'Tunis/Tunisie', 'Arabic', None),
#  ('Tunisia', 'Tunis/Tunisie', 'French', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'Spanish', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'Caribbean Hindustani', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'English', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'Chinese', None),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 'French', None),
#  ('Tonga', 'Tonga', 'unspecified', 0.03),
#  ('Tonga', 'Tonga', 'English', None),
#  ('Tonga', 'Tonga', 'Tongan', None),
#  ('Tonga', 'Tonga', 'Other', 1.1),
#  ('Togo', 'Togo', 'Mina', None),
#  ('Togo', 'Togo', 'Ewe', None),
#  ('Togo', 'Togo', 'French', None),
#  ('Togo', 'Togo', 'Dagomba', None),
#  ('Togo', 'Togo', 'Kabye', None),
#  ('Thailand', 'Prathet Thai', 'Burmese', 1.3),
#  ('Thailand', 'Prathet Thai', 'Thai', 90.7),
#  ('Thailand', 'Prathet Thai', 'Other', 8.0),
#  ('Tanzania', 'Tanzania', 'Arabic', None),
#  ('Tanzania', 'Tanzania', 'English', None),
#  ('Tanzania', 'Tanzania', 'Kiswahili', None),
#  ('Tanzania', 'Tanzania', 'many', None),
#  ('Tajikistan', 'Tocikiston', 'Russian', None),
#  ('Tajikistan', 'Tocikiston', 'Tajik', None),
#  ('Syria', 'Suriya', 'Armenian', None),
#  ('Syria', 'Suriya', 'Arabic', None),
#  ('Syria', 'Suriya', 'Kurdish', None),
#  ('Syria', 'Suriya', 'English', None),
#  ('Syria', 'Suriya', 'French', None),
#  ('Syria', 'Suriya', 'Circassian', None),
#  ('Syria', 'Suriya', 'Aramaic', None),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'German', 63.0),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'English', 4.9),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Italian', 8.1),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'French', 22.7),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Other', 7.1),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Romansch', 0.5),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Spanish', 2.2),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Serbo-Croatian', 2.4),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Albanian', 3.0),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 'Portuguese', 3.7),
#  ('Sweden', 'Sverige', 'Swedish', None),
#  ('Swaziland', 'kaNgwane', 'siSwati', None),
#  ('Swaziland', 'kaNgwane', 'English', None),
#  ('Suriname', 'Suriname', 'English', None),
#  ('Suriname', 'Suriname', 'Javanese', None),
#  ('Suriname', 'Suriname', 'Caribbean Hindustani', None),
#  ('Suriname', 'Suriname', 'Sranang Tongo', None),
#  ('Suriname', 'Suriname', 'Dutch', None),
#  ('Sudan', 'As-Sudan', 'English', None),
#  ('Sudan', 'As-Sudan', 'Arabic', None),
#  ('Sudan', 'As-Sudan', 'Fur', None),
#  ('Sudan', 'As-Sudan', 'Ta Bedawie', None),
#  ('Sudan', 'As-Sudan', 'Nubian', None),
#  ('Sri Lanka', 'Sri Lanka/Ilankai', 'Other', 8.0),
#  ('Sri Lanka', 'Sri Lanka/Ilankai', 'Sinhala', 74.0),
#  ('Sri Lanka', 'Sri Lanka/Ilankai', 'Tamil', 18.0),
#  ('Spain', 'Espana', 'Galician', 7.0),
#  ('Spain', 'Espana', 'Castilian Spanish', 74.0),
#  ('Spain', 'Espana', 'Basque', 2.0),
#  ('Spain', 'Espana', 'Catalan', 17.0),
#  ('Spain', 'Espana', 'Aranese', None),
#  ('South Korea', 'Taehan Min\x92guk (Namhan)', 'Korean', None),
#  ('South Korea', 'Taehan Min\x92guk (Namhan)', 'English', None),
#  ('South Africa', 'South Africa', 'Sepedi', 9.1),
#  ('South Africa', 'South Africa', 'IsiXhosa', 16.0),
#  ('South Africa', 'South Africa', 'IsiZulu', 22.7),
#  ('South Africa', 'South Africa', 'Afrikaans', 13.5),
#  ('South Africa', 'South Africa', 'Other', 1.6),
#  ('South Africa', 'South Africa', 'sign', 0.5),
#  ('South Africa', 'South Africa', 'isiNdebele', 2.1),
#  ('South Africa', 'South Africa', 'Tshivenda', 2.4),
#  ('South Africa', 'South Africa', 'siSwati', 2.5),
#  ('South Africa', 'South Africa', 'Xitsonga', 4.5),
#  ('South Africa', 'South Africa', 'Sesotho', 7.6),
#  ('South Africa', 'South Africa', 'Setswana', 8.0),
#  ('South Africa', 'South Africa', 'English', 9.6),
#  ('Somalia', 'Soomaaliya', 'Italian', None),
#  ('Somalia', 'Soomaaliya', 'English', None),
#  ('Somalia', 'Soomaaliya', 'Arabic', None),
#  ('Somalia', 'Soomaaliya', 'Somali', None),
#  ('Solomon Islands', 'Solomon Islands', 'indigenous', None),
#  ('Solomon Islands', 'Solomon Islands', 'English', 1.0),
#  ('Solomon Islands', 'Solomon Islands', 'Melanesian pidgin', None),
#  ('Slovenia', 'Slovenija', 'Italian', None),
#  ('Slovenia', 'Slovenija', 'Serbo', 4.5),
#  ('Slovenia', 'Slovenija', 'Other', 4.4),
#  ('Slovenia', 'Slovenija', 'Slovenian', 91.1),
#  ('Slovenia', 'Slovenija', 'Hungarian', None),
#  ('Slovakia', 'Slovensko', 'Roma', 2.3),
#  ('Slovakia', 'Slovensko', 'Slovak', 78.6),
#  ('Slovakia', 'Slovensko', 'Other', 8.8),
#  ('Slovakia', 'Slovensko', 'Ruthenian', 1.0),
#  ('Slovakia', 'Slovensko', 'Hungarian', 9.4),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Malay', 11.9),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Mandarin', 36.3),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Other', 1.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Other Chinese', 1.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Other Indian', 1.2),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Teochew', 3.2),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Tamil', 3.2),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Cantonese', 4.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'Hokkien', 8.1),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 'English', 29.8),
#  ('Sierra Leone', 'Sierra Leone', 'English', None),
#  ('Sierra Leone', 'Sierra Leone', 'Krio', 10.0),
#  ('Sierra Leone', 'Sierra Leone', 'Temne', None),
#  ('Sierra Leone', 'Sierra Leone', 'Mende', None),
#  ('Seychelles', 'Sesel/Seychelles', 'English', 5.1),
#  ('Seychelles', 'Sesel/Seychelles', 'Seychellois', 89.1),
#  ('Seychelles', 'Sesel/Seychelles', 'unspecified', 1.4),
#  ('Seychelles', 'Sesel/Seychelles', 'Other', 3.8),
#  ('Seychelles', 'Sesel/Seychelles', 'French', 0.7),
#  ('Senegal', 'Senegal/Sounougal', 'Wolof', None),
#  ('Senegal', 'Senegal/Sounougal', 'French', None),
#  ('Senegal', 'Senegal/Sounougal', 'Soninke', None),
#  ('Senegal', 'Senegal/Sounougal', 'Serer', None),
#  ('Senegal', 'Senegal/Sounougal', 'Mandinka', None),
#  ('Senegal', 'Senegal/Sounougal', 'Jola', None),
#  ('Senegal', 'Senegal/Sounougal', 'Pular', None),
#  ('Saudi Arabia', 'Al-´Arabiya as-Sa´udiya', 'Arabic', None),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Cabo', 8.5),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Portuguese', 98.4),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Other', 2.4),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Lunguie', 1.0),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'English', 4.9),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Angolar', 6.6),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'French', 6.8),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 'Forro', 36.2),
#  ('San Marino', 'San Marino', 'Italian', None),
#  ('Samoa', 'Samoa', 'Samoan', None),
#  ('Samoa', 'Samoa', 'English', None),
#  ('Saint Vincent and the Grenadines', 'Saint Vincent and the Grenadines', 'French patois', None),
#  ('Saint Vincent and the Grenadines', 'Saint Vincent and the Grenadines', 'English', None),
#  ('Saint Lucia', 'Saint Lucia', 'English', None),
#  ('Saint Lucia', 'Saint Lucia', 'French patois', None),
#  ('Saint Kitts and Nevis', 'Saint Kitts and Nevis', 'English', None),
#  ('Rwanda', 'Rwanda/Urwanda', 'English', 0.1),
#  ('Rwanda', 'Rwanda/Urwanda', 'unspecified', 0.3),
#  ('Rwanda', 'Rwanda/Urwanda', 'Other', 0.03),
#  ('Rwanda', 'Rwanda/Urwanda', 'Swahili', 0.02),
#  ('Rwanda', 'Rwanda/Urwanda', 'French', 0.1),
#  ('Rwanda', 'Rwanda/Urwanda', 'Kinyarwanda', 99.4),
#  ('Russian Federation', 'Rossija', 'Other', 10.1),
#  ('Russian Federation', 'Rossija', 'Chechen', 1.0),
#  ('Russian Federation', 'Rossija', 'Tatar', 3.2),
#  ('Russian Federation', 'Rossija', 'Russian', 85.7),
#  ('Qatar', 'Qatar', 'English', None),
#  ('Qatar', 'Qatar', 'Arabic', None),
#  ('Puerto Rico', 'Puerto Rico', 'Spanish', None),
#  ('Puerto Rico', 'Puerto Rico', 'English', None),
#  ('Portugal', 'Portugal', 'Mirandese', None),
#  ('Portugal', 'Portugal', 'Portuguese', None),
#  ('Poland', 'Polska', 'Other', 1.1),
#  ('Poland', 'Polska', 'Polish', 98.2),
#  ('Poland', 'Polska', 'unspecified', 1.3),
#  ('Poland', 'Polska', 'Silesian', 1.4),
#  ('Philippines', 'Pilipinas', 'Other', None),
#  ('Philippines', 'Pilipinas', 'Filipino', None),
#  ('Philippines', 'Pilipinas', 'English', None),
#  ('Peru', 'Peru/Piruw', 'Quechua', 13.0),
#  ('Peru', 'Peru/Piruw', 'Other', 0.2),
#  ('Peru', 'Peru/Piruw', 'Other Native', 0.7),
#  ('Peru', 'Peru/Piruw', 'Ashaninka', 0.3),
#  ('Peru', 'Peru/Piruw', 'Aymara', 1.7),
#  ('Peru', 'Peru/Piruw', 'Spanish', 84.1),
#  ('Paraguay', 'Paraguay', 'Guarani', None),
#  ('Paraguay', 'Paraguay', 'Spanish', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'English', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'Tok Pisin', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'Other', None),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 'Hiri', None),
#  ('Panama', 'Panama', 'indigenous', None),
#  ('Panama', 'Panama', 'Spanish', None),
#  ('Panama', 'Panama', 'Japanese', None),
#  ('Panama', 'Panama', 'Korean', None),
#  ('Panama', 'Panama', 'Hebrew', None),
#  ('Panama', 'Panama', 'Other', None),
#  ('Panama', 'Panama', 'French', None),
#  ('Panama', 'Panama', 'Arabic', None),
#  ('Panama', 'Panama', 'Chinese', None),
#  ('Panama', 'Panama', 'English', None),
#  ('Panama', 'Panama', 'Panamanian English Creole', None),
#  ('Palestine', 'Filastin', None, None),
#  ('Palau', 'Belau/Palau', 'English', 19.1),
#  ('Palau', 'Belau/Palau', 'Other', 1.9),
#  ('Palau', 'Belau/Palau', 'Other', 2.8),
#  ('Palau', 'Belau/Palau', 'Chinese', 1.2),
#  ('Palau', 'Belau/Palau', 'Filipino', 9.9),
#  ('Palau', 'Belau/Palau', 'Palauan', 65.2),
#  ('Pakistan', 'Pakistan', 'Saraiki', 10.0),
#  ('Pakistan', 'Pakistan', 'Other', None),
#  ('Pakistan', 'Pakistan', 'Burushaski', None),
#  ('Pakistan', 'Pakistan', 'English', None),
#  ('Pakistan', 'Pakistan', 'Brahui', 1.0),
#  ('Pakistan', 'Pakistan', 'Hindko', 2.0),
#  ('Pakistan', 'Pakistan', 'Balochi', 3.0),
#  ('Pakistan', 'Pakistan', 'Urdu', 8.0),
#  ('Pakistan', 'Pakistan', 'Pashto', 8.0),
#  ('Pakistan', 'Pakistan', 'Sindhi', 12.0),
#  ('Pakistan', 'Pakistan', 'Punjabi', 48.0),
#  ('Oman', '´Uman', 'Urdu', None),
#  ('Oman', '´Uman', 'Baluchi', None),
#  ('Oman', '´Uman', 'Indian', None),
#  ('Oman', '´Uman', 'English', None),
#  ('Oman', '´Uman', 'Arabic', None),
#  ('Norway', 'Norge', 'Bokmal', None),
#  ('Norway', 'Norge', 'Other', None),
#  ('Norway', 'Norge', 'Nynorsk', None),
#  ('North Korea', 'Choson Minjujuui In´min Konghwaguk (Bukhan)', 'Korean', None),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Other Pacific Island', 10.1),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Other', 1.9),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Other Asian', 7.3),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Chinese', 6.8),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'English', 17.0),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Chamorro', 24.1),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 'Philippine', 32.8),
#  ('Nigeria', 'Nigeria', 'Other', None),
#  ('Nigeria', 'Nigeria', 'Fulani', None),
#  ('Nigeria', 'Nigeria', 'Igbo', None),
#  ('Nigeria', 'Nigeria', 'Yoruba', None),
#  ('Nigeria', 'Nigeria', 'Hausa', None),
#  ('Nigeria', 'Nigeria', 'English', None),
#  ('Niger', 'Niger', 'Djerma', None),
#  ('Niger', 'Niger', 'Hausa', None),
#  ('Niger', 'Niger', 'French', None),
#  ('Nicaragua', 'Nicaragua', 'Miskito', 2.2),
#  ('Nicaragua', 'Nicaragua', 'Other', 0.5),
#  ('Nicaragua', 'Nicaragua', 'Mestizo', 2.0),
#  ('Nicaragua', 'Nicaragua', 'Spanish', 95.3),
#  ('New Zealand', 'New Zealand/Aotearoa', 'New Zealand Sign', None),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Other', 20.5),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Yue', 1.0),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Northern Chinese', 1.2),
#  ('New Zealand', 'New Zealand/Aotearoa', 'French', 1.2),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Hindi', 1.6),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Samoan', 2.0),
#  ('New Zealand', 'New Zealand/Aotearoa', 'Maori', 3.5),
#  ('New Zealand', 'New Zealand/Aotearoa', 'English', 89.8),
#  ('New Caledonia', 'Nouvelle-Caledonie', 'Other', None),
#  ('New Caledonia', 'Nouvelle-Caledonie', 'French', None),
#  ('Netherlands', 'Nederland', 'Dutch', None),
#  ('Nepal', 'Nepal', 'unspecified', 0.2),
#  ('Nepal', 'Nepal', 'Other', 10.4),
#  ('Nepal', 'Nepal', 'Gurung', 1.2),
#  ('Nepal', 'Nepal', 'Limbu', 1.3),
#  ('Nepal', 'Nepal', 'Avadhi', 1.9),
#  ('Nepal', 'Nepal', 'Urdu', 2.6),
#  ('Nepal', 'Nepal', 'Bajjika', 3.0),
#  ('Nepal', 'Nepal', 'Magar', 3.0),
#  ('Nepal', 'Nepal', 'Newar', 3.2),
#  ('Nepal', 'Nepal', 'Tamang', 5.1),
#  ('Nepal', 'Nepal', 'Tharu', 5.8),
#  ('Nepal', 'Nepal', 'Bhojpuri', 6.0),
#  ('Nepal', 'Nepal', 'Nepali', 44.6),
#  ('Nepal', 'Nepal', 'Maithali', 11.7),
#  ('Nauru', 'Naoero/Nauru', 'English', 2.0),
#  ('Nauru', 'Naoero/Nauru', 'Other', 5.0),
#  ('Nauru', 'Naoero/Nauru', 'Nauruan', 93.0),
#  ('Namibia', 'Namibia', 'Other', 1.7),
#  ('Namibia', 'Namibia', 'Caprivi', 4.8),
#  ('Namibia', 'Namibia', 'Kavango', 8.5),
#  ('Namibia', 'Namibia', 'Other', 2.3),
#  ('Namibia', 'Namibia', 'Otjiherero', 8.6),
#  ('Namibia', 'Namibia', 'Afrikaans', 10.4),
#  ('Namibia', 'Namibia', 'Nama', 11.3),
#  ('Namibia', 'Namibia', 'Oshivambo', 48.9),
#  ('Namibia', 'Namibia', 'English', 3.4),
#  ('Myanmar', 'Myanma Pye', 'Burmese', None),
#  ('Mozambique', 'Mocambique', 'Echuwabo', 5.1),
#  ('Mozambique', 'Mocambique', 'Elomwe', 7.0),
#  ('Mozambique', 'Mocambique', 'Cisena', 7.5),
#  ('Mozambique', 'Mocambique', 'Xichangana', 10.3),
#  ('Mozambique', 'Mocambique', 'Portuguese', 10.7),
#  ('Mozambique', 'Mocambique', 'Emakhuwa', 25.3),
#  ('Mozambique', 'Mocambique', 'unspecified', 3.7),
#  ('Mozambique', 'Mocambique', 'Other', 30.4),
#  ('Morocco', 'Al-Maghrib', 'government', None),
#  ('Morocco', 'Al-Maghrib', 'and', None),
#  ('Morocco', 'Al-Maghrib', 'French', None),
#  ('Morocco', 'Al-Maghrib', 'Tarifit', None),
#  ('Morocco', 'Al-Maghrib', 'Tachelhit', None),
#  ('Morocco', 'Al-Maghrib', 'Berber', None),
#  ('Morocco', 'Al-Maghrib', 'Arabic', None),
#  ('Mongolia', 'Mongol Uls', 'Russian', None),
#  ('Mongolia', 'Mongol Uls', 'Turkic', None),
#  ('Mongolia', 'Mongol Uls', 'Mongolian', 90.0),
#  ('Monaco', 'Monaco', 'Italian', None),
#  ('Monaco', 'Monaco', 'Monegasque', None),
#  ('Monaco', 'Monaco', 'English', None),
#  ('Monaco', 'Monaco', 'French', None),
#  ('Moldova', 'Moldova', 'Romani', 0.3),
#  ('Moldova', 'Moldova', 'Bulgarian', 1.5),
#  ('Moldova', 'Moldova', 'Ukrainian', 3.9),
#  ('Moldova', 'Moldova', 'Gagauz', 4.2),
#  ('Moldova', 'Moldova', 'Russian', 9.7),
#  ('Moldova', 'Moldova', 'Romanian', 80.2),
#  ('Moldova', 'Moldova', 'Other', 0.2),
#  ('Micronesia, Federated States of', 'Micronesia', 'Nukuoro', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Woleaian', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Ulithian', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Yapese', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Pohnpeian', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Kosrean', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Chuukese', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'English', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Kapingamarangi', None),
#  ('Mexico', 'Mexico', 'indigenous', 0.8),
#  ('Mexico', 'Mexico', 'Spanish', 92.7),
#  ('Mexico', 'Mexico', 'unspecified', 0.8),
#  ('Mauritius', 'Mauritius', 'Other', 2.6),
#  ('Mauritius', 'Mauritius', 'French', 4.1),
#  ('Mauritius', 'Mauritius', 'Bhojpuri', 5.3),
#  ('Mauritius', 'Mauritius', 'Creole', 86.5),
#  ('Mauritius', 'Mauritius', 'unspecified', 0.1),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Wolof', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'French', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Soninke', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Pular', None),
#  ('Mauritania', 'Muritaniya/Mauritanie', 'Arabic', None),
#  ('Marshall Islands', 'Marshall Islands/Majol', 'Other', 1.8),
#  ('Marshall Islands', 'Marshall Islands/Majol', 'Marshallese', 98.2),
#  ('Malta', 'Malta', 'Other', 0.9),
#  ('Malta', 'Malta', 'multilingual', 3.0),
#  ('Malta', 'Malta', 'English', 6.0),
#  ('Malta', 'Malta', 'Maltese', 90.1),
#  ('Mali', 'Mali', 'Minianka', 4.3),
#  ('Mali', 'Mali', 'Sonrhai/Djerma', 5.6),
#  ('Mali', 'Mali', 'Malinke', 5.6),
#  ('Mali', 'Mali', 'French', None),
#  ('Mali', 'Mali', 'Other', 6.3),
#  ('Mali', 'Mali', 'unspecified', 0.7),
#  ('Mali', 'Mali', 'Bobo', 2.1),
#  ('Mali', 'Mali', 'Senoufo', 2.6),
#  ('Mali', 'Mali', 'Tamacheq', 3.5),
#  ('Mali', 'Mali', 'Peul/Foulfoulbe', 9.4),
#  ('Mali', 'Mali', 'Bambara', 46.3),
#  ('Mali', 'Mali', 'Maraka/Soninke', 6.4),
#  ('Mali', 'Mali', 'Dogon', 7.2),
#  ('Maldives', 'Dhivehi Raajje/Maldives', 'Dhivehi', None),
#  ('Maldives', 'Dhivehi Raajje/Maldives', 'English', None),
#  ('Malaysia', 'Malaysia', 'Malayalam', None),
#  ('Malaysia', 'Malaysia', 'Thai', None),
#  ('Malaysia', 'Malaysia', 'Panjabi', None),
#  ('Malaysia', 'Malaysia', 'Telugu', None),
#  ('Malaysia', 'Malaysia', 'Tamil', None),
#  ('Malaysia', 'Malaysia', 'Chinese', None),
#  ('Malaysia', 'Malaysia', 'English', None),
#  ('Malaysia', 'Malaysia', 'Bahasa Malaysia', None),
#  ('Malawi', 'Malawi', 'Chichewa', None),
#  ('Malawi', 'Malawi', 'English', None),
#  ('Malawi', 'Malawi', 'Chilambya', None),
#  ('Malawi', 'Malawi', 'Chinyakyusa', None),
#  ('Malawi', 'Malawi', 'Chitonga', None),
#  ('Malawi', 'Malawi', 'Chisena', None),
#  ('Malawi', 'Malawi', 'Chingoni', None),
#  ('Malawi', 'Malawi', 'Chinkhonde', None),
#  ('Malawi', 'Malawi', 'Chilomwe', None),
#  ('Malawi', 'Malawi', 'Chitumbuka', None),
#  ('Malawi', 'Malawi', 'Chiyao', None),
#  ('Malawi', 'Malawi', 'Chinyanja', None),
#  ('Madagascar', 'Madagasikara/Madagascar', 'English', None),
#  ('Madagascar', 'Madagasikara/Madagascar', 'Malagasy', None),
#  ('Madagascar', 'Madagasikara/Madagascar', 'French', None),
#  ('Macedonia', 'Makedonija', 'Serbian', 1.2),
#  ('Macedonia', 'Makedonija', 'Macedonian', 66.5),
#  ('Macedonia', 'Makedonija', 'Romani', 1.9),
#  ('Macedonia', 'Makedonija', 'Albanian', 25.1),
#  ('Macedonia', 'Makedonija', 'Turkish', 3.5),
#  ('Macedonia', 'Makedonija', 'Other', 1.8),
#  ('Macao', 'Macau/Aomen', None, None),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'French', 4.2),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'Luxembourgish', 88.8),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'Portuguese', 2.3),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'German', 1.1),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 'Other', 3.5),
#  ('Lithuania', 'Lietuva', 'Lithuanian', 82.0),
#  ('Lithuania', 'Lietuva', 'unspecified', 3.5),
#  ('Lithuania', 'Lietuva', 'Other', 0.9),
#  ('Lithuania', 'Lietuva', 'Polish', 5.6),
#  ('Lithuania', 'Lietuva', 'Russian', 8.0),
#  ('Liechtenstein', 'Liechtenstein', 'Italian', 1.1),
#  ('Liechtenstein', 'Liechtenstein', 'Other', 4.3),
#  ('Liechtenstein', 'Liechtenstein', 'German', 94.5),
#  ('Libya', 'Libiya', 'Italian', None),
#  ('Libya', 'Libiya', 'Berber', None),
#  ('Libya', 'Libiya', 'English', None),
#  ('Libya', 'Libiya', 'Arabic', None),
#  ('Liberia', 'Liberia', 'Other', None),
#  ('Liberia', 'Liberia', 'English', 20.0),
#  ('Lesotho', 'Lesotho', 'English', None),
#  ('Lesotho', 'Lesotho', 'Xhosa', None),
#  ('Lesotho', 'Lesotho', 'Zulu', None),
#  ('Lesotho', 'Lesotho', 'Sesotho', None),
#  ('Lebanon', 'Lubnan', 'French', None),
#  ('Lebanon', 'Lubnan', 'Armenian', None),
#  ('Lebanon', 'Lubnan', 'English', None),
#  ('Lebanon', 'Lubnan', 'Arabic', None),
#  ('Latvia', 'Latvija', 'Russian', 33.8),
#  ('Latvia', 'Latvija', 'unspecified', 9.4),
#  ('Latvia', 'Latvija', 'Other', 0.6),
#  ('Latvia', 'Latvija', 'Latvian', 56.3),
#  ('Laos', 'Lao', 'Other', None),
#  ('Laos', 'Lao', 'English', None),
#  ('Laos', 'Lao', 'French', None),
#  ('Laos', 'Lao', 'Lao', None),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Other', 5.2),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Russian', 9.0),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Uzbek', 14.4),
#  ('Kyrgyzstan', 'Kyrgyzstan', 'Kyrgyz', 71.4),
#  ('Kuwait', 'Al-Kuwayt', 'Arabic', None),
#  ('Kuwait', 'Al-Kuwayt', 'English', None),
#  ('Kiribati', 'Kiribati', 'English', None),
#  ('Kiribati', 'Kiribati', 'Kiribati', None),
#  ('Kenya', 'Kenya', 'English', None),
#  ('Kenya', 'Kenya', 'Other', None),
#  ('Kenya', 'Kenya', 'Kiswahili', None),
#  ('Kazakhstan', 'Qazaqstan', 'Kazakh', 74.0),
#  ('Kazakhstan', 'Qazaqstan', 'Russian', 94.4),
#  ('Jordan', 'Al-Urdunn', 'English', None),
#  ('Jordan', 'Al-Urdunn', 'Arabic', None),
#  ('Japan', 'Nihon/Nippon', 'Japanese', None),
#  ('Jamaica', 'Jamaica', 'English patois', None),
#  ('Jamaica', 'Jamaica', 'English', None),
#  ('Italy', 'Italia', 'German', None),
#  ('Italy', 'Italia', 'Slovene', None),
#  ('Italy', 'Italia', 'French', None),
#  ('Italy', 'Italia', 'Italian', None),
#  ('Israel', 'Yisra\x92el/Isra\x92il', 'English', None),
#  ('Israel', 'Yisra\x92el/Isra\x92il', 'Hebrew', None),
#  ('Israel', 'Yisra\x92el/Isra\x92il', 'Arabic', None),
#  ('Ireland', 'Ireland/Eire', 'Irish', 38.7),
#  ('Ireland', 'Ireland/Eire', 'English', 61.3),
#  ('Iraq', 'Al-´Iraq', 'Turkmen', None),
#  ('Iraq', 'Al-´Iraq', 'Kurdish', None),
#  ('Iraq', 'Al-´Iraq', 'Arabic', None),
#  ('Iraq', 'Al-´Iraq', 'Armenian', None),
#  ('Iraq', 'Al-´Iraq', 'Syriac', None),
#  ('Iran', 'Iran', 'Gilaki and Mazandarani', None),
#  ('Iran', 'Iran', 'Kurdish', None),
#  ('Iran', 'Iran', 'Persian', None),
#  ('Iran', 'Iran', 'Turkic', None),
#  ('Iran', 'Iran', 'Other', None),
#  ('Iran', 'Iran', 'Arabic', None),
#  ('Iran', 'Iran', 'Balochi', None),
#  ('Iran', 'Iran', 'Luri', None),
#  ('Indonesia', 'Indonesia', 'English', None),
#  ('Indonesia', 'Indonesia', 'Other', None),
#  ('Indonesia', 'Indonesia', 'Dutch', None),
#  ('Indonesia', 'Indonesia', 'Bahasa', None),
#  ('India', 'Bharat/India', 'Punjabi', 2.8),
#  ('India', 'Bharat/India', 'Other', 5.9),
#  ('India', 'Bharat/India', 'Maithili', 1.2),
#  ('India', 'Bharat/India', 'Assamese', 1.3),
#  ('India', 'Bharat/India', 'Oriya', 3.2),
#  ('India', 'Bharat/India', 'Malayalam', 3.2),
#  ('India', 'Bharat/India', 'Kannada', 3.7),
#  ('India', 'Bharat/India', 'Gujarati', 4.5),
#  ('India', 'Bharat/India', 'Urdu', 5.0),
#  ('India', 'Bharat/India', 'Tamil', 5.9),
#  ('India', 'Bharat/India', 'Marathi', 7.0),
#  ('India', 'Bharat/India', 'Telugu', 7.2),
#  ('India', 'Bharat/India', 'Bengali', 8.1),
#  ('India', 'Bharat/India', 'Hindi', 41.0),
#  ('Iceland', 'Island', 'Icelandic', None),
#  ('Iceland', 'Island', 'German', None),
#  ('Iceland', 'Island', 'Nordic', None),
#  ('Iceland', 'Island', 'English', None),
#  ('Hungary', 'Magyarorszag', 'Russian', 1.6),
#  ('Hungary', 'Magyarorszag', 'Other', 4.2),
#  ('Hungary', 'Magyarorszag', 'French', 1.2),
#  ('Hungary', 'Magyarorszag', 'Romanian', 1.3),
#  ('Hungary', 'Magyarorszag', 'German', 11.2),
#  ('Hungary', 'Magyarorszag', 'English', 16.0),
#  ('Hungary', 'Magyarorszag', 'Hungarian', 99.6),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Cantonese', 89.5),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Other', 1.6),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'English', 3.5),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Other Chinese', 4.0),
#  ('Hong Kong', 'Xianggang/Hong Kong', 'Mandarin', 1.4),
#  ('Honduras', 'Honduras', 'Spanish', None),
#  ('Honduras', 'Honduras', 'Amerindian', None),
#  ('Haiti', 'Haiti/Dayti', 'Creole', None),
#  ('Haiti', 'Haiti/Dayti', 'French', None),
#  ('Guyana', 'Guyana', 'Amerindian', None),
#  ('Guyana', 'Guyana', 'Guyanese Creole', None),
#  ('Guyana', 'Guyana', 'Chinese', None),
#  ('Guyana', 'Guyana', 'Indian', None),
#  ('Guyana', 'Guyana', 'English', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Mandingo', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Pular', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Portuguese', None),
#  ('Guinea-Bissau', 'Guine-Bissau', 'Crioulo', None),
#  ('Guinea', 'Guinee', 'French', None),
#  ('Guatemala', 'Guatemala', 'Spanish', 60.0),
#  ('Guatemala', 'Guatemala', 'Amerindian', 40.0),
#  ('Guam', 'Guam', 'Other Pacific Islander', 10.0),
#  ('Guam', 'Guam', 'Chamorro', 17.8),
#  ('Guam', 'Guam', 'English', 43.6),
#  ('Guam', 'Guam', 'Filipino', 21.2),
#  ('Guam', 'Guam', 'Other', 1.1),
#  ('Guam', 'Guam', 'Asian', 6.3),
#  ('Grenada', 'Grenada', 'French patois', None),
#  ('Grenada', 'Grenada', 'English', None),
#  ('Greenland', 'Kalaallit Nunaat/Gronland', 'Danish', None),
#  ('Greenland', 'Kalaallit Nunaat/Gronland', 'English', None),
#  ('Greenland', 'Kalaallit Nunaat/Gronland', 'Greenlandic', None),
#  ('Greece', 'Ellada', 'Other', 1.0),
#  ('Greece', 'Ellada', 'Greek', 99.0),
#  ('Gibraltar', 'Gibraltar', 'Spanish', None),
#  ('Gibraltar', 'Gibraltar', 'Portuguese', None),
#  ('Gibraltar', 'Gibraltar', 'Italian', None),
#  ('Gibraltar', 'Gibraltar', 'English', None),
#  ('Ghana', 'Ghana', 'Asante', 16.0),
#  ('Ghana', 'Ghana', 'Other', 31.2),
#  ('Ghana', 'Ghana', 'Ga', 3.1),
#  ('Ghana', 'Ghana', 'Akyem', 3.2),
#  ('Ghana', 'Ghana', 'Kokomba', 3.5),
#  ('Ghana', 'Ghana', 'Dagarte', 3.9),
#  ('Ghana', 'Ghana', 'Dangme', 4.2),
#  ('Ghana', 'Ghana', 'Dagomba', 4.4),
#  ('Ghana', 'Ghana', 'Boron', 4.9),
#  ('Ghana', 'Ghana', 'Fante', 11.6),
#  ('Ghana', 'Ghana', 'Ewe', 14.0),
#  ('Germany', 'Deutschland', 'German', None),
#  ('Georgia', 'Sakartvelo', 'Georgian', 87.6),
#  ('Georgia', 'Sakartvelo', 'Other', 1.0),
#  ('Georgia', 'Sakartvelo', 'Russian', 1.2),
#  ('Georgia', 'Sakartvelo', 'Armenian', 3.9),
#  ('Georgia', 'Sakartvelo', 'Azeri', 6.2),
#  ('Gambia', 'The Gambia', 'Mandinka', None),
#  ('Gambia', 'The Gambia', 'Other', None),
#  ('Gambia', 'The Gambia', 'Fula', None),
#  ('Gambia', 'The Gambia', 'Wolof', None),
#  ('Gambia', 'The Gambia', 'English', None),
#  ('Gabon', 'Le Gabon', 'Fang', None),
#  ('Gabon', 'Le Gabon', 'Bandjabi', None),
#  ('Gabon', 'Le Gabon', 'Bapounou/Eschira', None),
#  ('Gabon', 'Le Gabon', 'Nzebi', None),
#  ('Gabon', 'Le Gabon', 'Myene', None),
#  ('Gabon', 'Le Gabon', 'French', None),
#  ('French Polynesia', 'Polynesie francaise', 'Polynesian', 28.2),
#  ('French Polynesia', 'Polynesie francaise', 'Other', 1.8),
#  ('French Polynesia', 'Polynesie francaise', 'French', 70.0),
#  ('France', 'France', 'Occitan', None),
#  ('France', 'France', 'Mahorian', None),
#  ('France', 'France', 'Creole patois', None),
#  ('France', 'France', 'French', None),
#  ('France', 'France', 'Picard', None),
#  ('France', 'France', 'Flemish', None),
#  ('France', 'France', 'Basque', None),
#  ('France', 'France', 'Catalan', None),
#  ('France', 'France', 'Corsican', None),
#  ('France', 'France', 'Alsatian', None),
#  ('France', 'France', 'Breton', None),
#  ('France', 'France', 'Provencal', None),
#  ('France', 'France', 'French', 100.0),
#  ('Finland', 'Suomi', 'Other', 5.0),
#  ('Finland', 'Suomi', 'Swedish', 5.3),
#  ('Finland', 'Suomi', 'Finnish', 88.3),
#  ('Finland', 'Suomi', 'Russian', 1.4),
#  ('Fiji Islands', 'Fiji Islands', None, None),
#  ('Faroe Islands', 'Foroyar', 'Faroese', 93.8),
#  ('Faroe Islands', 'Foroyar', 'Danish', 3.2),
#  ('Faroe Islands', 'Foroyar', 'Other', 3.0),
#  ('Ethiopia', 'YeItyop´iya', 'Hadiyya', 1.7),
#  ('Ethiopia', 'YeItyop´iya', 'Afar', 1.7),
#  ('Ethiopia', 'YeItyop´iya', 'Gurage', 2.0),
#  ('Ethiopia', 'YeItyop´iya', 'Wolaytta', 2.2),
#  ('Ethiopia', 'YeItyop´iya', 'Sidamo', 4.0),
#  ('Ethiopia', 'YeItyop´iya', 'Tigrigna', 5.9),
#  ('Ethiopia', 'YeItyop´iya', 'Somali', 6.2),
#  ('Ethiopia', 'YeItyop´iya', 'Amharic', 29.3),
#  ('Ethiopia', 'YeItyop´iya', 'Oromo', 33.8),
#  ('Ethiopia', 'YeItyop´iya', 'Arabic', None),
#  ('Ethiopia', 'YeItyop´iya', 'English', None),
#  ('Ethiopia', 'YeItyop´iya', 'Other', 8.1),
#  ('Ethiopia', 'YeItyop´iya', 'Kafa', 1.1),
#  ('Ethiopia', 'YeItyop´iya', 'Opuuo', 1.2),
#  ('Ethiopia', 'YeItyop´iya', 'Gedeo', 1.3),
#  ('Ethiopia', 'YeItyop´iya', 'Gamo', 1.5),
#  ('Estonia', 'Eesti', 'unspecified', 0.1),
#  ('Estonia', 'Eesti', 'Other', 1.2),
#  ('Estonia', 'Eesti', 'Ukrainian', 0.6),
#  ('Estonia', 'Eesti', 'Russian', 29.6),
#  ('Estonia', 'Eesti', 'Estonian', 68.5),
#  ('Eritrea', 'Ertra', 'Afar', None),
#  ('Eritrea', 'Ertra', 'Kunama', None),
#  ('Eritrea', 'Ertra', 'Other', None),
#  ('Eritrea', 'Ertra', 'Tigre', None),
#  ('Eritrea', 'Ertra', 'English', None),
#  ('Eritrea', 'Ertra', 'Arabic', None),
#  ('Eritrea', 'Ertra', 'Tigrinya', None),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Other', None),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Bubi', 32.4),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Fang', None),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 'Spanish', 67.6),
#  ('El Salvador', 'El Salvador', 'Nawat', None),
#  ('El Salvador', 'El Salvador', 'Spanish', None),
#  ('Egypt', 'Misr', 'Arabic', None),
#  ('Egypt', 'Misr', 'English', None),
#  ('Ecuador', 'Ecuador', 'Other', 0.7),
#  ('Ecuador', 'Ecuador', 'foreign', 2.2),
#  ('Ecuador', 'Ecuador', 'Quechua', 4.1),
#  ('Ecuador', 'Ecuador', 'Spanish', 93.0),
#  ('Dominican Republic', 'Republica Dominicana', 'Spanish', None),
#  ('Dominica', 'Dominica', 'English', None),
#  ('Dominica', 'Dominica', 'French patois', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'French', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'Arabic', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'Somali', None),
#  ('Djibouti', 'Djibouti/Jibuti', 'Afar', None),
#  ('Denmark', 'Danmark', 'German', None),
#  ('Denmark', 'Danmark', 'Greenlandic', None),
#  ('Denmark', 'Danmark', 'Faroese', None),
#  ('Denmark', 'Danmark', 'Danish', None),
#  ('Czech Republic', '¸esko', None, None),
#  ('Cyprus', 'Kypros/Kibris', 'unspecified', 0.6),
#  ('Cyprus', 'Kypros/Kibris', 'Filipino', 1.1),
#  ('Cyprus', 'Kypros/Kibris', 'Arabic', 1.2),
#  ('Cyprus', 'Kypros/Kibris', 'Bulgarian', 2.2),
#  ('Cyprus', 'Kypros/Kibris', 'Russian', 2.5),
#  ('Cyprus', 'Kypros/Kibris', 'Romanian', 2.9),
#  ('Cyprus', 'Kypros/Kibris', 'English', 4.1),
#  ('Cyprus', 'Kypros/Kibris', 'Turkish', 0.2),
#  ('Cyprus', 'Kypros/Kibris', 'Greek', 80.9),
#  ('Cyprus', 'Kypros/Kibris', 'Other', 4.3),
#  ('Cuba', 'Cuba', 'Spanish', None),
#  ('Croatia', 'Hrvatska', 'Other', 3.0),
#  ('Croatia', 'Hrvatska', 'Serbian', 1.2),
#  ('Croatia', 'Hrvatska', 'unspecified', 0.2),
#  ('Croatia', 'Hrvatska', 'Croatian', 95.6),
#  ("Cote d'Ivoire", 'Cote d\x92Ivoire', 'French', None),
#  ("Cote d'Ivoire", 'Cote d\x92Ivoire', 'Other', None),
#  ('Costa Rica', 'Costa Rica', 'Spanish', None),
#  ('Costa Rica', 'Costa Rica', 'English', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Lingala', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'French', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Tshiluba', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Kikongo', None),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 'Kingwana', None),
#  ('Congo', 'Congo', 'Lingala', None),
#  ('Congo', 'Congo', 'French', None),
#  ('Congo', 'Congo', 'Other', None),
#  ('Comoros', 'Komori/Comores', 'French', None),
#  ('Comoros', 'Komori/Comores', 'Arabic', None),
#  ('Comoros', 'Komori/Comores', 'Shikomoro', None),
#  ('Colombia', 'Colombia', 'Spanish', None),
#  ('China', 'Zhongquo', 'Hakka', None),
#  ('China', 'Zhongquo', 'Gan', None),
#  ('China', 'Zhongquo', 'Xiang', None),
#  ('China', 'Zhongquo', 'Minnan', None),
#  ('China', 'Zhongquo', 'Minbei', None),
#  ('China', 'Zhongquo', 'Wu', None),
#  ('China', 'Zhongquo', 'Other', None),
#  ('China', 'Zhongquo', 'Mandarin', None),
#  ('China', 'Zhongquo', 'Yue', None),
#  ('Chile', 'Chile', 'Other', 2.3),
#  ('Chile', 'Chile', 'indigenous', 1.0),
#  ('Chile', 'Chile', 'English', 10.2),
#  ('Chile', 'Chile', 'Spanish', 99.5),
#  ('Chile', 'Chile', 'unspecified', 0.2),
#  ('Chad', 'Tchad/Tshad', 'Arabic', None),
#  ('Chad', 'Tchad/Tshad', 'Other', None),
#  ('Chad', 'Tchad/Tshad', 'Sara', None),
#  ('Chad', 'Tchad/Tshad', 'French', None),
#  ('Central African Republic', 'Centrafrique/Be-Afrika', 'French', None),
#  ('Central African Republic', 'Centrafrique/Be-Afrika', 'tribal', None),
#  ('Central African Republic', 'Centrafrique/Be-Afrika', 'Sangho', None),
#  ('Cayman Islands', 'Cayman Islands', 'English', 90.9),
#  ('Cayman Islands', 'Cayman Islands', 'Other', 1.7),
#  ('Cayman Islands', 'Cayman Islands', 'Filipino', 3.3),
#  ('Cayman Islands', 'Cayman Islands', 'Spanish', 4.0),
#  ('Cayman Islands', 'Cayman Islands', 'unspecified', 0.1),
#  ('Cape Verde', 'Cabo Verde', None, None),
#  ('Canada', 'Canada', 'Tagalog', 1.2),
#  ('Canada', 'Canada', 'Cantonese', 1.2),
#  ('Canada', 'Canada', 'German', 1.3),
#  ('Canada', 'Canada', 'Spanish', 1.3),
#  ('Canada', 'Canada', 'Italian', 1.3),
#  ('Canada', 'Canada', 'Punjabi', 1.4),
#  ('Canada', 'Canada', 'French', 22.0),
#  ('Canada', 'Canada', 'English', 58.7),
#  ('Canada', 'Canada', 'Other', 10.5),
#  ('Canada', 'Canada', 'Arabic', 1.1),
#  ('Cameroon', 'Cameroun/Cameroon', 'Other', None),
#  ('Cameroon', 'Cameroun/Cameroon', 'French', None),
#  ('Cameroon', 'Cameroun/Cameroon', 'English', None),
#  ('Cambodia', 'Kampuchea', 'Other', 3.7),
#  ('Cambodia', 'Kampuchea', 'Khmer', 96.3),
#  ('Burundi', 'Burundi/Uburundi', 'Kirundi', 38.8),
#  ('Burundi', 'Burundi/Uburundi', 'unspecified', 56.9),
#  ('Burundi', 'Burundi/Uburundi', 'Other', 3.7),
#  ('Burundi', 'Burundi/Uburundi', 'English', 0.06),
#  ('Burundi', 'Burundi/Uburundi', 'Swahili', 0.2),
#  ('Burundi', 'Burundi/Uburundi', 'French', 0.3),
#  ('Burkina Faso', 'Burkina Faso', 'Sudanic family', 90.0),
#  ('Burkina Faso', 'Burkina Faso', 'French', None),
#  ('Bulgaria', 'Balgarija', 'Romani', 3.8),
#  ('Bulgaria', 'Balgarija', 'Turkish', 8.2),
#  ('Bulgaria', 'Balgarija', 'Bulgarian', 76.8),
#  ('Bulgaria', 'Balgarija', 'unspecified', 10.5),
#  ('Bulgaria', 'Balgarija', 'Other', 0.7),
#  ('Brunei', 'Brunei Darussalam', 'Malay', None),
#  ('Brunei', 'Brunei Darussalam', 'English', None),
#  ('Brunei', 'Brunei Darussalam', 'Chinese', None),
#  ('Brazil', 'Brasil', 'Portuguese', None),
#  ('Botswana', 'Botswana', 'Sembukushu', 1.6),
#  ('Botswana', 'Botswana', 'Sesarwa', 1.7),
#  ('Botswana', 'Botswana', 'Zezuru', 2.0),
#  ('Botswana', 'Botswana', 'English', 2.8),
#  ('Botswana', 'Botswana', 'Shekgalagadi', 3.4),
#  ('Botswana', 'Botswana', 'Sekalanga', 7.4),
#  ('Botswana', 'Botswana', 'Setswana', 77.3),
#  ('Botswana', 'Botswana', 'Other', 2.8),
#  ('Botswana', 'Botswana', 'Ndebele', 1.0),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Croatian', 14.6),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Serbian', 30.8),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Bosnian', 52.9),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'No Answer', 0.2),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 'Other', 1.6),
#  ('Bolivia', 'Bolivia', 'Other', 0.4),
#  ('Bolivia', 'Bolivia', 'none', 0.1),
#  ('Bolivia', 'Bolivia', 'Guarani', 0.6),
#  ('Bolivia', 'Bolivia', 'Foreign Languages', 2.4),
#  ('Bolivia', 'Bolivia', 'Aymara', 14.6),
#  ('Bolivia', 'Bolivia', 'Quechua', 21.2),
#  ('Bolivia', 'Bolivia', 'Spanish', 60.7),
#  ('Bhutan', 'Druk-Yul', 'Other', 26.0),
#  ('Bhutan', 'Druk-Yul', 'Sharchhopka', 28.0),
#  ('Bhutan', 'Druk-Yul', 'Dzongkha', 24.0),
#  ('Bhutan', 'Druk-Yul', 'Lhotshamkha', 22.0),
#  ('Bermuda', 'Bermuda', 'Portuguese', None),
#  ('Bermuda', 'Bermuda', 'English', None),
#  ('Benin', 'Benin', 'Fon and Yoruba', None),
#  ('Benin', 'Benin', 'Tribal Languages', None),
#  ('Benin', 'Benin', 'French', None),
#  ('Belize', 'Belize', 'Other', 1.8),
#  ('Belize', 'Belize', 'Garifuna', 2.9),
#  ('Belize', 'Belize', 'German', 3.2),
#  ('Belize', 'Belize', 'Maya', 10.5),
#  ('Belize', 'Belize', 'Creole', 44.6),
#  ('Belize', 'Belize', 'Spanish', 56.6),
#  ('Belize', 'Belize', 'English', 62.9),
#  ('Belize', 'Belize', 'none', 0.2),
#  ('Belize', 'Belize', 'unknown', 0.3),
#  ('Belgium', 'Belgie/Belgique', 'Dutch', 60.0),
#  ('Belgium', 'Belgie/Belgique', 'German', 1.0),
#  ('Belgium', 'Belgie/Belgique', 'French', 40.0),
#  ('Belarus', 'Belarus', 'Belarusian', 23.4),
#  ('Belarus', 'Belarus', 'Russian', 70.2),
#  ('Belarus', 'Belarus', 'unspecified', 3.3),
#  ('Belarus', 'Belarus', 'Other', 3.1),
#  ('Barbados', 'Barbados', 'Bajan', None),
#  ('Barbados', 'Barbados', 'English', None),
#  ('Bangladesh', 'Bangladesh', 'Bangla', 98.8),
#  ('Bangladesh', 'Bangladesh', 'Other', 1.2),
#  ('Bahrain', 'Al-Bahrayn', 'English', None),
#  ('Bahrain', 'Al-Bahrayn', 'Arabic', None),
#  ('Bahrain', 'Al-Bahrayn', 'Farsi', None),
#  ('Bahrain', 'Al-Bahrayn', 'Urdu', None),
#  ('Bahamas', 'The Bahamas', 'English', None),
#  ('Bahamas', 'The Bahamas', 'Creole', None),
#  ('Azerbaijan', 'Azarbaycan', 'Russian', 1.4),
#  ('Azerbaijan', 'Azarbaycan', 'Azerbaijani', 92.5),
#  ('Azerbaijan', 'Azarbaycan', 'Other', 4.7),
#  ('Azerbaijan', 'Azarbaycan', 'Armenian', 1.4),
#  ('Austria', 'Osterreich', 'Serbian', 2.2),
#  ('Austria', 'Osterreich', 'Turkish', 2.3),
#  ('Austria', 'Osterreich', 'German', 88.6),
#  ('Austria', 'Osterreich', 'Croatian', 1.6),
#  ('Austria', 'Osterreich', 'Other', 5.3),
#  ('Australia', 'Australia', 'Vietnamese', 1.1),
#  ('Australia', 'Australia', 'Cantonese', 1.2),
#  ('Australia', 'Australia', 'Greek', 1.2),
#  ('Australia', 'Australia', 'Arabic', 1.3),
#  ('Australia', 'Australia', 'Italian', 1.4),
#  ('Australia', 'Australia', 'Mandarin', 1.6),
#  ('Australia', 'Australia', 'English', 76.8),
#  ('Australia', 'Australia', 'unspecified', 5.0),
#  ('Australia', 'Australia', 'Other', 10.4),
#  ('Aruba', 'Aruba', 'Chinese', 1.5),
#  ('Aruba', 'Aruba', 'unspecified', 0.4),
#  ('Aruba', 'Aruba', 'Other', 1.7),
#  ('Aruba', 'Aruba', 'Dutch', 6.1),
#  ('Aruba', 'Aruba', 'English', 7.1),
#  ('Aruba', 'Aruba', 'Spanish', 13.7),
#  ('Aruba', 'Aruba', 'Papiamento', 69.4),
#  ('Armenia', 'Hajastan', 'Kurdish', 1.0),
#  ('Armenia', 'Hajastan', 'Other', 1.0),
#  ('Armenia', 'Hajastan', 'Armenian', 97.9),
#  ('Argentina', 'Argentina', 'Italian', None),
#  ('Argentina', 'Argentina', 'Spanish', None),
#  ('Argentina', 'Argentina', 'French', None),
#  ('Argentina', 'Argentina', 'German', None),
#  ('Argentina', 'Argentina', 'English', None),
#  ('Argentina', 'Argentina', 'indigenous', None),
#  ('Antigua and Barbuda', 'Antigua and Barbuda', 'Antiguan creole', None),
#  ('Antigua and Barbuda', 'Antigua and Barbuda', 'English', None),
#  ('Angola', 'Angola', 'Muhumbi', 2.1),
#  ('Angola', 'Angola', 'Kwanhama', 2.3),
#  ('Angola', 'Angola', 'Fiote', 2.4),
#  ('Angola', 'Angola', 'Nganguela', 3.1),
#  ('Angola', 'Angola', 'Nhaneca', 3.4),
#  ('Angola', 'Angola', 'Other', 3.6),
#  ('Angola', 'Angola', 'Kimbundu', 7.8),
#  ('Angola', 'Angola', 'Kikongo', 8.2),
#  ('Angola', 'Angola', 'Umbundu', 23.0),
#  ('Angola', 'Angola', 'Portuguese', 71.2),
#  ('Angola', 'Angola', 'Chokwe', 6.5),
#  ('Angola', 'Angola', 'Luvale', 1.0),
#  ('Andorra', 'Andorra', 'French', None),
#  ('Andorra', 'Andorra', 'Portuguese', None),
#  ('Andorra', 'Andorra', 'Castilian', None),
#  ('Andorra', 'Andorra', 'Catalan', None),
#  ('American Samoa', 'Amerika Samoa', 'Samoan', 88.6),
#  ('American Samoa', 'Amerika Samoa', 'Other', 3.0),
#  ('American Samoa', 'Amerika Samoa', 'Other', 1.8),
#  ('American Samoa', 'Amerika Samoa', 'Tongan', 2.7),
#  ('American Samoa', 'Amerika Samoa', 'English', 3.9),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Shawiya', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Berber or Tamazight', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'French', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Tuareg', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Arabic', None),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 'Mzab', None),
#  ('Albania', 'Shqiperia', 'unspecified', 0.1),
#  ('Albania', 'Shqiperia', 'Other', 0.6),
#  ('Albania', 'Shqiperia', 'Greek', 0.5),
#  ('Albania', 'Shqiperia', 'Albanian', 98.8),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Other', 4.0),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Dari', 50.0),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Turkic', 11.0),
#  ('Afghanistan', 'Afganistan/Afqanestan', 'Pashto', 35.0)]

# %%
# left joing of countries and economies for year 2010
# %%sql
-- select name, region, and gdp_percapita
SELECT name, region, gdp_percapita
-- countries (alias c) on the left
FROM countries AS c
-- join with economies (alias e)
LEFT JOIN economies AS e
-- match on code fields
ON c.code = e.code
-- focus on 2010 entries
WHERE year = 2010;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 185 rows affected.
# [('Afghanistan', 'Southern and Central Asia', 539.667),
#  ('Angola', 'Central Africa', 3599.27),
#  ('Albania', 'Southern Europe', 4098.13),
#  ('United Arab Emirates', 'Middle East', 34628.6),
#  ('Argentina', 'South America', 10413.0),
#  ('Armenia', 'Middle East', 3121.78),
#  ('Antigua and Barbuda', 'Caribbean', 13531.8),
#  ('Australia', 'Australia and New Zealand', 56362.8),
#  ('Austria', 'Western Europe', 46757.1),
#  ('Azerbaijan', 'Middle East', 5847.26),
#  ('Burundi', 'Eastern Africa', 242.84),
#  ('Belgium', 'Western Europe', 44691.3),
#  ('Benin', 'Western Africa', 734.278),
#  ('Burkina Faso', 'Western Africa', 588.584),
#  ('Bangladesh', 'Southern and Central Asia', 807.531),
#  ('Bulgaria', 'Eastern Europe', 6743.74),
#  ('Bahrain', 'Middle East', 20823.2),
#  ('Bahamas', 'Caribbean', 22957.8),
#  ('Bosnia and Herzegovina', 'Southern Europe', 4404.37),
#  ('Belarus', 'Eastern Europe', 6023.15),
#  ('Belize', 'Central America', 4321.29),
#  ('Bolivia', 'South America', 1994.91),
#  ('Brazil', 'South America', 11297.8),
#  ('Barbados', 'Caribbean', 16079.9),
#  ('Brunei', 'Southeast Asia', 35437.2),
#  ('Bhutan', 'Southern and Central Asia', 1998.75),
#  ('Botswana', 'Southern Africa', 6853.67),
#  ('Central African Republic', 'Central Africa', 456.564),
#  ('Canada', 'North America', 47512.7),
#  ('Switzerland', 'Western Europe', 74570.7),
#  ('Chile', 'South America', 12789.8),
#  ('China', 'Eastern Asia', 4524.06),
#  ("Cote d'Ivoire", 'Western Africa', 1195.44),
#  ('Cameroon', 'Central Africa', 1158.78),
#  ('Congo, The Democratic Republic of the', 'Central Africa', 292.955),
#  ('Congo', 'Central Africa', 3183.68),
#  ('Colombia', 'South America', 6305.29),
#  ('Comoros', 'Eastern Africa', 789.466),
#  ('Cape Verde', 'Western Africa', 3413.26),
#  ('Costa Rica', 'Central America', 8300.69),
#  ('Cyprus', 'Middle East', 31262.5),
#  ('Czech Republic', 'Eastern Europe', 19787.3),
#  ('Germany', 'Western Europe', 42641.7),
#  ('Djibouti', 'Eastern Africa', 1306.54),
#  ('Dominica', 'Caribbean', 6975.99),
#  ('Denmark', 'Nordic Countries', 58177.2),
#  ('Dominican Republic', 'Caribbean', 5685.77),
#  ('Algeria', 'Northern Africa', 4480.72),
#  ('Ecuador', 'South America', 4633.25),
#  ('Egypt', 'Northern Africa', 2921.76),
#  ('Eritrea', 'Eastern Africa', 395.645),
#  ('Spain', 'Southern Europe', 30802.8),
#  ('Estonia', 'Baltic Countries', 14654.3),
#  ('Ethiopia', 'Eastern Africa', 360.829),
#  ('Finland', 'Nordic Countries', 46391.7),
#  ('Fiji Islands', 'Melanesia', 3780.24),
#  ('France', 'Western Europe', 42249.1),
#  ('Micronesia, Federated States of', 'Micronesia', 2888.18),
#  ('Gabon', 'Central Africa', 8917.32),
#  ('United Kingdom', 'British Islands', 38737.6),
#  ('Georgia', 'Middle East', 2951.24),
#  ('Ghana', 'Western Africa', 1357.64),
#  ('Guinea', 'Western Africa', 435.728),
#  ('Gambia', 'Western Africa', 562.2),
#  ('Guinea-Bissau', 'Western Africa', 582.54),
#  ('Equatorial Guinea', 'Central Africa', 23411.8),
#  ('Greece', 'Southern Europe', 26972.9),
#  ('Grenada', 'Caribbean', 7365.67),
#  ('Guatemala', 'Central America', 2875.31),
#  ('Guyana', 'South America', 3004.23),
#  ('Hong Kong', 'Eastern Asia', 32421.1),
#  ('Honduras', 'Central America', 2096.2),
#  ('Croatia', 'Southern Europe', 13505.0),
#  ('Haiti', 'Caribbean', 662.013),
#  ('Hungary', 'Eastern Europe', 13007.6),
#  ('Indonesia', 'Southeast Asia', 3178.13),
#  ('India', 'Southern and Central Asia', 1429.6),
#  ('Ireland', 'British Islands', 48439.1),
#  ('Iran', 'Southern and Central Asia', 6252.52),
#  ('Iraq', 'Middle East', 4473.71),
#  ('Iceland', 'Nordic Countries', 41622.7),
#  ('Israel', 'Middle East', 30673.4),
#  ('Italy', 'Southern Europe', 35969.2),
#  ('Jamaica', 'Caribbean', 4812.07),
#  ('Jordan', 'Middle East', 4322.82),
#  ('Japan', 'Eastern Asia', 44673.6),
#  ('Kazakhstan', 'Southern and Central Asia', 9008.71),
#  ('Kenya', 'Eastern Africa', 1038.95),
#  ('Kyrgyzstan', 'Southern and Central Asia', 875.264),
#  ('Cambodia', 'Southeast Asia', 781.912),
#  ('Kiribati', 'Micronesia', 1490.9),
#  ('Saint Kitts and Nevis', 'Caribbean', 13466.8),
#  ('South Korea', 'Eastern Asia', 22086.9),
#  ('Kuwait', 'Middle East', 32216.4),
#  ('Laos', 'Southeast Asia', 1069.75),
#  ('Lebanon', 'Middle East', 8755.85),
#  ('Liberia', 'Western Africa', 341.985),
#  ('Libya', 'Northern Africa', 12149.6),
#  ('Saint Lucia', 'Caribbean', 7491.66),
#  ('Sri Lanka', 'Southern and Central Asia', 2779.74),
#  ('Lesotho', 'Southern Africa', 1364.36),
#  ('Lithuania', 'Baltic Countries', 12010.7),
#  ('Luxembourg', 'Western Europe', 105574.0),
#  ('Latvia', 'Baltic Countries', 11228.1),
#  ('Macao', 'Eastern Asia', 50921.1),
#  ('Morocco', 'Northern Africa', 2926.67),
#  ('Moldova', 'Eastern Europe', 1632.78),
#  ('Madagascar', 'Eastern Africa', 414.143),
#  ('Maldives', 'Southern and Central Asia', 7259.49),
#  ('Mexico', 'Central America', 9199.8),
#  ('Marshall Islands', 'Micronesia', 3113.18),
#  ('Macedonia', 'Southern Europe', 4576.23),
#  ('Mali', 'Western Africa', 764.957),
#  ('Malta', 'Southern Europe', 21150.4),
#  ('Myanmar', 'Southeast Asia', 996.632),
#  ('Mongolia', 'Eastern Asia', 2608.31),
#  ('Mozambique', 'Eastern Africa', 429.948),
#  ('Mauritania', 'Western Africa', 1318.07),
#  ('Mauritius', 'Eastern Africa', 7772.13),
#  ('Malawi', 'Eastern Africa', 442.765),
#  ('Malaysia', 'Southeast Asia', 8920.48),
#  ('Namibia', 'Southern Africa', 5410.98),
#  ('Niger', 'Western Africa', 378.205),
#  ('Nigeria', 'Western Africa', 2365.01),
#  ('Nicaragua', 'Central America', 1523.48),
#  ('Netherlands', 'Western Europe', 50433.3),
#  ('Norway', 'Nordic Countries', 87309.3),
#  ('Nepal', 'Southern and Central Asia', 595.395),
#  ('Nauru', 'Micronesia', 4936.67),
#  ('New Zealand', 'Australia and New Zealand', 33221.9),
#  ('Oman', 'Middle East', 20327.1),
#  ('Pakistan', 'Southern and Central Asia', 1026.63),
#  ('Panama', 'Central America', 7896.91),
#  ('Peru', 'South America', 5008.68),
#  ('Philippines', 'Southeast Asia', 2155.41),
#  ('Palau', 'Micronesia', 10059.3),
#  ('Papua New Guinea', 'Melanesia', 2151.07),
#  ('Poland', 'Eastern Europe', 12601.9),
#  ('Puerto Rico', 'Caribbean', 26435.7),
#  ('Portugal', 'Southern Europe', 22580.7),
#  ('Paraguay', 'South America', 3199.48),
#  ('Qatar', 'Middle East', 76413.2),
#  ('Russian Federation', 'Eastern Europe', 11445.1),
#  ('Rwanda', 'Eastern Africa', 577.411),
#  ('Saudi Arabia', 'Middle East', 19112.7),
#  ('Sudan', 'Northern Africa', 1627.5),
#  ('Senegal', 'Western Africa', 999.775),
#  ('Singapore', 'Southeast Asia', 46569.4),
#  ('Solomon Islands', 'Melanesia', 1275.88),
#  ('Sierra Leone', 'Western Africa', 448.198),
#  ('El Salvador', 'Central America', 3546.08),
#  ('San Marino', 'Southern Europe', 64631.2),
#  ('Sao Tome and Principe', 'Central Africa', 1107.87),
#  ('Suriname', 'South America', 8224.07),
#  ('Slovakia', 'Eastern Europe', 16634.7),
#  ('Slovenia', 'Southern Europe', 23499.6),
#  ('Sweden', 'Nordic Countries', 51869.2),
#  ('Swaziland', 'Southern Africa', 4267.04),
#  ('Seychelles', 'Eastern Africa', 10805.1),
#  ('Syria', 'Middle East', 2806.69),
#  ('Chad', 'Central Africa', 1046.89),
#  ('Togo', 'Western Africa', 497.408),
#  ('Thailand', 'Southeast Asia', 5065.38),
#  ('Tajikistan', 'Southern and Central Asia', 740.733),
#  ('Turkmenistan', 'Southern and Central Asia', 4479.01),
#  ('Tonga', 'Polynesia', 3843.11),
#  ('Trinidad and Tobago', 'Caribbean', 16684.0),
#  ('Tunisia', 'Northern Africa', 4176.93),
#  ('Turkey', 'Middle East', 10475.6),
#  ('Tuvalu', 'Polynesia', 3076.88),
#  ('Tanzania', 'Eastern Africa', 725.765),
#  ('Uganda', 'Eastern Africa', 594.461),
#  ('Ukraine', 'Eastern Europe', 2982.81),
#  ('Uruguay', 'South America', 11859.9),
#  ('United States', 'North America', 48310.3),
#  ('Uzbekistan', 'Southern and Central Asia', 1367.13),
#  ('Saint Vincent and the Grenadines', 'Caribbean', 6224.22),
#  ('Venezuela', 'South America', 10316.8),
#  ('Vietnam', 'Southeast Asia', 1297.23),
#  ('Vanuatu', 'Melanesia', 2923.25),
#  ('Samoa', 'Polynesia', 3434.1),
#  ('Yemen', 'Middle East', 1266.79),
#  ('South Africa', 'Southern Africa', 7361.94),
#  ('Zambia', 'Eastern Africa', 1456.16),
#  ('Zimbabwe', 'Eastern Africa', 765.418)]

# %% [markdown]
# Modify query above to calculate the average GDP per capita AS `avg_gdp` for each region in 2010. Select the region and `avg_gdp` fields.

# %%
# %%sql
# -- calculate the average GDP per capita AS avg_gdp for each region in 2010. Select the region and avg_gdp fields
# SELECT region, AVG(gdp_percapita) AS avg_gdp
# -- countries (alias c) on the left
# FROM countries AS c
# -- join with economies (alias e)
# LEFT JOIN economies AS e
# -- match on code fields
# ON c.code = e.code
# -- focus on 2010 entries
# WHERE year = 2010
# GROUP BY region;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 23 rows affected.
# [('Southern Africa', 5051.59797363281),
#  ('Caribbean', 11413.339454064),
#  ('Eastern Africa', 1757.34816169739),
#  ('Southern Europe', 22926.4109108665),
#  ('Eastern Asia', 26205.8513997396),
#  ('South America', 7420.59923299154),
#  ('Baltic Countries', 12631.0299479167),
#  ('North America', 47911.509765625),
#  ('Australia and New Zealand', 44792.384765625),
#  ('Southern and Central Asia', 2797.15499441964),
#  ('Southeast Asia', 10547.1541320801),
#  ('Nordic Countries', 57073.99765625),
#  ('Middle East', 18204.6415153952),
#  ('Western Africa', 998.954866409302),
#  ('British Islands', 43588.330078125),
#  ('Micronesia', 4497.65197753906),
#  ('Melanesia', 2532.61001586914),
#  ('Eastern Europe', 10095.4565700955),
#  ('Central Africa', 4797.23992919922),
#  ('Polynesia', 3451.36336263021),
#  ('Northern Africa', 4713.86169433594),
#  ('Central America', 4969.97006225586),
#  ('Western Europe', 58130.9614955357)]

# %% [markdown]
# Arrange this data on average GDP per capita for each region in 2010 from highest to lowest average GDP per capita.

# %%
# %%sql
# -- select name, region, and gdp_percapita
# SELECT region, AVG(gdp_percapita) AS avg_gdp
# -- countries (alias c) on the left
# FROM countries AS c
# -- join with economies (alias e)
# LEFT JOIN economies AS e
# -- match on code fields
# ON c.code = e.code
# -- focus on 2010 entries
# WHERE year = 2010
# GROUP BY region
# ORDER BY avg_gdp DESC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 23 rows affected.
# [('Western Europe', 58130.9614955357),
#  ('Nordic Countries', 57073.99765625),
#  ('North America', 47911.509765625),
#  ('Australia and New Zealand', 44792.384765625),
#  ('British Islands', 43588.330078125),
#  ('Eastern Asia', 26205.8513997396),
#  ('Southern Europe', 22926.4109108665),
#  ('Middle East', 18204.6415153952),
#  ('Baltic Countries', 12631.0299479167),
#  ('Caribbean', 11413.339454064),
#  ('Southeast Asia', 10547.1541320801),
#  ('Eastern Europe', 10095.4565700955),
#  ('South America', 7420.59923299154),
#  ('Southern Africa', 5051.59797363281),
#  ('Central America', 4969.97006225586),
#  ('Central Africa', 4797.23992919922),
#  ('Northern Africa', 4713.86169433594),
#  ('Micronesia', 4497.65197753906),
#  ('Polynesia', 3451.36336263021),
#  ('Southern and Central Asia', 2797.15499441964),
#  ('Melanesia', 2532.61001586914),
#  ('Eastern Africa', 1757.34816169739),
#  ('Western Africa', 998.954866409302)]

# %% [markdown]
# # Right join
# Right joins aren't as common as left joins. One reason why is that you can always write a right join as a left join.

# %%
# %%sql
# -- convert this code to use RIGHT JOINs instead of LEFT JOINs
# /*
# SELECT cities.name AS city, urbanarea_pop, countries.name AS country,
#        indep_year, languages.name AS language, percent
# FROM cities
# LEFT JOIN countries
# ON cities.country_code = countries.code
# LEFT JOIN languages
# ON countries.code = languages.code
# ORDER BY city, language;
# */
#
# SELECT cities.name AS city, urbanarea_pop, countries.name AS country,
#        indep_year, languages.name AS language, percent
# FROM languages
# RIGHT JOIN countries
# ON languages.code = countries.code
# RIGHT JOIN cities
# ON countries.code = cities.country_code
# ORDER BY city, language;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 1375 rows affected.
# [('Abidjan', 4765000.0, "Cote d'Ivoire", 1960, 'French', None),
#  ('Abidjan', 4765000.0, "Cote d'Ivoire", 1960, 'Other', None),
#  ('Abu Dhabi', 1145000.0, 'United Arab Emirates', 1971, 'Arabic', None),
#  ('Abu Dhabi', 1145000.0, 'United Arab Emirates', 1971, 'English', None),
#  ('Abu Dhabi', 1145000.0, 'United Arab Emirates', 1971, 'Hindi', None),
#  ('Abu Dhabi', 1145000.0, 'United Arab Emirates', 1971, 'Persian', None),
#  ('Abu Dhabi', 1145000.0, 'United Arab Emirates', 1971, 'Urdu', None),
#  ('Abuja', 1235880.0, 'Nigeria', 1960, 'English', None),
#  ('Abuja', 1235880.0, 'Nigeria', 1960, 'Fulani', None),
#  ('Abuja', 1235880.0, 'Nigeria', 1960, 'Hausa', None),
#  ('Abuja', 1235880.0, 'Nigeria', 1960, 'Igbo', None),
#  ('Abuja', 1235880.0, 'Nigeria', 1960, 'Other', None),
#  ('Abuja', 1235880.0, 'Nigeria', 1960, 'Yoruba', None),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Akyem', 3.2),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Asante', 16.0),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Boron', 4.9),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Dagarte', 3.9),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Dagomba', 4.4),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Dangme', 4.2),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Ewe', 14.0),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Fante', 11.6),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Ga', 3.1),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Kokomba', 3.5),
#  ('Accra', 2070460.0, 'Ghana', 1957, 'Other', 31.2),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Afar', 1.7),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Amharic', 29.3),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Arabic', None),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'English', None),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Gamo', 1.5),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Gedeo', 1.3),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Gurage', 2.0),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Hadiyya', 1.7),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Kafa', 1.1),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Opuuo', 1.2),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Oromo', 33.8),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Other', 8.1),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Sidamo', 4.0),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Somali', 6.2),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Tigrigna', 5.9),
#  ('Addis Ababa', 3103670.0, 'Ethiopia', -1000, 'Wolaytta', 2.2),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Assamese', 1.3),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Bengali', 8.1),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Hindi', 41.0),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Kannada', 3.7),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Maithili', 1.2),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Marathi', 7.0),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Oriya', 3.2),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Other', 5.9),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Tamil', 5.9),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Telugu', 7.2),
#  ('Ahmedabad', 5570580.0, 'India', 1947, 'Urdu', 5.0),
#  ('Alexandria', 4616620.0, 'Egypt', 1922, 'Arabic', None),
#  ('Alexandria', 4616620.0, 'Egypt', 1922, 'English', None),
#  ('Algiers', 3415810.0, 'Algeria', 1962, 'Arabic', None),
#  ('Algiers', 3415810.0, 'Algeria', 1962, 'Berber or Tamazight', None),
#  ('Algiers', 3415810.0, 'Algeria', 1962, 'French', None),
#  ('Algiers', 3415810.0, 'Algeria', 1962, 'Mzab', None),
#  ('Algiers', 3415810.0, 'Algeria', 1962, 'Shawiya', None),
#  ('Algiers', 3415810.0, 'Algeria', 1962, 'Tuareg', None),
#  ('Almaty', 1703480.0, 'Kazakhstan', 1991, 'Kazakh', 74.0),
#  ('Almaty', 1703480.0, 'Kazakhstan', 1991, 'Russian', 94.4),
#  ('Ankara', 5271000.0, 'Turkey', 1923, 'Kurdish', None),
#  ('Ankara', 5271000.0, 'Turkey', 1923, 'Other', None),
#  ('Ankara', 5271000.0, 'Turkey', 1923, 'Turkish', None),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'English', 89.8),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'French', 1.2),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'Hindi', 1.6),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'Maori', 3.5),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'New Zealand Sign', None),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'Northern Chinese', 1.2),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'Other', 20.5),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'Samoan', 2.0),
#  ('Auckland', 1495000.0, 'New Zealand', 1907, 'Yue', 1.0),
#  ('Baghdad', 7180890.0, 'Iraq', 1932, 'Arabic', None),
#  ('Baghdad', 7180890.0, 'Iraq', 1932, 'Armenian', None),
#  ('Baghdad', 7180890.0, 'Iraq', 1932, 'Kurdish', None),
#  ('Baghdad', 7180890.0, 'Iraq', 1932, 'Syriac', None),
#  ('Baghdad', 7180890.0, 'Iraq', 1932, 'Turkmen', None),
#  ('Baku', 3202300.0, 'Azerbaijan', 1991, 'Armenian', 1.4),
#  ('Baku', 3202300.0, 'Azerbaijan', 1991, 'Azerbaijani', 92.5),
#  ('Baku', 3202300.0, 'Azerbaijan', 1991, 'Other', 4.7),
#  ('Baku', 3202300.0, 'Azerbaijan', 1991, 'Russian', 1.4),
#  ('Bandung', 2575480.0, 'Indonesia', 1945, 'Bahasa', None),
#  ('Bandung', 2575480.0, 'Indonesia', 1945, 'Dutch', None),
#  ('Bandung', 2575480.0, 'Indonesia', 1945, 'English', None),
#  ('Bandung', 2575480.0, 'Indonesia', 1945, 'Other', None),
#  ('Bangkok', 8280920.0, 'Thailand', 1350, 'Burmese', 1.3),
#  ('Bangkok', 8280920.0, 'Thailand', 1350, 'Other', 8.0),
#  ('Bangkok', 8280920.0, 'Thailand', 1350, 'Thai', 90.7),
#  ('Barcelona', 1604560.0, 'Spain', 1492, 'Aranese', None),
#  ('Barcelona', 1604560.0, 'Spain', 1492, 'Basque', 2.0),
#  ('Barcelona', 1604560.0, 'Spain', 1492, 'Castilian Spanish', 74.0),
#  ('Barcelona', 1604560.0, 'Spain', 1492, 'Catalan', 17.0),
#  ('Barcelona', 1604560.0, 'Spain', 1492, 'Galician', 7.0),
#  ('Barranquilla', 1386860.0, 'Colombia', 1810, 'Spanish', None),
#  ('Basra', 2750000.0, 'Iraq', 1932, 'Arabic', None),
#  ('Basra', 2750000.0, 'Iraq', 1932, 'Armenian', None),
#  ('Basra', 2750000.0, 'Iraq', 1932, 'Kurdish', None),
#  ('Basra', 2750000.0, 'Iraq', 1932, 'Syriac', None),
#  ('Basra', 2750000.0, 'Iraq', 1932, 'Turkmen', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Gan', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Hakka', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Mandarin', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Minbei', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Minnan', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Other', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Wu', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Xiang', None),
#  ('Beijing', 21516000.0, 'China', -1523, 'Yue', None),
#  ('Belo Horizonte', 2502560.0, 'Brazil', 1822, 'Portuguese', None),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Assamese', 1.3),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Bengali', 8.1),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Hindi', 41.0),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Kannada', 3.7),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Maithili', 1.2),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Marathi', 7.0),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Oriya', 3.2),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Other', 5.9),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Tamil', 5.9),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Telugu', 7.2),
#  ('Bengaluru', 8425970.0, 'India', 1947, 'Urdu', 5.0),
#  ('Berlin', 3517420.0, 'Germany', 1955, 'German', None),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Assamese', 1.3),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Bengali', 8.1),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Hindi', 41.0),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Kannada', 3.7),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Maithili', 1.2),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Marathi', 7.0),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Oriya', 3.2),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Other', 5.9),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Tamil', 5.9),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Telugu', 7.2),
#  ('Bhopal', 1798220.0, 'India', 1947, 'Urdu', 5.0),
#  ('Birmingham', 1111300.0, 'United Kingdom', 1066, 'English', None),
#  ('Bogota', 7878780.0, 'Colombia', 1810, 'Spanish', None),
#  ('Brasilia', 2556150.0, 'Brazil', 1822, 'Portuguese', None),
#  ('Brazzaville', 1827000.0, 'Congo', 1960, 'French', None),
#  ('Brazzaville', 1827000.0, 'Congo', 1960, 'Lingala', None),
#  ('Brazzaville', 1827000.0, 'Congo', 1960, 'Other', None),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'Arabic', 1.3),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'Cantonese', 1.2),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'English', 76.8),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'Greek', 1.2),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'Italian', 1.4),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'Mandarin', 1.6),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'Other', 10.4),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'unspecified', 5.0),
#  ('Brisbane', 1180280.0, 'Australia', 1901, 'Vietnamese', 1.1),
#  ('Bucharest', 1883420.0, None, None, None, None),
#  ('Budapest', 1759410.0, 'Hungary', 1918, 'English', 16.0),
#  ('Budapest', 1759410.0, 'Hungary', 1918, 'French', 1.2),
#  ('Budapest', 1759410.0, 'Hungary', 1918, 'German', 11.2),
#  ('Budapest', 1759410.0, 'Hungary', 1918, 'Hungarian', 99.6),
#  ('Budapest', 1759410.0, 'Hungary', 1918, 'Other', 4.2),
#  ('Budapest', 1759410.0, 'Hungary', 1918, 'Romanian', 1.3),
#  ('Budapest', 1759410.0, 'Hungary', 1918, 'Russian', 1.6),
#  ('Buenos Aires', 3054300.0, 'Argentina', 1816, 'English', None),
#  ('Buenos Aires', 3054300.0, 'Argentina', 1816, 'French', None),
#  ('Buenos Aires', 3054300.0, 'Argentina', 1816, 'German', None),
#  ('Buenos Aires', 3054300.0, 'Argentina', 1816, 'indigenous', None),
#  ('Buenos Aires', 3054300.0, 'Argentina', 1816, 'Italian', None),
#  ('Buenos Aires', 3054300.0, 'Argentina', 1816, 'Spanish', None),
#  ('Busan', 3510830.0, 'South Korea', 1948, 'English', None),
#  ('Busan', 3510830.0, 'South Korea', 1948, 'Korean', None),
#  ('Cairo', 10230400.0, 'Egypt', 1922, 'Arabic', None),
#  ('Cairo', 10230400.0, 'Egypt', 1922, 'English', None),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'Arabic', 1.1),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'Cantonese', 1.2),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'English', 58.7),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'French', 22.0),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'German', 1.3),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'Italian', 1.3),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'Other', 10.5),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'Punjabi', 1.4),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'Spanish', 1.3),
#  ('Calgary', 1235170.0, 'Canada', 1867, 'Tagalog', 1.2),
#  ('Cali', 2400650.0, 'Colombia', 1810, 'Spanish', None),
#  ('Caloocan', 1583980.0, 'Philippines', 1946, 'English', None),
#  ('Caloocan', 1583980.0, 'Philippines', 1946, 'Filipino', None),
#  ('Caloocan', 1583980.0, 'Philippines', 1946, 'Other', None),
#  ('Campinas', 1164100.0, 'Brazil', 1822, 'Portuguese', None),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'Afrikaans', 13.5),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'English', 9.6),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'isiNdebele', 2.1),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'IsiXhosa', 16.0),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'IsiZulu', 22.7),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'Other', 1.6),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'Sepedi', 9.1),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'Sesotho', 7.6),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'Setswana', 8.0),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'sign', 0.5),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'siSwati', 2.5),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'Tshivenda', 2.4),
#  ('Cape Town', 3740030.0, 'South Africa', 1910, 'Xitsonga', 4.5),
#  ('Caracas', 1943900.0, 'Venezuela', 1811, 'indigenous', None),
#  ('Caracas', 1943900.0, 'Venezuela', 1811, 'Spanish', None),
#  ('Casablanca', 5117830.0, 'Morocco', 1956, 'and', None),
#  ('Casablanca', 5117830.0, 'Morocco', 1956, 'Arabic', None),
#  ('Casablanca', 5117830.0, 'Morocco', 1956, 'Berber', None),
#  ('Casablanca', 5117830.0, 'Morocco', 1956, 'French', None),
#  ('Casablanca', 5117830.0, 'Morocco', 1956, 'government', None),
#  ('Casablanca', 5117830.0, 'Morocco', 1956, 'Tachelhit', None),
#  ('Casablanca', 5117830.0, 'Morocco', 1956, 'Tarifit', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Gan', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Hakka', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Mandarin', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Minbei', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Minnan', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Other', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Wu', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Xiang', None),
#  ('Changchun', 3815270.0, 'China', -1523, 'Yue', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Gan', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Hakka', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Mandarin', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Minbei', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Minnan', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Other', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Wu', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Xiang', None),
#  ('Changsha', 7044120.0, 'China', -1523, 'Yue', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Gan', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Hakka', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Mandarin', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Minbei', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Minnan', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Other', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Wu', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Xiang', None),
#  ('Chaozhou', 2669840.0, 'China', -1523, 'Yue', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Gan', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Hakka', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Mandarin', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Minbei', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Minnan', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Other', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Wu', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Xiang', None),
#  ('Chengdu', 4741930.0, 'China', -1523, 'Yue', None),
#  ('Chennai', 7088000.0, 'India', 1947, 'Assamese', 1.3),
#  ('Chennai', 7088000.0, 'India', 1947, 'Bengali', 8.1),
#  ('Chennai', 7088000.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Chennai', 7088000.0, 'India', 1947, 'Hindi', 41.0),
#  ('Chennai', 7088000.0, 'India', 1947, 'Kannada', 3.7),
#  ('Chennai', 7088000.0, 'India', 1947, 'Maithili', 1.2),
#  ('Chennai', 7088000.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Chennai', 7088000.0, 'India', 1947, 'Marathi', 7.0),
#  ('Chennai', 7088000.0, 'India', 1947, 'Oriya', 3.2),
#  ('Chennai', 7088000.0, 'India', 1947, 'Other', 5.9),
#  ('Chennai', 7088000.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Chennai', 7088000.0, 'India', 1947, 'Tamil', 5.9),
#  ('Chennai', 7088000.0, 'India', 1947, 'Telugu', 7.2),
#  ('Chennai', 7088000.0, 'India', 1947, 'Urdu', 5.0),
#  ('Chicago', 2695600.0, 'United States', 1776, 'English', 79.2),
#  ('Chicago', 2695600.0, 'United States', 1776, 'Other', 8.0),
#  ('Chicago', 2695600.0, 'United States', 1776, 'Spanish', 12.9),
#  ('Chittagong', 2581640.0, 'Bangladesh', 1971, 'Bangla', 98.8),
#  ('Chittagong', 2581640.0, 'Bangladesh', 1971, 'Other', 1.2),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Gan', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Hakka', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Mandarin', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Minbei', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Minnan', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Other', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Wu', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Xiang', None),
#  ('Chongqing', 8189800.0, 'China', -1523, 'Yue', None),
#  ('Cologne', 1057330.0, 'Germany', 1955, 'German', None),
#  ('Cordoba', 1330020.0, 'Argentina', 1816, 'English', None),
#  ('Cordoba', 1330020.0, 'Argentina', 1816, 'French', None),
#  ('Cordoba', 1330020.0, 'Argentina', 1816, 'German', None),
#  ('Cordoba', 1330020.0, 'Argentina', 1816, 'indigenous', None),
#  ('Cordoba', 1330020.0, 'Argentina', 1816, 'Italian', None),
#  ('Cordoba', 1330020.0, 'Argentina', 1816, 'Spanish', None),
#  ('Curitiba', 1879360.0, 'Brazil', 1822, 'Portuguese', None),
#  ('Daegu', 2492990.0, 'South Korea', 1948, 'English', None),
#  ('Daegu', 2492990.0, 'South Korea', 1948, 'Korean', None),
#  ('Daejeon', 1535030.0, 'South Korea', 1948, 'English', None),
#  ('Daejeon', 1535030.0, 'South Korea', 1948, 'Korean', None),
#  ('Dakar', 1146050.0, 'Senegal', 1960, 'French', None),
#  ('Dakar', 1146050.0, 'Senegal', 1960, 'Jola', None),
#  ('Dakar', 1146050.0, 'Senegal', 1960, 'Mandinka', None),
#  ('Dakar', 1146050.0, 'Senegal', 1960, 'Pular', None),
#  ('Dakar', 1146050.0, 'Senegal', 1960, 'Serer', None),
#  ('Dakar', 1146050.0, 'Senegal', 1960, 'Soninke', None),
#  ('Dakar', 1146050.0, 'Senegal', 1960, 'Wolof', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Gan', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Hakka', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Mandarin', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Minbei', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Minnan', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Other', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Wu', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Xiang', None),
#  ('Dalian', 2146100.0, 'China', -1523, 'Yue', None),
#  ('Dallas', 1317930.0, 'United States', 1776, 'English', 79.2),
#  ('Dallas', 1317930.0, 'United States', 1776, 'Other', 8.0),
#  ('Dallas', 1317930.0, 'United States', 1776, 'Spanish', 12.9),
#  ('Dar es Salaam', 4364540.0, 'Tanzania', 1961, 'Arabic', None),
#  ('Dar es Salaam', 4364540.0, 'Tanzania', 1961, 'English', None),
#  ('Dar es Salaam', 4364540.0, 'Tanzania', 1961, 'Kiswahili', None),
#  ('Dar es Salaam', 4364540.0, 'Tanzania', 1961, 'many', None),
#  ('Davao City', 1632990.0, 'Philippines', 1946, 'English', None),
#  ('Davao City', 1632990.0, 'Philippines', 1946, 'Filipino', None),
#  ('Davao City', 1632990.0, 'Philippines', 1946, 'Other', None),
#  ('Delhi', 16787900.0, 'India', 1947, 'Assamese', 1.3),
#  ('Delhi', 16787900.0, 'India', 1947, 'Bengali', 8.1),
#  ('Delhi', 16787900.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Delhi', 16787900.0, 'India', 1947, 'Hindi', 41.0),
#  ('Delhi', 16787900.0, 'India', 1947, 'Kannada', 3.7),
#  ('Delhi', 16787900.0, 'India', 1947, 'Maithili', 1.2),
#  ('Delhi', 16787900.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Delhi', 16787900.0, 'India', 1947, 'Marathi', 7.0),
#  ('Delhi', 16787900.0, 'India', 1947, 'Oriya', 3.2),
#  ('Delhi', 16787900.0, 'India', 1947, 'Other', 5.9),
#  ('Delhi', 16787900.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Delhi', 16787900.0, 'India', 1947, 'Tamil', 5.9),
#  ('Delhi', 16787900.0, 'India', 1947, 'Telugu', 7.2),
#  ('Delhi', 16787900.0, 'India', 1947, 'Urdu', 5.0),
#  ('Dhaka', 14543100.0, 'Bangladesh', 1971, 'Bangla', 98.8),
#  ('Dhaka', 14543100.0, 'Bangladesh', 1971, 'Other', 1.2),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Gan', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Hakka', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Mandarin', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Minbei', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Minnan', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Other', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Wu', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Xiang', None),
#  ('Dongguan', 8220210.0, 'China', -1523, 'Yue', None),
#  ('Douala', 2446940.0, 'Cameroon', 1960, 'English', None),
#  ('Douala', 2446940.0, 'Cameroon', 1960, 'French', None),
#  ('Douala', 2446940.0, 'Cameroon', 1960, 'Other', None),
#  ('Dubai', 2643410.0, 'United Arab Emirates', 1971, 'Arabic', None),
#  ('Dubai', 2643410.0, 'United Arab Emirates', 1971, 'English', None),
#  ('Dubai', 2643410.0, 'United Arab Emirates', 1971, 'Hindi', None),
#  ('Dubai', 2643410.0, 'United Arab Emirates', 1971, 'Persian', None),
#  ('Dubai', 2643410.0, 'United Arab Emirates', 1971, 'Urdu', None),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'Afrikaans', 13.5),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'English', 9.6),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'isiNdebele', 2.1),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'IsiXhosa', 16.0),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'IsiZulu', 22.7),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'Other', 1.6),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'Sepedi', 9.1),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'Sesotho', 7.6),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'Setswana', 8.0),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'sign', 0.5),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'siSwati', 2.5),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'Tshivenda', 2.4),
#  ('Durban', 3442360.0, 'South Africa', 1910, 'Xitsonga', 4.5),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'Afrikaans', 13.5),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'English', 9.6),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'isiNdebele', 2.1),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'IsiXhosa', 16.0),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'IsiZulu', 22.7),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'Other', 1.6),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'Sepedi', 9.1),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'Sesotho', 7.6),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'Setswana', 8.0),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'sign', 0.5),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'siSwati', 2.5),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'Tshivenda', 2.4),
#  ('Ekurhuleni', 3178470.0, 'South Africa', 1910, 'Xitsonga', 4.5),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'English', None),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Other', None),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Faisalabad', 6480760.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Fez', 1112070.0, 'Morocco', 1956, 'and', None),
#  ('Fez', 1112070.0, 'Morocco', 1956, 'Arabic', None),
#  ('Fez', 1112070.0, 'Morocco', 1956, 'Berber', None),
#  ('Fez', 1112070.0, 'Morocco', 1956, 'French', None),
#  ('Fez', 1112070.0, 'Morocco', 1956, 'government', None),
#  ('Fez', 1112070.0, 'Morocco', 1956, 'Tachelhit', None),
#  ('Fez', 1112070.0, 'Morocco', 1956, 'Tarifit', None),
#  ('Fortaleza', 2609720.0, 'Brazil', 1822, 'Portuguese', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Gan', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Hakka', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Mandarin', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Minbei', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Minnan', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Other', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Wu', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Xiang', None),
#  ('Foshan', 6151620.0, 'China', -1523, 'Yue', None),
#  ('Fukuoka', 1483050.0, 'Japan', -660, 'Japanese', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Gan', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Hakka', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Mandarin', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Minbei', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Minnan', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Other', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Wu', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Xiang', None),
#  ('Fuzhou', 7115370.0, 'China', -1523, 'Yue', None),
#  ('Giza', 4239990.0, 'Egypt', 1922, 'Arabic', None),
#  ('Giza', 4239990.0, 'Egypt', 1922, 'English', None),
#  ('Guadalajara', 1495190.0, 'Mexico', 1810, 'indigenous', 0.8),
#  ('Guadalajara', 1495190.0, 'Mexico', 1810, 'Spanish', 92.7),
#  ('Guadalajara', 1495190.0, 'Mexico', 1810, 'unspecified', 0.8),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Gan', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Hakka', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Mandarin', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Minbei', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Minnan', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Other', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Wu', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Xiang', None),
#  ('Guangzhou', 14043500.0, 'China', -1523, 'Yue', None),
#  ('Guatemala City', 2110100.0, 'Guatemala', 1821, 'Amerindian', 40.0),
#  ('Guatemala City', 2110100.0, 'Guatemala', 1821, 'Spanish', 60.0),
#  ('Guayaquil', 3600000.0, 'Ecuador', 1822, 'foreign', 2.2),
#  ('Guayaquil', 3600000.0, 'Ecuador', 1822, 'Other', 0.7),
#  ('Guayaquil', 3600000.0, 'Ecuador', 1822, 'Quechua', 4.1),
#  ('Guayaquil', 3600000.0, 'Ecuador', 1822, 'Spanish', 93.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'English', None),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Other', None),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Gujranwala', 2700000.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Hamburg', 1787410.0, 'Germany', 1955, 'German', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Gan', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Hakka', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Mandarin', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Minbei', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Minnan', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Other', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Wu', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Xiang', None),
#  ('Hangzhou', 3560390.0, 'China', -1523, 'Yue', None),
#  ('Hanoi', 6844100.0, 'Vietnam', 1945, 'English', None),
#  ('Hanoi', 6844100.0, 'Vietnam', 1945, 'Other', None),
#  ('Hanoi', 6844100.0, 'Vietnam', 1945, 'Vietnamese', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Chewa', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Chibarwe', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'English', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Kalanga', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Koisan', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Nambya', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Ndau', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Ndebele', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Shangani', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Shona', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'sign', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Sotho', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Tonga', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Tswana', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Venda', None),
#  ('Harare', 1606000.0, 'Zimbabwe', 1980, 'Xhosa', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Gan', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Hakka', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Mandarin', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Minbei', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Minnan', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Other', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Wu', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Xiang', None),
#  ('Harbin', 4280700.0, 'China', -1523, 'Yue', None),
#  ('Havana', 2106150.0, 'Cuba', 1902, 'Spanish', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Gan', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Hakka', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Mandarin', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Minbei', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Minnan', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Other', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Wu', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Xiang', None),
#  ('Hefei', 3352080.0, 'China', -1523, 'Yue', None),
#  ('Hiroshima', 1196270.0, 'Japan', -660, 'Japanese', None),
#  ('Ho Chi Minh City', 7681700.0, 'Vietnam', 1945, 'English', None),
#  ('Ho Chi Minh City', 7681700.0, 'Vietnam', 1945, 'Other', None),
#  ('Ho Chi Minh City', 7681700.0, 'Vietnam', 1945, 'Vietnamese', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Gan', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Hakka', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Mandarin', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Minbei', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Minnan', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Other', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Wu', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Xiang', None),
#  ('Hong Kong', 7374900.0, 'China', -1523, 'Yue', None),
#  ('Houston', 2489560.0, 'United States', 1776, 'English', 79.2),
#  ('Houston', 2489560.0, 'United States', 1776, 'Other', 8.0),
#  ('Houston', 2489560.0, 'United States', 1776, 'Spanish', 12.9),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'English', None),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Other', None),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Hyderabad', 3429470.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Assamese', 1.3),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Bengali', 8.1),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Hindi', 41.0),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Kannada', 3.7),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Maithili', 1.2),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Marathi', 7.0),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Oriya', 3.2),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Other', 5.9),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Tamil', 5.9),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Telugu', 7.2),
#  ('Hyderabad (India)', 7859250.0, 'India', 1947, 'Urdu', 5.0),
#  ('Ibadan', 1338660.0, 'Nigeria', 1960, 'English', None),
#  ('Ibadan', 1338660.0, 'Nigeria', 1960, 'Fulani', None),
#  ('Ibadan', 1338660.0, 'Nigeria', 1960, 'Hausa', None),
#  ('Ibadan', 1338660.0, 'Nigeria', 1960, 'Igbo', None),
#  ('Ibadan', 1338660.0, 'Nigeria', 1960, 'Other', None),
#  ('Ibadan', 1338660.0, 'Nigeria', 1960, 'Yoruba', None),
#  ('Incheon', 2978370.0, 'South Korea', 1948, 'English', None),
#  ('Incheon', 2978370.0, 'South Korea', 1948, 'Korean', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Arabic', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Balochi', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Gilaki and Mazandarani', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Kurdish', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Luri', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Other', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Persian', None),
#  ('Isfahan', 2243250.0, 'Iran', 1906, 'Turkic', None),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'English', None),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Other', None),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Islamabad', 1900000.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Istanbul', 14025000.0, 'Turkey', 1923, 'Kurdish', None),
#  ('Istanbul', 14025000.0, 'Turkey', 1923, 'Other', None),
#  ('Istanbul', 14025000.0, 'Turkey', 1923, 'Turkish', None),
#  ('Izmir', 4168000.0, 'Turkey', 1923, 'Kurdish', None),
#  ('Izmir', 4168000.0, 'Turkey', 1923, 'Other', None),
#  ('Izmir', 4168000.0, 'Turkey', 1923, 'Turkish', None),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Assamese', 1.3),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Bengali', 8.1),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Hindi', 41.0),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Kannada', 3.7),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Maithili', 1.2),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Marathi', 7.0),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Oriya', 3.2),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Other', 5.9),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Tamil', 5.9),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Telugu', 7.2),
#  ('Jaipur', 3073350.0, 'India', 1947, 'Urdu', 5.0),
#  ('Jakarta', 10075300.0, 'Indonesia', 1945, 'Bahasa', None),
#  ('Jakarta', 10075300.0, 'Indonesia', 1945, 'Dutch', None),
#  ('Jakarta', 10075300.0, 'Indonesia', 1945, 'English', None),
#  ('Jakarta', 10075300.0, 'Indonesia', 1945, 'Other', None),
#  ('Jeddah', 3456260.0, 'Saudi Arabia', 1932, 'Arabic', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Gan', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Hakka', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Mandarin', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Minbei', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Minnan', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Other', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Wu', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Xiang', None),
#  ('Jinan', 2009270.0, 'China', -1523, 'Yue', None),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'Afrikaans', 13.5),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'English', 9.6),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'isiNdebele', 2.1),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'IsiXhosa', 16.0),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'IsiZulu', 22.7),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'Other', 1.6),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'Sepedi', 9.1),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'Sesotho', 7.6),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'Setswana', 8.0),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'sign', 0.5),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'siSwati', 2.5),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'Tshivenda', 2.4),
#  ('Johannesburg', 4434830.0, 'South Africa', 1910, 'Xitsonga', 4.5),
#  ('Kabul', 3414100.0, 'Afghanistan', 1919, 'Dari', 50.0),
#  ('Kabul', 3414100.0, 'Afghanistan', 1919, 'Other', 4.0),
#  ('Kabul', 3414100.0, 'Afghanistan', 1919, 'Pashto', 35.0),
#  ('Kabul', 3414100.0, 'Afghanistan', 1919, 'Turkic', 11.0),
#  ('Kampala', 1507080.0, 'Uganda', 1962, 'Arabic', None),
#  ('Kampala', 1507080.0, 'Uganda', 1962, 'English', None),
#  ('Kampala', 1507080.0, 'Uganda', 1962, 'Ganda', None),
#  ('Kampala', 1507080.0, 'Uganda', 1962, 'Nilo', None),
#  ('Kampala', 1507080.0, 'Uganda', 1962, 'Other', None),
#  ('Kampala', 1507080.0, 'Uganda', 1962, 'Swahili', None),
#  ('Kano', 2153220.0, 'Nigeria', 1960, 'English', None),
#  ('Kano', 2153220.0, 'Nigeria', 1960, 'Fulani', None),
#  ('Kano', 2153220.0, 'Nigeria', 1960, 'Hausa', None),
#  ('Kano', 2153220.0, 'Nigeria', 1960, 'Igbo', None),
#  ('Kano', 2153220.0, 'Nigeria', 1960, 'Other', None),
#  ('Kano', 2153220.0, 'Nigeria', 1960, 'Yoruba', None),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Assamese', 1.3),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Bengali', 8.1),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Hindi', 41.0),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Kannada', 3.7),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Maithili', 1.2),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Marathi', 7.0),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Oriya', 3.2),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Other', 5.9),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Tamil', 5.9),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Telugu', 7.2),
#  ('Kanpur', 2768060.0, 'India', 1947, 'Urdu', 5.0),
#  ('Kaohsiung', 2778920.0, None, None, None, None),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'English', None),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Other', None),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Karachi', 27506000.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Arabic', None),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Balochi', None),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Gilaki and Mazandarani', None),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Kurdish', None),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Luri', None),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Other', None),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Persian', None),
#  ('Karaj', 1973470.0, 'Iran', 1906, 'Turkic', None),
#  ('Kawasaki', 1496040.0, 'Japan', -660, 'Japanese', None),
#  ('Kharkov', 1439570.0, 'Ukraine', 1991, 'Other', 2.9),
#  ('Kharkov', 1439570.0, 'Ukraine', 1991, 'Russian', 29.6),
#  ('Kharkov', 1439570.0, 'Ukraine', 1991, 'Ukrainian', 67.5),
#  ('Khartoum', 3639600.0, 'Sudan', 1956, 'Arabic', None),
#  ('Khartoum', 3639600.0, 'Sudan', 1956, 'English', None),
#  ('Khartoum', 3639600.0, 'Sudan', 1956, 'Fur', None),
#  ('Khartoum', 3639600.0, 'Sudan', 1956, 'Nubian', None),
#  ('Khartoum', 3639600.0, 'Sudan', 1956, 'Ta Bedawie', None),
#  ('Kiev', 2908700.0, 'Ukraine', 1991, 'Other', 2.9),
#  ('Kiev', 2908700.0, 'Ukraine', 1991, 'Russian', 29.6),
#  ('Kiev', 2908700.0, 'Ukraine', 1991, 'Ukrainian', 67.5),
#  ('Kinshasa', 10130000.0, 'Congo, The Democratic Republic of the', 1960, 'French', None),
#  ('Kinshasa', 10130000.0, 'Congo, The Democratic Republic of the', 1960, 'Kikongo', None),
#  ('Kinshasa', 10130000.0, 'Congo, The Democratic Republic of the', 1960, 'Kingwana', None),
#  ('Kinshasa', 10130000.0, 'Congo, The Democratic Republic of the', 1960, 'Lingala', None),
#  ('Kinshasa', 10130000.0, 'Congo, The Democratic Republic of the', 1960, 'Tshiluba', None),
#  ('Kobe', 1536500.0, 'Japan', -660, 'Japanese', None),
#  ('Kochi', 2232460.0, 'India', 1947, 'Assamese', 1.3),
#  ('Kochi', 2232460.0, 'India', 1947, 'Bengali', 8.1),
#  ('Kochi', 2232460.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Kochi', 2232460.0, 'India', 1947, 'Hindi', 41.0),
#  ('Kochi', 2232460.0, 'India', 1947, 'Kannada', 3.7),
#  ('Kochi', 2232460.0, 'India', 1947, 'Maithili', 1.2),
#  ('Kochi', 2232460.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Kochi', 2232460.0, 'India', 1947, 'Marathi', 7.0),
#  ('Kochi', 2232460.0, 'India', 1947, 'Oriya', 3.2),
#  ('Kochi', 2232460.0, 'India', 1947, 'Other', 5.9),
#  ('Kochi', 2232460.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Kochi', 2232460.0, 'India', 1947, 'Tamil', 5.9),
#  ('Kochi', 2232460.0, 'India', 1947, 'Telugu', 7.2),
#  ('Kochi', 2232460.0, 'India', 1947, 'Urdu', 5.0),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Assamese', 1.3),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Bengali', 8.1),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Hindi', 41.0),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Kannada', 3.7),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Maithili', 1.2),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Marathi', 7.0),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Oriya', 3.2),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Other', 5.9),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Tamil', 5.9),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Telugu', 7.2),
#  ('Kolkata', 4486680.0, 'India', 1947, 'Urdu', 5.0),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'Bahasa Malaysia', None),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'Chinese', None),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'English', None),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'Malayalam', None),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'Panjabi', None),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'Tamil', None),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'Telugu', None),
#  ('Kuala Lumpur', 1768000.0, 'Malaysia', 1957, 'Thai', None),
#  ('Kwangju', 1477780.0, 'South Korea', 1948, 'English', None),
#  ('Kwangju', 1477780.0, 'South Korea', 1948, 'Korean', None),
#  ('Kyoto', 1474570.0, 'Japan', -660, 'Japanese', None),
#  ('Lagos', 16060300.0, 'Nigeria', 1960, 'English', None),
#  ('Lagos', 16060300.0, 'Nigeria', 1960, 'Fulani', None),
#  ('Lagos', 16060300.0, 'Nigeria', 1960, 'Hausa', None),
#  ('Lagos', 16060300.0, 'Nigeria', 1960, 'Igbo', None),
#  ('Lagos', 16060300.0, 'Nigeria', 1960, 'Other', None),
#  ('Lagos', 16060300.0, 'Nigeria', 1960, 'Yoruba', None),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'English', None),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Other', None),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Lahore', 10355000.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Gan', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Hakka', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Mandarin', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Minbei', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Minnan', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Other', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Wu', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Xiang', None),
#  ('Lanzhou', 2177130.0, 'China', -1523, 'Yue', None),
#  ('Lima', 8852000.0, 'Peru', 1821, 'Ashaninka', 0.3),
#  ('Lima', 8852000.0, 'Peru', 1821, 'Aymara', 1.7),
#  ('Lima', 8852000.0, 'Peru', 1821, 'Other', 0.2),
#  ('Lima', 8852000.0, 'Peru', 1821, 'Other Native', 0.7),
#  ('Lima', 8852000.0, 'Peru', 1821, 'Quechua', 13.0),
#  ('Lima', 8852000.0, 'Peru', 1821, 'Spanish', 84.1),
#  ('London', 8673710.0, 'United Kingdom', 1066, 'English', None),
#  ('Los Angeles', 3884310.0, 'United States', 1776, 'English', 79.2),
#  ('Los Angeles', 3884310.0, 'United States', 1776, 'Other', 8.0),
#  ('Los Angeles', 3884310.0, 'United States', 1776, 'Spanish', 12.9),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Chokwe', 6.5),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Fiote', 2.4),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Kikongo', 8.2),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Kimbundu', 7.8),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Kwanhama', 2.3),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Luvale', 1.0),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Muhumbi', 2.1),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Nganguela', 3.1),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Nhaneca', 3.4),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Other', 3.6),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Portuguese', 71.2),
#  ('Luanda', 2825310.0, 'Angola', 1975, 'Umbundu', 23.0),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Assamese', 1.3),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Bengali', 8.1),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Hindi', 41.0),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Kannada', 3.7),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Maithili', 1.2),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Marathi', 7.0),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Oriya', 3.2),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Other', 5.9),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Tamil', 5.9),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Telugu', 7.2),
#  ('Lucknow', 2815600.0, 'India', 1947, 'Urdu', 5.0),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Bembe', 33.4),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Bisa', 1.0),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Chewa', 4.5),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'English', 1.7),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Kaonde', 1.8),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Lala', 1.8),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Lamba', 1.8),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Lenje', 1.1),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Lozi', 5.5),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Lunda', 1.9),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Luvale', 1.5),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Mambwe', 1.3),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Namwanga', 1.2),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Nsenga', 2.9),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Nyanja', 14.7),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Other', 9.7),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Tonga', 11.4),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'Tumbuka', 2.5),
#  ('Lusaka', 1742980.0, 'Zambia', 1964, 'unspecified', 0.2),
#  ('Madrid', 3207250.0, 'Spain', 1492, 'Aranese', None),
#  ('Madrid', 3207250.0, 'Spain', 1492, 'Basque', 2.0),
#  ('Madrid', 3207250.0, 'Spain', 1492, 'Castilian Spanish', 74.0),
#  ('Madrid', 3207250.0, 'Spain', 1492, 'Catalan', 17.0),
#  ('Madrid', 3207250.0, 'Spain', 1492, 'Galician', 7.0),
#  ('Makassar', 1338630.0, 'Indonesia', 1945, 'Bahasa', None),
#  ('Makassar', 1338630.0, 'Indonesia', 1945, 'Dutch', None),
#  ('Makassar', 1338630.0, 'Indonesia', 1945, 'English', None),
#  ('Makassar', 1338630.0, 'Indonesia', 1945, 'Other', None),
#  ('Managua', 2560790.0, 'Nicaragua', 1838, 'Mestizo', 2.0),
#  ('Managua', 2560790.0, 'Nicaragua', 1838, 'Miskito', 2.2),
#  ('Managua', 2560790.0, 'Nicaragua', 1838, 'Other', 0.5),
#  ('Managua', 2560790.0, 'Nicaragua', 1838, 'Spanish', 95.3),
#  ('Mandalay', 1319450.0, 'Myanmar', 1948, 'Burmese', None),
#  ('Manila', 1780150.0, 'Philippines', 1946, 'English', None),
#  ('Manila', 1780150.0, 'Philippines', 1946, 'Filipino', None),
#  ('Manila', 1780150.0, 'Philippines', 1946, 'Other', None),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'Cisena', 7.5),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'Echuwabo', 5.1),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'Elomwe', 7.0),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'Emakhuwa', 25.3),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'Other', 30.4),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'Portuguese', 10.7),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'unspecified', 3.7),
#  ('Maputo', 1766180.0, 'Mozambique', 1975, 'Xichangana', 10.3),
#  ('Maracaibo', 1599940.0, 'Venezuela', 1811, 'indigenous', None),
#  ('Maracaibo', 1599940.0, 'Venezuela', 1811, 'Spanish', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Arabic', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Balochi', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Gilaki and Mazandarani', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Kurdish', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Luri', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Other', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Persian', None),
#  ('Mashhad', 3312090.0, 'Iran', 1906, 'Turkic', None),
#  ('Medan', 2097610.0, 'Indonesia', 1945, 'Bahasa', None),
#  ('Medan', 2097610.0, 'Indonesia', 1945, 'Dutch', None),
#  ('Medan', 2097610.0, 'Indonesia', 1945, 'English', None),
#  ('Medan', 2097610.0, 'Indonesia', 1945, 'Other', None),
#  ('Medellin', 2441120.0, 'Colombia', 1810, 'Spanish', None),
#  ('Mexico City', 8974720.0, 'Mexico', 1810, 'indigenous', 0.8),
#  ('Mexico City', 8974720.0, 'Mexico', 1810, 'Spanish', 92.7),
#  ('Mexico City', 8974720.0, 'Mexico', 1810, 'unspecified', 0.8),
#  ('Milan', 1359900.0, 'Italy', 1861, 'French', None),
#  ('Milan', 1359900.0, 'Italy', 1861, 'German', None),
#  ('Milan', 1359900.0, 'Italy', 1861, 'Italian', None),
#  ('Milan', 1359900.0, 'Italy', 1861, 'Slovene', None),
#  ('Minsk', 1959780.0, 'Belarus', 1991, 'Belarusian', 23.4),
#  ('Minsk', 1959780.0, 'Belarus', 1991, 'Other', 3.1),
#  ('Minsk', 1959780.0, 'Belarus', 1991, 'Russian', 70.2),
#  ('Minsk', 1959780.0, 'Belarus', 1991, 'unspecified', 3.3),
#  ('Monterrey', 1130960.0, 'Mexico', 1810, 'indigenous', 0.8),
#  ('Monterrey', 1130960.0, 'Mexico', 1810, 'Spanish', 92.7),
#  ('Monterrey', 1130960.0, 'Mexico', 1810, 'unspecified', 0.8),
#  ('Montevideo', 1305080.0, 'Uruguay', 1828, 'Brazilero', None),
#  ('Montevideo', 1305080.0, 'Uruguay', 1828, 'Portunol', None),
#  ('Montevideo', 1305080.0, 'Uruguay', 1828, 'Spanish', None),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'Arabic', 1.1),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'Cantonese', 1.2),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'English', 58.7),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'French', 22.0),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'German', 1.3),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'Italian', 1.3),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'Other', 10.5),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'Punjabi', 1.4),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'Spanish', 1.3),
#  ('Montreal', 1649520.0, 'Canada', 1867, 'Tagalog', 1.2),
#  ('Moscow', 12197600.0, 'Russian Federation', 1991, 'Chechen', 1.0),
#  ('Moscow', 12197600.0, 'Russian Federation', 1991, 'Other', 10.1),
#  ('Moscow', 12197600.0, 'Russian Federation', 1991, 'Russian', 85.7),
#  ('Moscow', 12197600.0, 'Russian Federation', 1991, 'Tatar', 3.2),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'English', None),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Other', None),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Multan', 3117000.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Assamese', 1.3),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Bengali', 8.1),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Hindi', 41.0),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Kannada', 3.7),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Maithili', 1.2),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Marathi', 7.0),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Oriya', 3.2),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Other', 5.9),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Tamil', 5.9),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Telugu', 7.2),
#  ('Mumbai', 12478400.0, 'India', 1947, 'Urdu', 5.0),
#  ('Munich', 1450380.0, 'Germany', 1955, 'German', None),
#  ('Nagoya', 2296010.0, 'Japan', -660, 'Japanese', None),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Assamese', 1.3),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Bengali', 8.1),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Hindi', 41.0),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Kannada', 3.7),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Maithili', 1.2),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Marathi', 7.0),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Oriya', 3.2),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Other', 5.9),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Tamil', 5.9),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Telugu', 7.2),
#  ('Nagpur', 2405660.0, 'India', 1947, 'Urdu', 5.0),
#  ('Nairobi', 3138370.0, 'Kenya', 1963, 'English', None),
#  ('Nairobi', 3138370.0, 'Kenya', 1963, 'Kiswahili', None),
#  ('Nairobi', 3138370.0, 'Kenya', 1963, 'Other', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Gan', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Hakka', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Mandarin', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Minbei', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Minnan', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Other', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Wu', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Xiang', None),
#  ('Nanjing', 8230000.0, 'China', -1523, 'Yue', None),
#  ('New Taipei City', 3954930.0, None, None, None, None),
#  ('New York City', 8550400.0, 'United States', 1776, 'English', 79.2),
#  ('New York City', 8550400.0, 'United States', 1776, 'Other', 8.0),
#  ('New York City', 8550400.0, 'United States', 1776, 'Spanish', 12.9),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Gan', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Hakka', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Mandarin', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Minbei', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Minnan', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Other', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Wu', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Xiang', None),
#  ('Ningbo', 3491600.0, 'China', -1523, 'Yue', None),
#  ('Nizhny Novgorod', 1250620.0, 'Russian Federation', 1991, 'Chechen', 1.0),
#  ('Nizhny Novgorod', 1250620.0, 'Russian Federation', 1991, 'Other', 10.1),
#  ('Nizhny Novgorod', 1250620.0, 'Russian Federation', 1991, 'Russian', 85.7),
#  ('Nizhny Novgorod', 1250620.0, 'Russian Federation', 1991, 'Tatar', 3.2),
#  ('Novosibirsk', 1567090.0, 'Russian Federation', 1991, 'Chechen', 1.0),
#  ('Novosibirsk', 1567090.0, 'Russian Federation', 1991, 'Other', 10.1),
#  ('Novosibirsk', 1567090.0, 'Russian Federation', 1991, 'Russian', 85.7),
#  ('Novosibirsk', 1567090.0, 'Russian Federation', 1991, 'Tatar', 3.2),
#  ('Omsk', 1154120.0, 'Russian Federation', 1991, 'Chechen', 1.0),
#  ('Omsk', 1154120.0, 'Russian Federation', 1991, 'Other', 10.1),
#  ('Omsk', 1154120.0, 'Russian Federation', 1991, 'Russian', 85.7),
#  ('Omsk', 1154120.0, 'Russian Federation', 1991, 'Tatar', 3.2),
#  ('Oran', 1560330.0, 'Algeria', 1962, 'Arabic', None),
#  ('Oran', 1560330.0, 'Algeria', 1962, 'Berber or Tamazight', None),
#  ('Oran', 1560330.0, 'Algeria', 1962, 'French', None),
#  ('Oran', 1560330.0, 'Algeria', 1962, 'Mzab', None),
#  ('Oran', 1560330.0, 'Algeria', 1962, 'Shawiya', None),
#  ('Oran', 1560330.0, 'Algeria', 1962, 'Tuareg', None),
#  ('Osaka', 2691740.0, 'Japan', -660, 'Japanese', None),
#  ('Ouagadougou', 2200000.0, 'Burkina Faso', 1960, 'French', None),
#  ('Ouagadougou', 2200000.0, 'Burkina Faso', 1960, 'Sudanic family', 90.0),
#  ('Palembang', 1708410.0, 'Indonesia', 1945, 'Bahasa', None),
#  ('Palembang', 1708410.0, 'Indonesia', 1945, 'Dutch', None),
#  ('Palembang', 1708410.0, 'Indonesia', 1945, 'English', None),
#  ('Palembang', 1708410.0, 'Indonesia', 1945, 'Other', None),
#  ('Paris', 2229620.0, 'France', 843, 'Alsatian', None),
#  ('Paris', 2229620.0, 'France', 843, 'Basque', None),
#  ('Paris', 2229620.0, 'France', 843, 'Breton', None),
#  ('Paris', 2229620.0, 'France', 843, 'Catalan', None),
#  ('Paris', 2229620.0, 'France', 843, 'Corsican', None),
#  ('Paris', 2229620.0, 'France', 843, 'Creole patois', None),
#  ('Paris', 2229620.0, 'France', 843, 'Flemish', None),
#  ('Paris', 2229620.0, 'France', 843, 'French', 100.0),
#  ('Paris', 2229620.0, 'France', 843, 'French', None),
#  ('Paris', 2229620.0, 'France', 843, 'Mahorian', None),
#  ('Paris', 2229620.0, 'France', 843, 'Occitan', None),
#  ('Paris', 2229620.0, 'France', 843, 'Picard', None),
#  ('Paris', 2229620.0, 'France', 843, 'Provencal', None),
#  ('Patna', 1683200.0, 'India', 1947, 'Assamese', 1.3),
#  ('Patna', 1683200.0, 'India', 1947, 'Bengali', 8.1),
#  ('Patna', 1683200.0, 'India', 1947, 'Gujarati', 4.5),
#  ('Patna', 1683200.0, 'India', 1947, 'Hindi', 41.0),
#  ('Patna', 1683200.0, 'India', 1947, 'Kannada', 3.7),
#  ('Patna', 1683200.0, 'India', 1947, 'Maithili', 1.2),
#  ('Patna', 1683200.0, 'India', 1947, 'Malayalam', 3.2),
#  ('Patna', 1683200.0, 'India', 1947, 'Marathi', 7.0),
#  ('Patna', 1683200.0, 'India', 1947, 'Oriya', 3.2),
#  ('Patna', 1683200.0, 'India', 1947, 'Other', 5.9),
#  ('Patna', 1683200.0, 'India', 1947, 'Punjabi', 2.8),
#  ('Patna', 1683200.0, 'India', 1947, 'Tamil', 5.9),
#  ('Patna', 1683200.0, 'India', 1947, 'Telugu', 7.2),
#  ('Patna', 1683200.0, 'India', 1947, 'Urdu', 5.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Balochi', 3.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Brahui', 1.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Burushaski', None),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'English', None),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Hindko', 2.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Other', None),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Pashto', 8.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Punjabi', 48.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Saraiki', 10.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Sindhi', 12.0),
#  ('Peshawar', 3201000.0, 'Pakistan', 1947, 'Urdu', 8.0),
#  ('Philadelphia', 1567870.0, 'United States', 1776, 'English', 79.2),
#  ('Philadelphia', 1567870.0, 'United States', 1776, 'Other', 8.0),
#  ('Philadelphia', 1567870.0, 'United States', 1776, 'Spanish', 12.9),
#  ('Phnom Penh', 2234570.0, 'Cambodia', 1953, 'Khmer', 96.3),
#  ('Phnom Penh', 2234570.0, 'Cambodia', 1953, 'Other', 3.7),
#  ('Phoenix', 1563020.0, 'United States', 1776, 'English', 79.2),
#  ('Phoenix', 1563020.0, 'United States', 1776, 'Other', 8.0),
#  ...]

# %% [markdown]
# # Full join
# In this exercise, you'll examine how your results differ when using a full join versus using a left join and versus using an inner join with the `countries` and `currencies` tables.
#
# You will focus on the North American `region` and also where the `name` of the country is missing. Dig in to see what we mean!
#
# Begin with a full join with `countries` on the left and `currencies` on the right. The fields of interest have been SELECTed for you throughout this exercise.
#
# Then complete a similar left join and conclude with an inner join.
# - Choose records in which `region` corresponds to `North America` or is `NULL`
# - Repeat the same query as above but use a left join instead of a full join. Note what has changed compared to the full join result!
# - Repeat the same query as above but use a left join instead of a full join. Note what has changed compared to the full join result!

# %%
# %%sql
# SELECT name AS country, code, region, basic_unit
# FROM countries
# FULL JOIN currencies
# USING (code)
# WHERE region = 'North America' OR region IS NULL
# ORDER BY region;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 17 rows affected.
# [('Canada', 'CAN', 'North America', 'Canadian dollar'),
#  ('United States', 'USA', 'North America', 'United States dollar'),
#  ('Bermuda', 'BMU', 'North America', 'Bermudian dollar'),
#  ('Greenland', 'GRL', 'North America', None),
#  (None, 'TMP', None, 'United States dollar'),
#  (None, 'FLK', None, 'Falkland Islands pound'),
#  (None, 'AIA', None, 'East Caribbean dollar'),
#  (None, 'NIU', None, 'New Zealand dollar'),
#  (None, 'ROM', None, 'Romanian leu'),
#  (None, 'SHN', None, 'Saint Helena pound'),
#  (None, 'SGS', None, 'British pound'),
#  (None, 'TWN', None, 'New Taiwan dollar'),
#  (None, 'WLF', None, 'CFP franc'),
#  (None, 'MSR', None, 'East Caribbean dollar'),
#  (None, 'IOT', None, 'United States dollar'),
#  (None, 'CCK', None, 'Australian dollar'),
#  (None, 'COK', None, 'New Zealand dollar')]

# %%
# %%sql
# SELECT name AS country, code, region, basic_unit
# FROM countries
# LEFT JOIN currencies
# USING (code)
# WHERE region = 'North America' OR region IS NULL
# ORDER BY region;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 4 rows affected.
# [('Bermuda', 'BMU', 'North America', 'Bermudian dollar'),
#  ('Canada', 'CAN', 'North America', 'Canadian dollar'),
#  ('United States', 'USA', 'North America', 'United States dollar'),
#  ('Greenland', 'GRL', 'North America', None)]

# %%
# %%sql
# SELECT name AS country, code, region, basic_unit
# FROM countries
# INNER JOIN currencies
# USING (code)
# WHERE region = 'North America' OR region IS NULL
# ORDER BY region;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 3 rows affected.
# [('Bermuda', 'BMU', 'North America', 'Bermudian dollar'),
#  ('Canada', 'CAN', 'North America', 'Canadian dollar'),
#  ('United States', 'USA', 'North America', 'United States dollar')]

# %% [markdown]
# # Full join (2)
# You'll now investigate a similar exercise to the last one, but this time focused on using a table with more records on the left than the right. You'll work with the `languages` and `countries` tables.
#
# Begin with a full join with languages on the left and countries on the right. Appropriate fields have been selected for you again here.
# - Choose records in which countries.name starts with the capital letter `'V'` or is `NULL`. Lastly, arrange by `countries.name` in ascending order to more clearly see the results.
#
# - Repeat the same query as above but use a left join instead of a full join. Note what has changed compared to the full join result!
# - Repeat once more, but use an inner join instead of a left join. Note what has changed compared to the full join and left join results.

# %%
# %%sql
# SELECT countries.name, code, languages.name AS language
# FROM languages
# FULL JOIN countries
# USING (code)
# WHERE countries.name LIKE 'V%' OR countries.name IS NULL
# ORDER BY countries.name;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 53 rows affected.
# [('Vanuatu', 'VUT', 'Tribal Languages'),
#  ('Vanuatu', 'VUT', 'English'),
#  ('Vanuatu', 'VUT', 'French'),
#  ('Vanuatu', 'VUT', 'Other'),
#  ('Vanuatu', 'VUT', 'Bislama'),
#  ('Venezuela', 'VEN', 'Spanish'),
#  ('Venezuela', 'VEN', 'indigenous'),
#  ('Vietnam', 'VNM', 'Vietnamese'),
#  ('Vietnam', 'VNM', 'English'),
#  ('Vietnam', 'VNM', 'Other'),
#  ('Virgin Islands, British', 'VGB', None),
#  ('Virgin Islands, U.S.', 'VIR', None),
#  (None, 'NIU', 'English'),
#  (None, 'NIU', 'Niuean'),
#  (None, 'NIU', 'Other'),
#  (None, 'NFK', 'English'),
#  (None, 'NFK', 'Other'),
#  (None, 'ROM', 'Romanian'),
#  (None, 'ROM', 'Hungarian'),
#  (None, 'ROM', 'Romani'),
#  (None, 'ROM', 'Other'),
#  (None, 'ROM', 'unspecified'),
#  (None, 'SPM', 'French'),
#  (None, 'TWN', 'Mandarin'),
#  (None, 'TWN', 'Taiwanese'),
#  (None, 'TWN', 'Hakka'),
#  (None, 'TKL', 'Tokelauan'),
#  (None, 'TKL', 'English'),
#  (None, 'TKL', 'Samoan'),
#  (None, 'TKL', 'Tuvaluan'),
#  (None, 'TKL', 'Kiribati'),
#  (None, 'TKL', 'Other'),
#  (None, 'AIA', 'English'),
#  (None, 'TKL', 'unspecified'),
#  (None, 'WLF', 'Wallisian'),
#  (None, 'WLF', 'Futunian'),
#  (None, 'WLF', 'French'),
#  (None, 'WLF', 'Other'),
#  (None, 'ESH', 'Standard'),
#  (None, 'ESH', 'Hassaniya'),
#  (None, 'ESH', 'Moroccan'),
#  (None, 'TKL', 'none'),
#  (None, 'CXR', 'English'),
#  (None, 'CXR', 'Chinese'),
#  (None, 'CXR', 'Malay'),
#  (None, 'CCK', 'Malay'),
#  (None, 'CCK', 'English'),
#  (None, 'COK', 'English'),
#  (None, 'COK', 'Rarotongan'),
#  (None, 'COK', 'Other'),
#  (None, 'MSR', 'English'),
#  (None, 'NIU', 'Niuean'),
#  (None, 'NIU', 'Niuean')]

# %%
# %%sql
# SELECT countries.name, code, languages.name AS language
# FROM languages
# LEFT JOIN countries
# USING (code)
# WHERE countries.name LIKE 'V%' OR countries.name IS NULL
# ORDER BY countries.name;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 51 rows affected.
# [('Vanuatu', 'VUT', 'English'),
#  ('Vanuatu', 'VUT', 'Other'),
#  ('Vanuatu', 'VUT', 'French'),
#  ('Vanuatu', 'VUT', 'Tribal Languages'),
#  ('Vanuatu', 'VUT', 'Bislama'),
#  ('Venezuela', 'VEN', 'indigenous'),
#  ('Venezuela', 'VEN', 'Spanish'),
#  ('Vietnam', 'VNM', 'English'),
#  ('Vietnam', 'VNM', 'Vietnamese'),
#  ('Vietnam', 'VNM', 'Other'),
#  (None, 'NIU', 'Niuean'),
#  (None, 'NIU', 'Niuean'),
#  (None, 'NIU', 'English'),
#  (None, 'NIU', 'Niuean'),
#  (None, 'NIU', 'Other'),
#  (None, 'NFK', 'English'),
#  (None, 'NFK', 'Other'),
#  (None, 'ROM', 'Romanian'),
#  (None, 'ROM', 'Hungarian'),
#  (None, 'ROM', 'Romani'),
#  (None, 'ROM', 'Other'),
#  (None, 'ROM', 'unspecified'),
#  (None, 'SPM', 'French'),
#  (None, 'TWN', 'Mandarin'),
#  (None, 'TWN', 'Taiwanese'),
#  (None, 'TWN', 'Hakka'),
#  (None, 'TKL', 'Tokelauan'),
#  (None, 'TKL', 'English'),
#  (None, 'TKL', 'Samoan'),
#  (None, 'TKL', 'Tuvaluan'),
#  (None, 'TKL', 'Kiribati'),
#  (None, 'TKL', 'Other'),
#  (None, 'TKL', 'none'),
#  (None, 'TKL', 'unspecified'),
#  (None, 'WLF', 'Wallisian'),
#  (None, 'WLF', 'Futunian'),
#  (None, 'WLF', 'French'),
#  (None, 'WLF', 'Other'),
#  (None, 'ESH', 'Standard'),
#  (None, 'ESH', 'Hassaniya'),
#  (None, 'AIA', 'English'),
#  (None, 'ESH', 'Moroccan'),
#  (None, 'CXR', 'English'),
#  (None, 'CXR', 'Chinese'),
#  (None, 'CXR', 'Malay'),
#  (None, 'CCK', 'Malay'),
#  (None, 'CCK', 'English'),
#  (None, 'COK', 'English'),
#  (None, 'COK', 'Rarotongan'),
#  (None, 'COK', 'Other'),
#  (None, 'MSR', 'English')]

# %%
# %%sql
# SELECT countries.name, code, languages.name AS language
# FROM languages
# INNER JOIN countries
# USING (code)
# WHERE countries.name LIKE 'V%' OR countries.name IS NULL
# ORDER BY countries.name;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 10 rows affected.
# [('Vanuatu', 'VUT', 'Tribal Languages'),
#  ('Vanuatu', 'VUT', 'Bislama'),
#  ('Vanuatu', 'VUT', 'English'),
#  ('Vanuatu', 'VUT', 'French'),
#  ('Vanuatu', 'VUT', 'Other'),
#  ('Venezuela', 'VEN', 'Spanish'),
#  ('Venezuela', 'VEN', 'indigenous'),
#  ('Vietnam', 'VNM', 'Vietnamese'),
#  ('Vietnam', 'VNM', 'English'),
#  ('Vietnam', 'VNM', 'Other')]

# %% [markdown]
# - Complete a full join with `countries` on the left and `languages` on the right.Next, full join this result with `currencies` on the right.
# - Select the fields corresponding to the country name AS `country`, `region`, language name AS `language`, and basic and fractional units of currency.
# - Use `LIKE` to choose the Melanesia and Micronesia regions

# %%
# %%sql
# SELECT c1.name AS country, c1.region, l.name AS language,
#        c2.basic_unit, c2.frac_unit
# FROM countries AS c1
# FULL JOIN languages AS l
# USING (code)
# FULL JOIN currencies AS c2
# USING (code)
# WHERE region LIKE 'M%esia';
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 50 rows affected.
# [('Kiribati', 'Micronesia', 'English', 'Australian dollar', 'Cent'),
#  ('Kiribati', 'Micronesia', 'Kiribati', 'Australian dollar', 'Cent'),
#  ('Marshall Islands', 'Micronesia', 'Other', 'United States dollar', 'Cent'),
#  ('Marshall Islands', 'Micronesia', 'Marshallese', 'United States dollar', 'Cent'),
#  ('Nauru', 'Micronesia', 'Other', 'Australian dollar', 'Cent'),
#  ('Nauru', 'Micronesia', 'English', 'Australian dollar', 'Cent'),
#  ('Nauru', 'Micronesia', 'Nauruan', 'Australian dollar', 'Cent'),
#  ('New Caledonia', 'Melanesia', 'Other', 'CFP franc', 'Centime'),
#  ('New Caledonia', 'Melanesia', 'French', 'CFP franc', 'Centime'),
#  ('Palau', 'Micronesia', 'Other', 'United States dollar', 'Cent'),
#  ('Palau', 'Micronesia', 'Chinese', 'United States dollar', 'Cent'),
#  ('Palau', 'Micronesia', 'Filipino', 'United States dollar', 'Cent'),
#  ('Palau', 'Micronesia', 'English', 'United States dollar', 'Cent'),
#  ('Palau', 'Micronesia', 'Other', 'United States dollar', 'Cent'),
#  ('Palau', 'Micronesia', 'Palauan', 'United States dollar', 'Cent'),
#  ('Papua New Guinea', 'Melanesia', 'Other', 'Papua New Guinean kina', 'Toea'),
#  ('Papua New Guinea', 'Melanesia', 'Hiri', 'Papua New Guinean kina', 'Toea'),
#  ('Papua New Guinea', 'Melanesia', 'English', 'Papua New Guinean kina', 'Toea'),
#  ('Papua New Guinea', 'Melanesia', 'Tok Pisin', 'Papua New Guinean kina', 'Toea'),
#  ('Solomon Islands', 'Melanesia', 'indigenous', 'Solomon Islands dollar', 'Cent'),
#  ('Solomon Islands', 'Melanesia', 'English', 'Solomon Islands dollar', 'Cent'),
#  ('Solomon Islands', 'Melanesia', 'Melanesian pidgin', 'Solomon Islands dollar', 'Cent'),
#  ('Vanuatu', 'Melanesia', 'Other', 'Vanuatu vatu', None),
#  ('Vanuatu', 'Melanesia', 'French', 'Vanuatu vatu', None),
#  ('Vanuatu', 'Melanesia', 'English', 'Vanuatu vatu', None),
#  ('Vanuatu', 'Melanesia', 'Bislama', 'Vanuatu vatu', None),
#  ('Vanuatu', 'Melanesia', 'Tribal Languages', 'Vanuatu vatu', None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Kapingamarangi', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Nukuoro', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Woleaian', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Ulithian', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Yapese', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Pohnpeian', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Kosrean', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'Chuukese', None, None),
#  ('Micronesia, Federated States of', 'Micronesia', 'English', None, None),
#  ('Fiji Islands', 'Melanesia', None, None, None),
#  ('Northern Mariana Islands', 'Micronesia', 'Other', None, None),
#  ('Northern Mariana Islands', 'Micronesia', 'Other Asian', None, None),
#  ('Northern Mariana Islands', 'Micronesia', 'Chinese', None, None),
#  ('Northern Mariana Islands', 'Micronesia', 'Other Pacific Island', None, None),
#  ('Northern Mariana Islands', 'Micronesia', 'English', None, None),
#  ('Northern Mariana Islands', 'Micronesia', 'Chamorro', None, None),
#  ('Northern Mariana Islands', 'Micronesia', 'Philippine', None, None),
#  ('Guam', 'Micronesia', 'Other', None, None),
#  ('Guam', 'Micronesia', 'Asian', None, None),
#  ('Guam', 'Micronesia', 'Other Pacific Islander', None, None),
#  ('Guam', 'Micronesia', 'Chamorro', None, None),
#  ('Guam', 'Micronesia', 'Filipino', None, None),
#  ('Guam', 'Micronesia', 'English', None, None)]

# %% [markdown]
# # Cross Join
# This exercise looks to explore languages potentially and most frequently spoken in the cities of Hyderabad, India and Hyderabad, Pakistan.
#
# You will begin with a cross join with `cities AS c` on the left and `languages AS l` on the right. Then you will modify the query using an inner join in the next tab.
# - Create the cross join above and select only the city name AS city and language name AS language. (Recall that cross joins do not use `ON` or `USING`.)
# - Make use of `LIKE` and `Hyder%` to choose Hyderabad in both `countries`

# %%
# %%sql
# SELECT c.name as city, l.name AS language
# FROM cities AS c
# CROSS JOIN languages AS l
# WHERE c.name LIKE 'Hyder%'
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 1910 rows affected.
# [('Hyderabad (India)', 'Dari'),
#  ('Hyderabad', 'Dari'),
#  ('Hyderabad (India)', 'Pashto'),
#  ('Hyderabad', 'Pashto'),
#  ('Hyderabad (India)', 'Turkic'),
#  ('Hyderabad', 'Turkic'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Albanian'),
#  ('Hyderabad', 'Albanian'),
#  ('Hyderabad (India)', 'Greek'),
#  ('Hyderabad', 'Greek'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Berber or Tamazight'),
#  ('Hyderabad', 'Berber or Tamazight'),
#  ('Hyderabad (India)', 'Shawiya'),
#  ('Hyderabad', 'Shawiya'),
#  ('Hyderabad (India)', 'Mzab'),
#  ('Hyderabad', 'Mzab'),
#  ('Hyderabad (India)', 'Tuareg'),
#  ('Hyderabad', 'Tuareg'),
#  ('Hyderabad (India)', 'Samoan'),
#  ('Hyderabad', 'Samoan'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Tongan'),
#  ('Hyderabad', 'Tongan'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Catalan'),
#  ('Hyderabad', 'Catalan'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Castilian'),
#  ('Hyderabad', 'Castilian'),
#  ('Hyderabad (India)', 'Portuguese'),
#  ('Hyderabad', 'Portuguese'),
#  ('Hyderabad (India)', 'Portuguese'),
#  ('Hyderabad', 'Portuguese'),
#  ('Hyderabad (India)', 'Umbundu'),
#  ('Hyderabad', 'Umbundu'),
#  ('Hyderabad (India)', 'Kikongo'),
#  ('Hyderabad', 'Kikongo'),
#  ('Hyderabad (India)', 'Kimbundu'),
#  ('Hyderabad', 'Kimbundu'),
#  ('Hyderabad (India)', 'Chokwe'),
#  ('Hyderabad', 'Chokwe'),
#  ('Hyderabad (India)', 'Nhaneca'),
#  ('Hyderabad', 'Nhaneca'),
#  ('Hyderabad (India)', 'Nganguela'),
#  ('Hyderabad', 'Nganguela'),
#  ('Hyderabad (India)', 'Fiote'),
#  ('Hyderabad', 'Fiote'),
#  ('Hyderabad (India)', 'Kwanhama'),
#  ('Hyderabad', 'Kwanhama'),
#  ('Hyderabad (India)', 'Muhumbi'),
#  ('Hyderabad', 'Muhumbi'),
#  ('Hyderabad (India)', 'Luvale'),
#  ('Hyderabad', 'Luvale'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Antiguan creole'),
#  ('Hyderabad', 'Antiguan creole'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Italian'),
#  ('Hyderabad', 'Italian'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'indigenous'),
#  ('Hyderabad', 'indigenous'),
#  ('Hyderabad (India)', 'Armenian'),
#  ('Hyderabad', 'Armenian'),
#  ('Hyderabad (India)', 'Kurdish'),
#  ('Hyderabad', 'Kurdish'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Papiamento'),
#  ('Hyderabad', 'Papiamento'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Dutch'),
#  ('Hyderabad', 'Dutch'),
#  ('Hyderabad (India)', 'Chinese'),
#  ('Hyderabad', 'Chinese'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Mandarin'),
#  ('Hyderabad', 'Mandarin'),
#  ('Hyderabad (India)', 'Italian'),
#  ('Hyderabad', 'Italian'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Greek'),
#  ('Hyderabad', 'Greek'),
#  ('Hyderabad (India)', 'Cantonese'),
#  ('Hyderabad', 'Cantonese'),
#  ('Hyderabad (India)', 'Vietnamese'),
#  ('Hyderabad', 'Vietnamese'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Turkish'),
#  ('Hyderabad', 'Turkish'),
#  ('Hyderabad (India)', 'Serbian'),
#  ('Hyderabad', 'Serbian'),
#  ('Hyderabad (India)', 'Croatian'),
#  ('Hyderabad', 'Croatian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Azerbaijani'),
#  ('Hyderabad', 'Azerbaijani'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Armenian'),
#  ('Hyderabad', 'Armenian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Creole'),
#  ('Hyderabad', 'Creole'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Farsi'),
#  ('Hyderabad', 'Farsi'),
#  ('Hyderabad (India)', 'Urdu'),
#  ('Hyderabad', 'Urdu'),
#  ('Hyderabad (India)', 'Bangla'),
#  ('Hyderabad', 'Bangla'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Bajan'),
#  ('Hyderabad', 'Bajan'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Belarusian'),
#  ('Hyderabad', 'Belarusian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Dutch'),
#  ('Hyderabad', 'Dutch'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Creole'),
#  ('Hyderabad', 'Creole'),
#  ('Hyderabad (India)', 'Maya'),
#  ('Hyderabad', 'Maya'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Garifuna'),
#  ('Hyderabad', 'Garifuna'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unknown'),
#  ('Hyderabad', 'unknown'),
#  ('Hyderabad (India)', 'none'),
#  ('Hyderabad', 'none'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Fon and Yoruba'),
#  ('Hyderabad', 'Fon and Yoruba'),
#  ('Hyderabad (India)', 'Tribal Languages'),
#  ('Hyderabad', 'Tribal Languages'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Portuguese'),
#  ('Hyderabad', 'Portuguese'),
#  ('Hyderabad (India)', 'Sharchhopka'),
#  ('Hyderabad', 'Sharchhopka'),
#  ('Hyderabad (India)', 'Dzongkha'),
#  ('Hyderabad', 'Dzongkha'),
#  ('Hyderabad (India)', 'Lhotshamkha'),
#  ('Hyderabad', 'Lhotshamkha'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Quechua'),
#  ('Hyderabad', 'Quechua'),
#  ('Hyderabad (India)', 'Aymara'),
#  ('Hyderabad', 'Aymara'),
#  ('Hyderabad (India)', 'Foreign Languages'),
#  ('Hyderabad', 'Foreign Languages'),
#  ('Hyderabad (India)', 'Guarani'),
#  ('Hyderabad', 'Guarani'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'none'),
#  ('Hyderabad', 'none'),
#  ('Hyderabad (India)', 'Bosnian'),
#  ('Hyderabad', 'Bosnian'),
#  ('Hyderabad (India)', 'Serbian'),
#  ('Hyderabad', 'Serbian'),
#  ('Hyderabad (India)', 'Croatian'),
#  ('Hyderabad', 'Croatian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'No Answer'),
#  ('Hyderabad', 'No Answer'),
#  ('Hyderabad (India)', 'Setswana'),
#  ('Hyderabad', 'Setswana'),
#  ('Hyderabad (India)', 'Sekalanga'),
#  ('Hyderabad', 'Sekalanga'),
#  ('Hyderabad (India)', 'Shekgalagadi'),
#  ('Hyderabad', 'Shekgalagadi'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Zezuru'),
#  ('Hyderabad', 'Zezuru'),
#  ('Hyderabad (India)', 'Sesarwa'),
#  ('Hyderabad', 'Sesarwa'),
#  ('Hyderabad (India)', 'Sembukushu'),
#  ('Hyderabad', 'Sembukushu'),
#  ('Hyderabad (India)', 'Ndebele'),
#  ('Hyderabad', 'Ndebele'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Portuguese'),
#  ('Hyderabad', 'Portuguese'),
#  ('Hyderabad (India)', 'Malay'),
#  ('Hyderabad', 'Malay'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Chinese'),
#  ('Hyderabad', 'Chinese'),
#  ('Hyderabad (India)', 'Bulgarian'),
#  ('Hyderabad', 'Bulgarian'),
#  ('Hyderabad (India)', 'Turkish'),
#  ('Hyderabad', 'Turkish'),
#  ('Hyderabad (India)', 'Romani'),
#  ('Hyderabad', 'Romani'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Sudanic family'),
#  ('Hyderabad', 'Sudanic family'),
#  ('Hyderabad (India)', 'Burmese'),
#  ('Hyderabad', 'Burmese'),
#  ('Hyderabad (India)', 'Kirundi'),
#  ('Hyderabad', 'Kirundi'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Swahili'),
#  ('Hyderabad', 'Swahili'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Khmer'),
#  ('Hyderabad', 'Khmer'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Punjabi'),
#  ('Hyderabad', 'Punjabi'),
#  ('Hyderabad (India)', 'Italian'),
#  ('Hyderabad', 'Italian'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Cantonese'),
#  ('Hyderabad', 'Cantonese'),
#  ('Hyderabad (India)', 'Tagalog'),
#  ('Hyderabad', 'Tagalog'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Filipino'),
#  ('Hyderabad', 'Filipino'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Sangho'),
#  ('Hyderabad', 'Sangho'),
#  ('Hyderabad (India)', 'tribal'),
#  ('Hyderabad', 'tribal'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Sara'),
#  ('Hyderabad', 'Sara'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'indigenous'),
#  ('Hyderabad', 'indigenous'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Mandarin'),
#  ('Hyderabad', 'Mandarin'),
#  ('Hyderabad (India)', 'Yue'),
#  ('Hyderabad', 'Yue'),
#  ('Hyderabad (India)', 'Wu'),
#  ('Hyderabad', 'Wu'),
#  ('Hyderabad (India)', 'Minbei'),
#  ('Hyderabad', 'Minbei'),
#  ('Hyderabad (India)', 'Minnan'),
#  ('Hyderabad', 'Minnan'),
#  ('Hyderabad (India)', 'Xiang'),
#  ('Hyderabad', 'Xiang'),
#  ('Hyderabad (India)', 'Gan'),
#  ('Hyderabad', 'Gan'),
#  ('Hyderabad (India)', 'Hakka'),
#  ('Hyderabad', 'Hakka'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Chinese'),
#  ('Hyderabad', 'Chinese'),
#  ('Hyderabad (India)', 'Malay'),
#  ('Hyderabad', 'Malay'),
#  ('Hyderabad (India)', 'Malay'),
#  ('Hyderabad', 'Malay'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Shikomoro'),
#  ('Hyderabad', 'Shikomoro'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Lingala'),
#  ('Hyderabad', 'Lingala'),
#  ('Hyderabad (India)', 'Kingwana'),
#  ('Hyderabad', 'Kingwana'),
#  ('Hyderabad (India)', 'Kikongo'),
#  ('Hyderabad', 'Kikongo'),
#  ('Hyderabad (India)', 'Tshiluba'),
#  ('Hyderabad', 'Tshiluba'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Lingala'),
#  ('Hyderabad', 'Lingala'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Rarotongan'),
#  ('Hyderabad', 'Rarotongan'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Croatian'),
#  ('Hyderabad', 'Croatian'),
#  ('Hyderabad (India)', 'Serbian'),
#  ('Hyderabad', 'Serbian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Greek'),
#  ('Hyderabad', 'Greek'),
#  ('Hyderabad (India)', 'Turkish'),
#  ('Hyderabad', 'Turkish'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Romanian'),
#  ('Hyderabad', 'Romanian'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Bulgarian'),
#  ('Hyderabad', 'Bulgarian'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Filipino'),
#  ('Hyderabad', 'Filipino'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Danish'),
#  ('Hyderabad', 'Danish'),
#  ('Hyderabad (India)', 'Faroese'),
#  ('Hyderabad', 'Faroese'),
#  ('Hyderabad (India)', 'Greenlandic'),
#  ('Hyderabad', 'Greenlandic'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Somali'),
#  ('Hyderabad', 'Somali'),
#  ('Hyderabad (India)', 'Afar'),
#  ('Hyderabad', 'Afar'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'French patois'),
#  ('Hyderabad', 'French patois'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Quechua'),
#  ('Hyderabad', 'Quechua'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'foreign'),
#  ('Hyderabad', 'foreign'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Nawat'),
#  ('Hyderabad', 'Nawat'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Fang'),
#  ('Hyderabad', 'Fang'),
#  ('Hyderabad (India)', 'Bubi'),
#  ('Hyderabad', 'Bubi'),
#  ('Hyderabad (India)', 'Tigrinya'),
#  ('Hyderabad', 'Tigrinya'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Tigre'),
#  ('Hyderabad', 'Tigre'),
#  ('Hyderabad (India)', 'Kunama'),
#  ('Hyderabad', 'Kunama'),
#  ('Hyderabad (India)', 'Afar'),
#  ('Hyderabad', 'Afar'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Estonian'),
#  ('Hyderabad', 'Estonian'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Ukrainian'),
#  ('Hyderabad', 'Ukrainian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Oromo'),
#  ('Hyderabad', 'Oromo'),
#  ('Hyderabad (India)', 'Amharic'),
#  ('Hyderabad', 'Amharic'),
#  ('Hyderabad (India)', 'Somali'),
#  ('Hyderabad', 'Somali'),
#  ('Hyderabad (India)', 'Tigrigna'),
#  ('Hyderabad', 'Tigrigna'),
#  ('Hyderabad (India)', 'Sidamo'),
#  ('Hyderabad', 'Sidamo'),
#  ('Hyderabad (India)', 'Wolaytta'),
#  ('Hyderabad', 'Wolaytta'),
#  ('Hyderabad (India)', 'Gurage'),
#  ('Hyderabad', 'Gurage'),
#  ('Hyderabad (India)', 'Afar'),
#  ('Hyderabad', 'Afar'),
#  ('Hyderabad (India)', 'Hadiyya'),
#  ('Hyderabad', 'Hadiyya'),
#  ('Hyderabad (India)', 'Gamo'),
#  ('Hyderabad', 'Gamo'),
#  ('Hyderabad (India)', 'Gedeo'),
#  ('Hyderabad', 'Gedeo'),
#  ('Hyderabad (India)', 'Opuuo'),
#  ('Hyderabad', 'Opuuo'),
#  ('Hyderabad (India)', 'Kafa'),
#  ('Hyderabad', 'Kafa'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Faroese'),
#  ('Hyderabad', 'Faroese'),
#  ('Hyderabad (India)', 'Danish'),
#  ('Hyderabad', 'Danish'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Finnish'),
#  ('Hyderabad', 'Finnish'),
#  ('Hyderabad (India)', 'Swedish'),
#  ('Hyderabad', 'Swedish'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Provencal'),
#  ('Hyderabad', 'Provencal'),
#  ('Hyderabad (India)', 'Breton'),
#  ('Hyderabad', 'Breton'),
#  ('Hyderabad (India)', 'Alsatian'),
#  ('Hyderabad', 'Alsatian'),
#  ('Hyderabad (India)', 'Corsican'),
#  ('Hyderabad', 'Corsican'),
#  ('Hyderabad (India)', 'Catalan'),
#  ('Hyderabad', 'Catalan'),
#  ('Hyderabad (India)', 'Basque'),
#  ('Hyderabad', 'Basque'),
#  ('Hyderabad (India)', 'Flemish'),
#  ('Hyderabad', 'Flemish'),
#  ('Hyderabad (India)', 'Occitan'),
#  ('Hyderabad', 'Occitan'),
#  ('Hyderabad (India)', 'Picard'),
#  ('Hyderabad', 'Picard'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Creole patois'),
#  ('Hyderabad', 'Creole patois'),
#  ('Hyderabad (India)', 'Mahorian'),
#  ('Hyderabad', 'Mahorian'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Polynesian'),
#  ('Hyderabad', 'Polynesian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Fang'),
#  ('Hyderabad', 'Fang'),
#  ('Hyderabad (India)', 'Myene'),
#  ('Hyderabad', 'Myene'),
#  ('Hyderabad (India)', 'Nzebi'),
#  ('Hyderabad', 'Nzebi'),
#  ('Hyderabad (India)', 'Bapounou/Eschira'),
#  ('Hyderabad', 'Bapounou/Eschira'),
#  ('Hyderabad (India)', 'Bandjabi'),
#  ('Hyderabad', 'Bandjabi'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Mandinka'),
#  ('Hyderabad', 'Mandinka'),
#  ('Hyderabad (India)', 'Wolof'),
#  ('Hyderabad', 'Wolof'),
#  ('Hyderabad (India)', 'Fula'),
#  ('Hyderabad', 'Fula'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Georgian'),
#  ('Hyderabad', 'Georgian'),
#  ('Hyderabad (India)', 'Azeri'),
#  ('Hyderabad', 'Azeri'),
#  ('Hyderabad (India)', 'Armenian'),
#  ('Hyderabad', 'Armenian'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Asante'),
#  ('Hyderabad', 'Asante'),
#  ('Hyderabad (India)', 'Ewe'),
#  ('Hyderabad', 'Ewe'),
#  ('Hyderabad (India)', 'Fante'),
#  ('Hyderabad', 'Fante'),
#  ('Hyderabad (India)', 'Boron'),
#  ('Hyderabad', 'Boron'),
#  ('Hyderabad (India)', 'Dagomba'),
#  ('Hyderabad', 'Dagomba'),
#  ('Hyderabad (India)', 'Dangme'),
#  ('Hyderabad', 'Dangme'),
#  ('Hyderabad (India)', 'Dagarte'),
#  ('Hyderabad', 'Dagarte'),
#  ('Hyderabad (India)', 'Kokomba'),
#  ('Hyderabad', 'Kokomba'),
#  ('Hyderabad (India)', 'Akyem'),
#  ('Hyderabad', 'Akyem'),
#  ('Hyderabad (India)', 'Ga'),
#  ('Hyderabad', 'Ga'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Italian'),
#  ('Hyderabad', 'Italian'),
#  ('Hyderabad (India)', 'Portuguese'),
#  ('Hyderabad', 'Portuguese'),
#  ('Hyderabad (India)', 'Greek'),
#  ('Hyderabad', 'Greek'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Greenlandic'),
#  ('Hyderabad', 'Greenlandic'),
#  ('Hyderabad (India)', 'Danish'),
#  ('Hyderabad', 'Danish'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'French patois'),
#  ('Hyderabad', 'French patois'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Filipino'),
#  ('Hyderabad', 'Filipino'),
#  ('Hyderabad (India)', 'Chamorro'),
#  ('Hyderabad', 'Chamorro'),
#  ('Hyderabad (India)', 'Other Pacific Islander'),
#  ('Hyderabad', 'Other Pacific Islander'),
#  ('Hyderabad (India)', 'Asian'),
#  ('Hyderabad', 'Asian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Amerindian'),
#  ('Hyderabad', 'Amerindian'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Crioulo'),
#  ('Hyderabad', 'Crioulo'),
#  ('Hyderabad (India)', 'Portuguese'),
#  ('Hyderabad', 'Portuguese'),
#  ('Hyderabad (India)', 'Pular'),
#  ('Hyderabad', 'Pular'),
#  ('Hyderabad (India)', 'Mandingo'),
#  ('Hyderabad', 'Mandingo'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Guyanese Creole'),
#  ('Hyderabad', 'Guyanese Creole'),
#  ('Hyderabad (India)', 'Amerindian'),
#  ('Hyderabad', 'Amerindian'),
#  ('Hyderabad (India)', 'Indian'),
#  ('Hyderabad', 'Indian'),
#  ('Hyderabad (India)', 'Chinese'),
#  ('Hyderabad', 'Chinese'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Creole'),
#  ('Hyderabad', 'Creole'),
#  ('Hyderabad (India)', 'Spanish'),
#  ('Hyderabad', 'Spanish'),
#  ('Hyderabad (India)', 'Amerindian'),
#  ('Hyderabad', 'Amerindian'),
#  ('Hyderabad (India)', 'Cantonese'),
#  ('Hyderabad', 'Cantonese'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Mandarin'),
#  ('Hyderabad', 'Mandarin'),
#  ('Hyderabad (India)', 'Other Chinese'),
#  ('Hyderabad', 'Other Chinese'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Hungarian'),
#  ('Hyderabad', 'Hungarian'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Romanian'),
#  ('Hyderabad', 'Romanian'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Icelandic'),
#  ('Hyderabad', 'Icelandic'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Nordic'),
#  ('Hyderabad', 'Nordic'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Hindi'),
#  ('Hyderabad', 'Hindi'),
#  ('Hyderabad (India)', 'Bengali'),
#  ('Hyderabad', 'Bengali'),
#  ('Hyderabad (India)', 'Telugu'),
#  ('Hyderabad', 'Telugu'),
#  ('Hyderabad (India)', 'Marathi'),
#  ('Hyderabad', 'Marathi'),
#  ('Hyderabad (India)', 'Tamil'),
#  ('Hyderabad', 'Tamil'),
#  ('Hyderabad (India)', 'Urdu'),
#  ('Hyderabad', 'Urdu'),
#  ('Hyderabad (India)', 'Gujarati'),
#  ('Hyderabad', 'Gujarati'),
#  ('Hyderabad (India)', 'Kannada'),
#  ('Hyderabad', 'Kannada'),
#  ('Hyderabad (India)', 'Malayalam'),
#  ('Hyderabad', 'Malayalam'),
#  ('Hyderabad (India)', 'Oriya'),
#  ('Hyderabad', 'Oriya'),
#  ('Hyderabad (India)', 'Punjabi'),
#  ('Hyderabad', 'Punjabi'),
#  ('Hyderabad (India)', 'Assamese'),
#  ('Hyderabad', 'Assamese'),
#  ('Hyderabad (India)', 'Maithili'),
#  ('Hyderabad', 'Maithili'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Bahasa'),
#  ('Hyderabad', 'Bahasa'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Dutch'),
#  ('Hyderabad', 'Dutch'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Persian'),
#  ('Hyderabad', 'Persian'),
#  ('Hyderabad (India)', 'Turkic'),
#  ('Hyderabad', 'Turkic'),
#  ('Hyderabad (India)', 'Kurdish'),
#  ('Hyderabad', 'Kurdish'),
#  ('Hyderabad (India)', 'Gilaki and Mazandarani'),
#  ('Hyderabad', 'Gilaki and Mazandarani'),
#  ('Hyderabad (India)', 'Luri'),
#  ('Hyderabad', 'Luri'),
#  ('Hyderabad (India)', 'Balochi'),
#  ('Hyderabad', 'Balochi'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Kurdish'),
#  ('Hyderabad', 'Kurdish'),
#  ('Hyderabad (India)', 'Turkmen'),
#  ('Hyderabad', 'Turkmen'),
#  ('Hyderabad (India)', 'Syriac'),
#  ('Hyderabad', 'Syriac'),
#  ('Hyderabad (India)', 'Armenian'),
#  ('Hyderabad', 'Armenian'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Irish'),
#  ('Hyderabad', 'Irish'),
#  ('Hyderabad (India)', 'Hebrew'),
#  ('Hyderabad', 'Hebrew'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Italian'),
#  ('Hyderabad', 'Italian'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Slovene'),
#  ('Hyderabad', 'Slovene'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'English patois'),
#  ('Hyderabad', 'English patois'),
#  ('Hyderabad (India)', 'Japanese'),
#  ('Hyderabad', 'Japanese'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Kazakh'),
#  ('Hyderabad', 'Kazakh'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Kiswahili'),
#  ('Hyderabad', 'Kiswahili'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Kiribati'),
#  ('Hyderabad', 'Kiribati'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Korean'),
#  ('Hyderabad', 'Korean'),
#  ('Hyderabad (India)', 'Korean'),
#  ('Hyderabad', 'Korean'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Kyrgyz'),
#  ('Hyderabad', 'Kyrgyz'),
#  ('Hyderabad (India)', 'Uzbek'),
#  ('Hyderabad', 'Uzbek'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Lao'),
#  ('Hyderabad', 'Lao'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Latvian'),
#  ('Hyderabad', 'Latvian'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Armenian'),
#  ('Hyderabad', 'Armenian'),
#  ('Hyderabad (India)', 'Sesotho'),
#  ('Hyderabad', 'Sesotho'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Zulu'),
#  ('Hyderabad', 'Zulu'),
#  ('Hyderabad (India)', 'Xhosa'),
#  ('Hyderabad', 'Xhosa'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Arabic'),
#  ('Hyderabad', 'Arabic'),
#  ('Hyderabad (India)', 'Italian'),
#  ('Hyderabad', 'Italian'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Berber'),
#  ('Hyderabad', 'Berber'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Italian'),
#  ('Hyderabad', 'Italian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Lithuanian'),
#  ('Hyderabad', 'Lithuanian'),
#  ('Hyderabad (India)', 'Russian'),
#  ('Hyderabad', 'Russian'),
#  ('Hyderabad (India)', 'Polish'),
#  ('Hyderabad', 'Polish'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'unspecified'),
#  ('Hyderabad', 'unspecified'),
#  ('Hyderabad (India)', 'Luxembourgish'),
#  ('Hyderabad', 'Luxembourgish'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Portuguese'),
#  ('Hyderabad', 'Portuguese'),
#  ('Hyderabad (India)', 'German'),
#  ('Hyderabad', 'German'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'Macedonian'),
#  ('Hyderabad', 'Macedonian'),
#  ('Hyderabad (India)', 'Albanian'),
#  ('Hyderabad', 'Albanian'),
#  ('Hyderabad (India)', 'Turkish'),
#  ('Hyderabad', 'Turkish'),
#  ('Hyderabad (India)', 'Romani'),
#  ('Hyderabad', 'Romani'),
#  ('Hyderabad (India)', 'Serbian'),
#  ('Hyderabad', 'Serbian'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Other'),
#  ('Hyderabad (India)', 'French'),
#  ('Hyderabad', 'French'),
#  ('Hyderabad (India)', 'Malagasy'),
#  ('Hyderabad', 'Malagasy'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Chichewa'),
#  ('Hyderabad', 'Chichewa'),
#  ('Hyderabad (India)', 'Chinyanja'),
#  ('Hyderabad', 'Chinyanja'),
#  ('Hyderabad (India)', 'Chiyao'),
#  ('Hyderabad', 'Chiyao'),
#  ('Hyderabad (India)', 'Chitumbuka'),
#  ('Hyderabad', 'Chitumbuka'),
#  ('Hyderabad (India)', 'Chilomwe'),
#  ('Hyderabad', 'Chilomwe'),
#  ('Hyderabad (India)', 'Chinkhonde'),
#  ('Hyderabad', 'Chinkhonde'),
#  ('Hyderabad (India)', 'Chingoni'),
#  ('Hyderabad', 'Chingoni'),
#  ('Hyderabad (India)', 'Chisena'),
#  ('Hyderabad', 'Chisena'),
#  ('Hyderabad (India)', 'Chitonga'),
#  ('Hyderabad', 'Chitonga'),
#  ('Hyderabad (India)', 'Chinyakyusa'),
#  ('Hyderabad', 'Chinyakyusa'),
#  ('Hyderabad (India)', 'Chilambya'),
#  ('Hyderabad', 'Chilambya'),
#  ('Hyderabad (India)', 'Bahasa Malaysia'),
#  ('Hyderabad', 'Bahasa Malaysia'),
#  ('Hyderabad (India)', 'English'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad (India)', 'Chinese'),
#  ('Hyderabad', 'Chinese'),
#  ('Hyderabad (India)', 'Tamil'),
#  ('Hyderabad', 'Tamil'),
#  ('Hyderabad (India)', 'Telugu'),
#  ('Hyderabad', 'Telugu'),
#  ('Hyderabad (India)', 'Malayalam'),
#  ('Hyderabad', 'Malayalam'),
#  ...]

# %% [markdown]
# Use an inner join instead of a cross join. Think about what the difference will be in the results for this inner join result and the one for the cross join.

# %%
# %%sql
# SELECT c.name as city, l.name AS language
# FROM cities AS c
# INNER JOIN languages AS l
# ON c.country_code = l.code
# WHERE c.name LIKE 'Hyder%'
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 25 rows affected.
# [('Hyderabad (India)', 'Hindi'),
#  ('Hyderabad (India)', 'Bengali'),
#  ('Hyderabad (India)', 'Telugu'),
#  ('Hyderabad (India)', 'Marathi'),
#  ('Hyderabad (India)', 'Tamil'),
#  ('Hyderabad (India)', 'Urdu'),
#  ('Hyderabad (India)', 'Gujarati'),
#  ('Hyderabad (India)', 'Kannada'),
#  ('Hyderabad (India)', 'Malayalam'),
#  ('Hyderabad (India)', 'Oriya'),
#  ('Hyderabad (India)', 'Punjabi'),
#  ('Hyderabad (India)', 'Assamese'),
#  ('Hyderabad (India)', 'Maithili'),
#  ('Hyderabad (India)', 'Other'),
#  ('Hyderabad', 'Punjabi'),
#  ('Hyderabad', 'Sindhi'),
#  ('Hyderabad', 'Saraiki'),
#  ('Hyderabad', 'Pashto'),
#  ('Hyderabad', 'Urdu'),
#  ('Hyderabad', 'Balochi'),
#  ('Hyderabad', 'Hindko'),
#  ('Hyderabad', 'Brahui'),
#  ('Hyderabad', 'English'),
#  ('Hyderabad', 'Burushaski'),
#  ('Hyderabad', 'Other')]

# %% [markdown]
# # challenge
# In terms of life expectancy for 2010, determine the names of the lowest five countries and their regions.
# - Select country `name` AS `country`, `region`, and life expectancy AS `life_exp`.
# - Make sure to use `LEFT` `JOIN`, `ORDER BY`, and `LIMIT`.

# %%
# %%sql
# SELECT c.name AS country, c.region, p.life_expectancy AS life_exp
# FROM countries AS c
# LEFT JOIN populations AS p
# ON c.code = p.country_code
# WHERE year = 2010
# ORDER BY life_exp ASC
# LIMIT 5;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 5 rows affected.
# [('Lesotho', 'Southern Africa', 47.4834),
#  ('Central African Republic', 'Central Africa', 47.6253),
#  ('Sierra Leone', 'Western Africa', 48.229),
#  ('Swaziland', 'Southern Africa', 48.3458),
#  ('Zimbabwe', 'Eastern Africa', 49.5747)]

# %%
# %%sql
# CREATE TABLE economies2010 (
#   code                  VARCHAR,
#   year                  INTEGER,
#   income_group          VARCHAR,
#   gross_savings         REAL
# );
# CREATE TABLE economies2015 (
#   code                  VARCHAR,
#   year                  INTEGER,
#   income_group          VARCHAR,
#   gross_savings         REAL
# );
# Out:
#  * postgresql://dennis:***@localhost/dennis
# Done.
# Done.
# []

# %% [markdown]
# # Union
# - Combine these two tables (`economies2010` and `economies2015`) into one table containing all of the fields in `economies2010`
# - Sort this resulting single table by country code and then by year, both in ascending order.

# %%
# %%sql
# -- pick specified columns from 2010 table
# SELECT *
# -- 2010 table will be on top
# FROM economies2010
# -- which set theory clause?
# UNION
# -- pick specified columns from 2015 table
# SELECT *
# -- 2015 table on the bottom
# FROM economies2015
# -- order accordingly
# ORDER BY code, year ASC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 380 rows affected.
# [('AFG', 2010, 'Low income', 37.133),
#  ('AFG', 2015, 'Low income', 21.466),
#  ('AGO', 2010, 'Upper middle income', 23.534),
#  ('AGO', 2015, 'Upper middle income', -0.425),
#  ('ALB', 2010, 'Upper middle income', 20.011),
#  ('ALB', 2015, 'Upper middle income', 13.84),
#  ('ARE', 2010, 'High income', 27.073),
#  ('ARE', 2015, 'High income', 34.106),
#  ('ARG', 2010, 'Upper middle income', 17.361),
#  ('ARG', 2015, 'Upper middle income', 14.111),
#  ('ARM', 2010, 'Lower middle income', 15.797),
#  ('ARM', 2015, 'Lower middle income', 18.306),
#  ('ATG', 2010, 'High income', 13.398),
#  ('ATG', 2015, 'High income', 18.754),
#  ('AUS', 2010, 'High income', 23.584),
#  ('AUS', 2015, 'High income', 22.111),
#  ('AUT', 2010, 'High income', 25.521),
#  ('AUT', 2015, 'High income', 25.353),
#  ('AZE', 2010, 'Upper middle income', 46.567),
#  ('AZE', 2015, 'Upper middle income', 26.4),
#  ('BDI', 2010, 'Low income', 3.723),
#  ('BDI', 2015, 'Low income', -11.014),
#  ('BEL', 2010, 'High income', 24.456),
#  ('BEL', 2015, 'High income', 23.653),
#  ('BEN', 2010, 'Low income', 14.905),
#  ('BEN', 2015, 'Low income', 17.567),
#  ('BFA', 2010, 'Low income', 15.788),
#  ('BFA', 2015, 'Low income', 5.31),
#  ('BGD', 2010, 'Lower middle income', 29.141),
#  ('BGD', 2015, 'Lower middle income', 29.707),
#  ('BGR', 2010, 'Upper middle income', 20.845),
#  ('BGR', 2015, 'Upper middle income', 21.056),
#  ('BHR', 2010, 'High income', 36.206),
#  ('BHR', 2015, 'High income', 21.955),
#  ('BHS', 2010, 'High income', 15.141),
#  ('BHS', 2015, 'High income', 11.243),
#  ('BIH', 2010, 'Upper middle income', 10.115),
#  ('BIH', 2015, 'Upper middle income', 10.217),
#  ('BLR', 2010, 'Upper middle income', 26.186),
#  ('BLR', 2015, 'Upper middle income', 25.419),
#  ('BLZ', 2010, 'Upper middle income', 10.33),
#  ('BLZ', 2015, 'Upper middle income', 12.155),
#  ('BOL', 2010, 'Lower middle income', 24.969),
#  ('BOL', 2015, 'Lower middle income', 13.31),
#  ('BRA', 2010, 'Upper middle income', 18.368),
#  ('BRA', 2015, 'Upper middle income', 15.865),
#  ('BRB', 2010, 'High income', 8.12),
#  ('BRB', 2015, 'High income', 7.473),
#  ('BRN', 2010, 'High income', None),
#  ('BRN', 2015, 'High income', None),
#  ('BTN', 2010, 'Lower middle income', 44.674),
#  ('BTN', 2015, 'Lower middle income', 32.024),
#  ('BWA', 2010, 'Upper middle income', 32.162),
#  ('BWA', 2015, 'Upper middle income', 40.026),
#  ('CAF', 2010, 'Low income', 4.115),
#  ('CAF', 2015, 'Low income', 4.882),
#  ('CAN', 2010, 'High income', 19.898),
#  ('CAN', 2015, 'High income', 20.416),
#  ('CHE', 2010, 'High income', 38.881),
#  ('CHE', 2015, 'High income', 34.52),
#  ('CHL', 2010, 'High income', 24.839),
#  ('CHL', 2015, 'High income', 21.306),
#  ('CHN', 2010, 'Upper middle income', 51.802),
#  ('CHN', 2015, 'Upper middle income', 47.457),
#  ('CIV', 2010, 'Lower middle income', 16.765),
#  ('CIV', 2015, 'Lower middle income', 16.82),
#  ('CMR', 2010, 'Lower middle income', 17.524),
#  ('CMR', 2015, 'Lower middle income', 17.088),
#  ('COD', 2010, 'Low income', 15.574),
#  ('COD', 2015, 'Low income', 16.495),
#  ('COG', 2010, 'Lower middle income', 27.651),
#  ('COG', 2015, 'Lower middle income', -8.049),
#  ('COL', 2010, 'Upper middle income', 19.107),
#  ('COL', 2015, 'Upper middle income', 20.23),
#  ('COM', 2010, 'Low income', 15.22),
#  ('COM', 2015, 'Low income', 19.221),
#  ('CPV', 2010, 'Lower middle income', 25.257),
#  ('CPV', 2015, 'Lower middle income', 37.094),
#  ('CRI', 2010, 'Upper middle income', 16.489),
#  ('CRI', 2015, 'Upper middle income', 15.725),
#  ('CYP', 2010, 'High income', 12.507),
#  ('CYP', 2015, 'High income', 11.55),
#  ('CZE', 2010, 'High income', 23.588),
#  ('CZE', 2015, 'High income', 28.266),
#  ('DEU', 2010, 'High income', 25.241),
#  ('DEU', 2015, 'High income', 27.571),
#  ('DJI', 2010, 'Lower middle income', 24.089),
#  ('DJI', 2015, 'Lower middle income', 19.039),
#  ('DMA', 2010, 'Upper middle income', 2.462),
#  ('DMA', 2015, 'Upper middle income', 8.814),
#  ('DNK', 2010, 'High income', 24.639),
#  ('DNK', 2015, 'High income', 28.91),
#  ('DOM', 2010, 'Upper middle income', 18.745),
#  ('DOM', 2015, 'Upper middle income', 21.447),
#  ('DZA', 2010, 'Upper middle income', 49.869),
#  ('DZA', 2015, 'Upper middle income', 34.738),
#  ('ECU', 2010, 'Upper middle income', 25.757),
#  ('ECU', 2015, 'Upper middle income', 24.657),
#  ('EGY', 2010, 'Lower middle income', 19.421),
#  ('EGY', 2015, 'Lower middle income', 10.62),
#  ('ERI', 2010, 'Low income', -9.257),
#  ('ERI', 2015, 'Low income', 1.329),
#  ('ESP', 2010, 'High income', 19.628),
#  ('ESP', 2015, 'High income', 21.429),
#  ('EST', 2010, 'High income', 23.087),
#  ('EST', 2015, 'High income', 25.422),
#  ('ETH', 2010, 'Low income', 24.494),
#  ('ETH', 2015, 'Low income', 31.269),
#  ('FIN', 2010, 'High income', 22.843),
#  ('FIN', 2015, 'High income', 20.728),
#  ('FJI', 2010, 'Upper middle income', None),
#  ('FJI', 2015, 'Upper middle income', None),
#  ('FRA', 2010, 'High income', 21.075),
#  ('FRA', 2015, 'High income', 22.163),
#  ('FSM', 2010, 'Lower middle income', None),
#  ('FSM', 2015, 'Lower middle income', None),
#  ('GAB', 2010, 'Upper middle income', 41.009),
#  ('GAB', 2015, 'Upper middle income', 29.315),
#  ('GBR', 2010, 'High income', 13.233),
#  ('GBR', 2015, 'High income', 12.952),
#  ('GEO', 2010, 'Upper middle income', 11.64),
#  ('GEO', 2015, 'Upper middle income', 20.136),
#  ('GHA', 2010, 'Lower middle income', 17.276),
#  ('GHA', 2015, 'Lower middle income', 17.146),
#  ('GIN', 2010, 'Low income', 0.135),
#  ('GIN', 2015, 'Low income', -9.697),
#  ('GMB', 2010, 'Low income', 5.026),
#  ('GMB', 2015, 'Low income', 4.687),
#  ('GNB', 2010, 'Low income', -2.057),
#  ('GNB', 2015, 'Low income', 9.374),
#  ('GNQ', 2010, 'Upper middle income', 41.231),
#  ('GNQ', 2015, 'Upper middle income', 54.939),
#  ('GRC', 2010, 'High income', 5.664),
#  ('GRC', 2015, 'High income', 9.783),
#  ('GRD', 2010, 'Upper middle income', -1.702),
#  ('GRD', 2015, 'Upper middle income', 0.231),
#  ('GTM', 2010, 'Lower middle income', 12.575),
#  ('GTM', 2015, 'Lower middle income', 13.115),
#  ('GUY', 2010, 'Upper middle income', 7.88),
#  ('GUY', 2015, 'Upper middle income', 8.214),
#  ('HKG', 2010, 'High income', 30.892),
#  ('HKG', 2015, 'High income', 24.858),
#  ('HND', 2010, 'Lower middle income', 17.547),
#  ('HND', 2015, 'Lower middle income', 18.403),
#  ('HRV', 2010, 'High income', 20.278),
#  ('HRV', 2015, 'High income', 23.894),
#  ('HTI', 2010, 'Low income', 23.869),
#  ('HTI', 2015, 'Low income', 29.277),
#  ('HUN', 2010, 'High income', 20.992),
#  ('HUN', 2015, 'High income', 25.102),
#  ('IDN', 2010, 'Lower middle income', 33.582),
#  ('IDN', 2015, 'Lower middle income', 32.14),
#  ('IND', 2010, 'Lower middle income', 33.689),
#  ('IND', 2015, 'Lower middle income', 31.689),
#  ('IRL', 2010, 'High income', 16.039),
#  ('IRL', 2015, 'High income', 31.998),
#  ('IRN', 2010, 'Upper middle income', 41.522),
#  ('IRN', 2015, 'Upper middle income', 34.511),
#  ('IRQ', 2010, 'Upper middle income', 23.736),
#  ('IRQ', 2015, 'Upper middle income', 17.971),
#  ('ISL', 2010, 'High income', 7.256),
#  ('ISL', 2015, 'High income', 24.552),
#  ('ISR', 2010, 'High income', 22.064),
#  ('ISR', 2015, 'High income', 24.296),
#  ('ITA', 2010, 'High income', 17.121),
#  ('ITA', 2015, 'High income', 18.934),
#  ('JAM', 2010, 'Upper middle income', 13.41),
#  ('JAM', 2015, 'Upper middle income', 12.111),
#  ('JOR', 2010, 'Upper middle income', 18.381),
#  ('JOR', 2015, 'Upper middle income', 10.146),
#  ('JPN', 2010, 'High income', 25.174),
#  ('JPN', 2015, 'High income', 26.99),
#  ('KAZ', 2010, 'Upper middle income', 26.309),
#  ('KAZ', 2015, 'Upper middle income', 26.533),
#  ('KEN', 2010, 'Lower middle income', 14.809),
#  ('KEN', 2015, 'Lower middle income', 14.392),
#  ('KGZ', 2010, 'Lower middle income', 24.869),
#  ('KGZ', 2015, 'Lower middle income', 18.333),
#  ('KHM', 2010, 'Lower middle income', 10.521),
#  ('KHM', 2015, 'Lower middle income', 11.798),
#  ('KIR', 2010, 'Lower middle income', None),
#  ('KIR', 2015, 'Lower middle income', None),
#  ('KNA', 2010, 'High income', 13.133),
#  ('KNA', 2015, 'High income', 17.742),
#  ('KOR', 2010, 'High income', 34.659),
#  ('KOR', 2015, 'High income', 36.58),
#  ('KWT', 2010, 'High income', 50.831),
#  ('KWT', 2015, 'High income', 31.649),
#  ('LAO', 2010, 'Lower middle income', None),
#  ('LAO', 2015, 'Lower middle income', None),
#  ('LBN', 2010, 'Upper middle income', 3.847),
#  ('LBN', 2015, 'Upper middle income', 3.82),
#  ('LBR', 2010, 'Low income', None),
#  ('LBR', 2015, 'Low income', None),
#  ('LBY', 2010, 'Upper middle income', None),
#  ('LBY', 2015, 'Upper middle income', None),
#  ('LCA', 2010, 'Upper middle income', 11.734),
#  ('LCA', 2015, 'Upper middle income', 17.103),
#  ('LKA', 2010, 'Lower middle income', 28.457),
#  ('LKA', 2015, 'Lower middle income', 27.586),
#  ('LSO', 2010, 'Lower middle income', 16.421),
#  ('LSO', 2015, 'Lower middle income', 30.116),
#  ('LTU', 2010, 'High income', 17.671),
#  ('LTU', 2015, 'High income', 17.555),
#  ('LUX', 2010, 'High income', 24.899),
#  ('LUX', 2015, 'High income', 24.865),
#  ('LVA', 2010, 'High income', 21.365),
#  ('LVA', 2015, 'High income', 21.325),
#  ('MAC', 2010, 'High income', None),
#  ('MAC', 2015, 'High income', None),
#  ('MAR', 2010, 'Lower middle income', 29.7),
#  ('MAR', 2015, 'Lower middle income', 28.079),
#  ('MDA', 2010, 'Lower middle income', 16.001),
#  ('MDA', 2015, 'Lower middle income', 17.961),
#  ('MDG', 2010, 'Low income', 13.74),
#  ('MDG', 2015, 'Low income', 11.15),
#  ('MDV', 2010, 'Upper middle income', 6.844),
#  ('MDV', 2015, 'Upper middle income', 9.798),
#  ('MEX', 2010, 'Upper middle income', 21.555),
#  ('MEX', 2015, 'Upper middle income', 20.019),
#  ('MHL', 2010, 'Upper middle income', None),
#  ('MHL', 2015, 'Upper middle income', None),
#  ('MKD', 2010, 'Upper middle income', 22.443),
#  ('MKD', 2015, 'Upper middle income', 29.029),
#  ('MLI', 2010, 'Low income', 13.306),
#  ('MLI', 2015, 'Low income', 10.118),
#  ('MLT', 2010, 'High income', 18.954),
#  ('MLT', 2015, 'High income', 29.024),
#  ('MMR', 2010, 'Lower middle income', 23.184),
#  ('MMR', 2015, 'Lower middle income', 19.313),
#  ('MNE', 2010, 'Upper middle income', -1.246),
#  ('MNE', 2015, 'Upper middle income', 6.702),
#  ('MNG', 2010, 'Lower middle income', 26.881),
#  ('MNG', 2015, 'Lower middle income', 21.122),
#  ('MOZ', 2010, 'Low income', 8.081),
#  ('MOZ', 2015, 'Low income', 14.228),
#  ('MRT', 2010, 'Lower middle income', 30.703),
#  ('MRT', 2015, 'Lower middle income', 18.915),
#  ('MUS', 2010, 'Upper middle income', 14.27),
#  ('MUS', 2015, 'Upper middle income', 16.312),
#  ('MWI', 2010, 'Low income', 26.25),
#  ('MWI', 2015, 'Low income', 2.676),
#  ('MYS', 2010, 'Upper middle income', 33.468),
#  ('MYS', 2015, 'Upper middle income', 28.087),
#  ('NAM', 2010, 'Upper middle income', 20.709),
#  ('NAM', 2015, 'Upper middle income', 20.514),
#  ('NER', 2010, 'Low income', 25.45),
#  ('NER', 2015, 'Low income', 24.479),
#  ('NGA', 2010, 'Lower middle income', 20.843),
#  ('NGA', 2015, 'Lower middle income', 12.298),
#  ('NIC', 2010, 'Lower middle income', 15.542),
#  ('NIC', 2015, 'Lower middle income', 23.627),
#  ('NLD', 2010, 'High income', 27.798),
#  ('NLD', 2015, 'High income', 27.854),
#  ('NOR', 2010, 'High income', 36.27),
#  ('NOR', 2015, 'High income', 36.88),
#  ('NPL', 2010, 'Low income', 35.909),
#  ('NPL', 2015, 'Low income', 43.787),
#  ('NRU', 2010, 'High income', None),
#  ('NRU', 2015, 'High income', None),
#  ('NZL', 2010, 'High income', 24.648),
#  ('NZL', 2015, 'High income', 20.123),
#  ('OMN', 2010, 'High income', 33.761),
#  ('OMN', 2015, 'High income', 18.347),
#  ('PAK', 2010, 'Lower middle income', 13.577),
#  ('PAK', 2015, 'Lower middle income', 14.48),
#  ('PAN', 2010, 'Upper middle income', 26.436),
#  ('PAN', 2015, 'Upper middle income', 39.271),
#  ('PER', 2010, 'Upper middle income', 22.505),
#  ('PER', 2015, 'Upper middle income', 19.703),
#  ('PHL', 2010, 'Lower middle income', 24.138),
#  ('PHL', 2015, 'Lower middle income', 23.036),
#  ('PLW', 2010, 'Upper middle income', None),
#  ('PLW', 2015, 'Upper middle income', None),
#  ('PNG', 2010, 'Lower middle income', None),
#  ('PNG', 2015, 'Lower middle income', None),
#  ('POL', 2010, 'High income', 15.913),
#  ('POL', 2015, 'High income', 19.832),
#  ('PRI', 2010, 'High income', None),
#  ('PRI', 2015, 'High income', None),
#  ('PRT', 2010, 'High income', 10.709),
#  ('PRT', 2015, 'High income', 15.521),
#  ('PRY', 2010, 'Upper middle income', 15.905),
#  ('PRY', 2015, 'Upper middle income', 15.781),
#  ('QAT', 2010, 'High income', 50.419),
#  ('QAT', 2015, 'High income', 46.556),
#  ('ROU', 2010, 'Upper middle income', 21.755),
#  ('ROU', 2015, 'Upper middle income', 23.747),
#  ('RUS', 2010, 'Upper middle income', 24.417),
#  ('RUS', 2015, 'Upper middle income', 27.175),
#  ('RWA', 2010, 'Low income', 6.369),
#  ('RWA', 2015, 'Low income', 8.687),
#  ('SAU', 2010, 'High income', 43.414),
#  ('SAU', 2015, 'High income', 26.174),
#  ('SDN', 2010, 'Lower middle income', 17.259),
#  ('SDN', 2015, 'Lower middle income', 9.263),
#  ('SEN', 2010, 'Low income', 17.708),
#  ('SEN', 2015, 'Low income', 16.576),
#  ('SGP', 2010, 'High income', 51.68),
#  ('SGP', 2015, 'High income', 44.88),
#  ('SLB', 2010, 'Lower middle income', 12.799),
#  ('SLB', 2015, 'Lower middle income', 17.332),
#  ('SLE', 2010, 'Low income', 9.581),
#  ('SLE', 2015, 'Low income', 0.947),
#  ('SLV', 2010, 'Lower middle income', 10.831),
#  ('SLV', 2015, 'Lower middle income', 10.425),
#  ('SMR', 2010, 'High income', None),
#  ('SMR', 2015, 'High income', None),
#  ('SRB', 2010, 'Upper middle income', 12.102),
#  ('SRB', 2015, 'Upper middle income', 14.141),
#  ('SSD', 2010, 'Low income', None),
#  ('SSD', 2015, 'Low income', 7.304),
#  ('STP', 2010, 'Lower middle income', 32.965),
#  ('STP', 2015, 'Lower middle income', 19.363),
#  ('SUR', 2010, 'Upper middle income', 50.552),
#  ('SUR', 2015, 'Upper middle income', 50.155),
#  ('SVK', 2010, 'High income', 19.303),
#  ('SVK', 2015, 'High income', 23.415),
#  ('SVN', 2010, 'High income', 22.121),
#  ('SVN', 2015, 'High income', 25.243),
#  ('SWE', 2010, 'High income', 28.876),
#  ('SWE', 2015, 'High income', 28.902),
#  ('SWZ', 2010, 'Lower middle income', 3.179),
#  ('SWZ', 2015, 'Lower middle income', 22.994),
#  ('SYC', 2010, 'High income', 17.241),
#  ('SYC', 2015, 'High income', 15.005),
#  ('SYR', 2010, 'Lower middle income', 23.845),
#  ('SYR', 2015, 'Lower middle income', None),
#  ('TCD', 2010, 'Low income', 25.871),
#  ('TCD', 2015, 'Low income', 14.605),
#  ('TGO', 2010, 'Low income', 17.634),
#  ('TGO', 2015, 'Low income', 15.912),
#  ('THA', 2010, 'Upper middle income', 28.724),
#  ('THA', 2015, 'Upper middle income', 30.301),
#  ('TJK', 2010, 'Lower middle income', 6.999),
#  ('TJK', 2015, 'Lower middle income', 12.495),
#  ('TKM', 2010, 'Upper middle income', None),
#  ('TKM', 2015, 'Upper middle income', None),
#  ('TLS', 2010, 'Lower middle income', None),
#  ('TLS', 2015, 'Lower middle income', None),
#  ('TON', 2010, 'Lower middle income', None),
#  ('TON', 2015, 'Lower middle income', None),
#  ('TTO', 2010, 'High income', 13.168),
#  ('TTO', 2015, 'High income', 11.131),
#  ('TUN', 2010, 'Lower middle income', 20.825),
#  ('TUN', 2015, 'Lower middle income', 12.528),
#  ('TUR', 2010, 'Upper middle income', 21.334),
#  ('TUR', 2015, 'Upper middle income', 24.743),
#  ('TUV', 2010, 'Upper middle income', None),
#  ('TUV', 2015, 'Upper middle income', None),
#  ('TZA', 2010, 'Low income', 21.248),
#  ('TZA', 2015, 'Low income', 24.079),
#  ('UGA', 2010, 'Low income', 18.7),
#  ('UGA', 2015, 'Low income', 17.888),
#  ('UKR', 2010, 'Lower middle income', 18.654),
#  ('UKR', 2015, 'Lower middle income', 15.657),
#  ('URY', 2010, 'High income', 17.593),
#  ('URY', 2015, 'High income', 17.713),
#  ('USA', 2010, 'High income', 15.086),
#  ('USA', 2015, 'High income', 19.107),
#  ('UZB', 2010, 'Lower middle income', 37.267),
#  ('UZB', 2015, 'Lower middle income', 30.29),
#  ('VCT', 2010, 'Upper middle income', -1.591),
#  ('VCT', 2015, 'Upper middle income', 2.483),
#  ('VEN', 2010, 'Upper middle income', 31.591),
#  ('VEN', 2015, 'Upper middle income', 31.787),
#  ('VNM', 2010, 'Lower middle income', 31.902),
#  ('VNM', 2015, 'Lower middle income', 28.055),
#  ('VUT', 2010, 'Lower middle income', None),
#  ('VUT', 2015, 'Lower middle income', None),
#  ('WSM', 2010, 'Lower middle income', None),
#  ('WSM', 2015, 'Lower middle income', None),
#  ('YEM', 2010, 'Lower middle income', 8.25),
#  ('YEM', 2015, 'Lower middle income', -3.715),
#  ('ZAF', 2010, 'Upper middle income', 18.012),
#  ('ZAF', 2015, 'Upper middle income', 16.46),
#  ('ZMB', 2010, 'Lower middle income', 37.404),
#  ('ZMB', 2015, 'Lower middle income', 39.177),
#  ('ZWE', 2010, 'Low income', 16.109),
#  ('ZWE', 2015, 'Low income', 5.563)]

# %% [markdown]
# `UNION` can also be used to determine all occurrences of a field across multiple tables.
# - Determine all (non-duplicated) country codes in either the `cities` or the `currencies` table. The result should be a table with only one field called `country_code`.
# - Sort by country_code in alphabetical order.

# %%
# %%sql
# SELECT code AS country_code
# FROM currencies
# UNION
# SELECT country_code
# FROM cities
# ORDER BY  country_code
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 205 rows affected.
# [('ABW',),
#  ('AFG',),
#  ('AGO',),
#  ('AIA',),
#  ('ALB',),
#  ('AND',),
#  ('ARE',),
#  ('ARG',),
#  ('ARM',),
#  ('ATG',),
#  ('AUS',),
#  ('AUT',),
#  ('AZE',),
#  ('BDI',),
#  ('BEL',),
#  ('BEN',),
#  ('BFA',),
#  ('BGD',),
#  ('BGR',),
#  ('BHR',),
#  ('BIH',),
#  ('BLR',),
#  ('BLZ',),
#  ('BMU',),
#  ('BOL',),
#  ('BRA',),
#  ('BRB',),
#  ('BRN',),
#  ('BTN',),
#  ('BWA',),
#  ('CAF',),
#  ('CAN',),
#  ('CCK',),
#  ('CHE',),
#  ('CHL',),
#  ('CHN',),
#  ('CIV',),
#  ('CMR',),
#  ('COD',),
#  ('COG',),
#  ('COK',),
#  ('COL',),
#  ('COM',),
#  ('CPV',),
#  ('CRI',),
#  ('CUB',),
#  ('CYM',),
#  ('CYP',),
#  ('CZE',),
#  ('DEU',),
#  ('DJI',),
#  ('DMA',),
#  ('DNK',),
#  ('DOM',),
#  ('DZA',),
#  ('ECU',),
#  ('EGY',),
#  ('ERI',),
#  ('ESP',),
#  ('EST',),
#  ('ETH',),
#  ('FIN',),
#  ('FLK',),
#  ('FRA',),
#  ('FRO',),
#  ('GAB',),
#  ('GBR',),
#  ('GEO',),
#  ('GHA',),
#  ('GIB',),
#  ('GIN',),
#  ('GNB',),
#  ('GNQ',),
#  ('GRC',),
#  ('GRD',),
#  ('GTM',),
#  ('GUY',),
#  ('HKG',),
#  ('HND',),
#  ('HRV',),
#  ('HTI',),
#  ('HUN',),
#  ('IDN',),
#  ('IND',),
#  ('IOT',),
#  ('IRL',),
#  ('IRN',),
#  ('IRQ',),
#  ('ISL',),
#  ('ISR',),
#  ('ITA',),
#  ('JAM',),
#  ('JOR',),
#  ('JPN',),
#  ('KAZ',),
#  ('KEN',),
#  ('KGZ',),
#  ('KHM',),
#  ('KIR',),
#  ('KNA',),
#  ('KOR',),
#  ('KWT',),
#  ('LAO',),
#  ('LBN',),
#  ('LBR',),
#  ('LBY',),
#  ('LCA',),
#  ('LIE',),
#  ('LKA',),
#  ('LSO',),
#  ('LTU',),
#  ('LUX',),
#  ('LVA',),
#  ('MAR',),
#  ('MCO',),
#  ('MDA',),
#  ('MDG',),
#  ('MDV',),
#  ('MEX',),
#  ('MHL',),
#  ('MLI',),
#  ('MLT',),
#  ('MMR',),
#  ('MNG',),
#  ('MOZ',),
#  ('MRT',),
#  ('MSR',),
#  ('MUS',),
#  ('MWI',),
#  ('MYS',),
#  ('NAM',),
#  ('NCL',),
#  ('NER',),
#  ('NGA',),
#  ('NIC',),
#  ('NIU',),
#  ('NLD',),
#  ('NOR',),
#  ('NPL',),
#  ('NRU',),
#  ('NZL',),
#  ('OMN',),
#  ('PAK',),
#  ('PAN',),
#  ('PER',),
#  ('PHL',),
#  ('PLW',),
#  ('PNG',),
#  ('POL',),
#  ('PRK',),
#  ('PRT',),
#  ('PRY',),
#  ('PSE',),
#  ('PYF',),
#  ('QAT',),
#  ('ROM',),
#  ('RUS',),
#  ('RWA',),
#  ('SAU',),
#  ('SDN',),
#  ('SEN',),
#  ('SGP',),
#  ('SGS',),
#  ('SHN',),
#  ('SLB',),
#  ('SLE',),
#  ('SLV',),
#  ('SMR',),
#  ('SOM',),
#  ('SUR',),
#  ('SVK',),
#  ('SVN',),
#  ('SWE',),
#  ('SWZ',),
#  ('SYC',),
#  ('SYR',),
#  ('TCA',),
#  ('TCD',),
#  ('TGO',),
#  ('THA',),
#  ('TJK',),
#  ('TKM',),
#  ('TMP',),
#  ('TON',),
#  ('TTO',),
#  ('TUN',),
#  ('TUR',),
#  ('TUV',),
#  ('TWN',),
#  ('TZA',),
#  ('UGA',),
#  ('UKR',),
#  ('URY',),
#  ('USA',),
#  ('UZB',),
#  ('VCT',),
#  ('VEN',),
#  ('VNM',),
#  ('VUT',),
#  ('WLF',),
#  ('WSM',),
#  ('YEM',),
#  ('ZAF',),
#  ('ZMB',),
#  ('ZWE',)]

# %% [markdown]
# # Union all
# As you saw, duplicates were removed from the previous two exercises by using `UNION`.
#
# To include duplicates, you can use `UNION ALL`.
#
# - Determine all combinations (include duplicates) of country code and year that exist in either the `economies` or the `populations` tables.
# - The result of the query should only have two columns/fields.
# - Think about how many records this query should result in.
# - You'll use code very similar to this in your next exercise after the video. Make note of this code after completing it.

# %%
# %%sql
# SELECT country_code AS code, year
# FROM populations
# UNION ALL
# SELECT code, year
# FROM economies
# ORDER BY code, year;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 814 rows affected.
# [('ABW', 2010),
#  ('ABW', 2015),
#  ('AFG', 2010),
#  ('AFG', 2010),
#  ('AFG', 2015),
#  ('AFG', 2015),
#  ('AGO', 2010),
#  ('AGO', 2010),
#  ('AGO', 2015),
#  ('AGO', 2015),
#  ('ALB', 2010),
#  ('ALB', 2010),
#  ('ALB', 2015),
#  ('ALB', 2015),
#  ('AND', 2010),
#  ('AND', 2015),
#  ('ARE', 2010),
#  ('ARE', 2010),
#  ('ARE', 2015),
#  ('ARE', 2015),
#  ('ARG', 2010),
#  ('ARG', 2010),
#  ('ARG', 2015),
#  ('ARG', 2015),
#  ('ARM', 2010),
#  ('ARM', 2010),
#  ('ARM', 2015),
#  ('ARM', 2015),
#  ('ASM', 2010),
#  ('ASM', 2015),
#  ('ATG', 2010),
#  ('ATG', 2010),
#  ('ATG', 2015),
#  ('ATG', 2015),
#  ('AUS', 2010),
#  ('AUS', 2010),
#  ('AUS', 2015),
#  ('AUS', 2015),
#  ('AUT', 2010),
#  ('AUT', 2010),
#  ('AUT', 2015),
#  ('AUT', 2015),
#  ('AZE', 2010),
#  ('AZE', 2010),
#  ('AZE', 2015),
#  ('AZE', 2015),
#  ('BDI', 2010),
#  ('BDI', 2010),
#  ('BDI', 2015),
#  ('BDI', 2015),
#  ('BEL', 2010),
#  ('BEL', 2010),
#  ('BEL', 2015),
#  ('BEL', 2015),
#  ('BEN', 2010),
#  ('BEN', 2010),
#  ('BEN', 2015),
#  ('BEN', 2015),
#  ('BFA', 2010),
#  ('BFA', 2010),
#  ('BFA', 2015),
#  ('BFA', 2015),
#  ('BGD', 2010),
#  ('BGD', 2010),
#  ('BGD', 2015),
#  ('BGD', 2015),
#  ('BGR', 2010),
#  ('BGR', 2010),
#  ('BGR', 2015),
#  ('BGR', 2015),
#  ('BHR', 2010),
#  ('BHR', 2010),
#  ('BHR', 2015),
#  ('BHR', 2015),
#  ('BHS', 2010),
#  ('BHS', 2010),
#  ('BHS', 2015),
#  ('BHS', 2015),
#  ('BIH', 2010),
#  ('BIH', 2010),
#  ('BIH', 2015),
#  ('BIH', 2015),
#  ('BLR', 2010),
#  ('BLR', 2010),
#  ('BLR', 2015),
#  ('BLR', 2015),
#  ('BLZ', 2010),
#  ('BLZ', 2010),
#  ('BLZ', 2015),
#  ('BLZ', 2015),
#  ('BMU', 2010),
#  ('BMU', 2015),
#  ('BOL', 2010),
#  ('BOL', 2010),
#  ('BOL', 2015),
#  ('BOL', 2015),
#  ('BRA', 2010),
#  ('BRA', 2010),
#  ('BRA', 2015),
#  ('BRA', 2015),
#  ('BRB', 2010),
#  ('BRB', 2010),
#  ('BRB', 2015),
#  ('BRB', 2015),
#  ('BRN', 2010),
#  ('BRN', 2010),
#  ('BRN', 2015),
#  ('BRN', 2015),
#  ('BTN', 2010),
#  ('BTN', 2010),
#  ('BTN', 2015),
#  ('BTN', 2015),
#  ('BWA', 2010),
#  ('BWA', 2010),
#  ('BWA', 2015),
#  ('BWA', 2015),
#  ('CAF', 2010),
#  ('CAF', 2010),
#  ('CAF', 2015),
#  ('CAF', 2015),
#  ('CAN', 2010),
#  ('CAN', 2010),
#  ('CAN', 2015),
#  ('CAN', 2015),
#  ('CHE', 2010),
#  ('CHE', 2010),
#  ('CHE', 2015),
#  ('CHE', 2015),
#  ('CHI', 2010),
#  ('CHI', 2015),
#  ('CHL', 2010),
#  ('CHL', 2010),
#  ('CHL', 2015),
#  ('CHL', 2015),
#  ('CHN', 2010),
#  ('CHN', 2010),
#  ('CHN', 2015),
#  ('CHN', 2015),
#  ('CIV', 2010),
#  ('CIV', 2010),
#  ('CIV', 2015),
#  ('CIV', 2015),
#  ('CMR', 2010),
#  ('CMR', 2010),
#  ('CMR', 2015),
#  ('CMR', 2015),
#  ('COD', 2010),
#  ('COD', 2010),
#  ('COD', 2015),
#  ('COD', 2015),
#  ('COG', 2010),
#  ('COG', 2010),
#  ('COG', 2015),
#  ('COG', 2015),
#  ('COL', 2010),
#  ('COL', 2010),
#  ('COL', 2015),
#  ('COL', 2015),
#  ('COM', 2010),
#  ('COM', 2010),
#  ('COM', 2015),
#  ('COM', 2015),
#  ('CPV', 2010),
#  ('CPV', 2010),
#  ('CPV', 2015),
#  ('CPV', 2015),
#  ('CRI', 2010),
#  ('CRI', 2010),
#  ('CRI', 2015),
#  ('CRI', 2015),
#  ('CUB', 2010),
#  ('CUB', 2015),
#  ('CUW', 2010),
#  ('CUW', 2015),
#  ('CYM', 2010),
#  ('CYM', 2015),
#  ('CYP', 2010),
#  ('CYP', 2010),
#  ('CYP', 2015),
#  ('CYP', 2015),
#  ('CZE', 2010),
#  ('CZE', 2010),
#  ('CZE', 2015),
#  ('CZE', 2015),
#  ('DEU', 2010),
#  ('DEU', 2010),
#  ('DEU', 2015),
#  ('DEU', 2015),
#  ('DJI', 2010),
#  ('DJI', 2010),
#  ('DJI', 2015),
#  ('DJI', 2015),
#  ('DMA', 2010),
#  ('DMA', 2010),
#  ('DMA', 2015),
#  ('DMA', 2015),
#  ('DNK', 2010),
#  ('DNK', 2010),
#  ('DNK', 2015),
#  ('DNK', 2015),
#  ('DOM', 2010),
#  ('DOM', 2010),
#  ('DOM', 2015),
#  ('DOM', 2015),
#  ('DZA', 2010),
#  ('DZA', 2010),
#  ('DZA', 2015),
#  ('DZA', 2015),
#  ('ECU', 2010),
#  ('ECU', 2010),
#  ('ECU', 2015),
#  ('ECU', 2015),
#  ('EGY', 2010),
#  ('EGY', 2010),
#  ('EGY', 2015),
#  ('EGY', 2015),
#  ('ERI', 2010),
#  ('ERI', 2010),
#  ('ERI', 2015),
#  ('ERI', 2015),
#  ('ESP', 2010),
#  ('ESP', 2010),
#  ('ESP', 2015),
#  ('ESP', 2015),
#  ('EST', 2010),
#  ('EST', 2010),
#  ('EST', 2015),
#  ('EST', 2015),
#  ('ETH', 2010),
#  ('ETH', 2010),
#  ('ETH', 2015),
#  ('ETH', 2015),
#  ('FIN', 2010),
#  ('FIN', 2010),
#  ('FIN', 2015),
#  ('FIN', 2015),
#  ('FJI', 2010),
#  ('FJI', 2010),
#  ('FJI', 2015),
#  ('FJI', 2015),
#  ('FRA', 2010),
#  ('FRA', 2010),
#  ('FRA', 2015),
#  ('FRA', 2015),
#  ('FRO', 2010),
#  ('FRO', 2015),
#  ('FSM', 2010),
#  ('FSM', 2010),
#  ('FSM', 2015),
#  ('FSM', 2015),
#  ('GAB', 2010),
#  ('GAB', 2010),
#  ('GAB', 2015),
#  ('GAB', 2015),
#  ('GBR', 2010),
#  ('GBR', 2010),
#  ('GBR', 2015),
#  ('GBR', 2015),
#  ('GEO', 2010),
#  ('GEO', 2010),
#  ('GEO', 2015),
#  ('GEO', 2015),
#  ('GHA', 2010),
#  ('GHA', 2010),
#  ('GHA', 2015),
#  ('GHA', 2015),
#  ('GIB', 2010),
#  ('GIB', 2015),
#  ('GIN', 2010),
#  ('GIN', 2010),
#  ('GIN', 2015),
#  ('GIN', 2015),
#  ('GMB', 2010),
#  ('GMB', 2010),
#  ('GMB', 2015),
#  ('GMB', 2015),
#  ('GNB', 2010),
#  ('GNB', 2010),
#  ('GNB', 2015),
#  ('GNB', 2015),
#  ('GNQ', 2010),
#  ('GNQ', 2010),
#  ('GNQ', 2015),
#  ('GNQ', 2015),
#  ('GRC', 2010),
#  ('GRC', 2010),
#  ('GRC', 2015),
#  ('GRC', 2015),
#  ('GRD', 2010),
#  ('GRD', 2010),
#  ('GRD', 2015),
#  ('GRD', 2015),
#  ('GRL', 2010),
#  ('GRL', 2015),
#  ('GTM', 2010),
#  ('GTM', 2010),
#  ('GTM', 2015),
#  ('GTM', 2015),
#  ('GUM', 2010),
#  ('GUM', 2015),
#  ('GUY', 2010),
#  ('GUY', 2010),
#  ('GUY', 2015),
#  ('GUY', 2015),
#  ('HKG', 2010),
#  ('HKG', 2010),
#  ('HKG', 2015),
#  ('HKG', 2015),
#  ('HND', 2010),
#  ('HND', 2010),
#  ('HND', 2015),
#  ('HND', 2015),
#  ('HRV', 2010),
#  ('HRV', 2010),
#  ('HRV', 2015),
#  ('HRV', 2015),
#  ('HTI', 2010),
#  ('HTI', 2010),
#  ('HTI', 2015),
#  ('HTI', 2015),
#  ('HUN', 2010),
#  ('HUN', 2010),
#  ('HUN', 2015),
#  ('HUN', 2015),
#  ('IDN', 2010),
#  ('IDN', 2010),
#  ('IDN', 2015),
#  ('IDN', 2015),
#  ('IMN', 2010),
#  ('IMN', 2015),
#  ('IND', 2010),
#  ('IND', 2010),
#  ('IND', 2015),
#  ('IND', 2015),
#  ('IRL', 2010),
#  ('IRL', 2010),
#  ('IRL', 2015),
#  ('IRL', 2015),
#  ('IRN', 2010),
#  ('IRN', 2010),
#  ('IRN', 2015),
#  ('IRN', 2015),
#  ('IRQ', 2010),
#  ('IRQ', 2010),
#  ('IRQ', 2015),
#  ('IRQ', 2015),
#  ('ISL', 2010),
#  ('ISL', 2010),
#  ('ISL', 2015),
#  ('ISL', 2015),
#  ('ISR', 2010),
#  ('ISR', 2010),
#  ('ISR', 2015),
#  ('ISR', 2015),
#  ('ITA', 2010),
#  ('ITA', 2010),
#  ('ITA', 2015),
#  ('ITA', 2015),
#  ('JAM', 2010),
#  ('JAM', 2010),
#  ('JAM', 2015),
#  ('JAM', 2015),
#  ('JOR', 2010),
#  ('JOR', 2010),
#  ('JOR', 2015),
#  ('JOR', 2015),
#  ('JPN', 2010),
#  ('JPN', 2010),
#  ('JPN', 2015),
#  ('JPN', 2015),
#  ('KAZ', 2010),
#  ('KAZ', 2010),
#  ('KAZ', 2015),
#  ('KAZ', 2015),
#  ('KEN', 2010),
#  ('KEN', 2010),
#  ('KEN', 2015),
#  ('KEN', 2015),
#  ('KGZ', 2010),
#  ('KGZ', 2010),
#  ('KGZ', 2015),
#  ('KGZ', 2015),
#  ('KHM', 2010),
#  ('KHM', 2010),
#  ('KHM', 2015),
#  ('KHM', 2015),
#  ('KIR', 2010),
#  ('KIR', 2010),
#  ('KIR', 2015),
#  ('KIR', 2015),
#  ('KNA', 2010),
#  ('KNA', 2010),
#  ('KNA', 2015),
#  ('KNA', 2015),
#  ('KOR', 2010),
#  ('KOR', 2010),
#  ('KOR', 2015),
#  ('KOR', 2015),
#  ('KWT', 2010),
#  ('KWT', 2010),
#  ('KWT', 2015),
#  ('KWT', 2015),
#  ('LAO', 2010),
#  ('LAO', 2010),
#  ('LAO', 2015),
#  ('LAO', 2015),
#  ('LBN', 2010),
#  ('LBN', 2010),
#  ('LBN', 2015),
#  ('LBN', 2015),
#  ('LBR', 2010),
#  ('LBR', 2010),
#  ('LBR', 2015),
#  ('LBR', 2015),
#  ('LBY', 2010),
#  ('LBY', 2010),
#  ('LBY', 2015),
#  ('LBY', 2015),
#  ('LCA', 2010),
#  ('LCA', 2010),
#  ('LCA', 2015),
#  ('LCA', 2015),
#  ('LIE', 2010),
#  ('LIE', 2015),
#  ('LKA', 2010),
#  ('LKA', 2010),
#  ('LKA', 2015),
#  ('LKA', 2015),
#  ('LSO', 2010),
#  ('LSO', 2010),
#  ('LSO', 2015),
#  ('LSO', 2015),
#  ('LTU', 2010),
#  ('LTU', 2010),
#  ('LTU', 2015),
#  ('LTU', 2015),
#  ('LUX', 2010),
#  ('LUX', 2010),
#  ('LUX', 2015),
#  ('LUX', 2015),
#  ('LVA', 2010),
#  ('LVA', 2010),
#  ('LVA', 2015),
#  ('LVA', 2015),
#  ('MAC', 2010),
#  ('MAC', 2010),
#  ('MAC', 2015),
#  ('MAC', 2015),
#  ('MAF', 2010),
#  ('MAF', 2015),
#  ('MAR', 2010),
#  ('MAR', 2010),
#  ('MAR', 2015),
#  ('MAR', 2015),
#  ('MCO', 2010),
#  ('MCO', 2015),
#  ('MDA', 2010),
#  ('MDA', 2010),
#  ('MDA', 2015),
#  ('MDA', 2015),
#  ('MDG', 2010),
#  ('MDG', 2010),
#  ('MDG', 2015),
#  ('MDG', 2015),
#  ('MDV', 2010),
#  ('MDV', 2010),
#  ('MDV', 2015),
#  ('MDV', 2015),
#  ('MEX', 2010),
#  ('MEX', 2010),
#  ('MEX', 2015),
#  ('MEX', 2015),
#  ('MHL', 2010),
#  ('MHL', 2010),
#  ('MHL', 2015),
#  ('MHL', 2015),
#  ('MKD', 2010),
#  ('MKD', 2010),
#  ('MKD', 2015),
#  ('MKD', 2015),
#  ('MLI', 2010),
#  ('MLI', 2010),
#  ('MLI', 2015),
#  ('MLI', 2015),
#  ('MLT', 2010),
#  ('MLT', 2010),
#  ('MLT', 2015),
#  ('MLT', 2015),
#  ('MMR', 2010),
#  ('MMR', 2010),
#  ('MMR', 2015),
#  ('MMR', 2015),
#  ('MNE', 2010),
#  ('MNE', 2010),
#  ('MNE', 2015),
#  ('MNE', 2015),
#  ('MNG', 2010),
#  ('MNG', 2010),
#  ('MNG', 2015),
#  ('MNG', 2015),
#  ('MNP', 2010),
#  ('MNP', 2015),
#  ('MOZ', 2010),
#  ('MOZ', 2010),
#  ('MOZ', 2015),
#  ('MOZ', 2015),
#  ('MRT', 2010),
#  ('MRT', 2010),
#  ('MRT', 2015),
#  ('MRT', 2015),
#  ('MUS', 2010),
#  ('MUS', 2010),
#  ('MUS', 2015),
#  ('MUS', 2015),
#  ('MWI', 2010),
#  ('MWI', 2010),
#  ('MWI', 2015),
#  ('MWI', 2015),
#  ('MYS', 2010),
#  ('MYS', 2010),
#  ('MYS', 2015),
#  ('MYS', 2015),
#  ('NAM', 2010),
#  ('NAM', 2010),
#  ('NAM', 2015),
#  ('NAM', 2015),
#  ('NCL', 2010),
#  ('NCL', 2015),
#  ('NER', 2010),
#  ('NER', 2010),
#  ('NER', 2015),
#  ('NER', 2015),
#  ('NGA', 2010),
#  ('NGA', 2010),
#  ('NGA', 2015),
#  ('NGA', 2015),
#  ('NIC', 2010),
#  ('NIC', 2010),
#  ('NIC', 2015),
#  ('NIC', 2015),
#  ('NLD', 2010),
#  ('NLD', 2010),
#  ('NLD', 2015),
#  ('NLD', 2015),
#  ('NOR', 2010),
#  ('NOR', 2010),
#  ('NOR', 2015),
#  ('NOR', 2015),
#  ('NPL', 2010),
#  ('NPL', 2010),
#  ('NPL', 2015),
#  ('NPL', 2015),
#  ('NRU', 2010),
#  ('NRU', 2010),
#  ('NRU', 2015),
#  ('NRU', 2015),
#  ('NZL', 2010),
#  ('NZL', 2010),
#  ('NZL', 2015),
#  ('NZL', 2015),
#  ('OMN', 2010),
#  ('OMN', 2010),
#  ('OMN', 2015),
#  ('OMN', 2015),
#  ('PAK', 2010),
#  ('PAK', 2010),
#  ('PAK', 2015),
#  ('PAK', 2015),
#  ('PAN', 2010),
#  ('PAN', 2010),
#  ('PAN', 2015),
#  ('PAN', 2015),
#  ('PER', 2010),
#  ('PER', 2010),
#  ('PER', 2015),
#  ('PER', 2015),
#  ('PHL', 2010),
#  ('PHL', 2010),
#  ('PHL', 2015),
#  ('PHL', 2015),
#  ('PLW', 2010),
#  ('PLW', 2010),
#  ('PLW', 2015),
#  ('PLW', 2015),
#  ('PNG', 2010),
#  ('PNG', 2010),
#  ('PNG', 2015),
#  ('PNG', 2015),
#  ('POL', 2010),
#  ('POL', 2010),
#  ('POL', 2015),
#  ('POL', 2015),
#  ('PRI', 2010),
#  ('PRI', 2010),
#  ('PRI', 2015),
#  ('PRI', 2015),
#  ('PRK', 2010),
#  ('PRK', 2015),
#  ('PRT', 2010),
#  ('PRT', 2010),
#  ('PRT', 2015),
#  ('PRT', 2015),
#  ('PRY', 2010),
#  ('PRY', 2010),
#  ('PRY', 2015),
#  ('PRY', 2015),
#  ('PSE', 2010),
#  ('PSE', 2015),
#  ('PYF', 2010),
#  ('PYF', 2015),
#  ('QAT', 2010),
#  ('QAT', 2010),
#  ('QAT', 2015),
#  ('QAT', 2015),
#  ('ROU', 2010),
#  ('ROU', 2010),
#  ('ROU', 2015),
#  ('ROU', 2015),
#  ('RUS', 2010),
#  ('RUS', 2010),
#  ('RUS', 2015),
#  ('RUS', 2015),
#  ('RWA', 2010),
#  ('RWA', 2010),
#  ('RWA', 2015),
#  ('RWA', 2015),
#  ('SAU', 2010),
#  ('SAU', 2010),
#  ('SAU', 2015),
#  ('SAU', 2015),
#  ('SDN', 2010),
#  ('SDN', 2010),
#  ('SDN', 2015),
#  ('SDN', 2015),
#  ('SEN', 2010),
#  ('SEN', 2010),
#  ('SEN', 2015),
#  ('SEN', 2015),
#  ('SGP', 2010),
#  ('SGP', 2010),
#  ('SGP', 2015),
#  ('SGP', 2015),
#  ('SLB', 2010),
#  ('SLB', 2010),
#  ('SLB', 2015),
#  ('SLB', 2015),
#  ('SLE', 2010),
#  ('SLE', 2010),
#  ('SLE', 2015),
#  ('SLE', 2015),
#  ('SLV', 2010),
#  ('SLV', 2010),
#  ('SLV', 2015),
#  ('SLV', 2015),
#  ('SMR', 2010),
#  ('SMR', 2010),
#  ('SMR', 2015),
#  ('SMR', 2015),
#  ('SOM', 2010),
#  ('SOM', 2015),
#  ('SRB', 2010),
#  ('SRB', 2010),
#  ('SRB', 2015),
#  ('SRB', 2015),
#  ('SSD', 2010),
#  ('SSD', 2010),
#  ('SSD', 2015),
#  ('SSD', 2015),
#  ('STP', 2010),
#  ('STP', 2010),
#  ('STP', 2015),
#  ('STP', 2015),
#  ('SUR', 2010),
#  ('SUR', 2010),
#  ('SUR', 2015),
#  ('SUR', 2015),
#  ('SVK', 2010),
#  ('SVK', 2010),
#  ('SVK', 2015),
#  ('SVK', 2015),
#  ('SVN', 2010),
#  ('SVN', 2010),
#  ('SVN', 2015),
#  ('SVN', 2015),
#  ('SWE', 2010),
#  ('SWE', 2010),
#  ('SWE', 2015),
#  ('SWE', 2015),
#  ('SWZ', 2010),
#  ('SWZ', 2010),
#  ('SWZ', 2015),
#  ('SWZ', 2015),
#  ('SXM', 2010),
#  ('SXM', 2015),
#  ('SYC', 2010),
#  ('SYC', 2010),
#  ('SYC', 2015),
#  ('SYC', 2015),
#  ('SYR', 2010),
#  ('SYR', 2010),
#  ('SYR', 2015),
#  ('SYR', 2015),
#  ('TCA', 2010),
#  ('TCA', 2015),
#  ('TCD', 2010),
#  ('TCD', 2010),
#  ('TCD', 2015),
#  ('TCD', 2015),
#  ('TGO', 2010),
#  ('TGO', 2010),
#  ('TGO', 2015),
#  ('TGO', 2015),
#  ('THA', 2010),
#  ('THA', 2010),
#  ('THA', 2015),
#  ('THA', 2015),
#  ('TJK', 2010),
#  ('TJK', 2010),
#  ('TJK', 2015),
#  ('TJK', 2015),
#  ('TKM', 2010),
#  ('TKM', 2010),
#  ('TKM', 2015),
#  ('TKM', 2015),
#  ('TLS', 2010),
#  ('TLS', 2010),
#  ('TLS', 2015),
#  ('TLS', 2015),
#  ('TON', 2010),
#  ('TON', 2010),
#  ('TON', 2015),
#  ('TON', 2015),
#  ('TTO', 2010),
#  ('TTO', 2010),
#  ('TTO', 2015),
#  ('TTO', 2015),
#  ('TUN', 2010),
#  ('TUN', 2010),
#  ('TUN', 2015),
#  ('TUN', 2015),
#  ('TUR', 2010),
#  ('TUR', 2010),
#  ('TUR', 2015),
#  ('TUR', 2015),
#  ('TUV', 2010),
#  ('TUV', 2010),
#  ('TUV', 2015),
#  ('TUV', 2015),
#  ('TZA', 2010),
#  ('TZA', 2010),
#  ('TZA', 2015),
#  ('TZA', 2015),
#  ('UGA', 2010),
#  ('UGA', 2010),
#  ('UGA', 2015),
#  ('UGA', 2015),
#  ('UKR', 2010),
#  ('UKR', 2010),
#  ('UKR', 2015),
#  ('UKR', 2015),
#  ('URY', 2010),
#  ('URY', 2010),
#  ('URY', 2015),
#  ('URY', 2015),
#  ('USA', 2010),
#  ('USA', 2010),
#  ('USA', 2015),
#  ('USA', 2015),
#  ('UZB', 2010),
#  ('UZB', 2010),
#  ('UZB', 2015),
#  ('UZB', 2015),
#  ('VCT', 2010),
#  ('VCT', 2010),
#  ('VCT', 2015),
#  ('VCT', 2015),
#  ('VEN', 2010),
#  ('VEN', 2010),
#  ('VEN', 2015),
#  ('VEN', 2015),
#  ('VGB', 2010),
#  ('VGB', 2015),
#  ('VIR', 2010),
#  ('VIR', 2015),
#  ('VNM', 2010),
#  ('VNM', 2010),
#  ('VNM', 2015),
#  ('VNM', 2015),
#  ('VUT', 2010),
#  ('VUT', 2010),
#  ('VUT', 2015),
#  ('VUT', 2015),
#  ('WSM', 2010),
#  ('WSM', 2010),
#  ('WSM', 2015),
#  ('WSM', 2015),
#  ('XKX', 2010),
#  ('XKX', 2015),
#  ('YEM', 2010),
#  ('YEM', 2010),
#  ('YEM', 2015),
#  ('YEM', 2015),
#  ('ZAF', 2010),
#  ('ZAF', 2010),
#  ('ZAF', 2015),
#  ('ZAF', 2015),
#  ('ZMB', 2010),
#  ('ZMB', 2010),
#  ('ZMB', 2015),
#  ('ZMB', 2015),
#  ('ZWE', 2010),
#  ('ZWE', 2010),
#  ('ZWE', 2015),
#  ('ZWE', 2015)]

# %% [markdown]
# # Intersect
# Repeat the previous `UNION ALL` exercise, this time looking at the records in common for country code and year for the `economies` and `populations` tables.
# - Again, order by code and then by year, both in ascending order.
# - Note the number of records here (given at the bottom of query result) compared to the similar `UNION ALL` query result (814 records).

# %%
# %%sql
# SELECT country_code AS code, year
# FROM populations
# INTERSECT
# SELECT code, year
# FROM economies
# ORDER BY code, year;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 380 rows affected.
# [('AFG', 2010),
#  ('AFG', 2015),
#  ('AGO', 2010),
#  ('AGO', 2015),
#  ('ALB', 2010),
#  ('ALB', 2015),
#  ('ARE', 2010),
#  ('ARE', 2015),
#  ('ARG', 2010),
#  ('ARG', 2015),
#  ('ARM', 2010),
#  ('ARM', 2015),
#  ('ATG', 2010),
#  ('ATG', 2015),
#  ('AUS', 2010),
#  ('AUS', 2015),
#  ('AUT', 2010),
#  ('AUT', 2015),
#  ('AZE', 2010),
#  ('AZE', 2015),
#  ('BDI', 2010),
#  ('BDI', 2015),
#  ('BEL', 2010),
#  ('BEL', 2015),
#  ('BEN', 2010),
#  ('BEN', 2015),
#  ('BFA', 2010),
#  ('BFA', 2015),
#  ('BGD', 2010),
#  ('BGD', 2015),
#  ('BGR', 2010),
#  ('BGR', 2015),
#  ('BHR', 2010),
#  ('BHR', 2015),
#  ('BHS', 2010),
#  ('BHS', 2015),
#  ('BIH', 2010),
#  ('BIH', 2015),
#  ('BLR', 2010),
#  ('BLR', 2015),
#  ('BLZ', 2010),
#  ('BLZ', 2015),
#  ('BOL', 2010),
#  ('BOL', 2015),
#  ('BRA', 2010),
#  ('BRA', 2015),
#  ('BRB', 2010),
#  ('BRB', 2015),
#  ('BRN', 2010),
#  ('BRN', 2015),
#  ('BTN', 2010),
#  ('BTN', 2015),
#  ('BWA', 2010),
#  ('BWA', 2015),
#  ('CAF', 2010),
#  ('CAF', 2015),
#  ('CAN', 2010),
#  ('CAN', 2015),
#  ('CHE', 2010),
#  ('CHE', 2015),
#  ('CHL', 2010),
#  ('CHL', 2015),
#  ('CHN', 2010),
#  ('CHN', 2015),
#  ('CIV', 2010),
#  ('CIV', 2015),
#  ('CMR', 2010),
#  ('CMR', 2015),
#  ('COD', 2010),
#  ('COD', 2015),
#  ('COG', 2010),
#  ('COG', 2015),
#  ('COL', 2010),
#  ('COL', 2015),
#  ('COM', 2010),
#  ('COM', 2015),
#  ('CPV', 2010),
#  ('CPV', 2015),
#  ('CRI', 2010),
#  ('CRI', 2015),
#  ('CYP', 2010),
#  ('CYP', 2015),
#  ('CZE', 2010),
#  ('CZE', 2015),
#  ('DEU', 2010),
#  ('DEU', 2015),
#  ('DJI', 2010),
#  ('DJI', 2015),
#  ('DMA', 2010),
#  ('DMA', 2015),
#  ('DNK', 2010),
#  ('DNK', 2015),
#  ('DOM', 2010),
#  ('DOM', 2015),
#  ('DZA', 2010),
#  ('DZA', 2015),
#  ('ECU', 2010),
#  ('ECU', 2015),
#  ('EGY', 2010),
#  ('EGY', 2015),
#  ('ERI', 2010),
#  ('ERI', 2015),
#  ('ESP', 2010),
#  ('ESP', 2015),
#  ('EST', 2010),
#  ('EST', 2015),
#  ('ETH', 2010),
#  ('ETH', 2015),
#  ('FIN', 2010),
#  ('FIN', 2015),
#  ('FJI', 2010),
#  ('FJI', 2015),
#  ('FRA', 2010),
#  ('FRA', 2015),
#  ('FSM', 2010),
#  ('FSM', 2015),
#  ('GAB', 2010),
#  ('GAB', 2015),
#  ('GBR', 2010),
#  ('GBR', 2015),
#  ('GEO', 2010),
#  ('GEO', 2015),
#  ('GHA', 2010),
#  ('GHA', 2015),
#  ('GIN', 2010),
#  ('GIN', 2015),
#  ('GMB', 2010),
#  ('GMB', 2015),
#  ('GNB', 2010),
#  ('GNB', 2015),
#  ('GNQ', 2010),
#  ('GNQ', 2015),
#  ('GRC', 2010),
#  ('GRC', 2015),
#  ('GRD', 2010),
#  ('GRD', 2015),
#  ('GTM', 2010),
#  ('GTM', 2015),
#  ('GUY', 2010),
#  ('GUY', 2015),
#  ('HKG', 2010),
#  ('HKG', 2015),
#  ('HND', 2010),
#  ('HND', 2015),
#  ('HRV', 2010),
#  ('HRV', 2015),
#  ('HTI', 2010),
#  ('HTI', 2015),
#  ('HUN', 2010),
#  ('HUN', 2015),
#  ('IDN', 2010),
#  ('IDN', 2015),
#  ('IND', 2010),
#  ('IND', 2015),
#  ('IRL', 2010),
#  ('IRL', 2015),
#  ('IRN', 2010),
#  ('IRN', 2015),
#  ('IRQ', 2010),
#  ('IRQ', 2015),
#  ('ISL', 2010),
#  ('ISL', 2015),
#  ('ISR', 2010),
#  ('ISR', 2015),
#  ('ITA', 2010),
#  ('ITA', 2015),
#  ('JAM', 2010),
#  ('JAM', 2015),
#  ('JOR', 2010),
#  ('JOR', 2015),
#  ('JPN', 2010),
#  ('JPN', 2015),
#  ('KAZ', 2010),
#  ('KAZ', 2015),
#  ('KEN', 2010),
#  ('KEN', 2015),
#  ('KGZ', 2010),
#  ('KGZ', 2015),
#  ('KHM', 2010),
#  ('KHM', 2015),
#  ('KIR', 2010),
#  ('KIR', 2015),
#  ('KNA', 2010),
#  ('KNA', 2015),
#  ('KOR', 2010),
#  ('KOR', 2015),
#  ('KWT', 2010),
#  ('KWT', 2015),
#  ('LAO', 2010),
#  ('LAO', 2015),
#  ('LBN', 2010),
#  ('LBN', 2015),
#  ('LBR', 2010),
#  ('LBR', 2015),
#  ('LBY', 2010),
#  ('LBY', 2015),
#  ('LCA', 2010),
#  ('LCA', 2015),
#  ('LKA', 2010),
#  ('LKA', 2015),
#  ('LSO', 2010),
#  ('LSO', 2015),
#  ('LTU', 2010),
#  ('LTU', 2015),
#  ('LUX', 2010),
#  ('LUX', 2015),
#  ('LVA', 2010),
#  ('LVA', 2015),
#  ('MAC', 2010),
#  ('MAC', 2015),
#  ('MAR', 2010),
#  ('MAR', 2015),
#  ('MDA', 2010),
#  ('MDA', 2015),
#  ('MDG', 2010),
#  ('MDG', 2015),
#  ('MDV', 2010),
#  ('MDV', 2015),
#  ('MEX', 2010),
#  ('MEX', 2015),
#  ('MHL', 2010),
#  ('MHL', 2015),
#  ('MKD', 2010),
#  ('MKD', 2015),
#  ('MLI', 2010),
#  ('MLI', 2015),
#  ('MLT', 2010),
#  ('MLT', 2015),
#  ('MMR', 2010),
#  ('MMR', 2015),
#  ('MNE', 2010),
#  ('MNE', 2015),
#  ('MNG', 2010),
#  ('MNG', 2015),
#  ('MOZ', 2010),
#  ('MOZ', 2015),
#  ('MRT', 2010),
#  ('MRT', 2015),
#  ('MUS', 2010),
#  ('MUS', 2015),
#  ('MWI', 2010),
#  ('MWI', 2015),
#  ('MYS', 2010),
#  ('MYS', 2015),
#  ('NAM', 2010),
#  ('NAM', 2015),
#  ('NER', 2010),
#  ('NER', 2015),
#  ('NGA', 2010),
#  ('NGA', 2015),
#  ('NIC', 2010),
#  ('NIC', 2015),
#  ('NLD', 2010),
#  ('NLD', 2015),
#  ('NOR', 2010),
#  ('NOR', 2015),
#  ('NPL', 2010),
#  ('NPL', 2015),
#  ('NRU', 2010),
#  ('NRU', 2015),
#  ('NZL', 2010),
#  ('NZL', 2015),
#  ('OMN', 2010),
#  ('OMN', 2015),
#  ('PAK', 2010),
#  ('PAK', 2015),
#  ('PAN', 2010),
#  ('PAN', 2015),
#  ('PER', 2010),
#  ('PER', 2015),
#  ('PHL', 2010),
#  ('PHL', 2015),
#  ('PLW', 2010),
#  ('PLW', 2015),
#  ('PNG', 2010),
#  ('PNG', 2015),
#  ('POL', 2010),
#  ('POL', 2015),
#  ('PRI', 2010),
#  ('PRI', 2015),
#  ('PRT', 2010),
#  ('PRT', 2015),
#  ('PRY', 2010),
#  ('PRY', 2015),
#  ('QAT', 2010),
#  ('QAT', 2015),
#  ('ROU', 2010),
#  ('ROU', 2015),
#  ('RUS', 2010),
#  ('RUS', 2015),
#  ('RWA', 2010),
#  ('RWA', 2015),
#  ('SAU', 2010),
#  ('SAU', 2015),
#  ('SDN', 2010),
#  ('SDN', 2015),
#  ('SEN', 2010),
#  ('SEN', 2015),
#  ('SGP', 2010),
#  ('SGP', 2015),
#  ('SLB', 2010),
#  ('SLB', 2015),
#  ('SLE', 2010),
#  ('SLE', 2015),
#  ('SLV', 2010),
#  ('SLV', 2015),
#  ('SMR', 2010),
#  ('SMR', 2015),
#  ('SRB', 2010),
#  ('SRB', 2015),
#  ('SSD', 2010),
#  ('SSD', 2015),
#  ('STP', 2010),
#  ('STP', 2015),
#  ('SUR', 2010),
#  ('SUR', 2015),
#  ('SVK', 2010),
#  ('SVK', 2015),
#  ('SVN', 2010),
#  ('SVN', 2015),
#  ('SWE', 2010),
#  ('SWE', 2015),
#  ('SWZ', 2010),
#  ('SWZ', 2015),
#  ('SYC', 2010),
#  ('SYC', 2015),
#  ('SYR', 2010),
#  ('SYR', 2015),
#  ('TCD', 2010),
#  ('TCD', 2015),
#  ('TGO', 2010),
#  ('TGO', 2015),
#  ('THA', 2010),
#  ('THA', 2015),
#  ('TJK', 2010),
#  ('TJK', 2015),
#  ('TKM', 2010),
#  ('TKM', 2015),
#  ('TLS', 2010),
#  ('TLS', 2015),
#  ('TON', 2010),
#  ('TON', 2015),
#  ('TTO', 2010),
#  ('TTO', 2015),
#  ('TUN', 2010),
#  ('TUN', 2015),
#  ('TUR', 2010),
#  ('TUR', 2015),
#  ('TUV', 2010),
#  ('TUV', 2015),
#  ('TZA', 2010),
#  ('TZA', 2015),
#  ('UGA', 2010),
#  ('UGA', 2015),
#  ('UKR', 2010),
#  ('UKR', 2015),
#  ('URY', 2010),
#  ('URY', 2015),
#  ('USA', 2010),
#  ('USA', 2015),
#  ('UZB', 2010),
#  ('UZB', 2015),
#  ('VCT', 2010),
#  ('VCT', 2015),
#  ('VEN', 2010),
#  ('VEN', 2015),
#  ('VNM', 2010),
#  ('VNM', 2015),
#  ('VUT', 2010),
#  ('VUT', 2015),
#  ('WSM', 2010),
#  ('WSM', 2015),
#  ('YEM', 2010),
#  ('YEM', 2015),
#  ('ZAF', 2010),
#  ('ZAF', 2015),
#  ('ZMB', 2010),
#  ('ZMB', 2015),
#  ('ZWE', 2010),
#  ('ZWE', 2015)]

# %% [markdown]
# # Intersect (2)
# As you think about major world cities and their corresponding country, you may ask which countries also have a city with the same name as their country name?
# - Use `INTERSECT` to answer this question with `countries` and `cities`!

# %%
# %%sql
# SELECT name
# FROM countries
# INTERSECT
# SELECT name
# FROM cities;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 2 rows affected.
# [('Singapore',), ('Hong Kong',)]

# %% [markdown]
# # Except
# Get the names of cities in `cities` which are not noted as capital cities in `countries` as a single field result.
#
# Note that there are some countries in the world that are not included in the `countries` table, which will result in some cities not being labeled as capital cities when in fact they are.

# %%
# %%sql
# SELECT name
# FROM cities
# EXCEPT
# SELECT capital
# FROM countries
# ORDER BY name;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 170 rows affected.
# [('Abidjan',),
#  ('Ahmedabad',),
#  ('Alexandria',),
#  ('Almaty',),
#  ('Auckland',),
#  ('Bandung',),
#  ('Barcelona',),
#  ('Barranquilla',),
#  ('Basra',),
#  ('Belo Horizonte',),
#  ('Bengaluru',),
#  ('Bhopal',),
#  ('Birmingham',),
#  ('Brisbane',),
#  ('Bucharest',),
#  ('Busan',),
#  ('Calgary',),
#  ('Cali',),
#  ('Caloocan',),
#  ('Campinas',),
#  ('Cape Town',),
#  ('Casablanca',),
#  ('Changchun',),
#  ('Changsha',),
#  ('Chaozhou',),
#  ('Chengdu',),
#  ('Chennai',),
#  ('Chicago',),
#  ('Chittagong',),
#  ('Chongqing',),
#  ('Cologne',),
#  ('Cordoba',),
#  ('Curitiba',),
#  ('Daegu',),
#  ('Daejeon',),
#  ('Dalian',),
#  ('Dallas',),
#  ('Dar es Salaam',),
#  ('Davao City',),
#  ('Delhi',),
#  ('Dongguan',),
#  ('Douala',),
#  ('Dubai',),
#  ('Durban',),
#  ('Ekurhuleni',),
#  ('Faisalabad',),
#  ('Fez',),
#  ('Fortaleza',),
#  ('Foshan',),
#  ('Fukuoka',),
#  ('Fuzhou',),
#  ('Giza',),
#  ('Guadalajara',),
#  ('Guangzhou',),
#  ('Guayaquil',),
#  ('Gujranwala',),
#  ('Hamburg',),
#  ('Hangzhou',),
#  ('Harbin',),
#  ('Hefei',),
#  ('Hiroshima',),
#  ('Ho Chi Minh City',),
#  ('Hong Kong',),
#  ('Houston',),
#  ('Hyderabad',),
#  ('Hyderabad (India)',),
#  ('Ibadan',),
#  ('Incheon',),
#  ('Isfahan',),
#  ('Istanbul',),
#  ('Izmir',),
#  ('Jaipur',),
#  ('Jeddah',),
#  ('Jinan',),
#  ('Johannesburg',),
#  ('Kano',),
#  ('Kanpur',),
#  ('Kaohsiung',),
#  ('Karachi',),
#  ('Karaj',),
#  ('Kawasaki',),
#  ('Kharkov',),
#  ('Kobe',),
#  ('Kochi',),
#  ('Kolkata',),
#  ('Kwangju',),
#  ('Kyoto',),
#  ('Lagos',),
#  ('Lahore',),
#  ('Lanzhou',),
#  ('Los Angeles',),
#  ('Lucknow',),
#  ('Makassar',),
#  ('Mandalay',),
#  ('Maracaibo',),
#  ('Mashhad',),
#  ('Medan',),
#  ('Medellin',),
#  ('Milan',),
#  ('Monterrey',),
#  ('Montreal',),
#  ('Multan',),
#  ('Mumbai',),
#  ('Munich',),
#  ('Nagoya',),
#  ('Nagpur',),
#  ('Nanjing',),
#  ('New Taipei City',),
#  ('New York City',),
#  ('Ningbo',),
#  ('Nizhny Novgorod',),
#  ('Novosibirsk',),
#  ('Omsk',),
#  ('Oran',),
#  ('Osaka',),
#  ('Palembang',),
#  ('Patna',),
#  ('Peshawar',),
#  ('Philadelphia',),
#  ('Phoenix',),
#  ('Porto Alegre',),
#  ('Pune',),
#  ('Qingdao',),
#  ('Quanzhou',),
#  ('Quezon City',),
#  ('Rawalpindi',),
#  ('Recife',),
#  ('Rio de Janeiro',),
#  ('Rosario',),
#  ('Rostov-on-Don',),
#  ('Saint Petersburg',),
#  ('Saitama',),
#  ('Salvador',),
#  ('San Antonio',),
#  ('San Diego',),
#  ('Santa Cruz de la Sierra',),
#  ('Sao Paulo',),
#  ('Sapporo',),
#  ('Semarang',),
#  ('Shanghai',),
#  ('Shantou',),
#  ('Shenyang',),
#  ('Shenzhen',),
#  ('Shijiazhuang',),
#  ('Shiraz',),
#  ('Surabaya',),
#  ('Surat',),
#  ('Suzhou',),
#  ('Tabriz',),
#  ('Taichung',),
#  ('Tainan',),
#  ('Taipei',),
#  ('Tangshan',),
#  ("T'bilisi",),
#  ('Tianjin',),
#  ('Tijuana',),
#  ('Toronto',),
#  ('Ulsan',),
#  ('Vijayawada',),
#  ('Visakhapatnam',),
#  ('Wenzhou',),
#  ('Wuhan',),
#  ('Xiamen',),
#  ("Xi'an",),
#  ('Yangon',),
#  ('Yekaterinburg',),
#  ('Yokohama',),
#  ('Zhengzhou',),
#  ('Zhongshan',),
#  ('Zunyi',)]

# %%
# %%sql
# SELECT monarch, country
# FROM monarchs
# EXCEPT
# SELECT prime_minister, country
# FROM prime_ministers;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 2 rows affected.
# [('Harald V', 'Norway'), ('Felipe VI', 'Spain')]

# %% [markdown]
# # Except (2)
# Now you will complete the previous query in reverse!
#
# Determine the names of capital cities that are not listed in the cities table

# %%
# %%sql
# SELECT capital
# FROM countries
# EXCEPT
# SELECT name
# FROM cities
# ORDER BY capital;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 136 rows affected.
# [('Agana',),
#  ('Amman',),
#  ('Amsterdam',),
#  ('Andorra la Vella',),
#  ('Antananarivo',),
#  ('Apia',),
#  ('Ashgabat',),
#  ('Asmara',),
#  ('Astana',),
#  ('Asuncion',),
#  ('Athens',),
#  ('Bamako',),
#  ('Bandar Seri Begawan',),
#  ('Bangui',),
#  ('Banjul',),
#  ('Basseterre',),
#  ('Beirut',),
#  ('Belmopan',),
#  ('Bern',),
#  ('Bishkek',),
#  ('Bissau',),
#  ('Bratislava',),
#  ('Bridgetown',),
#  ('Brussels',),
#  ('Bujumbura',),
#  ('Canberra',),
#  ('Castries',),
#  ('Charlotte Amalie',),
#  ('Chisinau',),
#  ('Colombo',),
#  ('Conakry',),
#  ('Copenhagen',),
#  ('Damascus',),
#  ('Djibouti',),
#  ('Dodoma',),
#  ('Doha',),
#  ('Dublin',),
#  ('Dushanbe',),
#  ('Freetown',),
#  ('Funafuti',),
#  ('Gaborone',),
#  ('Georgetown',),
#  ('George Town',),
#  ('Grand Turk',),
#  ('Hamilton',),
#  ('Helsinki',),
#  ('Honiara',),
#  ('Kathmandu',),
#  ('Kigali',),
#  ('Kingston',),
#  ('Kingstown',),
#  ('Koror',),
#  ('Kuwait City',),
#  ('La Paz',),
#  ('Libreville',),
#  ('Lilongwe',),
#  ('Lisbon',),
#  ('Ljubljana',),
#  ('Lome',),
#  ('Luxembourg',),
#  ('Majuro',),
#  ('Malabo',),
#  ('Male',),
#  ('Manama',),
#  ('Maseru',),
#  ('Mbabane',),
#  ('Mogadishu',),
#  ('Monaco',),
#  ('Monrovia',),
#  ('Moroni',),
#  ('Muscat',),
#  ('Nassau',),
#  ('Naypyidaw',),
#  ("N'Djamena",),
#  ('New Delhi',),
#  ('Niamey',),
#  ('Nicosia',),
#  ('Nouakchott',),
#  ("Noum'ea",),
#  ("Nuku'alofa",),
#  ('Nuuk',),
#  ('Oranjestad',),
#  ('Oslo',),
#  ('Ottawa',),
#  ('Pago Pago',),
#  ('Palikir',),
#  ('Panama City',),
#  ('Papeete',),
#  ('Paramaribo',),
#  ('Port-au-Prince',),
#  ('Port Louis',),
#  ('Port Moresby',),
#  ('Port-of-Spain',),
#  ('Porto-Novo',),
#  ('Port-Vila',),
#  ('Praia',),
#  ('Pretoria',),
#  ('Rabat',),
#  ('Reykjavik',),
#  ('Riga',),
#  ('Road Town',),
#  ('Roseau',),
#  ("Saint George's",),
#  ("Saint John's",),
#  ('Saipan',),
#  ('San Jose',),
#  ('San Juan',),
#  ('San Marino',),
#  ('San Salvador',),
#  ('Santo Domingo',),
#  ('Sao Tome',),
#  ('Sarajevo',),
#  ('Skopje',),
#  ('Sofia',),
#  ('Stockholm',),
#  ('Suva',),
#  ('Tallinn',),
#  ('Tarawa',),
#  ('Tbilisi',),
#  ('Tegucigalpa',),
#  ('Thimphu',),
#  ('Tirane',),
#  ('Torshavn',),
#  ('Ulaanbaatar',),
#  ('Vaduz',),
#  ('Valletta',),
#  ('Victoria',),
#  ('Vientiane',),
#  ('Vilnius',),
#  ('Washington D.C.',),
#  ('Wellington',),
#  ('Windhoek',),
#  ('Yamoussoukro',),
#  ('Yaren District',),
#  ('Zagreb',),
#  (None,)]

# %%
# %%sql
# SELECT president,country,continent
# FROM presidents
# WHERE country IN
#     (SELECT name
#     FROM states
#     WHERE indep_year < 1800);
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 1 rows affected.
# [('Marcelo Rebelo de Sousa', 'Portugal', 'Europe')]

# %%
# %%sql
# SELECT president,country,continent
# FROM presidents
# WHERE continent LIKE '%America'
#     AND country NOT IN
#     (SELECT name
#     FROM states
#     WHERE indep_year < 1800);
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 3 rows affected.
# [('Jovenel Moise', 'Haiti', 'North America'),
#  ('Jose Mujica', 'Uruguay', 'South America'),
#  ('Michelle Bachelet', 'Chile', 'South America')]

# %%
# %%sql
# SELECT distinct name
# FROM languages
# WHERE code IN
#     (SELECT code
#     FROM countries
#     WHERE region = 'Middle East')
# ORDER BY name
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 27 rows affected.
# [('Arabic',),
#  ('Aramaic',),
#  ('Armenian',),
#  ('Azerbaijani',),
#  ('Azeri',),
#  ('Baluchi',),
#  ('Bulgarian',),
#  ('Circassian',),
#  ('English',),
#  ('Farsi',),
#  ('Filipino',),
#  ('French',),
#  ('Georgian',),
#  ('Greek',),
#  ('Hebrew',),
#  ('Hindi',),
#  ('Indian',),
#  ('Kurdish',),
#  ('Other',),
#  ('Persian',),
#  ('Romanian',),
#  ('Russian',),
#  ('Syriac',),
#  ('Turkish',),
#  ('Turkmen',),
#  ('unspecified',),
#  ('Urdu',)]

# %% [markdown]
# # Set theory challenge
# The task here is to incorporate two of UNION/UNION ALL/INTERSECT/EXCEPT to solve a challenge involving three tables.
# - Identify the country codes that are included in either `economies` or `currencies` but not in `populations`.
# - Use that result to determine the names of cities in the countries that match the specification in the previous instruction

# %%
# %%sql
# -- select the city name
# SELECT name
# -- alias the table where city name resides
# FROM cities AS c1
# -- choose only records matching the result of multiple set theory clauses
# WHERE c1.country_code IN
# (
#     -- select appropriate field from economies AS e
#     SELECT c2.code
#     FROM currencies AS c2
#     -- get all additional (unique) values of the field from currencies AS c2
#     UNION ALL
#     SELECT distinct c2.code
#     FROM currencies AS c2
#     -- exclude those appearing in populations AS p
#     EXCEPT
#     SELECT p.country_code
#     FROM populations AS p
# );
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 6 rows affected.
# [('Bucharest',),
#  ('Kaohsiung',),
#  ('New Taipei City',),
#  ('Taichung',),
#  ('Tainan',),
#  ('Taipei',)]

# %%
# %%sql
# -- Asian countires below average fert_rate
# SELECT name, fert_rate
# FROM states
# WHERE continent = 'Asia'
#    AND fert_rate <
#        (SELECT AVG(fert_rate)
#         FROM states);
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 2 rows affected.
# [('Brunei', 1.96), ('Vietnam', 1.7)]

# %% [markdown]
# # Subquery inside SELECT clause

# %%
# %%sql
# --Subquery inside SELECT clause - complete
# SELECT DISTINCT continent,
#     (SELECT COUNT(*)
#      FROM states
#      WHERE prime_ministers.continent = states.continent) AS countries_num
# FROM prime_ministers;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 5 rows affected.
# [('Africa', 2),
#  ('Asia', 4),
#  ('Europe', 3),
#  ('North America', 1),
#  ('Oceania', 1)]

# %%
# %%sql
# SELECT country_code,life_expectancy
# FROM populations
# WHERE life_expectancy >
#    (SELECT AVG(life_expectancy)
#    FROM populations
#    WHERE year=2015)
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 226 rows affected.
# [('ABW', 74.9535),
#  ('ABW', 75.5736),
#  ('ALB', 77.0369),
#  ('ALB', 78.0145),
#  ('ARE', 76.6752),
#  ('ARE', 77.5412),
#  ('ARG', 75.485),
#  ('ARG', 76.3342),
#  ('ARM', 74.2263),
#  ('ARM', 74.7971),
#  ('ATG', 75.3088),
#  ('ATG', 76.1002),
#  ('AUS', 81.6951),
#  ('AUS', 82.4512),
#  ('AUT', 80.5805),
#  ('AUT', 81.8439),
#  ('BEL', 80.1829),
#  ('BEL', 81.2878),
#  ('BGD', 72.0012),
#  ('BGR', 73.5122),
#  ('BGR', 74.4659),
#  ('BHR', 76.1276),
#  ('BHR', 76.8191),
#  ('BHS', 74.5924),
#  ('BHS', 75.3968),
#  ('BIH', 75.8077),
#  ('BIH', 76.5886),
#  ('BLR', 73.6244),
#  ('BMU', 79.2885),
#  ('BMU', 81.0122),
#  ('BRA', 73.2641),
#  ('BRA', 74.6759),
#  ('BRB', 74.8453),
#  ('BRB', 75.6584),
#  ('BRN', 77.5983),
#  ('BRN', 79.0408),
#  ('CAN', 81.1976),
#  ('CAN', 82.1376),
#  ('CHE', 82.2463),
#  ('CHE', 83.1976),
#  ('CHI', 80.0104),
#  ('CHI', 80.7517),
#  ('CHL', 80.2758),
#  ('CHL', 81.7876),
#  ('CHN', 75.0074),
#  ('CHN', 75.9863),
#  ('COL', 73.2779),
#  ('COL', 74.182),
#  ('CPV', 72.5979),
#  ('CPV', 73.3556),
#  ('CRI', 78.736),
#  ('CRI', 79.5865),
#  ('CUB', 78.9356),
#  ('CUB', 79.5464),
#  ('CYP', 79.382),
#  ('CYP', 80.3071),
#  ('CZE', 77.4244),
#  ('CZE', 79.4732),
#  ('DEU', 79.9878),
#  ('DEU', 81.0902),
#  ('DNK', 79.1),
#  ('DNK', 81.1),
#  ('DOM', 72.7498),
#  ('DOM', 73.6767),
#  ('DZA', 73.804),
#  ('DZA', 75.0425),
#  ('ECU', 75.0298),
#  ('ECU', 76.1029),
#  ('ESP', 81.6268),
#  ('ESP', 83.3805),
#  ('EST', 75.4293),
#  ('EST', 77.1317),
#  ('FIN', 79.8707),
#  ('FIN', 81.3854),
#  ('FRA', 81.6634),
#  ('FRA', 82.6707),
#  ('FRO', 80.639),
#  ('FRO', 81.6341),
#  ('GBR', 80.4024),
#  ('GBR', 81.6049),
#  ('GEO', 74.0024),
#  ('GEO', 74.8174),
#  ('GRC', 80.3878),
#  ('GRC', 81.5878),
#  ('GRD', 72.5675),
#  ('GRD', 73.523),
#  ('GTM', 71.9565),
#  ('GUM', 78.1009),
#  ('GUM', 79.379),
#  ('HKG', 82.9781),
#  ('HKG', 84.278),
#  ('HND', 72.394),
#  ('HND', 73.3331),
#  ('HRV', 76.4756),
#  ('HRV', 77.2756),
#  ('HUN', 74.2073),
#  ('HUN', 75.961),
#  ('IRL', 80.7439),
#  ('IRL', 81.5024),
#  ('IRN', 73.9832),
#  ('IRN', 75.5913),
#  ('ISL', 81.8976),
#  ('ISL', 82.861),
#  ('ISR', 81.6024),
#  ('ISR', 82.0512),
#  ('ITA', 82.0366),
#  ('ITA', 83.4902),
#  ('JAM', 74.8475),
#  ('JAM', 75.7982),
#  ('JOR', 73.4358),
#  ('JOR', 74.2033),
#  ('JPN', 82.8427),
#  ('JPN', 83.8437),
#  ('KAZ', 72.0),
#  ('KOR', 80.5512),
#  ('KOR', 82.1559),
#  ('KWT', 74.1166),
#  ('KWT', 74.6979),
#  ('LBN', 78.4654),
#  ('LBN', 79.6286),
#  ('LBY', 71.7374),
#  ('LBY', 71.8263),
#  ('LCA', 74.4711),
#  ('LCA', 75.1845),
#  ('LIE', 81.8415),
#  ('LIE', 82.0732),
#  ('LKA', 74.3392),
#  ('LKA', 74.9532),
#  ('LTU', 73.2683),
#  ('LTU', 75.1195),
#  ('LUX', 80.6317),
#  ('LUX', 82.2293),
#  ('LVA', 73.4829),
#  ('LVA', 74.1244),
#  ('MAC', 79.6904),
#  ('MAC', 80.7661),
#  ('MAF', 78.722),
#  ('MAF', 79.4707),
#  ('MAR', 72.5769),
#  ('MAR', 74.2893),
#  ('MDV', 76.2005),
#  ('MDV', 76.979),
#  ('MEX', 76.0268),
#  ('MEX', 76.9207),
#  ('MKD', 74.7226),
#  ('MKD', 75.4953),
#  ('MLT', 81.3976),
#  ('MLT', 81.9463),
#  ('MNE', 75.0453),
#  ('MNE', 76.3377),
#  ('MUS', 72.9673),
#  ('MUS', 74.3532),
#  ('MYS', 74.1578),
#  ('MYS', 74.8752),
#  ('NCL', 77.4732),
#  ('NCL', 77.7732),
#  ('NIC', 73.5817),
#  ('NIC', 75.0981),
#  ('NLD', 80.7024),
#  ('NLD', 81.7073),
#  ('NOR', 80.9976),
#  ('NOR', 82.1),
#  ('NZL', 80.7024),
#  ('NZL', 81.4568),
#  ('OMN', 76.0528),
#  ('OMN', 77.3242),
#  ('PAN', 76.8636),
#  ('PAN', 77.7673),
#  ('PER', 73.6398),
#  ('PER', 74.7807),
#  ('POL', 76.2463),
#  ('POL', 78.2049),
#  ('PRI', 78.4116),
#  ('PRI', 79.5723),
#  ('PRT', 79.0268),
#  ('PRT', 81.5219),
#  ('PRY', 72.3013),
#  ('PRY', 73.0256),
#  ('PSE', 72.2149),
#  ('PSE', 73.0742),
#  ('PYF', 75.6954),
#  ('PYF', 76.7524),
#  ('QAT', 77.8255),
#  ('QAT', 78.7626),
#  ('ROU', 73.4585),
#  ('ROU', 74.961),
#  ('SAU', 73.7016),
#  ('SAU', 74.4933),
#  ('SGP', 81.5415),
#  ('SGP', 82.5951),
#  ('SLV', 73.0011),
#  ('SMR', 83.1594),
#  ('SRB', 74.3366),
#  ('SRB', 75.4878),
#  ('SVK', 75.1122),
#  ('SVK', 77.2122),
#  ('SVN', 79.422),
#  ('SVN', 81.078),
#  ('SWE', 81.4512),
#  ('SWE', 82.5512),
#  ('SYC', 73.1976),
#  ('SYC', 73.2293),
#  ('SYR', 72.3074),
#  ('THA', 73.6944),
#  ('THA', 74.6012),
#  ('TON', 72.1826),
#  ('TON', 72.944),
#  ('TUN', 74.6117),
#  ('TUN', 74.976),
#  ('TUR', 74.0909),
#  ('TUR', 75.4262),
#  ('URY', 76.3946),
#  ('URY', 77.1382),
#  ('USA', 78.5415),
#  ('USA', 78.7415),
#  ('VCT', 72.3464),
#  ('VCT', 73.0524),
#  ('VEN', 73.6716),
#  ('VEN', 74.4096),
#  ('VIR', 79.1732),
#  ('VIR', 79.8732),
#  ('VNM', 74.9904),
#  ('VNM', 75.7777),
#  ('VUT', 72.1574),
#  ('WSM', 72.417),
#  ('WSM', 73.7649)]

# %% [markdown]
# # Subquery inside where
# Select all fields from populations with records corresponding to larger than 1.15 times the average life_expectancy in 2015

# %%
# %%sql
# SELECT *
# FROM populations
# WHERE life_expectancy > 1.15 *
# (SELECT AVG(life_expectancy) FROM populations
#    WHERE year=2015)
#    AND year = 2015
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 10 rows affected.
# [(21, 'AUS', 2015, 1.833, 82.4512, 23789800.0),
#  (376, 'CHE', 2015, 1.54, 83.1976, 8281430.0),
#  (356, 'ESP', 2015, 1.32, 83.3805, 46444000.0),
#  (134, 'FRA', 2015, 2.01, 82.6707, 66538400.0),
#  (170, 'HKG', 2015, 1.195, 84.278, 7305700.0),
#  (174, 'ISL', 2015, 1.93, 82.861, 330815.0),
#  (190, 'ITA', 2015, 1.37, 83.4902, 60730600.0),
#  (194, 'JPN', 2015, 1.46, 83.8437, 126958000.0),
#  (340, 'SGP', 2015, 1.24, 82.5951, 5535000.0),
#  (374, 'SWE', 2015, 1.88, 82.5512, 9799190.0)]

# %% [markdown]
# # Subquery inside where (2)
# get the urban area population for only capital cities
# - Make use of the `capital` field in the `countries` table in your subquery.
# - Select the city name, country code, and urban area population fields.

# %%
# %%sql
# -- select the appropriate fields
# SELECT  name, country_code, urbanarea_pop
# -- from the cities table
# FROM cities
# -- with city name in the field of capital cities
# WHERE name IN
#   (SELECT capital
#    FROM countries)
# ORDER BY urbanarea_pop DESC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 66 rows affected.
# [('Beijing', 'CHN', 21516000.0),
#  ('Dhaka', 'BGD', 14543100.0),
#  ('Tokyo', 'JPN', 13513700.0),
#  ('Moscow', 'RUS', 12197600.0),
#  ('Cairo', 'EGY', 10230400.0),
#  ('Kinshasa', 'COD', 10130000.0),
#  ('Jakarta', 'IDN', 10075300.0),
#  ('Seoul', 'KOR', 9995780.0),
#  ('Mexico City', 'MEX', 8974720.0),
#  ('Lima', 'PER', 8852000.0),
#  ('London', 'GBR', 8673710.0),
#  ('Bangkok', 'THA', 8280920.0),
#  ('Tehran', 'IRN', 8154050.0),
#  ('Bogota', 'COL', 7878780.0),
#  ('Baghdad', 'IRQ', 7180890.0),
#  ('Hanoi', 'VNM', 6844100.0),
#  ('Santiago', 'CHL', 5743720.0),
#  ('Riyadh', 'SAU', 5676620.0),
#  ('Singapore', 'SGP', 5535000.0),
#  ('Ankara', 'TUR', 5271000.0),
#  ('Khartoum', 'SDN', 3639600.0),
#  ('Berlin', 'DEU', 3517420.0),
#  ('Algiers', 'DZA', 3415810.0),
#  ('Kabul', 'AFG', 3414100.0),
#  ('Pyongyang', 'PRK', 3255390.0),
#  ('Madrid', 'ESP', 3207250.0),
#  ('Baku', 'AZE', 3202300.0),
#  ('Nairobi', 'KEN', 3138370.0),
#  ('Addis Ababa', 'ETH', 3103670.0),
#  ('Buenos Aires', 'ARG', 3054300.0),
#  ('Kiev', 'UKR', 2908700.0),
#  ('Rome', 'ITA', 2877220.0),
#  ('Luanda', 'AGO', 2825310.0),
#  ('Quito', 'ECU', 2671190.0),
#  ('Managua', 'NIC', 2560790.0),
#  ('Brasilia', 'BRA', 2556150.0),
#  ('Yaounde', 'CMR', 2440460.0),
#  ('Tashkent', 'UZB', 2309600.0),
#  ('Phnom Penh', 'KHM', 2234570.0),
#  ('Paris', 'FRA', 2229620.0),
#  ('Ouagadougou', 'BFA', 2200000.0),
#  ('Guatemala City', 'GTM', 2110100.0),
#  ('Havana', 'CUB', 2106150.0),
#  ('Accra', 'GHA', 2070460.0),
#  ('Minsk', 'BLR', 1959780.0),
#  ('Caracas', 'VEN', 1943900.0),
#  ("Sana'a", 'YEM', 1937450.0),
#  ('Islamabad', 'PAK', 1900000.0),
#  ('Vienna', 'AUT', 1863880.0),
#  ('Brazzaville', 'COG', 1827000.0),
#  ('Manila', 'PHL', 1780150.0),
#  ('Kuala Lumpur', 'MYS', 1768000.0),
#  ('Maputo', 'MOZ', 1766180.0),
#  ('Budapest', 'HUN', 1759410.0),
#  ('Warsaw', 'POL', 1753980.0),
#  ('Lusaka', 'ZMB', 1742980.0),
#  ('Harare', 'ZWE', 1606000.0),
#  ('Kampala', 'UGA', 1507080.0),
#  ('Prague', 'CZE', 1324000.0),
#  ('Montevideo', 'URY', 1305080.0),
#  ('Abuja', 'NGA', 1235880.0),
#  ('Dakar', 'SEN', 1146050.0),
#  ('Abu Dhabi', 'ARE', 1145000.0),
#  ('Tripoli', 'LBY', 1126000.0),
#  ('Yerevan', 'ARM', 1060140.0),
#  ('Tunis', 'TUN', 1056250.0)]

# %% [markdown]
# How to use `GROUP BY` with aggregate functions and an inner join to get summarized information from multiple tables

# %%
# %%sql
# SELECT countries.name AS country, COUNT(*) AS cities_num
# FROM cities
# INNER JOIN countries
# ON countries.code = cities.country_code
# GROUP BY country
# ORDER BY cities_num DESC, country
# LIMIT 9;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 9 rows affected.
# [('China', 36),
#  ('India', 18),
#  ('Japan', 11),
#  ('Brazil', 10),
#  ('Pakistan', 9),
#  ('United States', 9),
#  ('Indonesia', 7),
#  ('Russian Federation', 7),
#  ('South Korea', 7)]

# %%
# %%sql
# -- using sub qurry to get the same result as above
# SELECT countries.name  AS country,
#   (SELECT count(*)
#    FROM cities
#    WHERE countries.code = cities.country_code) AS cities_num
# FROM countries
# ORDER BY cities_num DESC, country
# LIMIT 9;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 9 rows affected.
# [('China', 36),
#  ('India', 18),
#  ('Japan', 11),
#  ('Brazil', 10),
#  ('Pakistan', 9),
#  ('United States', 9),
#  ('Indonesia', 7),
#  ('Russian Federation', 7),
#  ('South Korea', 7)]

# %% [markdown]
# ## Subquery inside FROM clause
# Subquery can be used as a temp table in from clause
#
# You will use this to determine the number of languages spoken for each country, identified by the country's local name! (Note this may be different than the name field and is stored in the local_name field.)
# - Begin by determining for each country code how many languages are listed in the languages table using `SELECT`, `FROM`, and `GROUP BY`.

# %%
# %%sql
# SELECT code, COUNT(*) AS lang_num
# FROM languages
# GROUP BY code;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 212 rows affected.
# [('PRY', 2),
#  ('NRU', 3),
#  ('MDG', 3),
#  ('ASM', 5),
#  ('TZA', 4),
#  ('PLW', 6),
#  ('NLD', 1),
#  ('VEN', 2),
#  ('BMU', 2),
#  ('MSR', 1),
#  ('COG', 3),
#  ('CUB', 1),
#  ('HUN', 7),
#  ('AUT', 5),
#  ('IRL', 2),
#  ('GIB', 4),
#  ('GBR', 1),
#  ('ISR', 3),
#  ('CAF', 3),
#  ('GMB', 5),
#  ('EST', 5),
#  ('MMR', 1),
#  ('SOM', 4),
#  ('HKG', 5),
#  ('KNA', 1),
#  ('URY', 3),
#  ('BEL', 3),
#  ('MRT', 5),
#  ('BTN', 4),
#  ('FSM', 9),
#  ('VNM', 3),
#  ('ERI', 7),
#  ('MHL', 2),
#  ('LBN', 4),
#  ('CCK', 2),
#  ('SVN', 5),
#  ('LTU', 5),
#  ('VUT', 5),
#  ('CIV', 2),
#  ('PHL', 3),
#  ('MLT', 4),
#  ('GUM', 6),
#  ('TCA', 1),
#  ('DJI', 4),
#  ('SEN', 7),
#  ('CXR', 3),
#  ('ESP', 5),
#  ('TUN', 3),
#  ('GHA', 11),
#  ('SGP', 10),
#  ('JAM', 2),
#  ('BLR', 4),
#  ('BRB', 2),
#  ('SUR', 5),
#  ('OMN', 5),
#  ('TWN', 3),
#  ('HRV', 4),
#  ('GRC', 2),
#  ('LBR', 2),
#  ('MYS', 8),
#  ('GNB', 4),
#  ('TJK', 2),
#  ('HTI', 2),
#  ('NIC', 4),
#  ('LAO', 4),
#  ('BHR', 4),
#  ('NGA', 6),
#  ('DOM', 1),
#  ('MUS', 5),
#  ('LIE', 3),
#  ('LBY', 4),
#  ('ATG', 2),
#  ('TON', 4),
#  ('ABW', 7),
#  ('CRI', 2),
#  ('PRT', 2),
#  ('ZWE', 16),
#  ('TKM', 4),
#  ('MDV', 2),
#  ('SLB', 3),
#  ('AZE', 4),
#  ('FRO', 3),
#  ('NOR', 3),
#  ('ZMB', 19),
#  ('ROM', 5),
#  ('MDA', 7),
#  ('DNK', 4),
#  ('BLZ', 9),
#  ('AGO', 12),
#  ('AND', 4),
#  ('DMA', 2),
#  ('BOL', 7),
#  ('MWI', 12),
#  ('IRQ', 5),
#  ('WSM', 2),
#  ('LSO', 4),
#  ('KHM', 2),
#  ('NPL', 14),
#  ('IND', 14),
#  ('EGY', 2),
#  ('SWZ', 2),
#  ('CMR', 3),
#  ('GUY', 5),
#  ('GRL', 3),
#  ('CHL', 5),
#  ('BGR', 5),
#  ('GTM', 2),
#  ('GEO', 5),
#  ('ARG', 6),
#  ('USA', 3),
#  ('LUX', 5),
#  ('ARM', 3),
#  ('RUS', 4),
#  ('NAM', 9),
#  ('VCT', 2),
#  ('LVA', 4),
#  ('BGD', 2),
#  ('BIH', 5),
#  ('COD', 5),
#  ('TUV', 4),
#  ('KAZ', 2),
#  ('FIN', 4),
#  ('BHS', 2),
#  ('IRN', 8),
#  ('SYC', 5),
#  ('PNG', 4),
#  ('GRD', 2),
#  ('PAK', 11),
#  ('BFA', 2),
#  ('ALB', 4),
#  ('PAN', 11),
#  ('AIA', 1),
#  ('KGZ', 4),
#  ('BRN', 3),
#  ('COK', 3),
#  ('STP', 8),
#  ('NIU', 5),
#  ('NZL', 9),
#  ('UKR', 3),
#  ('DZA', 6),
#  ('THA', 3),
#  ('BDI', 6),
#  ('JOR', 2),
#  ('NFK', 2),
#  ('KWT', 2),
#  ('COL', 1),
#  ('GIN', 1),
#  ('MLI', 13),
#  ('POL', 4),
#  ('TUR', 3),
#  ('SWE', 1),
#  ('SVK', 5),
#  ('PRK', 1),
#  ('DEU', 1),
#  ('MOZ', 8),
#  ('IDN', 4),
#  ('CYP', 10),
#  ('ARE', 5),
#  ('SLE', 4),
#  ('SLV', 2),
#  ('AUS', 9),
#  ('GAB', 6),
#  ('PYF', 3),
#  ('FRA', 13),
#  ('CHN', 9),
#  ('UGA', 6),
#  ('MAR', 7),
#  ('ZAF', 13),
#  ('ESH', 3),
#  ('TTO', 5),
#  ('SYR', 7),
#  ('LKA', 3),
#  ('CAN', 10),
#  ('TKL', 8),
#  ('BRA', 1),
#  ('BWA', 9),
#  ('MKD', 6),
#  ('WLF', 4),
#  ('AFG', 4),
#  ('SDN', 5),
#  ('GNQ', 4),
#  ('RWA', 6),
#  ('CHE', 10),
#  ('ISL', 4),
#  ('KOR', 2),
#  ('ECU', 4),
#  ('PER', 6),
#  ('NCL', 2),
#  ('MCO', 4),
#  ('PRI', 2),
#  ('KIR', 2),
#  ('TGO', 5),
#  ('YEM', 1),
#  ('MNP', 7),
#  ('ITA', 4),
#  ('CYM', 5),
#  ('BEN', 3),
#  ('HND', 2),
#  ('SAU', 1),
#  ('LCA', 2),
#  ('NER', 3),
#  ('KEN', 3),
#  ('JPN', 1),
#  ('SPM', 1),
#  ('COM', 3),
#  ('MNG', 3),
#  ('SMR', 1),
#  ('MEX', 3),
#  ('QAT', 2),
#  ('UZB', 4),
#  ('TCD', 4),
#  ('ETH', 16)]

# %% [markdown]
# - Include the previous query (aliased as subquery) as a subquery in the `FROM` clause of a new query.
# - Select the local name of the country from countries.
# - Also, select `lang_num` from `subquery`.
# - Make sure to use `WHERE` appropriately to match `code` in `countries` and in `subquery`.
# - Sort by `lang_num` in descending order.

# %%
# %%sql
# SELECT name,local_name,lang_num
# FROM countries,
#     (SELECT code,COUNT(*) AS lang_num
#      FROM languages
#      GROUP BY code) AS subquery
# WHERE countries.code = subquery.code
# ORDER BY lang_num DESC;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 199 rows affected.
# [('Zambia', 'Zambia', 19),
#  ('Ethiopia', 'YeItyop´iya', 16),
#  ('Zimbabwe', 'Zimbabwe', 16),
#  ('India', 'Bharat/India', 14),
#  ('Nepal', 'Nepal', 14),
#  ('Mali', 'Mali', 13),
#  ('France', 'France', 13),
#  ('South Africa', 'South Africa', 13),
#  ('Malawi', 'Malawi', 12),
#  ('Angola', 'Angola', 12),
#  ('Pakistan', 'Pakistan', 11),
#  ('Panama', 'Panama', 11),
#  ('Ghana', 'Ghana', 11),
#  ('Singapore', 'Singapore/Singapura/Xinjiapo/Singapur', 10),
#  ('Cyprus', 'Kypros/Kibris', 10),
#  ('Canada', 'Canada', 10),
#  ('Switzerland', 'Schweiz/Suisse/Svizzera/Svizra', 10),
#  ('Belize', 'Belize', 9),
#  ('Australia', 'Australia', 9),
#  ('China', 'Zhongquo', 9),
#  ('Micronesia, Federated States of', 'Micronesia', 9),
#  ('Namibia', 'Namibia', 9),
#  ('Botswana', 'Botswana', 9),
#  ('New Zealand', 'New Zealand/Aotearoa', 9),
#  ('Mozambique', 'Mocambique', 8),
#  ('Sao Tome and Principe', 'Sao Tome e Principe', 8),
#  ('Iran', 'Iran', 8),
#  ('Malaysia', 'Malaysia', 8),
#  ('Syria', 'Suriya', 7),
#  ('Aruba', 'Aruba', 7),
#  ('Bolivia', 'Bolivia', 7),
#  ('Moldova', 'Moldova', 7),
#  ('Hungary', 'Magyarorszag', 7),
#  ('Morocco', 'Al-Maghrib', 7),
#  ('Northern Mariana Islands', 'Northern Mariana Islands', 7),
#  ('Senegal', 'Senegal/Sounougal', 7),
#  ('Eritrea', 'Ertra', 7),
#  ('Nigeria', 'Nigeria', 6),
#  ('Uganda', 'Uganda', 6),
#  ('Macedonia', 'Makedonija', 6),
#  ('Palau', 'Belau/Palau', 6),
#  ('Gabon', 'Le Gabon', 6),
#  ('Peru', 'Peru/Piruw', 6),
#  ('Algeria', 'Al-Jaza\x92ir/Algerie', 6),
#  ('Argentina', 'Argentina', 6),
#  ('Guam', 'Guam', 6),
#  ('Rwanda', 'Rwanda/Urwanda', 6),
#  ('Burundi', 'Burundi/Uburundi', 6),
#  ('Suriname', 'Suriname', 5),
#  ('Vanuatu', 'Vanuatu', 5),
#  ('Oman', '´Uman', 5),
#  ('Bosnia and Herzegovina', 'Bosna i Hercegovina', 5),
#  ('American Samoa', 'Amerika Samoa', 5),
#  ('Bulgaria', 'Balgarija', 5),
#  ('Cayman Islands', 'Cayman Islands', 5),
#  ('Chile', 'Chile', 5),
#  ('Trinidad and Tobago', 'Trinidad and Tobago', 5),
#  ('Spain', 'Espana', 5),
#  ('Gambia', 'The Gambia', 5),
#  ('Georgia', 'Sakartvelo', 5),
#  ('Togo', 'Togo', 5),
#  ('Estonia', 'Eesti', 5),
#  ('Guyana', 'Guyana', 5),
#  ('Hong Kong', 'Xianggang/Hong Kong', 5),
#  ('Iraq', 'Al-´Iraq', 5),
#  ('United Arab Emirates', 'Al-Imarat al-´Arabiya al-Muttahida', 5),
#  ('Austria', 'Osterreich', 5),
#  ('Mauritius', 'Mauritius', 5),
#  ('Sudan', 'As-Sudan', 5),
#  ('Slovenia', 'Slovenija', 5),
#  ('Slovakia', 'Slovensko', 5),
#  ('Congo, The Democratic Republic of the', 'Republique Democratique du Congo', 5),
#  ('Seychelles', 'Sesel/Seychelles', 5),
#  ('Lithuania', 'Lietuva', 5),
#  ('Luxembourg', 'Luxembourg/Letzebuerg', 5),
#  ('Mauritania', 'Muritaniya/Mauritanie', 5),
#  ('Guinea-Bissau', 'Guine-Bissau', 4),
#  ('Denmark', 'Danmark', 4),
#  ('Albania', 'Shqiperia', 4),
#  ('Afghanistan', 'Afganistan/Afqanestan', 4),
#  ('Gibraltar', 'Gibraltar', 4),
#  ('Andorra', 'Andorra', 4),
#  ('Kyrgyzstan', 'Kyrgyzstan', 4),
#  ('Tonga', 'Tonga', 4),
#  ('Sierra Leone', 'Sierra Leone', 4),
#  ('Ecuador', 'Ecuador', 4),
#  ('Azerbaijan', 'Azarbaycan', 4),
#  ('Belarus', 'Belarus', 4),
#  ('Malta', 'Malta', 4),
#  ('Chad', 'Tchad/Tshad', 4),
#  ('Turkmenistan', 'Turkmenostan', 4),
#  ('Croatia', 'Hrvatska', 4),
#  ('Djibouti', 'Djibouti/Jibuti', 4),
#  ('Tuvalu', 'Tuvalu', 4),
#  ('Bhutan', 'Druk-Yul', 4),
#  ('Laos', 'Lao', 4),
#  ('Latvia', 'Latvija', 4),
#  ('Lesotho', 'Lesotho', 4),
#  ('Lebanon', 'Lubnan', 4),
#  ('Uzbekistan', 'Uzbekiston', 4),
#  ('Libya', 'Libiya', 4),
#  ('Russian Federation', 'Rossija', 4),
#  ('Monaco', 'Monaco', 4),
#  ('Indonesia', 'Indonesia', 4),
#  ('Tanzania', 'Tanzania', 4),
#  ('Iceland', 'Island', 4),
#  ('Poland', 'Polska', 4),
#  ('Italy', 'Italia', 4),
#  ('Bahrain', 'Al-Bahrayn', 4),
#  ('Papua New Guinea', 'Papua New Guinea/Papua Niugini', 4),
#  ('Finland', 'Suomi', 4),
#  ('Nicaragua', 'Nicaragua', 4),
#  ('Somalia', 'Soomaaliya', 4),
#  ('Equatorial Guinea', 'Guinea Ecuatorial', 4),
#  ('Thailand', 'Prathet Thai', 3),
#  ('Armenia', 'Hajastan', 3),
#  ('Belgium', 'Belgie/Belgique', 3),
#  ('Benin', 'Benin', 3),
#  ('Brunei', 'Brunei Darussalam', 3),
#  ('Philippines', 'Pilipinas', 3),
#  ('Faroe Islands', 'Foroyar', 3),
#  ('Greenland', 'Kalaallit Nunaat/Gronland', 3),
#  ('Israel', 'Yisra\x92el/Isra\x92il', 3),
#  ('Cameroon', 'Cameroun/Cameroon', 3),
#  ('Kenya', 'Kenya', 3),
#  ('Central African Republic', 'Centrafrique/Be-Afrika', 3),
#  ('Comoros', 'Komori/Comores', 3),
#  ('Congo', 'Congo', 3),
#  ('Liechtenstein', 'Liechtenstein', 3),
#  ('Madagascar', 'Madagasikara/Madagascar', 3),
#  ('Mexico', 'Mexico', 3),
#  ('Mongolia', 'Mongol Uls', 3),
#  ('Nauru', 'Naoero/Nauru', 3),
#  ('Niger', 'Niger', 3),
#  ('Norway', 'Norge', 3),
#  ('French Polynesia', 'Polynesie francaise', 3),
#  ('Solomon Islands', 'Solomon Islands', 3),
#  ('Sri Lanka', 'Sri Lanka/Ilankai', 3),
#  ('Tunisia', 'Tunis/Tunisie', 3),
#  ('Turkey', 'Turkiye', 3),
#  ('Ukraine', 'Ukrajina', 3),
#  ('Uruguay', 'Uruguay', 3),
#  ('Vietnam', 'Viet Nam', 3),
#  ('United States', 'United States', 3),
#  ('South Korea', 'Taehan Min\x92guk (Namhan)', 2),
#  ('Costa Rica', 'Costa Rica', 2),
#  ('Burkina Faso', 'Burkina Faso', 2),
#  ('Barbados', 'Barbados', 2),
#  ('Saint Lucia', 'Saint Lucia', 2),
#  ('Antigua and Barbuda', 'Antigua and Barbuda', 2),
#  ('New Caledonia', 'Nouvelle-Caledonie', 2),
#  ('Kiribati', 'Kiribati', 2),
#  ('Paraguay', 'Paraguay', 2),
#  ("Cote d'Ivoire", 'Cote d\x92Ivoire', 2),
#  ('Bermuda', 'Bermuda', 2),
#  ('Portugal', 'Portugal', 2),
#  ('Puerto Rico', 'Puerto Rico', 2),
#  ('Marshall Islands', 'Marshall Islands/Majol', 2),
#  ('Maldives', 'Dhivehi Raajje/Maldives', 2),
#  ('Qatar', 'Qatar', 2),
#  ('Liberia', 'Liberia', 2),
#  ('Kazakhstan', 'Qazaqstan', 2),
#  ('Cambodia', 'Kampuchea', 2),
#  ('Jordan', 'Al-Urdunn', 2),
#  ('Bangladesh', 'Bangladesh', 2),
#  ('Samoa', 'Samoa', 2),
#  ('Saint Vincent and the Grenadines', 'Saint Vincent and the Grenadines', 2),
#  ('Jamaica', 'Jamaica', 2),
#  ('Swaziland', 'kaNgwane', 2),
#  ('Ireland', 'Ireland/Eire', 2),
#  ('Honduras', 'Honduras', 2),
#  ('Tajikistan', 'Tocikiston', 2),
#  ('Haiti', 'Haiti/Dayti', 2),
#  ('Greece', 'Ellada', 2),
#  ('Guatemala', 'Guatemala', 2),
#  ('Grenada', 'Grenada', 2),
#  ('El Salvador', 'El Salvador', 2),
#  ('Egypt', 'Misr', 2),
#  ('Kuwait', 'Al-Kuwayt', 2),
#  ('Venezuela', 'Venezuela', 2),
#  ('Bahamas', 'The Bahamas', 2),
#  ('Dominica', 'Dominica', 2),
#  ('Myanmar', 'Myanma Pye', 1),
#  ('Sweden', 'Sverige', 1),
#  ('Saint Kitts and Nevis', 'Saint Kitts and Nevis', 1),
#  ('Germany', 'Deutschland', 1),
#  ('Cuba', 'Cuba', 1),
#  ('San Marino', 'San Marino', 1),
#  ('Saudi Arabia', 'Al-´Arabiya as-Sa´udiya', 1),
#  ('North Korea', 'Choson Minjujuui In´min Konghwaguk (Bukhan)', 1),
#  ('Colombia', 'Colombia', 1),
#  ('Yemen', 'Al-Yaman', 1),
#  ('Japan', 'Nihon/Nippon', 1),
#  ('Guinea', 'Guinee', 1),
#  ('Dominican Republic', 'Republica Dominicana', 1),
#  ('Turks and Caicos Islands', 'The Turks and Caicos Islands', 1),
#  ('Netherlands', 'Nederland', 1),
#  ('United Kingdom', 'United Kingdom', 1),
#  ('Brazil', 'Brasil', 1)]

# %%
# %%sql
# SELECT DISTINCT monarchs.continent, subquery.max_perc
# FROM monarchs,
#     (SELECT continent, MAX(women_parli_perc) AS max_perc
#      FROM states
#      GROUP BY continent) AS subquery
# WHERE monarchs.continent = subquery.continent
# ORDER BY continent;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 2 rows affected.
# [('Asia', 24.0), ('Europe', 39.6)]

# %% [markdown]
# # Advanced subquery
# You can also nest multiple subqueries to answer even more specific questions.
#
# In this exercise, for each of the six continents listed in 2015, you'll identify which country had the maximum inflation rate (and how high it was) using multiple subqueries

# %%
# %%sql
# SELECT name, continent, inflation_rate
# FROM countries
# INNER JOIN economies
# ON countries.code = economies.code
# WHERE year = 2015
#     AND inflation_rate IN (
#         SELECT MAX(inflation_rate) AS max_inf
#         FROM (
#              SELECT name, continent, inflation_rate
#              FROM countries
#              INNER JOIN economies
#              ON countries.code = economies.code
#              WHERE year = 2015) AS subquery
#         GROUP BY continent);
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 6 rows affected.
# [('Haiti', 'North America', 7.524),
#  ('Malawi', 'Africa', 21.858),
#  ('Nauru', 'Oceania', 9.784),
#  ('Ukraine', 'Europe', 48.684),
#  ('Venezuela', 'South America', 121.738),
#  ('Yemen', 'Asia', 39.403)]

# %% [markdown]
# # Subquery challenge
# Use a subquery to get 2015 economic data for countries that do not have
#
# - gov_form of "Constitutional Monarchy" or
# - 'Republic' in their `gov_form`.
# - Select the country code, inflation rate, and unemployment rate.
# - Order by inflation rate ascending.

# %%
# %%sql
# SELECT code, inflation_rate, unemployment_rate
# FROM economies
# WHERE year = 2015 AND code NOT IN
#   (SELECT code
#    FROM countries
#    WHERE (gov_form = 'Constitutional Monarchy' OR gov_form LIKE '%Republic%'))
# ORDER BY inflation_rate;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 26 rows affected.
# [('AFG', -1.549, None),
#  ('CHE', -1.14, 3.178),
#  ('PRI', -0.751, 12.0),
#  ('ROU', -0.596, 6.812),
#  ('BRN', -0.423, 6.9),
#  ('TON', -0.283, None),
#  ('OMN', 0.065, None),
#  ('TLS', 0.553, None),
#  ('BEL', 0.62, 8.492),
#  ('CAN', 1.132, 6.9),
#  ('MNE', 1.204, None),
#  ('SRB', 1.392, 18.2),
#  ('AUS', 1.461, 6.058),
#  ('QAT', 1.814, None),
#  ('BHR', 1.836, None),
#  ('WSM', 1.923, None),
#  ('MYS', 2.104, 3.1),
#  ('SAU', 2.189, 5.591),
#  ('HKG', 3.037, 3.296),
#  ('KWT', 3.233, 2.072),
#  ('ARE', 4.07, None),
#  ('MAC', 4.564, 1.825),
#  ('SWZ', 4.96, None),
#  ('BTN', 6.336, 3.2),
#  ('LBY', 9.839, None),
#  ('SSD', 52.813, None)]

# %% [markdown]
# # Final challenge
# Get the country names and other 2015 data in the `economies` table and the `countries` table for Central American countries with an official language
# - Select unique country names. Also select the total investment and imports fields.
# - Use a left join with `countries` on the left. (An inner join would also work, but please use a left join here.)
# - Match on `code` in the two tables `AND` use a subquery inside of `ON` to choose the appropriate `languages` records.
# - Order by country name ascending.

# %%
# %%sql
# SELECT DISTINCT name,total_investment,imports
# FROM countries AS c
# LEFT JOIN economies AS e
# ON (c.code = e.code
#    AND c.code IN
#        ( SELECT code
#        FROM languages AS l
#        WHERE official = 'true'))
# WHERE year = 2015 AND region = 'Central America'
# ORDER BY name
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 7 rows affected.
# [('Belize', 22.014, 6.743),
#  ('Costa Rica', 20.218, 4.629),
#  ('El Salvador', 13.983, 8.193),
#  ('Guatemala', 13.433, 15.124),
#  ('Honduras', 24.633, 9.353),
#  ('Nicaragua', 31.862, 11.665),
#  ('Panama', 46.557, 5.898)]

# %% [markdown]
# # Final challenge (2)
# Calculate the average fertility rate for each region in 2015.
# - Include the name of region, its continent, and average fertility rate aliased as `avg_fert_rate`.
# - Sort based on `avg_fert_rate` ascending.
# - Remember that you'll need to `GROUP BY` all fields that aren't included in the aggregate function of `SELECT`

# %%
# %%sql
# -- choose fields
# SELECT region,continent,AVG(fertility_rate) AS avg_fert_rate
# -- left table
# FROM countries
# -- right table
# LEFT JOIN populations
# -- join conditions
# ON countries.code = populations.country_code
# -- specific records matching a condition
# WHERE year = 2015
# -- aggregated for each what?
# GROUP BY region,continent
# -- how should we sort?
# ORDER BY avg_fert_rate;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 23 rows affected.
# [('Southern Europe', 'Europe', 1.42610000371933),
#  ('Eastern Europe', 'Europe', 1.49088890022702),
#  ('Baltic Countries', 'Europe', 1.60333331425985),
#  ('Eastern Asia', 'Asia', 1.62071430683136),
#  ('Western Europe', 'Europe', 1.6325000077486),
#  ('North America', 'North America', 1.76575002074242),
#  ('British Islands', 'Europe', 1.875),
#  ('Nordic Countries', 'Europe', 1.89333335558573),
#  ('Australia and New Zealand', 'Oceania', 1.91149997711182),
#  ('Caribbean', 'North America', 1.95057143483843),
#  ('Southeast Asia', 'Asia', 2.15600001811981),
#  ('South America', 'South America', 2.27475001414617),
#  ('Central America', 'North America', 2.32637499272823),
#  ('Middle East', 'Asia', 2.54705556895998),
#  ('Southern and Central Asia', 'Asia', 2.63414285864149),
#  ('Micronesia', 'Oceania', 2.86475002765656),
#  ('Northern Africa', 'Africa', 2.9081666469574),
#  ('Southern Africa', 'Africa', 2.99079999923706),
#  ('Melanesia', 'Oceania', 3.13579998016357),
#  ('Polynesia', 'Oceania', 3.24433326721191),
#  ('Eastern Africa', 'Africa', 4.38670586838442),
#  ('Western Africa', 'Africa', 4.96012498438358),
#  ('Central Africa', 'Africa', 4.96788883209229)]

# %% [markdown]
# Determine the top 10 capital cities in Europe and the Americas in terms of a calculated percentage using city_proper_pop and metroarea_pop in cities
# - Select the city name, country code, city proper population, and metro area population. Calculate the percentage of metro area population composed of city proper population for each city in cities, aliased as `city_perc`.
# - Focus only on capital cities in Europe and the Americas in a subquery.
# - Make sure to exclude records with missing data on metro area population.
# - Order the result by `city_perc` descending.
# - Then determine the top 10 capital cities in Europe and the Americas in terms of this `city_perc` percentage.

# %%
# %%sql
# SELECT name, country_code, city_proper_pop, metroarea_pop,
#       city_proper_pop / metroarea_pop * 100 AS city_perc
# FROM cities
# WHERE name IN
#   (SELECT capital
#    FROM countries
#    WHERE (continent = 'Europe'
#       OR continent LIKE '%America'))
#      AND metroarea_pop IS NOT NULL
# ORDER BY city_perc DESC
# LIMIT 10;
# Out:
#  * postgresql://dennis:***@localhost/dennis
# 10 rows affected.
# [('Lima', 'PER', 8852000.0, 10750000.0, 82.3441863059998),
#  ('Bogota', 'COL', 7878780.0, 9800000.0, 80.3957462310791),
#  ('Moscow', 'RUS', 12197600.0, 16170000.0, 75.4334926605225),
#  ('Vienna', 'AUT', 1863880.0, 2600000.0, 71.6877281665802),
#  ('Montevideo', 'URY', 1305080.0, 1947600.0, 67.0096158981323),
#  ('Caracas', 'VEN', 1943900.0, 2923960.0, 66.4818167686462),
#  ('Rome', 'ITA', 2877220.0, 4353780.0, 66.0855233669281),
#  ('Brasilia', 'BRA', 2556150.0, 3919860.0, 65.2101457118988),
#  ('London', 'GBR', 8673710.0, 13879800.0, 62.4918222427368),
#  ('Budapest', 'HUN', 1759410.0, 2927940.0, 60.090184211731)]
